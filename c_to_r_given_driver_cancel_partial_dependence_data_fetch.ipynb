# %%
# fetch data containing model predictions and features on test data

# %%
# Install packages (one-time)

# %%
# %%bash
# source $VIRTUAL_ENV_DIR/python3/bin/activate
#
# install_package_python3.sh add dsw_qr==0.1.13
#
# $VIRTUAL_ENV_DIR/python3/bin/python -m pip install galileo
# $VIRTUAL_ENV_DIR/python3/bin/python -m pip install galileo-py
# $VIRTUAL_ENV_DIR/python3/bin/python -m pip install tchannel
# Out:
# Updating dependencies
# Resolving dependencies...
#
#
# Package operations: 1 install, 2 updates, 0 removals
#
#   - Updating tornado (4.5.3 -> 5.1.1)
#   - Updating cachetools (3.1.1 -> 4.1.1)
#   - Installing wheel (0.35.1)
# Looking in indexes: https://yoober11:****@pypi.uberinternal.com/index
# ...
# Looking in indexes: https://yoober11:****@pypi.uberinternal.com/index
# ...
#   Using cached tornado-4.5.3-cp36-cp36m-linux_x86_64.whl
# ...
#   Using cached https://pypi.uberinternal.com/packages/packages/2f/a6/30b0a0bef12283e83e58c1d6e7b5aabc7acfc4110df81a4471655d33e704/cachetools-3.1.1-py2.py3-none-any.whl (11 kB)
# ...
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.1.1
#     Uninstalling cachetools-4.1.1:
#       Successfully uninstalled cachetools-4.1.1
# ...

# %%
# fetch data

# %%
import os

import pandas as pd
from dsw_qr import dsw_qr
# Out:
# 2022-08-18 16:41:28,857 jaeger_tracing WARNING Jaeger tracer already initialized, skipping

# %%
USER_EMAIL = 'targupt@uber.com'

# %%
def prepare_query(region, sample_percentage):
    QUERY = """select
      derived_accepted_app_rating_avg_4week,
      derived_accepted_surge_multiplier_var_1week,
      derived_supply_surge,
      derived_accepted_trip_distance_haversine_avg_1week,
      derived_accepts_total_4week,
      derived_dropoff_location_longitude,
      derived_accepted_trip_distance_haversine_var_1week,
      derived_cancels_total_1week,
      derived_accepted_dispatched_eta_avg_1week,
      derived_canceled_eta_delta_avg_1week,
      derived_accepted_surge_multiplier_avg_1week,
      derived_eta,
      derived_canceled_trip_distance_haversine_var_1week,
      derived_is_commute,
      derived_days_since_signup,
      derived_canceled_eta_delta_avg_4week,
      derived_rank,
      derived_surge_diff,
      derived_accepted_eta_delta_avg_1week,
      derived_canceled_dispatched_eta_var_1week,
      derived_accepted_eyeball_eta_seconds_var_4week,
      derived_accepted_dispatched_eta_avg_4week,
      derived_canceled_eyeball_eta_seconds_var_1week,
      derived_accepted_trip_distance_haversine_var_4week,
      derived_diff_eta_delta_accepted_eta_delta_avg_4week,
      derived_hour_of_day,
      derived_request_location_longitude,
      derived_canceled_eta_delta_var_1week,
      derived_fd_eta,
      derived_accepted_eta_delta_var_4week,
      derived_accepted_eyeball_eta_seconds_avg_4week,
      derived_accepted_dispatched_eta_var_4week,
      derived_accepted_app_rating_var_4week,
      derived_diff_dispatched_eta_accepted_dispatched_eta_avg_4week,
      derived_canceled_dispatched_eta_avg_1week,
      derived_accepted_surge_multiplier_avg_4week,
      derived_canceled_eyeball_eta_seconds_avg_1week,
      derived_accepted_trip_distance_haversine_avg_4week,
      derived_city_id,
      derived_canceled_eyeball_eta_seconds_avg_4week,
      derived_diff_trip_distance_en_route_distance,
      derived_canceled_dispatched_eta_var_4week,
      derived_canceled_trip_distance_haversine_avg_4week,
      derived_accepted_eyeball_eta_seconds_avg_1week,
      derived_eyeball_eta,
      derived_canceled_app_rating_var_4week,
      derived_accepted_app_rating_var_1week,
      derived_is_forward_dispatched,
      derived_distance_request_to_dropoff,
      derived_accepted_eta_delta_avg_4week,
      derived_accepted_eyeball_eta_seconds_var_1week,
      derived_canceled_eyeball_eta_seconds_var_4week,
      derived_request_location_latitude,
      derived_canceled_app_rating_avg_1week,
      derived_canceled_surge_multiplier_avg_1week,
      derived_canceled_dispatched_eta_avg_4week,
      derived_canceled_trip_distance_haversine_var_4week,
      derived_is_fifo,
      derived_trip_distance_haversine,
      derived_eta_delta,
      derived_cancels_avg_4week,
      derived_accepted_surge_multiplier_var_4week,
      derived_day_of_week,
      derived_canceled_surge_multiplier_var_4week,
      derived_dropoff_location_latitude,
      derived_supply_location_longitude,
      derived_accepts_total_1week,
      derived_canceled_app_rating_avg_4week,
      derived_accepted_app_rating_avg_1week,
      derived_canceled_surge_multiplier_var_1week,
      derived_canceled_trip_distance_haversine_avg_1week,
      derived_supply_location_latitude,
      derived_accepted_dispatched_eta_var_1week,
      derived_canceled_eta_delta_var_4week,
      derived_distance_supply_to_request,
      derived_cancels_avg_1week,
      derived_eta_remaining,
      derived_diff_eyeball_eta_accepted_eyeball_eta_seconds_avg_4week,
      derived_canceled_surge_multiplier_avg_4week,
      derived_canceled_app_rating_var_1week,
      derived_distance_supply_to_dropoff,
      derived_cancels_total_4week,
      derived_accepted_eta_delta_var_1week,
      probability
    from
      intelligent_dispatch.targupt_c_to_r_conditioned_driver_cancel_model_v1
    where product_parent_name = 'UberX MASTER' and vehicle_view_id in ('1174', '3721', '20006709', '20027775', '3410', '20034601', '1117', '1177', '1176', '951', '3182', '12073', '967', '20004411', '10000200', '833', '8229', '13801', '674', '20002123', '10057', '20027771', '991', '3395', '20025163', '15795', '760', '20015213', '20001217', '994', '13635', '20011127', '2507', '1503', '687', '1041', '1149', '3079', '1171', '3579', '20001317', '907', '10001308', '20003693', '20004089', '900', '803', '806', '761', '2241', '809', '971', '20001561', '1158', '20004087', '20001269', '1520', '1492', '20001213', '784', '929', '20001215', '1002', '845', '3133', '3553', '12873', '20000803', '3549', '890', '20001235', '20009027', '1162',
'521', '10001884', '2450', '364', '9697', '353', '10002062', '10002150', '685', '11107', '1159', '20001257', '4457', '2875', '20006367', '428', '13033', '11803', '1519', '1427', '2016', '764', '1966', '1976', '905', '615', '844', '785', '843', '748', '10000420', '603', '651', '662', '1720', '11399', '828', '842', '911', '20002013', '10002430', '10000576', '9851', '745', '12945', '20020743', '20000337', '20007593', '755', '11255', '749', '3923', '10001518', '2090', '10004302', '930', '20002015', '10001002', '47', '10002446', '10002060', '20004685', '20004685', '20002971', '20009273', '793', '683', '832', '20000081', '20001319', '1556', '564', '13365', '1975', '2489', '686', '4465', '10004480', '352', '20001167', '10004382', '10004300', '350', '11369', '433', '20001159', '14321', '11179', '5383', '13695', '20009279', '854', '901', '11331', '958', '1985', '20001333', '12089', '10002296', '839', '14315', '20001337', '841', '20002011', '2451', '10001508', '20000027', '799', '20002009', '401', '1572', '14417', '10000418', '10000556', '10001520', '10002428', '20000655', '15831', '7057', '11471', '11469', '837', '5433', '2494', '5407', '11783', '7415', '11279', '3825', '11047', '5341', '4177', '20018783', '20010119', '1377', '5345', '1376', '2011', '10000598', '4185', '4183', '2020', '2009', '2028', '10000344', '2022', '4187', '2007', '10001360', '2015', '1379', '1217', '2032', '2019', '2021', '5339', '1575', '20010119', '425', '688', '895', '928', '8899', '20011151', '20031309', '20021641', '10000478', '1216', '6149', '10002522', '5485', '10407', '7423', '1216', '3298', '120', '1812', '1964', '570', '235', '10285', '1512', '8285', '1490', '5235', '2846', '20002399', '13117', '13117', '4455', '1049', '6627', '326', '577', '174', '430', '714', '123', '228', '457', '738', '347', '184', '476', '125', '663', '180', '116', '940', '232', '39')
      and mega_region = '{}'
      and abs(mod(from_big_endian_64(xxhash64(CAST(job_uuid AS varbinary))), 100)) <= {}""".format(region, sample_percentage)
    return QUERY

sample_percentage = 1
region = 'APAC'
QUERY = prepare_query(region, sample_percentage)

# %%
from queryrunner_client import Client
qr = Client(user_email='targupt@uber.com')
qr.list_datasources()
cursor = qr.execute("presto", QUERY)
result = cursor.fetchall()
# Out:
# 08/18/2022 06:12:53 PM Send empty tier_metadata {} to queryrunner. Query is default to tier 5.
# 08/18/2022 06:12:53 PM  [Polling] b74d4ec1-7bce-4a94-b24c-832b8591ae64
# 08/18/2022 06:12:53 PM  [Status] created
# 08/18/2022 06:12:54 PM  [Status] started validation
# 08/18/2022 06:12:56 PM  [Status] finished validation
# 08/18/2022 06:12:58 PM  [Status] started waiting to execute
# 08/18/2022 06:13:24 PM  [Status] started execution
# 08/18/2022 06:18:40 PM  [Status] completed success
# 08/18/2022 06:18:40 PM  [Query Success] completed success

# %%
import pandas as pd
pd.DataFrame(result).to_csv("data/{}_cr_given_driver_cancel_prediction_sample.csv".format(region.lower()), index=False)
