# %%
# Reference: https://michelangelo-studio.uberinternal.com/file/f379d46c-10ff-4631-b320-5ff5d6f96f70

# %%
# %%bash
# source $VIRTUAL_ENV_DIR/python3/bin/activate
#
# install_package_python3.sh add dsw_qr==0.1.13
#
# $VIRTUAL_ENV_DIR/python3/bin/python -m pip install galileo
# $VIRTUAL_ENV_DIR/python3/bin/python -m pip install galileo-py
# $VIRTUAL_ENV_DIR/python3/bin/python -m pip install tchannel
# $VIRTUAL_ENV_DIR/python3/bin/python -m pip install matching-ds-tools==0.7.3
# $VIRTUAL_ENV_DIR/python3/bin/python -m pip install dataclasses
# $VIRTUAL_ENV_DIR/python3/bin/python -m pip install pandas==0.25.3
# Out:
# Updating dependencies
# Resolving dependencies...
#
#
# Package operations: 1 install, 6 updates, 0 removals
#
#   - Updating tornado (4.5.3 -> 5.1.1)
#   - Updating cachetools (3.1.1 -> 4.1.1)
#   - Updating idna (2.8 -> 2.10)
#   - Updating protobuf (3.12.2 -> 3.13.0)
#   - Updating requests (2.22.0 -> 2.24.0)
#   - Installing wheel (0.35.1)
#   - Updating h3 (3.6.4 -> 3.7.0)
# Looking in indexes: https://yoober11:****@pypi.uberinternal.com/index
# Requirement already satisfied: galileo in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (0.5.1)
# Requirement already satisfied: requests in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo) (2.24.0)
# Requirement already satisfied: pyusb>=1a in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo) (1.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from requests->galileo) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from requests->galileo) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from requests->galileo) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from requests->galileo) (3.0.4)
# Looking in indexes: https://yoober11:****@pypi.uberinternal.com/index
# Requirement already satisfied: galileo-py in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (1.19.5)
# Requirement already satisfied: wonkapy>=3.0.2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (3.0.2)
# Requirement already satisfied: tornado-extras>=1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (1.4.0)
# Collecting tornado<5,>=4.4
#   Using cached tornado-4.5.3-cp36-cp36m-linux_x86_64.whl
# Requirement already satisfied: jaeger-client-python>=4.0.0 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (4.0.0)
# Requirement already satisfied: opentracing-instrumentation in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (3.3.1)
# Requirement already satisfied: tchannel>=2.0.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (2.1.0)
# Collecting cachetools~=3.0
#   Using cached https://pypi.uberinternal.com/packages/packages/2f/a6/30b0a0bef12283e83e58c1d6e7b5aabc7acfc4110df81a4471655d33e704/cachetools-3.1.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: ujson in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (1.35)
# Requirement already satisfied: clay-sortsol-logging>1.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (1.2.0)
# Requirement already satisfied: flask in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (1.1.2)
# Requirement already satisfied: m3>=3.2.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (4.3.1)
# Requirement already satisfied: six in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (1.15.0)
# Requirement already satisfied: deprecation<3,>=1.0.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from galileo-py) (2.0.7)
# Requirement already satisfied: raven in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from clay-sortsol-logging>1.1->galileo-py) (6.1.0)
# Requirement already satisfied: pyyaml in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from clay-sortsol-logging>1.1->galileo-py) (5.3.1)
# Requirement already satisfied: sortsol>=1.0.298 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from clay-sortsol-logging>1.1->galileo-py) (1.1.0)
# Requirement already satisfied: packaging in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from deprecation<3,>=1.0.1->galileo-py) (20.4)
# Requirement already satisfied: jaeger-client<5,>4 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from jaeger-client-python>=4.0.0->galileo-py) (4.3.0)
# Requirement already satisfied: futures in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from jaeger-client-python>=4.0.0->galileo-py) (3.1.1)
# Requirement already satisfied: clay-config in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from jaeger-client-python>=4.0.0->galileo-py) (2.1.1)
# Requirement already satisfied: future in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from m3>=3.2.1->galileo-py) (0.16.0)
# Requirement already satisfied: thriftrw>=1.8 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from m3>=3.2.1->galileo-py) (1.8.1)
# Requirement already satisfied: wrapt in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from opentracing-instrumentation->galileo-py) (1.12.1)
# Requirement already satisfied: opentracing<3,>=2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from opentracing-instrumentation->galileo-py) (2.3.0)
# Requirement already satisfied: contextlib2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from opentracing-instrumentation->galileo-py) (0.6.0.post1)
# Requirement already satisfied: crcmod<2,>=1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel>=2.0.1->galileo-py) (1.7)
# Requirement already satisfied: threadloop<2,>=1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel>=2.0.1->galileo-py) (1.0.2)
# Requirement already satisfied: toro in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tornado-extras>=1->galileo-py) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from flask->galileo-py) (2.11.2)
# Requirement already satisfied: Werkzeug>=0.15 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from flask->galileo-py) (1.0.1)
# Requirement already satisfied: click>=5.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from flask->galileo-py) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from flask->galileo-py) (1.1.0)
# Requirement already satisfied: thrift in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from jaeger-client<5,>4->jaeger-client-python>=4.0.0->galileo-py) (0.13.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from Jinja2>=2.10.1->flask->galileo-py) (1.1.1)
# Requirement already satisfied: pycrypto>=2.0 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (2.6.1)
# Requirement already satisfied: dnspython>=1.9.4 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (1.16.0)
# Requirement already satisfied: kafka-rest-py>=0.2.10 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (0.3.4)
# Requirement already satisfied: kazoo>=0.7 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (2.8.0)
# Requirement already satisfied: send-nsca>=0.1.3 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (0.1.4.1)
# Requirement already satisfied: uhashring>=1.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (1.1)
# Requirement already satisfied: boto<3.0,>=2.2.0 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (2.49.0)
# Requirement already satisfied: ubermon>=0.4.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (0.4.1)
# Requirement already satisfied: ply in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from thriftrw>=1.8->m3>=3.2.1->galileo-py) (3.11)
# Requirement already satisfied: clay-config-file in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from clay-config->jaeger-client-python>=4.0.0->galileo-py) (1.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from packaging->deprecation<3,>=1.0.1->galileo-py) (2.4.7)
# Requirement already satisfied: redis>=2.0 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from ubermon>=0.4.1->sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (3.4.1)
# Requirement already satisfied: python-dateutil>=1.5 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from ubermon>=0.4.1->sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (2.8.1)
# Requirement already satisfied: simplejson in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from ubermon>=0.4.1->sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (3.10.0)
# Requirement already satisfied: psutil>=1.0 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from ubermon>=0.4.1->sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (5.7.3)
# Requirement already satisfied: setuptools>=31.0.0 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from ubermon>=0.4.1->sortsol>=1.0.298->clay-sortsol-logging>1.1->galileo-py) (54.1.2)
# Installing collected packages: tornado, cachetools
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.1.1
#     Uninstalling cachetools-4.1.1:
#       Successfully uninstalled cachetools-4.1.1
# Successfully installed cachetools-3.1.1 tornado-4.5.3
# Looking in indexes: https://yoober11:****@pypi.uberinternal.com/index
# Requirement already satisfied: tchannel in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (2.1.0)
# Requirement already satisfied: threadloop<2,>=1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel) (1.0.2)
# Requirement already satisfied: future in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel) (0.16.0)
# Requirement already satisfied: thriftrw<2,>=0.4 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel) (1.8.1)
# Requirement already satisfied: opentracing-instrumentation>3 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel) (3.3.1)
# Requirement already satisfied: crcmod<2,>=1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel) (1.7)
# Requirement already satisfied: tornado<5,>=4.3 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel) (4.5.3)
# Requirement already satisfied: six in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel) (1.15.0)
# Requirement already satisfied: opentracing>2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel) (2.3.0)
# Requirement already satisfied: contextlib2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel) (0.6.0.post1)
# Requirement already satisfied: futures in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from tchannel) (3.1.1)
# Requirement already satisfied: wrapt in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from opentracing-instrumentation>3->tchannel) (1.12.1)
# Requirement already satisfied: ply in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from thriftrw<2,>=0.4->tchannel) (3.11)
# Looking in indexes: https://yoober11:****@pypi.uberinternal.com/index
# Requirement already satisfied: matching-ds-tools==0.7.3 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (0.7.3)
# Requirement already satisfied: dataclasses==0.8 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from matching-ds-tools==0.7.3) (0.8)
# Collecting pandas>1
#   Using cached https://pypi.uberinternal.com/packages/packages/c3/e2/00cacecafbab071c787019f00ad84ca3185952f6bb9bca9550ed83870d4d/pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Requirement already satisfied: pytz>2021 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from matching-ds-tools==0.7.3) (2021.3)
# Requirement already satisfied: queryrunner-client>3 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from matching-ds-tools==0.7.3) (3.4.1)
# Collecting requests==2.22.0
#   Using cached https://pypi.uberinternal.com/packages/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57 kB)
# Collecting protobuf==3.12.2
#   Using cached https://pypi.uberinternal.com/packages/packages/28/05/9867ef8eafd12265267bee138fa2c46ebf34a276ea4cbe184cba4c606e8b/protobuf-3.12.2-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Requirement already satisfied: haversine==2.1.2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from matching-ds-tools==0.7.3) (2.1.2)
# Requirement already satisfied: ujson==1.35 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from matching-ds-tools==0.7.3) (1.35)
# Collecting h3==3.6.4
#   Using cached https://pypi.uberinternal.com/packages/packages/bf/77/df4b7b3f989cbd3aec5894f6058a31981f05f151f9bbfc3f5827178eeedc/h3-3.6.4-cp36-cp36m-manylinux2010_x86_64.whl (761 kB)
# Requirement already satisfied: six>=1.9 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from protobuf==3.12.2->matching-ds-tools==0.7.3) (1.15.0)
# Requirement already satisfied: setuptools in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from protobuf==3.12.2->matching-ds-tools==0.7.3) (54.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from requests==2.22.0->matching-ds-tools==0.7.3) (2020.6.20)
# Collecting idna<2.9,>=2.5
#   Using cached https://pypi.uberinternal.com/packages/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from requests==2.22.0->matching-ds-tools==0.7.3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from requests==2.22.0->matching-ds-tools==0.7.3) (1.25.11)
# Requirement already satisfied: numpy>=1.15.4 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from pandas>1->matching-ds-tools==0.7.3) (1.16.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from pandas>1->matching-ds-tools==0.7.3) (2.8.1)
# Requirement already satisfied: wonkapy>=3 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from queryrunner-client>3->matching-ds-tools==0.7.3) (3.0.2)
# Requirement already satisfied: future==0.16.0 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from queryrunner-client>3->matching-ds-tools==0.7.3) (0.16.0)
# Requirement already satisfied: pysocks>=1.5.7 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from queryrunner-client>3->matching-ds-tools==0.7.3) (1.7.1)
# Requirement already satisfied: querybuilder-client==0.6.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from queryrunner-client>3->matching-ds-tools==0.7.3) (0.6.1)
# Requirement already satisfied: clay-config>=2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from queryrunner-client>3->matching-ds-tools==0.7.3) (2.1.1)
# Requirement already satisfied: pyyaml in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from queryrunner-client>3->matching-ds-tools==0.7.3) (5.3.1)
# Requirement already satisfied: m3>=4 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from queryrunner-client>3->matching-ds-tools==0.7.3) (4.3.1)
# Requirement already satisfied: hive-csv-reader==0.1.9 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from queryrunner-client>3->matching-ds-tools==0.7.3) (0.1.9)
# Requirement already satisfied: clay-config-file in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from clay-config>=2->queryrunner-client>3->matching-ds-tools==0.7.3) (1.2.1)
# Requirement already satisfied: thriftrw>=1.8 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from m3>=4->queryrunner-client>3->matching-ds-tools==0.7.3) (1.8.1)
# Requirement already satisfied: tornado<6 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from m3>=4->queryrunner-client>3->matching-ds-tools==0.7.3) (4.5.3)
# Requirement already satisfied: ply in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from thriftrw>=1.8->m3>=4->queryrunner-client>3->matching-ds-tools==0.7.3) (3.11)
# Installing collected packages: idna, requests, protobuf, pandas, h3
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.13.0
#     Uninstalling protobuf-3.13.0:
#       Successfully uninstalled protobuf-3.13.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 0.25.3
#     Uninstalling pandas-0.25.3:
#       Successfully uninstalled pandas-0.25.3
#   Attempting uninstall: h3
#     Found existing installation: h3 3.7.0
#     Uninstalling h3-3.7.0:
#       Successfully uninstalled h3-3.7.0
# Successfully installed h3-3.6.4 idna-2.8 pandas-1.1.5 protobuf-3.12.2 requests-2.22.0
# Looking in indexes: https://yoober11:****@pypi.uberinternal.com/index
# Requirement already satisfied: dataclasses in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (0.8)
# Looking in indexes: https://yoober11:****@pypi.uberinternal.com/index
# Collecting pandas==0.25.3
#   Using cached https://pypi.uberinternal.com/packages/packages/52/3f/f6a428599e0d4497e1595030965b5ba455fd8ade6e977e3c819973c4b41d/pandas-0.25.3-cp36-cp36m-manylinux1_x86_64.whl (10.4 MB)
# Requirement already satisfied: pytz>=2017.2 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from pandas==0.25.3) (2021.3)
# Requirement already satisfied: numpy>=1.13.3 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from pandas==0.25.3) (1.16.6)
# Requirement already satisfied: python-dateutil>=2.6.1 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from pandas==0.25.3) (2.8.1)
# Requirement already satisfied: six>=1.5 in /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas==0.25.3) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# Successfully installed pandas-0.25.3
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
#     WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
#     WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 0.71.0 requires cachetools>=4.0, but you have cachetools 3.1.1 which is incompatible.
# streamlit 0.71.0 requires tornado>=5.0, but you have tornado 4.5.3 which is incompatible.
# mxpkg 1.1.65 requires bcrypt==3.1.7, but you have bcrypt 3.2.0 which is incompatible.
# mxpkg 1.1.65 requires certifi==2020.4.5.1, but you have certifi 2020.6.20 which is incompatible.
# mxpkg 1.1.65 requires cffi==1.14.0, but you have cffi 1.14.3 which is incompatible.
# mxpkg 1.1.65 requires clay-config-file==1.2.0, but you have clay-config-file 1.2.1 which is incompatible.
# mxpkg 1.1.65 requires click==7.1.1, but you have click 7.1.2 which is incompatible.
# mxpkg 1.1.65 requires colorama==0.4.3, but you have colorama 0.4.4 which is incompatible.
# mxpkg 1.1.65 requires cryptography==2.9, but you have cryptography 3.2 which is incompatible.
# mxpkg 1.1.65 requires cython==0.29.16, but you have cython 0.29.21 which is incompatible.
# mxpkg 1.1.65 requires gitdb==4.0.2, but you have gitdb 4.0.5 which is incompatible.
# mxpkg 1.1.65 requires gitpython==3.1.0, but you have gitpython 3.1.11 which is incompatible.
# mxpkg 1.1.65 requires grpcio==1.28.1, but you have grpcio 1.29.0 which is incompatible.
# mxpkg 1.1.65 requires grpcio-tools==1.28.1, but you have grpcio-tools 1.29.0 which is incompatible.
# mxpkg 1.1.65 requires h3==3.7.4, but you have h3 3.7.0 which is incompatible.
# mxpkg 1.1.65 requires humanize==2.3.0, but you have humanize 3.1.0 which is incompatible.
# mxpkg 1.1.65 requires idna==2.9, but you have idna 2.10 which is incompatible.
# mxpkg 1.1.65 requires jinja2==2.11.1, but you have jinja2 2.11.2 which is incompatible.
# mxpkg 1.1.65 requires joblib==0.10.3, but you have joblib 0.13.2 which is incompatible.
# mxpkg 1.1.65 requires kazoo==2.7.0, but you have kazoo 2.8.0 which is incompatible.
# mxpkg 1.1.65 requires m3==4.2.1, but you have m3 4.3.1 which is incompatible.
# mxpkg 1.1.65 requires matplotlib==2.2.4, but you have matplotlib 3.3.2 which is incompatible.
# mxpkg 1.1.65 requires neuropod==0.1.1, but you have neuropod 0.2.0 which is incompatible.
# mxpkg 1.1.65 requires numpy==1.16.4, but you have numpy 1.16.6 which is incompatible.
# mxpkg 1.1.65 requires opentracing-instrumentation==3.2.1, but you have opentracing-instrumentation 3.3.1 which is incompatible.
# mxpkg 1.1.65 requires packaging==20.3, but you have packaging 20.4 which is incompatible.
# mxpkg 1.1.65 requires pandas==0.25, but you have pandas 0.25.3 which is incompatible.
# mxpkg 1.1.65 requires paramiko==2.7.1, but you have paramiko 2.7.2 which is incompatible.
# mxpkg 1.1.65 requires plotly==4.1.1, but you have plotly 4.12.0 which is incompatible.
# mxpkg 1.1.65 requires psutil==5.7.0, but you have psutil 5.7.3 which is incompatible.
# mxpkg 1.1.65 requires py4j==0.10.4, but you have py4j 0.10.7 which is incompatible.
# mxpkg 1.1.65 requires pyarrow==0.16.0, but you have pyarrow 2.0.0 which is incompatible.
# mxpkg 1.1.65 requires pynacl==1.3.0, but you have pynacl 1.4.0 which is incompatible.
# mxpkg 1.1.65 requires pypika==0.37.11, but you have pypika 0.47.4 which is incompatible.
# mxpkg 1.1.65 requires pytz==2022.2, but you have pytz 2021.3 which is incompatible.
# mxpkg 1.1.65 requires pyyaml==5.1, but you have pyyaml 5.3.1 which is incompatible.
# mxpkg 1.1.65 requires requests==2.23.0, but you have requests 2.24.0 which is incompatible.
# mxpkg 1.1.65 requires scikit-learn==0.20.3, but you have scikit-learn 0.22.2 which is incompatible.
# mxpkg 1.1.65 requires scipy==1.2.1, but you have scipy 1.5.3 which is incompatible.
# mxpkg 1.1.65 requires seaborn==0.9.0, but you have seaborn 0.11.0 which is incompatible.
# mxpkg 1.1.65 requires semver==2.9.1, but you have semver 2.13.0 which is incompatible.
# mxpkg 1.1.65 requires six==1.14.0, but you have six 1.15.0 which is incompatible.
# mxpkg 1.1.65 requires smmap==3.0.1, but you have smmap 3.0.4 which is incompatible.
# mxpkg 1.1.65 requires statsmodels==0.9.0, but you have statsmodels 0.12.0 which is incompatible.
# mxpkg 1.1.65 requires thrift==0.11.0, but you have thrift 0.13.0 which is incompatible.
# mxpkg 1.1.65 requires tqdm==4.33.0, but you have tqdm 4.51.0 which is incompatible.
# mxpkg 1.1.65 requires typing==3.7.4.1, but you have typing 3.7.4.3 which is incompatible.
# mxpkg 1.1.65 requires urllib3==1.25.8, but you have urllib3 1.25.11 which is incompatible.
# mxpkg 1.1.65 requires watchdog==0.9.0, but you have watchdog 0.10.3 which is incompatible.
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
#     WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
#     WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
#     WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
#     WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
#     WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyenv3 0.1.0 requires scikit-learn==0.18.1, but you have scikit-learn 0.22.2 which is incompatible.
# streamlit 0.71.0 requires cachetools>=4.0, but you have cachetools 3.1.1 which is incompatible.
# streamlit 0.71.0 requires tornado>=5.0, but you have tornado 4.5.3 which is incompatible.
# production-function 0.1.38 requires scikit-learn==0.20.3, but you have scikit-learn 0.22.2 which is incompatible.
# production-function 0.1.38 requires scipy==1.2.1, but you have scipy 1.5.3 which is incompatible.
# production-function 0.1.38 requires seaborn==0.9.0, but you have seaborn 0.11.0 which is incompatible.
# production-function 0.1.38 requires statsmodels==0.9.0, but you have statsmodels 0.12.0 which is incompatible.
# mxpkg 1.1.65 requires bcrypt==3.1.7, but you have bcrypt 3.2.0 which is incompatible.
# mxpkg 1.1.65 requires certifi==2020.4.5.1, but you have certifi 2020.6.20 which is incompatible.
# mxpkg 1.1.65 requires cffi==1.14.0, but you have cffi 1.14.3 which is incompatible.
# mxpkg 1.1.65 requires clay-config-file==1.2.0, but you have clay-config-file 1.2.1 which is incompatible.
# mxpkg 1.1.65 requires click==7.1.1, but you have click 7.1.2 which is incompatible.
# mxpkg 1.1.65 requires colorama==0.4.3, but you have colorama 0.4.4 which is incompatible.
# mxpkg 1.1.65 requires cryptography==2.9, but you have cryptography 3.2 which is incompatible.
# mxpkg 1.1.65 requires cython==0.29.16, but you have cython 0.29.21 which is incompatible.
# mxpkg 1.1.65 requires gitdb==4.0.2, but you have gitdb 4.0.5 which is incompatible.
# mxpkg 1.1.65 requires gitpython==3.1.0, but you have gitpython 3.1.11 which is incompatible.
# mxpkg 1.1.65 requires grpcio==1.28.1, but you have grpcio 1.29.0 which is incompatible.
# mxpkg 1.1.65 requires grpcio-tools==1.28.1, but you have grpcio-tools 1.29.0 which is incompatible.
# mxpkg 1.1.65 requires h3==3.7.4, but you have h3 3.6.4 which is incompatible.
# mxpkg 1.1.65 requires humanize==2.3.0, but you have humanize 3.1.0 which is incompatible.
# mxpkg 1.1.65 requires idna==2.9, but you have idna 2.8 which is incompatible.
# mxpkg 1.1.65 requires jinja2==2.11.1, but you have jinja2 2.11.2 which is incompatible.
# mxpkg 1.1.65 requires joblib==0.10.3, but you have joblib 0.13.2 which is incompatible.
# mxpkg 1.1.65 requires kazoo==2.7.0, but you have kazoo 2.8.0 which is incompatible.
# mxpkg 1.1.65 requires m3==4.2.1, but you have m3 4.3.1 which is incompatible.
# mxpkg 1.1.65 requires matplotlib==2.2.4, but you have matplotlib 3.3.2 which is incompatible.
# mxpkg 1.1.65 requires neuropod==0.1.1, but you have neuropod 0.2.0 which is incompatible.
# mxpkg 1.1.65 requires numpy==1.16.4, but you have numpy 1.16.6 which is incompatible.
# mxpkg 1.1.65 requires opentracing-instrumentation==3.2.1, but you have opentracing-instrumentation 3.3.1 which is incompatible.
# mxpkg 1.1.65 requires packaging==20.3, but you have packaging 20.4 which is incompatible.
# mxpkg 1.1.65 requires pandas==0.25, but you have pandas 1.1.5 which is incompatible.
# mxpkg 1.1.65 requires paramiko==2.7.1, but you have paramiko 2.7.2 which is incompatible.
# mxpkg 1.1.65 requires plotly==4.1.1, but you have plotly 4.12.0 which is incompatible.
# mxpkg 1.1.65 requires protobuf>=3.13.0, but you have protobuf 3.12.2 which is incompatible.
# mxpkg 1.1.65 requires psutil==5.7.0, but you have psutil 5.7.3 which is incompatible.
# mxpkg 1.1.65 requires py4j==0.10.4, but you have py4j 0.10.7 which is incompatible.
# mxpkg 1.1.65 requires pyarrow==0.16.0, but you have pyarrow 2.0.0 which is incompatible.
# mxpkg 1.1.65 requires pynacl==1.3.0, but you have pynacl 1.4.0 which is incompatible.
# mxpkg 1.1.65 requires pypika==0.37.11, but you have pypika 0.47.4 which is incompatible.
# mxpkg 1.1.65 requires pytz==2022.2, but you have pytz 2021.3 which is incompatible.
# mxpkg 1.1.65 requires pyyaml==5.1, but you have pyyaml 5.3.1 which is incompatible.
# mxpkg 1.1.65 requires requests==2.23.0, but you have requests 2.22.0 which is incompatible.
# mxpkg 1.1.65 requires scikit-learn==0.20.3, but you have scikit-learn 0.22.2 which is incompatible.
# mxpkg 1.1.65 requires scipy==1.2.1, but you have scipy 1.5.3 which is incompatible.
# mxpkg 1.1.65 requires seaborn==0.9.0, but you have seaborn 0.11.0 which is incompatible.
# mxpkg 1.1.65 requires semver==2.9.1, but you have semver 2.13.0 which is incompatible.
# mxpkg 1.1.65 requires six==1.14.0, but you have six 1.15.0 which is incompatible.
# mxpkg 1.1.65 requires smmap==3.0.1, but you have smmap 3.0.4 which is incompatible.
# mxpkg 1.1.65 requires statsmodels==0.9.0, but you have statsmodels 0.12.0 which is incompatible.
# mxpkg 1.1.65 requires thrift==0.11.0, but you have thrift 0.13.0 which is incompatible.
# mxpkg 1.1.65 requires tqdm==4.33.0, but you have tqdm 4.51.0 which is incompatible.
# mxpkg 1.1.65 requires typing==3.7.4.1, but you have typing 3.7.4.3 which is incompatible.
# mxpkg 1.1.65 requires urllib3==1.25.8, but you have urllib3 1.25.11 which is incompatible.
# mxpkg 1.1.65 requires watchdog==0.9.0, but you have watchdog 0.10.3 which is incompatible.
# geoip2 4.1.0 requires requests<3.0.0,>=2.24.0, but you have requests 2.22.0 which is incompatible.
# abpkg 1.0.8 requires protobuf>=3.13.0, but you have protobuf 3.12.2 which is incompatible.
# abpkg 1.0.8 requires requests>=2.23.0, but you have requests 2.22.0 which is incompatible.
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
#     WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -andas (/dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyenv3 0.1.0 requires scikit-learn==0.18.1, but you have scikit-learn 0.22.2 which is incompatible.
# streamlit 0.71.0 requires cachetools>=4.0, but you have cachetools 3.1.1 which is incompatible.
# streamlit 0.71.0 requires tornado>=5.0, but you have tornado 4.5.3 which is incompatible.
# production-function 0.1.38 requires scikit-learn==0.20.3, but you have scikit-learn 0.22.2 which is incompatible.
# production-function 0.1.38 requires scipy==1.2.1, but you have scipy 1.5.3 which is incompatible.
# production-function 0.1.38 requires seaborn==0.9.0, but you have seaborn 0.11.0 which is incompatible.
# production-function 0.1.38 requires statsmodels==0.9.0, but you have statsmodels 0.12.0 which is incompatible.
# mxpkg 1.1.65 requires bcrypt==3.1.7, but you have bcrypt 3.2.0 which is incompatible.
# mxpkg 1.1.65 requires certifi==2020.4.5.1, but you have certifi 2020.6.20 which is incompatible.
# mxpkg 1.1.65 requires cffi==1.14.0, but you have cffi 1.14.3 which is incompatible.
# mxpkg 1.1.65 requires clay-config-file==1.2.0, but you have clay-config-file 1.2.1 which is incompatible.
# mxpkg 1.1.65 requires click==7.1.1, but you have click 7.1.2 which is incompatible.
# mxpkg 1.1.65 requires colorama==0.4.3, but you have colorama 0.4.4 which is incompatible.
# mxpkg 1.1.65 requires cryptography==2.9, but you have cryptography 3.2 which is incompatible.
# mxpkg 1.1.65 requires cython==0.29.16, but you have cython 0.29.21 which is incompatible.
# mxpkg 1.1.65 requires gitdb==4.0.2, but you have gitdb 4.0.5 which is incompatible.
# mxpkg 1.1.65 requires gitpython==3.1.0, but you have gitpython 3.1.11 which is incompatible.
# mxpkg 1.1.65 requires grpcio==1.28.1, but you have grpcio 1.29.0 which is incompatible.
# mxpkg 1.1.65 requires grpcio-tools==1.28.1, but you have grpcio-tools 1.29.0 which is incompatible.
# mxpkg 1.1.65 requires h3==3.7.4, but you have h3 3.6.4 which is incompatible.
# mxpkg 1.1.65 requires humanize==2.3.0, but you have humanize 3.1.0 which is incompatible.
# mxpkg 1.1.65 requires idna==2.9, but you have idna 2.8 which is incompatible.
# mxpkg 1.1.65 requires jinja2==2.11.1, but you have jinja2 2.11.2 which is incompatible.
# mxpkg 1.1.65 requires joblib==0.10.3, but you have joblib 0.13.2 which is incompatible.
# mxpkg 1.1.65 requires kazoo==2.7.0, but you have kazoo 2.8.0 which is incompatible.
# mxpkg 1.1.65 requires m3==4.2.1, but you have m3 4.3.1 which is incompatible.
# mxpkg 1.1.65 requires matplotlib==2.2.4, but you have matplotlib 3.3.2 which is incompatible.
# mxpkg 1.1.65 requires neuropod==0.1.1, but you have neuropod 0.2.0 which is incompatible.
# mxpkg 1.1.65 requires numpy==1.16.4, but you have numpy 1.16.6 which is incompatible.
# mxpkg 1.1.65 requires opentracing-instrumentation==3.2.1, but you have opentracing-instrumentation 3.3.1 which is incompatible.
# mxpkg 1.1.65 requires packaging==20.3, but you have packaging 20.4 which is incompatible.
# mxpkg 1.1.65 requires pandas==0.25, but you have pandas 0.25.3 which is incompatible.
# mxpkg 1.1.65 requires paramiko==2.7.1, but you have paramiko 2.7.2 which is incompatible.
# mxpkg 1.1.65 requires plotly==4.1.1, but you have plotly 4.12.0 which is incompatible.
# mxpkg 1.1.65 requires protobuf>=3.13.0, but you have protobuf 3.12.2 which is incompatible.
# mxpkg 1.1.65 requires psutil==5.7.0, but you have psutil 5.7.3 which is incompatible.
# mxpkg 1.1.65 requires py4j==0.10.4, but you have py4j 0.10.7 which is incompatible.
# mxpkg 1.1.65 requires pyarrow==0.16.0, but you have pyarrow 2.0.0 which is incompatible.
# mxpkg 1.1.65 requires pynacl==1.3.0, but you have pynacl 1.4.0 which is incompatible.
# mxpkg 1.1.65 requires pypika==0.37.11, but you have pypika 0.47.4 which is incompatible.
# mxpkg 1.1.65 requires pytz==2022.2, but you have pytz 2021.3 which is incompatible.
# mxpkg 1.1.65 requires pyyaml==5.1, but you have pyyaml 5.3.1 which is incompatible.
# mxpkg 1.1.65 requires requests==2.23.0, but you have requests 2.22.0 which is incompatible.
# mxpkg 1.1.65 requires scikit-learn==0.20.3, but you have scikit-learn 0.22.2 which is incompatible.
# mxpkg 1.1.65 requires scipy==1.2.1, but you have scipy 1.5.3 which is incompatible.
# mxpkg 1.1.65 requires seaborn==0.9.0, but you have seaborn 0.11.0 which is incompatible.
# mxpkg 1.1.65 requires semver==2.9.1, but you have semver 2.13.0 which is incompatible.
# mxpkg 1.1.65 requires six==1.14.0, but you have six 1.15.0 which is incompatible.
# mxpkg 1.1.65 requires smmap==3.0.1, but you have smmap 3.0.4 which is incompatible.
# mxpkg 1.1.65 requires statsmodels==0.9.0, but you have statsmodels 0.12.0 which is incompatible.
# mxpkg 1.1.65 requires thrift==0.11.0, but you have thrift 0.13.0 which is incompatible.
# mxpkg 1.1.65 requires tqdm==4.33.0, but you have tqdm 4.51.0 which is incompatible.
# mxpkg 1.1.65 requires typing==3.7.4.1, but you have typing 3.7.4.3 which is incompatible.
# mxpkg 1.1.65 requires urllib3==1.25.8, but you have urllib3 1.25.11 which is incompatible.
# mxpkg 1.1.65 requires watchdog==0.9.0, but you have watchdog 0.10.3 which is incompatible.
# matching-ds-tools 0.7.3 requires pandas>1, but you have pandas 0.25.3 which is incompatible.
# abpkg 1.0.8 requires protobuf>=3.13.0, but you have protobuf 3.12.2 which is incompatible.
# abpkg 1.0.8 requires requests>=2.23.0, but you have requests 2.22.0 which is incompatible.

# %%
import json
import datetime
import re

import logging
import math
logging.basicConfig()
logging.getLogger().setLevel(logging.INFO)

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from queryrunner_client import Client
qclient = Client(user_email='mshehata@uber.com')
USER_EMAIL = 'mshehata@uber.com'
CONSUMER_NAME = 'intelligentdispatch'

import os
import warnings
warnings.filterwarnings('ignore')
import multiprocessing
from joblib import Parallel, delayed
#num_cores = multiprocessing.cpu_count()
n_cores = 4

# %%
from dataclasses import dataclass
import itertools
from typing import *
import numpy as np
import pandas as pd
from queryrunner_client import Client as QRClient
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.optimize import linear_sum_assignment

# %%
import mdstk
from mdstk.data_fetcher.data_fetcher import DataFetcher
from mdstk.data_fetcher.cached_data_fetcher import CachedDataFetcher

# %%
mdstk.__version__
# Out:
# '0.7.3'

# %%
class MyDataFetcher(DataFetcher):
    def query_many_presto(self, *args, **kwargs):
        return super().query_many_presto(*args, **kwargs)

# %%
# data collection for lsr
QUERY = """
with dispatch as (select distinct
    datestr,
    msg.cityid,
    msg.ctplangenrequestuuid as plangen_uuid,
    msg.ctrequestuuid as scan_uuid,
    j as job_uuid,
    msg.supplyuuid,
    msg.planactiontype
from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
cross join unnest(msg.jobuuid) jobs(j)
where datestr = '{datestr}'
and msg.cityid = {city_id}
and msg.vehicleviewid = {vvid} 
and msg.tenancy = 'uber/production'
and CARDINALITY(msg.jobuuid) > 0
and substr(msg.ctrequestuuid, 1, length('{digits}')) = '{digits}'
and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= {sample_percentage}
),
plangen as (
select distinct
msg.scanuuid as plangen_uuid, 
p.uuid as job_uuid,
j.supplyuuid
from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
cross join unnest(msg.proposals) as job(j)
cross join unnest(j.jobs) as plan(p)
where datestr = '{datestr}'
and msg.cityid = {city_id}
and msg.flowtype = 'solo_batch'
and msg.tenancy = 'uber/production'
and j.status = 'eligible'
),
created as (
select distinct
    msg.jobuuid,
    msg.timestamp
from rawdata.kafka_hp_demand_job_created_nodedup
where datestr = '{datestr}'
and msg.region.id = {city_id}
and msg.tenancy = 'uber/production'
),
mgv as (
select distinct datestr,
       msg.city_id,
       msg.job_uuid,
       msg.request_ts_ms,
       msg.client_uuid,
       msg.ct_request_uuid as plangen_uuid,
       msg.supply_uuid,
       msg.supply_plan_uuid as plan_uuid,
       msg.unadjusted_eta as eta,
       msg.adjustedeta,
       msg.ranking_metric,
       round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
       round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
       round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
       msg.preferred_destination_adjustment,
       msg.objective_value as of_value,
       msg.inconvenience_etd - msg.ranking_metric as trip_length
from   rawdata.kafka_hp_multileg_mgv_log_nodedup
where  datestr = '{datestr}'
and    msg.city_id = {city_id}
and    msg.tenancy = 'uber/production'
and    msg.vehicle_view_id = {vvid} 
and    msg.flow_type = 'solo_batch'
and    msg.job_uuid <> msg.client_uuid
and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
),
mgv1 as (
select distinct msg.job_uuid,
       msg.supply_uuid,
       max(msg.eventual_completion_probability) as continuation_cr
from   rawdata.kafka_hp_multileg_mgv_log_nodedup
where  datestr = '{datestr}'
and    msg.city_id = {city_id}
and    msg.environment = 'production'
and    msg.vehicle_view_id = {vvid} 
and    msg.flow_type = 'solo_batch'
and    msg.job_uuid <> msg.client_uuid
group by 1,2
),
test as (
select distinct
    mgv.datestr,
    mgv.city_id,
    dispatch.scan_uuid,
    mgv.plangen_uuid,
    mgv.job_uuid,
    (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
    dispatch.planactiontype,
    mgv.supply_uuid,
    case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
    mgv.eta,
    mgv.adjustedeta,
    mgv.ranking_metric,
    mgv.d_proba,
    mgv.r_proba,
    mgv.s_proba,
    mgv1.continuation_cr,
    mgv.preferred_destination_adjustment,
    mgv.of_value,
    mgv.trip_length,
    fare.est_rider_quoted_final_fare as fare
from mgv
join mgv1
on mgv.job_uuid = mgv1.job_uuid
and mgv.supply_uuid = mgv1.supply_uuid
join created
on mgv.job_uuid = created.jobuuid
join plangen
on mgv.plangen_uuid = plangen.plangen_uuid
and mgv.job_uuid = plangen.job_uuid
and mgv.supply_uuid = plangen.supplyuuid
join dispatch
on mgv.plangen_uuid = dispatch.plangen_uuid
and mgv.job_uuid = dispatch.job_uuid
join dwh.fact_trip_fare fare 
on mgv.job_uuid = fare.trip_uuid
and fare.datestr = '{datestr}'
and fare.city_id = {city_id}
)
select * from test
order by job_Uuid

"""

# %%
@dataclass
class Query:
    prefix: str
    hex_digits: str
    city_id: int
    vvid: str
    datestr: str
    sample_percentage: int

    def __post_init__(self):
        self.name = f'{self.prefix}_city{self.city_id}_{self.vvid}_{self.datestr}_segment{self.hex_digits}'
        self.qry = QUERY.format(city_id=self.city_id, vvid=self.vvid, digits=self.hex_digits, datestr=self.datestr, sample_percentage=self.sample_percentage)
        print(self.qry)
        #print(abc)
        #if self.city_id == 5:
        #    print("------")
        #    print(self.qry)

# %%
class MyDataFetcher(DataFetcher):
    def query_many_presto(self, *args, **kwargs):
        return super().query_many_presto(*args, **kwargs)

# %%
def clean_df(df, d = 0.5, r = 0.2, s = 0.01):
    df = df[df['fare'].notnull()]
    df = df[df['d_proba'].notnull()]
    df = df[df['r_proba'].notnull()]
    df = df[df['s_proba'].notnull()]
    df = df[df['adjustedeta']<1500]
    df['d_proba'] = df['d_proba'].fillna(d)
    df['r_proba'] = df['r_proba'].fillna(r)
    df['s_proba'] = df['s_proba'].fillna(s)
    df['trip_length'][df['trip_length'] <= 100] = 100
    df = df.drop_duplicates()
    df = df.dropna()
    return df

def compute_new_of(df, gamma = 1):
    df['cr'] = (1 - df['d_proba']) * (1 - df['r_proba']) + df['d_proba'] * df['continuation_cr']   
    df['new_of'] = - df['fare'] * df['cr'] * (1 - (df['adjustedeta']/1500))**gamma * np.abs(1500 - df['of_value']) / (1500 - df['of_value'])
    return df

# %%
# local solver
def solve_dict(
    scan: dict, 
    cost_col: str, 
    job_singleton: float = 1500,
    infinity: float = 1000000
):
    job_list = list(set([k[0] for k in scan.keys()]))
    job_idx = {j: i for i, j in enumerate(job_list)}
    job_count = len(job_list)

    supply_list = list(set([k[1] for k in scan.keys()]))
    supply_idx = {s: i for i, s in enumerate(supply_list)}
    supply_count = len(supply_list)
    
    utility = np.full((len(job_list), len(supply_list) + len(job_list)), infinity, dtype=np.float32)
    for k in scan.keys():
        jidx = job_idx[k[0]]
        sidx = supply_idx[k[1]]
        utility[jidx, sidx] = scan[k][cost_col]
    for i in range(len(job_list)):
        utility[i, supply_count + i] = job_singleton
            
    # solve
    job_sol, supply_sol = linear_sum_assignment(utility)

    result = set()
    for jidx, sidx in zip(job_sol, supply_sol):
        j = job_list[jidx]
        if sidx >= supply_count:
            result.add((j,))
        else:
            s = supply_list[sidx]
            result.add((j, s))
            
    assert len(result) == len(job_list)
    return result

# %%
@dataclass
class ScanMetrics:
    total_jobs: int = 0.
    total_eta: float = 0.
    total_offer: float = 0.
    total_ar: float = 0.
    total_rc: float = 0.
    total_cr: float = 0.
    total_trip: float = 0.
    total_gb: float = 0.
    total_overwrite: int = 0.
    
    def __add__(self, o: 'ScanMetrics') -> 'ScanMetrics':
        return ScanMetrics(
            self.total_jobs + o.total_jobs,
            self.total_eta + o.total_eta,
            self.total_offer + o.total_offer,
            self.total_ar + o.total_ar,
            self.total_rc + o.total_rc,
            self.total_trip + o.total_trip,
            self.total_overwrite + o.total_overwrite,
            self.total_gb + o.total_gb,
            self.total_cr + o.total_cr
        )
    def __iadd__(self, o: 'ScanMetrics') -> 'ScanMetrics':
        self.total_jobs += o.total_jobs
        self.total_eta += o.total_eta
        self.total_offer += o.total_offer
        self.total_ar += o.total_ar
        self.total_rc += o.total_rc
        self.total_trip += o.total_trip
        self.total_overwrite += o.total_overwrite
        self.total_gb += o.total_gb
        self.total_cr += o.total_cr
        return self

# %%
def metric_summary_dict(
    scan_dict: Dict[str, Dict[str, Any]],
    matching: set, 
    overwrite: int,
) -> ScanMetrics:
    sm = ScanMetrics()
    sm.total_jobs = len(matching)
    sm.total_overwrite = overwrite
    
    for m in matching:
        if len(m) == 2:
            row = scan_dict[(m[0], m[1])]
            sm.total_offer += 1
            sm.total_eta += row['adjustedeta']
            sm.total_ar += 1 - row['d_proba']
            sm.total_rc += row['r_proba']
            sm.total_cr += row['cr']
            if row['trip_length'] < 7200:
                sm.total_trip += row['trip_length']
            if row['fare'] > 0:
                sm.total_gb += row['cr'] * row['fare']
    return sm

def solve_all_dict(df, solver: Callable[[dict], set]):
    total_scans = dict(tuple(df.groupby('scan_uuid')))

    sm = ScanMetrics()
    for scan_uuid, scan_df in total_scans.items():
        scan = (scan_df.set_index(['job_uuid', 'supply_uuid']).to_dict(orient='index'))
        matching, overwrite = solver(scan)
        sm += metric_summary_dict(scan, matching, overwrite)
        
    return {'total_jobs': sm.total_jobs,
            'match_rate': sm.total_offer * 1.0 / sm.total_jobs,
            'overwrite': sm.total_overwrite * 1.0 / sm.total_jobs,
            'Average Matched ETA': sm.total_eta * 1.0 / sm.total_offer,
            'Average CR': sm.total_cr * 1.0 / sm.total_offer,
            'Driver AR': sm.total_ar * 1.0 / sm.total_offer,
            'Rider cancel': sm.total_rc * 1.0 / sm.total_offer,
            'Average trip length': sm.total_trip * 1.0 / sm.total_offer,
            'Average GB': sm.total_gb * 1.0 / sm.total_offer,
            'Total GB': sm.total_gb
           }

# %%
def different_matching_decision(m1,m2):
    return m1.difference(m2), m2.difference(m1)

def supply_cost_solve_dict(scan, markov = False, secondary_singleton = 0.0):
    primary_matching = solve_dict(scan, 'of_value', job_singleton = 1500)
    if markov:      
        return primary_matching, 0
    secondary_matching = solve_dict(scan, 'new_of', job_singleton = secondary_singleton)
    different_matches = len(different_matching_decision(primary_matching, secondary_matching)[0])
    return secondary_matching, different_matches

# %%
def convert_dict(d):
    tmp_df = pd.DataFrame()
    tmp_df['jobs'] = [d['total_jobs']]
    tmp_df['match_rate'] = [d['match_rate']]
    tmp_df['overwrite'] = [d['overwrite']]
    tmp_df['ETA'] = [d['Average Matched ETA']]
    tmp_df['AR'] = [d['Driver AR']]
    tmp_df['RC'] = [d['Rider cancel']]
    tmp_df['Average trip length'] = [d['Average trip length']]
    tmp_df['Total GB'] = [d['Total GB']]
    tmp_df['Average GB'] = [d['Average GB']]
    tmp_df['Average CR'] = [d['Average CR']]
    return tmp_df

# %%
prefix = 'replay'
hex_digits = '0'

city_id_vvids = {14: '(940)',
                 5: '(39)',
                 18: '(285)',
                 458: '(3825)',
                 7: '(180)',
                 12: '(125)',
                 90: '(651)',
                 39: '(539)',
                 143: '(9697)',
                 16: '(7423)',
                 148: '(3227)',
                 531: '(1964)',
                 214: '(1720)',
                 1542: '(10004302)',
                }

#city_id_vvids = {
#                 458: '(3825)',
#                }

datestrs = [  # 1 week
   '2022-09-16'
]

sample_percentage = 1

queries = [
    Query(prefix=prefix, hex_digits=hex_digits, city_id=city_id, vvid=vvid, datestr=datestr, sample_percentage=sample_percentage)
    for (city_id, vvid), datestr in itertools.product(city_id_vvids.items(), datestrs)
]

cache_qry_map = {
    q.name: q.qry 
    for q in queries
}

cdf = CachedDataFetcher(
    data_fetcher=MyDataFetcher(
        user_email=USER_EMAIL,
        consumer_name=CONSUMER_NAME,
    ),
    cache_qry_map=cache_qry_map,
    datacenter='dca1',
    datasource='presto-secure',
)

cdf.fetch(bust_cache=False)
# Out:
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 14
# and msg.vehicleviewid = (940)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 14
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 14
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 14
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (940)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 14
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (940)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 14
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 5
# and msg.vehicleviewid = (39)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 5
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 5
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 5
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (39)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 5
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (39)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 5
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 18
# and msg.vehicleviewid = (285)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 18
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 18
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 18
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (285)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 18
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (285)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 18
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 458
# and msg.vehicleviewid = (3825)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 458
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 458
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 458
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (3825)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 458
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (3825)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 458
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 7
# and msg.vehicleviewid = (180)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 7
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 7
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 7
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (180)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 7
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (180)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 7
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 12
# and msg.vehicleviewid = (125)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 12
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 12
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 12
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (125)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 12
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (125)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 12
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 90
# and msg.vehicleviewid = (651)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 90
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 90
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 90
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (651)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 90
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (651)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 90
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 39
# and msg.vehicleviewid = (539)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 39
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 39
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 39
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (539)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 39
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (539)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 39
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 143
# and msg.vehicleviewid = (9697)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 143
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 143
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 143
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (9697)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 143
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (9697)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 143
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 16
# and msg.vehicleviewid = (7423)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 16
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 16
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 16
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (7423)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 16
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (7423)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 16
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 148
# and msg.vehicleviewid = (3227)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 148
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 148
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 148
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (3227)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 148
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (3227)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 148
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 531
# and msg.vehicleviewid = (1964)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 531
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 531
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 531
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (1964)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 531
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (1964)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 531
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 214
# and msg.vehicleviewid = (1720)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 214
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 214
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 214
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (1720)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 214
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (1720)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 214
# )
# select * from test
# order by job_Uuid
#
#
#
# with dispatch as (select distinct
#     datestr,
#     msg.cityid,
#     msg.ctplangenrequestuuid as plangen_uuid,
#     msg.ctrequestuuid as scan_uuid,
#     j as job_uuid,
#     msg.supplyuuid,
#     msg.planactiontype
# from rawdata_user.kafka_hp_multileg_dispatched_plan_nodedup
# cross join unnest(msg.jobuuid) jobs(j)
# where datestr = '2022-09-16'
# and msg.cityid = 1542
# and msg.vehicleviewid = (10004302)
# and msg.tenancy = 'uber/production'
# and CARDINALITY(msg.jobuuid) > 0
# and substr(msg.ctrequestuuid, 1, length('0')) = '0'
# and abs(mod(from_big_endian_64(xxhash64(CAST(msg.ctrequestuuid AS varbinary))), 100)) <= 1
# ),
# plangen as (
# select distinct
# msg.scanuuid as plangen_uuid,
# p.uuid as job_uuid,
# j.supplyuuid
# from rawdata_user.kafka_hp_multileg_matching_observability_proposals_v2_nodedup
# cross join unnest(msg.proposals) as job(j)
# cross join unnest(j.jobs) as plan(p)
# where datestr = '2022-09-16'
# and msg.cityid = 1542
# and msg.flowtype = 'solo_batch'
# and msg.tenancy = 'uber/production'
# and j.status = 'eligible'
# ),
# created as (
# select distinct
#     msg.jobuuid,
#     msg.timestamp
# from rawdata.kafka_hp_demand_job_created_nodedup
# where datestr = '2022-09-16'
# and msg.region.id = 1542
# and msg.tenancy = 'uber/production'
# ),
# mgv as (
# select distinct datestr,
#        msg.city_id,
#        msg.job_uuid,
#        msg.request_ts_ms,
#        msg.client_uuid,
#        msg.ct_request_uuid as plangen_uuid,
#        msg.supply_uuid,
#        msg.supply_plan_uuid as plan_uuid,
#        msg.unadjusted_eta as eta,
#        msg.adjustedeta,
#        msg.ranking_metric,
#        round(1 - msg.solo_cancel_model_driver_accept_prob, 4) as d_proba,
#        round(1 - msg.solo_cancel_model_rider_accept_prob, 4) as r_proba,
#        round(1 - msg.spinner_survive_prob_before_next_scan, 4) as s_proba,
#        msg.preferred_destination_adjustment,
#        msg.objective_value as of_value,
#        msg.inconvenience_etd - msg.ranking_metric as trip_length
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 1542
# and    msg.tenancy = 'uber/production'
# and    msg.vehicle_view_id = (10004302)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# and    msg.calculator_type in ('markov_eta_v2', 'compound_completion_rate_of')
# ),
# mgv1 as (
# select distinct msg.job_uuid,
#        msg.supply_uuid,
#        max(msg.eventual_completion_probability) as continuation_cr
# from   rawdata.kafka_hp_multileg_mgv_log_nodedup
# where  datestr = '2022-09-16'
# and    msg.city_id = 1542
# and    msg.environment = 'production'
# and    msg.vehicle_view_id = (10004302)
# and    msg.flow_type = 'solo_batch'
# and    msg.job_uuid <> msg.client_uuid
# group by 1,2
# ),
# test as (
# select distinct
#     mgv.datestr,
#     mgv.city_id,
#     dispatch.scan_uuid,
#     mgv.plangen_uuid,
#     mgv.job_uuid,
#     (mgv.request_ts_ms - created.timestamp)/1000 as time_since_creation,
#     dispatch.planactiontype,
#     mgv.supply_uuid,
#     case when dispatch.supplyuuid = mgv.supply_uuid then 1 else 0 end as is_selected,
#     mgv.eta,
#     mgv.adjustedeta,
#     mgv.ranking_metric,
#     mgv.d_proba,
#     mgv.r_proba,
#     mgv.s_proba,
#     mgv1.continuation_cr,
#     mgv.preferred_destination_adjustment,
#     mgv.of_value,
#     mgv.trip_length,
#     fare.est_rider_quoted_final_fare as fare
# from mgv
# join mgv1
# on mgv.job_uuid = mgv1.job_uuid
# and mgv.supply_uuid = mgv1.supply_uuid
# join created
# on mgv.job_uuid = created.jobuuid
# join plangen
# on mgv.plangen_uuid = plangen.plangen_uuid
# and mgv.job_uuid = plangen.job_uuid
# and mgv.supply_uuid = plangen.supplyuuid
# join dispatch
# on mgv.plangen_uuid = dispatch.plangen_uuid
# and mgv.job_uuid = dispatch.job_uuid
# join dwh.fact_trip_fare fare
# on mgv.job_uuid = fare.trip_uuid
# and fare.datestr = '2022-09-16'
# and fare.city_id = 1542
# )
# select * from test
# order by job_Uuid
# Loaded 14/14 dataframes from cache!

# %%
cdf.dfs
# Out:
# {'replay_city14_(940)_2022-09-16_segment0':           datestr  city_id                             scan_uuid  \
#  0      2022-09-16       14  0f50395f-a6ea-4b91-9571-e661a4564f40
#  1      2022-09-16       14  0f50395f-a6ea-4b91-9571-e661a4564f40
#  2      2022-09-16       14  0f50395f-a6ea-4b91-9571-e661a4564f40
#  3      2022-09-16       14  0f50395f-a6ea-4b91-9571-e661a4564f40
#  4      2022-09-16       14  0f50395f-a6ea-4b91-9571-e661a4564f40
#  ...           ...      ...                                   ...
#  10912  2022-09-16       14  0d372dbb-e94b-480d-b494-ee55e90c17dd
#  10913  2022-09-16       14  0d372dbb-e94b-480d-b494-ee55e90c17dd
#  10914  2022-09-16       14  0d372dbb-e94b-480d-b494-ee55e90c17dd
#  10915  2022-09-16       14  0d372dbb-e94b-480d-b494-ee55e90c17dd
#  10916  2022-09-16       14  0d372dbb-e94b-480d-b494-ee55e90c17dd
#
#                                 plangen_uuid  \
#  0      8a7d8159-2ef8-4590-913d-7816615a80d1
#  1      8a7d8159-2ef8-4590-913d-7816615a80d1
#  2      8a7d8159-2ef8-4590-913d-7816615a80d1
#  3      8a7d8159-2ef8-4590-913d-7816615a80d1
#  4      8a7d8159-2ef8-4590-913d-7816615a80d1
#  ...                                     ...
#  10912  76fa68d8-75e6-488d-b0a8-dc7570f11adf
#  10913  76fa68d8-75e6-488d-b0a8-dc7570f11adf
#  10914  76fa68d8-75e6-488d-b0a8-dc7570f11adf
#  10915  76fa68d8-75e6-488d-b0a8-dc7570f11adf
#  10916  76fa68d8-75e6-488d-b0a8-dc7570f11adf
#
#                                     job_uuid  time_since_creation  \
#  0      00252fe2-2392-46d9-b6d0-9407cc6a22a3                  200
#  1      00252fe2-2392-46d9-b6d0-9407cc6a22a3                  200
#  2      00252fe2-2392-46d9-b6d0-9407cc6a22a3                  200
#  3      00252fe2-2392-46d9-b6d0-9407cc6a22a3                  200
#  4      00252fe2-2392-46d9-b6d0-9407cc6a22a3                  200
#  ...                                     ...                  ...
#  10912  ffc93677-4abb-447e-a764-a5a9f5c17581                    2
#  10913  ffc93677-4abb-447e-a764-a5a9f5c17581                    2
#  10914  ffc93677-4abb-447e-a764-a5a9f5c17581                    2
#  10915  ffc93677-4abb-447e-a764-a5a9f5c17581                    2
#  10916  ffc93677-4abb-447e-a764-a5a9f5c17581                    2
#
#        planactiontype                           supply_uuid  is_selected  \
#  0         KEEP_ALIVE  5374d1f9-b63d-4781-bb62-e951b192f921            0
#  1         KEEP_ALIVE  6e561ecb-0b28-4b6e-aae0-8f1b74959ee9            0
#  2         KEEP_ALIVE  0ffc826b-f4ff-4e11-80b0-fc4b2fdf9435            0
#  3         KEEP_ALIVE  c1a1ce24-acbb-4227-91e8-2a582fc5e4ff            0
#  4         KEEP_ALIVE  57e217b0-6d66-4877-a9d6-fee1efff8282            0
#  ...              ...                                   ...          ...
#  10912          OFFER  2936dda5-a766-4cd7-978d-5dfa47500eda            0
#  10913          OFFER  40086a81-9d96-4edf-b1f2-1a2bcc7dc7b0            0
#  10914          OFFER  094993f6-689a-4dfe-848b-130757dac508            0
#  10915          OFFER  b1a41fb2-0af0-44eb-b54b-483f0758a29c            0
#  10916          OFFER  5086dfcc-7eb1-4ab6-adcd-c74f7d7f9988            0
#
#            eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0      1025.0         1025          1025.0   0.1047   0.5691   0.0084
#  1       854.0          854           854.0   0.7886   0.4728   0.0084
#  2      1208.0         1208          1208.0   0.1704   0.6828   0.0084
#  3      1442.0         1442          1442.0   0.2444   0.7199   0.0084
#  4      1349.0         1349          1349.0   0.1870   0.7199   0.0084
#  ...       ...          ...             ...      ...      ...      ...
#  10912  1055.0         1055          1055.0   0.1484   0.7256   0.0034
#  10913   681.0          681           681.0   0.4156   0.4047   0.0034
#  10914   603.0          603           603.0   0.1870   0.3503   0.0034
#  10915   638.0          638           638.0   0.0643   0.3559   0.0034
#  10916   642.0          642           642.0   0.1251   0.3700   0.0034
#
#         continuation_cr  preferred_destination_adjustment     of_value  \
#  0             0.497873                               0.0  1310.605093
#  1             0.511981                               0.0  1219.402096
#  2             0.426962                               0.0  1423.480325
#  3             0.451422                               0.0  1502.385763
#  4             0.454177                               0.0  1473.589395
#  ...                ...                               ...          ...
#  10912         0.469971                               0.0  1397.717627
#  10913         0.621831                               0.0  1062.553186
#  10914         0.646833                               0.0   945.951376
#  10915         0.644114                               0.0   961.272073
#  10916         0.653791                               0.0   981.458950
#
#         trip_length   fare
#  0            360.0  16.96
#  1            360.0  16.96
#  2            360.0  16.96
#  3            360.0  16.96
#  4            360.0  16.96
#  ...            ...    ...
#  10912        660.0  11.91
#  10913        660.0  11.91
#  10914        660.0  11.91
#  10915        660.0  11.91
#  10916        660.0  11.91
#
#  [10917 rows x 20 columns],
#  'replay_city5_(39)_2022-09-16_segment0':           datestr  city_id                             scan_uuid  \
#  0      2022-09-16        5  0a565d12-19d2-4404-b94d-96a1fe81f635
#  1      2022-09-16        5  0a565d12-19d2-4404-b94d-96a1fe81f635
#  2      2022-09-16        5  0a565d12-19d2-4404-b94d-96a1fe81f635
#  3      2022-09-16        5  0a565d12-19d2-4404-b94d-96a1fe81f635
#  4      2022-09-16        5  0a565d12-19d2-4404-b94d-96a1fe81f635
#  ...           ...      ...                                   ...
#  23896  2022-09-16        5  0f2e73a0-020f-43ab-83b2-0589055db112
#  23897  2022-09-16        5  0f2e73a0-020f-43ab-83b2-0589055db112
#  23898  2022-09-16        5  0f2e73a0-020f-43ab-83b2-0589055db112
#  23899  2022-09-16        5  0f2e73a0-020f-43ab-83b2-0589055db112
#  23900  2022-09-16        5  0f2e73a0-020f-43ab-83b2-0589055db112
#
#                                 plangen_uuid  \
#  0      42231959-ba79-4bf0-a73f-5854d17d91fe
#  1      42231959-ba79-4bf0-a73f-5854d17d91fe
#  2      42231959-ba79-4bf0-a73f-5854d17d91fe
#  3      42231959-ba79-4bf0-a73f-5854d17d91fe
#  4      42231959-ba79-4bf0-a73f-5854d17d91fe
#  ...                                     ...
#  23896  86fffd07-6832-4f23-9100-05ee7182539d
#  23897  86fffd07-6832-4f23-9100-05ee7182539d
#  23898  86fffd07-6832-4f23-9100-05ee7182539d
#  23899  86fffd07-6832-4f23-9100-05ee7182539d
#  23900  86fffd07-6832-4f23-9100-05ee7182539d
#
#                                     job_uuid  time_since_creation  \
#  0      00577378-a765-466d-9645-0aea2c9d68fd                   44
#  1      00577378-a765-466d-9645-0aea2c9d68fd                   44
#  2      00577378-a765-466d-9645-0aea2c9d68fd                   44
#  3      00577378-a765-466d-9645-0aea2c9d68fd                   44
#  4      00577378-a765-466d-9645-0aea2c9d68fd                   44
#  ...                                     ...                  ...
#  23896  ffbcf7ee-1219-4e02-bea4-930d1238af9d                    0
#  23897  ffbcf7ee-1219-4e02-bea4-930d1238af9d                    0
#  23898  ffbcf7ee-1219-4e02-bea4-930d1238af9d                    0
#  23899  ffbcf7ee-1219-4e02-bea4-930d1238af9d                    0
#  23900  ffbcf7ee-1219-4e02-bea4-930d1238af9d                    0
#
#        planactiontype                           supply_uuid  is_selected  \
#  0              OFFER  c97e9f86-9a38-4e2c-9d83-8e0fb22438b5            0
#  1              OFFER  533cf6d5-f81b-46ed-9387-17bfe72cf203            0
#  2              OFFER  50fa0e73-08e8-4963-8367-0407e6fe71c8            0
#  3              OFFER  fc745a3d-4c26-4eba-b487-f675ee3dfddc            0
#  4              OFFER  76b7af82-32c4-49db-bca4-d0216886b44d            0
#  ...              ...                                   ...          ...
#  23896          OFFER  6ace59e7-0d89-4cb3-90c3-203458b5718c            0
#  23897          OFFER  c3aeac7d-54c2-461e-a4c3-619a93e38335            0
#  23898          OFFER  e29f937e-1724-490d-adfe-7e998d78a42a            0
#  23899          OFFER  c76020d9-63a3-4238-824b-93519dcccdfb            0
#  23900          OFFER  83f9f0e7-b29c-43fe-9734-237e4ec4037b            0
#
#           eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0      778.0          778           778.0   0.3949   0.4856   0.0066
#  1      910.0          910           910.0   0.4901   0.5803   0.0066
#  2      886.0          886           886.0   0.5120   0.5691   0.0066
#  3      642.0          642           642.0   0.2882   0.3700   0.0066
#  4      839.0          839           839.0   0.3086   0.5328   0.0066
#  ...      ...          ...             ...      ...      ...      ...
#  23896  652.0          652           652.0   0.1666   0.2363   0.0028
#  23897  294.0          294           294.0   0.1493   0.0209   0.0028
#  23898  932.0          932           932.0   0.6742   0.4684   0.0028
#  23899  717.0          717           717.0   0.2196   0.2921   0.0028
#  23900  543.0          543           543.0   0.3004   0.1448   0.0028
#
#         continuation_cr  preferred_destination_adjustment  of_value  \
#  0             0.567019                               0.0  0.793095
#  1             0.561510                               0.0  0.855172
#  2             0.561510                               0.0  0.846924
#  3             0.596853                               0.0  0.691372
#  4             0.567019                               0.0  0.825334
#  ...                ...                               ...       ...
#  23896         0.684023                               0.0  0.632140
#  23897         0.787969                               0.0  0.276309
#  23898         0.585577                               0.0  0.831282
#  23899         0.614853                               0.0  0.695310
#  23900         0.708919                               0.0  0.537442
#
#         trip_length   fare
#  0            720.0  25.96
#  1            720.0  25.96
#  2            720.0  25.96
#  3            720.0  25.96
#  4            720.0  25.96
#  ...            ...    ...
#  23896       1320.0  20.42
#  23897       1320.0  20.42
#  23898       1320.0  20.42
#  23899       1320.0  20.42
#  23900       1320.0  20.42
#
#  [23901 rows x 20 columns],
#  'replay_city18_(285)_2022-09-16_segment0':           datestr  city_id                             scan_uuid  \
#  0      2022-09-16       18  0c9e3bb9-8a2a-4a0f-9d34-69f4cbc46715
#  1      2022-09-16       18  0c9e3bb9-8a2a-4a0f-9d34-69f4cbc46715
#  2      2022-09-16       18  0c9e3bb9-8a2a-4a0f-9d34-69f4cbc46715
#  3      2022-09-16       18  0c9e3bb9-8a2a-4a0f-9d34-69f4cbc46715
#  4      2022-09-16       18  0c9e3bb9-8a2a-4a0f-9d34-69f4cbc46715
#  ...           ...      ...                                   ...
#  31163  2022-09-16       18  0b39a8e1-b589-4fc7-a7b0-efe62490006d
#  31164  2022-09-16       18  0b39a8e1-b589-4fc7-a7b0-efe62490006d
#  31165  2022-09-16       18  0b39a8e1-b589-4fc7-a7b0-efe62490006d
#  31166  2022-09-16       18  0b39a8e1-b589-4fc7-a7b0-efe62490006d
#  31167  2022-09-16       18  0b39a8e1-b589-4fc7-a7b0-efe62490006d
#
#                                 plangen_uuid  \
#  0      c8998c42-d659-47dc-ba66-ec6c4fcde63d
#  1      c8998c42-d659-47dc-ba66-ec6c4fcde63d
#  2      c8998c42-d659-47dc-ba66-ec6c4fcde63d
#  3      c8998c42-d659-47dc-ba66-ec6c4fcde63d
#  4      c8998c42-d659-47dc-ba66-ec6c4fcde63d
#  ...                                     ...
#  31163  e0eb5fd7-a265-4472-b5b0-b1ede354c503
#  31164  e0eb5fd7-a265-4472-b5b0-b1ede354c503
#  31165  e0eb5fd7-a265-4472-b5b0-b1ede354c503
#  31166  e0eb5fd7-a265-4472-b5b0-b1ede354c503
#  31167  e0eb5fd7-a265-4472-b5b0-b1ede354c503
#
#                                     job_uuid  time_since_creation  \
#  0      005cc9b3-22c2-472e-9431-2453c553eb32                  109
#  1      005cc9b3-22c2-472e-9431-2453c553eb32                  109
#  2      005cc9b3-22c2-472e-9431-2453c553eb32                  109
#  3      005cc9b3-22c2-472e-9431-2453c553eb32                  109
#  4      005cc9b3-22c2-472e-9431-2453c553eb32                  109
#  ...                                     ...                  ...
#  31163  fff0c03c-d1d8-4f4d-9144-bf9fb0224f42                   22
#  31164  fff0c03c-d1d8-4f4d-9144-bf9fb0224f42                   22
#  31165  fff0c03c-d1d8-4f4d-9144-bf9fb0224f42                   22
#  31166  fff0c03c-d1d8-4f4d-9144-bf9fb0224f42                   22
#  31167  fff0c03c-d1d8-4f4d-9144-bf9fb0224f42                   22
#
#        planactiontype                           supply_uuid  is_selected  \
#  0              OFFER  bf1d056e-bcee-42c2-818e-63c0078979ec            0
#  1              OFFER  e32c9b15-41cc-4b2f-905a-9337007dfe56            0
#  2              OFFER  91026b99-6457-4077-b121-32d4e192938b            0
#  3              OFFER  36be07e8-e1c9-4dfa-beff-da54b801e016            1
#  4              OFFER  89723214-cb93-4716-8705-6590d477766c            0
#  ...              ...                                   ...          ...
#  31163          OFFER  601581c2-f9ef-4773-a9b4-f34290ed8c8c            0
#  31164          OFFER  6c26441e-9a45-495d-ab87-b47b429a3f72            0
#  31165          OFFER  806ca527-8d67-4fd0-90af-3e53bf09656f            0
#  31166          OFFER  a096a845-8b7f-42cd-b1fd-b24505d6c30a            0
#  31167          OFFER  d1771ff6-493b-4aac-a7c6-74f368955a18            0
#
#            eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0      1489.0         1489          1489.0      NaN      0.0   0.0067
#  1      1012.0         1012          1012.0      NaN      0.0   0.0067
#  2      1482.0         1482          1482.0      NaN      0.0   0.0067
#  3       772.0          772           772.0      NaN      0.0   0.0067
#  4       927.0          927           927.0      NaN      0.0   0.0067
#  ...       ...          ...             ...      ...      ...      ...
#  31163   553.0          553           553.0      NaN      0.0   0.0034
#  31164   832.0          832           832.0      NaN      0.0   0.0034
#  31165   789.0          789           789.0      NaN      0.0   0.0034
#  31166  1010.0         1010          1010.0      NaN      0.0   0.0034
#  31167  1168.0         1168          1168.0      NaN      0.0   0.0034
#
#         continuation_cr  preferred_destination_adjustment     of_value  \
#  0                  NaN                               0.0  1569.432170
#  1                  NaN                               0.0  1120.076303
#  2                  NaN                               0.0  1565.661931
#  3                  NaN                               0.0   840.688766
#  4                  NaN                               0.0  1026.813380
#  ...                ...                               ...          ...
#  31163              NaN                               0.0   601.468295
#  31164              NaN                               0.0   913.613868
#  31165              NaN                               0.0   872.926883
#  31166              NaN                               0.0  1126.630770
#  31167              NaN                               0.0  1313.183879
#
#         trip_length   fare
#  0           1560.0  13.39
#  1           1560.0  13.39
#  2           1560.0  13.39
#  3           1560.0  13.39
#  4           1560.0  13.39
#  ...            ...    ...
#  31163        360.0   6.69
#  31164        360.0   6.69
#  31165        360.0   6.69
#  31166        360.0   6.69
#  31167        360.0   6.69
#
#  [31168 rows x 20 columns],
#  'replay_city458_(3825)_2022-09-16_segment0':            datestr  city_id                             scan_uuid  \
#  0       2022-09-16      458  0871afe7-01d4-46cb-a95b-ff4a420f3721
#  1       2022-09-16      458  0871afe7-01d4-46cb-a95b-ff4a420f3721
#  2       2022-09-16      458  0871afe7-01d4-46cb-a95b-ff4a420f3721
#  3       2022-09-16      458  0871afe7-01d4-46cb-a95b-ff4a420f3721
#  4       2022-09-16      458  0871afe7-01d4-46cb-a95b-ff4a420f3721
#  ...            ...      ...                                   ...
#  295920  2022-09-16      458  0b6fe7f5-4b11-4110-a1fa-4bea0585b64d
#  295921  2022-09-16      458  0b6fe7f5-4b11-4110-a1fa-4bea0585b64d
#  295922  2022-09-16      458  0b6fe7f5-4b11-4110-a1fa-4bea0585b64d
#  295923  2022-09-16      458  0b6fe7f5-4b11-4110-a1fa-4bea0585b64d
#  295924  2022-09-16      458  0b6fe7f5-4b11-4110-a1fa-4bea0585b64d
#
#                                  plangen_uuid  \
#  0       0daa6f64-5842-4663-a689-9d9b3b437034
#  1       0daa6f64-5842-4663-a689-9d9b3b437034
#  2       0daa6f64-5842-4663-a689-9d9b3b437034
#  3       0daa6f64-5842-4663-a689-9d9b3b437034
#  4       0daa6f64-5842-4663-a689-9d9b3b437034
#  ...                                      ...
#  295920  9bb285f8-697d-4532-83a6-43a0afe70053
#  295921  9bb285f8-697d-4532-83a6-43a0afe70053
#  295922  9bb285f8-697d-4532-83a6-43a0afe70053
#  295923  9bb285f8-697d-4532-83a6-43a0afe70053
#  295924  9bb285f8-697d-4532-83a6-43a0afe70053
#
#                                      job_uuid  time_since_creation  \
#  0       0008ee74-00ec-437c-ba9f-8f8bc966335b                  173
#  1       0008ee74-00ec-437c-ba9f-8f8bc966335b                  173
#  2       0008ee74-00ec-437c-ba9f-8f8bc966335b                  173
#  3       0008ee74-00ec-437c-ba9f-8f8bc966335b                  173
#  4       0008ee74-00ec-437c-ba9f-8f8bc966335b                  173
#  ...                                      ...                  ...
#  295920  fffb5ffd-4c9c-495f-9393-ec2f7353044f                  149
#  295921  fffb5ffd-4c9c-495f-9393-ec2f7353044f                  149
#  295922  fffb5ffd-4c9c-495f-9393-ec2f7353044f                  149
#  295923  fffb5ffd-4c9c-495f-9393-ec2f7353044f                  149
#  295924  fffb5ffd-4c9c-495f-9393-ec2f7353044f                  149
#
#         planactiontype                           supply_uuid  is_selected  \
#  0               OFFER  a259df5d-3860-4118-b19b-842e0c69410f            0
#  1               OFFER  33f7398f-4772-4cc4-95e2-eb4f56527be0            0
#  2               OFFER  f71b5409-b472-4f3c-979e-6237c2f4fa5d            0
#  3               OFFER  35a14495-f672-4c87-ae37-a6a2d66a9fc0            0
#  4               OFFER  39595575-9249-43d7-97cd-4b090589a756            0
#  ...               ...                                   ...          ...
#  295920          OFFER  f4bffd80-4243-4f7f-9074-e80d255810ab            0
#  295921          OFFER  f9ef7f52-ba6d-4649-a8c6-24dcf502bff8            1
#  295922          OFFER  e0834c0d-2be6-42fa-a65a-e33cd2ae5520            0
#  295923          OFFER  50ccb042-e2cd-42ba-b369-94f576d442f3            0
#  295924          OFFER  a70fdb75-5b6f-4fa6-b354-859ada1a29ee            0
#
#             eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0        605.0          575           575.0   0.9935   0.2140   0.0139
#  1        719.0          719           719.0   0.8454   0.2871   0.0139
#  2        652.0          652           652.0   0.9065   0.2402   0.0139
#  3        362.0          362           362.0   0.9383   0.0760   0.0139
#  4        774.0          774           774.0   0.6908   0.3072   0.0139
#  ...        ...          ...             ...      ...      ...      ...
#  295920   976.0          976           976.0   0.5868   0.2030   0.0139
#  295921   377.0          377           377.0   0.6084   0.0516   0.0139
#  295922   472.0          472           472.0   0.8570   0.0740   0.0139
#  295923   752.0          752           752.0   0.9165   0.1210   0.0139
#  295924  1004.0         1004          1004.0   0.4872   0.2070   0.0139
#
#          continuation_cr  preferred_destination_adjustment     of_value  \
#  0              0.596853                              30.0   894.744314
#  1              0.311281                               0.0  1039.277629
#  2              0.580921                               0.0   962.621712
#  3              0.339735                               0.0   584.399147
#  4              0.469971                               0.0  1077.686599
#  ...                 ...                               ...          ...
#  295920         0.533217                               0.0  1199.367932
#  295921         0.716090                               0.0   545.582948
#  295922         0.682205                               0.0   685.611186
#  295923         0.583258                               0.0  1002.834354
#  295924         0.513450                               0.0  1203.421968
#
#          trip_length   fare
#  0             660.0  39.92
#  1             660.0  39.92
#  2             660.0  39.92
#  3             660.0  39.92
#  4             660.0  39.92
#  ...             ...    ...
#  295920       4560.0  49.94
#  295921       4560.0  49.94
#  295922       4560.0  49.94
#  295923       4560.0  49.94
#  295924       4560.0  49.94
#
#  [295925 rows x 20 columns],
#  'replay_city7_(180)_2022-09-16_segment0':          datestr  city_id                             scan_uuid  \
#  0     2022-09-16        7  0ea0cd5b-1a64-47d0-bd87-e293f8952edd
#  1     2022-09-16        7  0ea0cd5b-1a64-47d0-bd87-e293f8952edd
#  2     2022-09-16        7  0ea0cd5b-1a64-47d0-bd87-e293f8952edd
#  3     2022-09-16        7  0ea0cd5b-1a64-47d0-bd87-e293f8952edd
#  4     2022-09-16        7  0ea0cd5b-1a64-47d0-bd87-e293f8952edd
#  ...          ...      ...                                   ...
#  3728  2022-09-16        7  0ea0cd5b-1a64-47d0-bd87-e293f8952edd
#  3729  2022-09-16        7  09a8095e-e47c-470c-a625-297526c20a22
#  3730  2022-09-16        7  0ea0cd5b-1a64-47d0-bd87-e293f8952edd
#  3731  2022-09-16        7  0ea0cd5b-1a64-47d0-bd87-e293f8952edd
#  3732  2022-09-16        7  0ea0cd5b-1a64-47d0-bd87-e293f8952edd
#
#                                plangen_uuid  \
#  0     74d92e08-ff10-41e8-89d9-5a9892625a0e
#  1     74d92e08-ff10-41e8-89d9-5a9892625a0e
#  2     74d92e08-ff10-41e8-89d9-5a9892625a0e
#  3     74d92e08-ff10-41e8-89d9-5a9892625a0e
#  4     74d92e08-ff10-41e8-89d9-5a9892625a0e
#  ...                                    ...
#  3728  6649e4df-fc6b-4c06-809e-d28920d596af
#  3729  b51f1909-656f-4338-8205-5689559253d3
#  3730  dce18785-5b28-4f73-a776-0e0606e9127b
#  3731  dce18785-5b28-4f73-a776-0e0606e9127b
#  3732  dce18785-5b28-4f73-a776-0e0606e9127b
#
#                                    job_uuid  time_since_creation  \
#  0     008cf5b0-f9d3-4b03-8c60-0b9dd1152c40                  204
#  1     008cf5b0-f9d3-4b03-8c60-0b9dd1152c40                  204
#  2     008cf5b0-f9d3-4b03-8c60-0b9dd1152c40                  204
#  3     008cf5b0-f9d3-4b03-8c60-0b9dd1152c40                  204
#  4     008cf5b0-f9d3-4b03-8c60-0b9dd1152c40                  204
#  ...                                    ...                  ...
#  3728  fe9dd65f-0c59-4c7d-82c6-41c335082a12                   49
#  3729  feb82d11-49d3-4b6a-8eb2-1789f85ee3f7                   47
#  3730  fed52864-febf-4df4-b44e-7b6225c46db4                  567
#  3731  fed52864-febf-4df4-b44e-7b6225c46db4                  567
#  3732  fed52864-febf-4df4-b44e-7b6225c46db4                  567
#
#       planactiontype                           supply_uuid  is_selected  \
#  0        KEEP_ALIVE  f47b2192-0856-4436-b4cd-2aac00c9beb6            0
#  1        KEEP_ALIVE  85a6d3e1-01c8-4f14-9dbf-a6a53b8185ac            0
#  2        KEEP_ALIVE  01e0eba7-d85a-4076-85c7-af1959efd162            0
#  3        KEEP_ALIVE  3259394e-d827-4e1d-8fbe-7cb2896a2097            0
#  4        KEEP_ALIVE  6a4cca50-edbc-4371-b6ac-d4902c01f31a            0
#  ...             ...                                   ...          ...
#  3728     KEEP_ALIVE  3259394e-d827-4e1d-8fbe-7cb2896a2097            0
#  3729     KEEP_ALIVE  745a3020-c015-496f-9d68-13e7e7b021d9            0
#  3730          OFFER  97e161e9-6944-4146-9689-883bf64bee62            0
#  3731          OFFER  b07b5bbb-8d57-4289-a4e4-4b7b6c422eda            1
#  3732          OFFER  57750042-973a-4d9f-90bb-e7939c5157b4            0
#
#           eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0     1352.0         1352          1352.0   0.8264   0.2092   0.0049
#  1     1328.0         1328          1328.0   0.4379   0.2544   0.0049
#  2     1481.0         1481          1481.0   0.1882   0.2580   0.0049
#  3      890.0          890           890.0   0.6348   0.1204   0.0049
#  4     1276.0         1276          1276.0   0.7886   0.2305   0.0049
#  ...      ...          ...             ...      ...      ...      ...
#  3728   900.0          900           900.0   0.6219   0.1058   0.0088
#  3729  1458.0         1458          1458.0   0.6348   0.2624   0.0086
#  3730  1245.0         1245          1245.0   0.5727   0.2694   0.0049
#  3731   422.0          422           422.0   0.0812   0.0548   0.0049
#  3732  1010.0         1010          1010.0   0.6879   0.1567   0.0049
#
#        continuation_cr  preferred_destination_adjustment  of_value  \
#  0            0.670815                               0.0  0.963515
#  1            0.636180                               0.0  0.953738
#  2            0.624246                               0.0  0.996941
#  3            0.690061                               0.0  0.754518
#  4            0.652407                               0.0  0.938884
#  ...               ...                               ...       ...
#  3728         0.738377                               0.0  0.750781
#  3729         0.694296                               0.0  0.991882
#  3730         0.624246                               0.0  0.926896
#  3731         0.724428                               0.0  0.386419
#  3732         0.670486                               0.0  0.821099
#
#        trip_length   fare
#  0          2400.0  55.48
#  1          2400.0  55.48
#  2          2400.0  55.48
#  3          2400.0  55.48
#  4          2400.0  55.48
#  ...           ...    ...
#  3728        840.0  14.94
#  3729       2220.0  31.99
#  3730        300.0   5.80
#  3731        300.0   5.80
#  3732        300.0   5.80
#
#  [3733 rows x 20 columns],
#  'replay_city12_(125)_2022-09-16_segment0':           datestr  city_id                             scan_uuid  \
#  0      2022-09-16       12  02150b7d-1dbc-4c32-a14d-0efce1454b63
#  1      2022-09-16       12  04572848-b12b-4a9e-8c4c-64b0b779f999
#  2      2022-09-16       12  04572848-b12b-4a9e-8c4c-64b0b779f999
#  3      2022-09-16       12  04572848-b12b-4a9e-8c4c-64b0b779f999
#  4      2022-09-16       12  08dd9ca9-b178-46c3-bf9c-647eb787aa65
#  ...           ...      ...                                   ...
#  10421  2022-09-16       12  095d9cb4-7a7e-4560-b67b-9d21ea3e2e6f
#  10422  2022-09-16       12  095d9cb4-7a7e-4560-b67b-9d21ea3e2e6f
#  10423  2022-09-16       12  02150b7d-1dbc-4c32-a14d-0efce1454b63
#  10424  2022-09-16       12  02150b7d-1dbc-4c32-a14d-0efce1454b63
#  10425  2022-09-16       12  02150b7d-1dbc-4c32-a14d-0efce1454b63
#
#                                 plangen_uuid  \
#  0      c0de59a7-af20-49ea-9c5b-fec366c5b7db
#  1      0d5330a9-dc60-4892-90fb-edc1e5ed8a64
#  2      0d5330a9-dc60-4892-90fb-edc1e5ed8a64
#  3      0d5330a9-dc60-4892-90fb-edc1e5ed8a64
#  4      05f85b5d-0121-4830-b378-e1c3a7494ab8
#  ...                                     ...
#  10421  42357e4b-611e-4d53-b26d-11c6e6fb4691
#  10422  42357e4b-611e-4d53-b26d-11c6e6fb4691
#  10423  04fd5216-a70b-4782-ae7d-2cc321f73b4c
#  10424  04fd5216-a70b-4782-ae7d-2cc321f73b4c
#  10425  04fd5216-a70b-4782-ae7d-2cc321f73b4c
#
#                                     job_uuid  time_since_creation  \
#  0      004a9d92-cf74-4501-b3fe-b146ba86df71                  424
#  1      00524107-530b-4368-b613-d6efc029db0f                 1342
#  2      00524107-530b-4368-b613-d6efc029db0f                 1342
#  3      00524107-530b-4368-b613-d6efc029db0f                 1342
#  4      006c88f1-9e89-44fc-a703-b4e770437f72                   19
#  ...                                     ...                  ...
#  10421  ff99371f-3acf-481e-972b-e764b673cd9d                  699
#  10422  ff99371f-3acf-481e-972b-e764b673cd9d                  699
#  10423  ffa72d96-07c2-4fc7-a349-f02b1cccc1b1                  114
#  10424  ffa72d96-07c2-4fc7-a349-f02b1cccc1b1                  114
#  10425  ffa72d96-07c2-4fc7-a349-f02b1cccc1b1                  114
#
#        planactiontype                           supply_uuid  is_selected  \
#  0         KEEP_ALIVE  3403a987-5211-48af-8115-ed96371f6faa            0
#  1         KEEP_ALIVE  d2308a61-2ee4-41b2-aa10-cc5c14de800f            0
#  2         KEEP_ALIVE  fed190e7-1123-4eaa-90be-91d90009cabb            0
#  3         KEEP_ALIVE  f658d988-bfc5-4eaf-916c-e2176fd29916            0
#  4         KEEP_ALIVE  e80e2426-ec43-47b0-a67b-1a4203220209            0
#  ...              ...                                   ...          ...
#  10421     KEEP_ALIVE  2374fe17-9bec-43f9-9636-e5dab1be9a2d            0
#  10422     KEEP_ALIVE  bb8c6f45-4272-46fc-bc17-90b0ff880471            0
#  10423     KEEP_ALIVE  4e0d0ee1-e04c-4233-af00-1fb3247fbb2a            0
#  10424     KEEP_ALIVE  6bbc6b62-0e32-4fc6-bdf6-508739ad9fc2            0
#  10425     KEEP_ALIVE  c8527969-f29e-415e-a3a6-024eae8fa3c8            0
#
#            eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0      1289.0         1289          1289.0   0.2117   0.2695   0.0268
#  1      1441.0         1441          1441.0   0.3975   0.0524   0.0268
#  2      1301.0         1301          1301.0   0.3172   0.0496   0.0268
#  3      1214.0         1214          1214.0   0.1276   0.0415   0.0268
#  4       949.0          859           859.0   0.5254   0.2789   0.0064
#  ...       ...          ...             ...      ...      ...      ...
#  10421   979.0          979           979.0   0.3341   0.0383   0.0268
#  10422  1160.0         1160          1160.0   0.0972   0.0529   0.0268
#  10423  1382.0         1382          1382.0   0.3949   0.3233   0.0260
#  10424   901.0          901           901.0   0.7886   0.1419   0.0260
#  10425  1263.0         1263          1263.0   0.1768   0.2846   0.0260
#
#         continuation_cr  preferred_destination_adjustment  of_value  \
#  0             0.611213                               0.0  0.939650
#  1             0.760879                               0.0  0.984702
#  2             0.773041                               0.0  0.928558
#  3             0.782422                               0.0  0.882452
#  4             0.628545                              90.0  0.770138
#  ...                ...                               ...       ...
#  10421         0.792349                               0.0  0.760121
#  10422         0.774807                               0.0  0.854670
#  10423         0.695179                               0.0  0.972539
#  10424         0.684023                               0.0  0.775121
#  10425         0.687918                               0.0  0.929975
#
#         trip_length   fare
#  0           3540.0  54.92
#  1           2220.0  59.88
#  2           2220.0  59.88
#  3           2220.0  59.88
#  4            240.0  15.29
#  ...            ...    ...
#  10421       1500.0  46.40
#  10422       1500.0  46.40
#  10423       2820.0  59.96
#  10424       2820.0  59.96
#  10425       2820.0  59.96
#
#  [10426 rows x 20 columns],
#  'replay_city90_(651)_2022-09-16_segment0':           datestr  city_id                             scan_uuid  \
#  0      2022-09-16       90  00b21333-4784-4742-a9c0-1a3888f1ccbb
#  1      2022-09-16       90  00b21333-4784-4742-a9c0-1a3888f1ccbb
#  2      2022-09-16       90  00b21333-4784-4742-a9c0-1a3888f1ccbb
#  3      2022-09-16       90  00b21333-4784-4742-a9c0-1a3888f1ccbb
#  4      2022-09-16       90  00b21333-4784-4742-a9c0-1a3888f1ccbb
#  ...           ...      ...                                   ...
#  79268  2022-09-16       90  0692e93a-3838-4d4e-8298-f15cc4c435c0
#  79269  2022-09-16       90  0692e93a-3838-4d4e-8298-f15cc4c435c0
#  79270  2022-09-16       90  0692e93a-3838-4d4e-8298-f15cc4c435c0
#  79271  2022-09-16       90  0692e93a-3838-4d4e-8298-f15cc4c435c0
#  79272  2022-09-16       90  0692e93a-3838-4d4e-8298-f15cc4c435c0
#
#                                 plangen_uuid  \
#  0      d8afcecf-1937-4b0a-b071-c6b38f5d6f36
#  1      d8afcecf-1937-4b0a-b071-c6b38f5d6f36
#  2      d8afcecf-1937-4b0a-b071-c6b38f5d6f36
#  3      d8afcecf-1937-4b0a-b071-c6b38f5d6f36
#  4      d8afcecf-1937-4b0a-b071-c6b38f5d6f36
#  ...                                     ...
#  79268  46efca29-9f65-4c8a-bf04-7ad4e49dd5f8
#  79269  46efca29-9f65-4c8a-bf04-7ad4e49dd5f8
#  79270  46efca29-9f65-4c8a-bf04-7ad4e49dd5f8
#  79271  46efca29-9f65-4c8a-bf04-7ad4e49dd5f8
#  79272  46efca29-9f65-4c8a-bf04-7ad4e49dd5f8
#
#                                     job_uuid  time_since_creation  \
#  0      0006ff85-34ef-4229-b24c-bbc57532476a                  117
#  1      0006ff85-34ef-4229-b24c-bbc57532476a                  117
#  2      0006ff85-34ef-4229-b24c-bbc57532476a                  117
#  3      0006ff85-34ef-4229-b24c-bbc57532476a                  117
#  4      0006ff85-34ef-4229-b24c-bbc57532476a                  117
#  ...                                     ...                  ...
#  79268  fffffabb-d8b6-4f9e-8fe6-ff64126a88d8                   87
#  79269  fffffabb-d8b6-4f9e-8fe6-ff64126a88d8                   87
#  79270  fffffabb-d8b6-4f9e-8fe6-ff64126a88d8                   87
#  79271  fffffabb-d8b6-4f9e-8fe6-ff64126a88d8                   87
#  79272  fffffabb-d8b6-4f9e-8fe6-ff64126a88d8                   87
#
#        planactiontype                           supply_uuid  is_selected  \
#  0              OFFER  ed6c43d8-10fb-43ab-847d-06b7b0189bca            0
#  1              OFFER  c41aab7a-6daa-4073-a92d-be3ee7ab3c48            0
#  2              OFFER  2f44384d-6663-4efd-b952-24dea80acfd0            0
#  3              OFFER  f62a9fee-f7ce-4de6-9166-b62373db5abb            0
#  4              OFFER  3be858b5-1380-47f8-99e8-ef0da7040390            0
#  ...              ...                                   ...          ...
#  79268     KEEP_ALIVE  d69bf085-b4ab-4e61-9fff-d3ad7041df9e            0
#  79269     KEEP_ALIVE  17a3b950-0f76-474f-abec-5ae20e45dcc1            0
#  79270     KEEP_ALIVE  9b284217-d7b4-46fe-9674-273ba972c8f1            0
#  79271     KEEP_ALIVE  0d1c928c-f2c2-464c-a835-b38f864b690d            0
#  79272     KEEP_ALIVE  d4eb8801-ef91-4c32-9967-e58a6eeb7eab            0
#
#            eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0      1186.0         1186          1186.0   0.9256   0.3355   0.0101
#  1       843.0          843           843.0   0.6024   0.2246   0.0101
#  2       350.0          350           350.0   0.9827   0.1186   0.0101
#  3       559.0          559           559.0   0.9921   0.1548   0.0101
#  4      1195.0         1105          1105.0   0.4144   0.4181   0.0101
#  ...       ...          ...             ...      ...      ...      ...
#  79268  1288.0         1288          1288.0   0.6922   0.5453   0.0108
#  79269   839.0          839           839.0   0.8679   0.2305   0.0108
#  79270  1080.0         1080          1080.0   0.4121   0.3931   0.0108
#  79271  1245.0          345           345.0   0.6797   0.5254   0.0108
#  79272  1158.0         1158          1158.0   0.7845   0.4293   0.0108
#
#         continuation_cr  preferred_destination_adjustment     of_value  \
#  0             0.379668                               0.0  1385.870276
#  1             0.428912                               0.0  1061.671914
#  2             0.375584                               0.0   605.048733
#  3             0.397964                               0.0   816.917531
#  4             0.410203                              90.0  1317.592504
#  ...                ...                               ...          ...
#  79268         0.636180                               0.0  1468.403343
#  79269         0.706232                               0.0  1089.772468
#  79270         0.672448                               0.0  1293.507470
#  79271         0.533747                               0.0  1075.817764
#  79272         0.571645                               0.0  1388.008875
#
#         trip_length    fare
#  0           2640.0  249.99
#  1           2640.0  249.99
#  2           2640.0  249.99
#  3           2640.0  249.99
#  4           2640.0  249.99
#  ...            ...     ...
#  79268        900.0   79.92
#  79269        900.0   79.92
#  79270        900.0   79.92
#  79271        900.0   79.92
#  79272        900.0   79.92
#
#  [79273 rows x 20 columns],
#  'replay_city39_(539)_2022-09-16_segment0':           datestr  city_id                             scan_uuid  \
#  0      2022-09-16       39  0adcf9c4-1c78-4143-9851-30204d775c99
#  1      2022-09-16       39  0adcf9c4-1c78-4143-9851-30204d775c99
#  2      2022-09-16       39  0adcf9c4-1c78-4143-9851-30204d775c99
#  3      2022-09-16       39  0adcf9c4-1c78-4143-9851-30204d775c99
#  4      2022-09-16       39  0adcf9c4-1c78-4143-9851-30204d775c99
#  ...           ...      ...                                   ...
#  17794  2022-09-16       39  0cac88a9-41d2-4d73-86d6-5c69160b6825
#  17795  2022-09-16       39  0cac88a9-41d2-4d73-86d6-5c69160b6825
#  17796  2022-09-16       39  0cac88a9-41d2-4d73-86d6-5c69160b6825
#  17797  2022-09-16       39  0cac88a9-41d2-4d73-86d6-5c69160b6825
#  17798  2022-09-16       39  0cac88a9-41d2-4d73-86d6-5c69160b6825
#
#                                 plangen_uuid  \
#  0      2e4eb49f-58bf-4110-99c8-e3c344aa6429
#  1      2e4eb49f-58bf-4110-99c8-e3c344aa6429
#  2      2e4eb49f-58bf-4110-99c8-e3c344aa6429
#  3      2e4eb49f-58bf-4110-99c8-e3c344aa6429
#  4      2e4eb49f-58bf-4110-99c8-e3c344aa6429
#  ...                                     ...
#  17794  b2dc0ee5-ec98-4da0-ae67-443225c0ccb1
#  17795  b2dc0ee5-ec98-4da0-ae67-443225c0ccb1
#  17796  b2dc0ee5-ec98-4da0-ae67-443225c0ccb1
#  17797  b2dc0ee5-ec98-4da0-ae67-443225c0ccb1
#  17798  b2dc0ee5-ec98-4da0-ae67-443225c0ccb1
#
#                                     job_uuid  time_since_creation  \
#  0      006afff2-8a84-48b5-8d67-4c256df2ed27                    0
#  1      006afff2-8a84-48b5-8d67-4c256df2ed27                    0
#  2      006afff2-8a84-48b5-8d67-4c256df2ed27                    0
#  3      006afff2-8a84-48b5-8d67-4c256df2ed27                    0
#  4      006afff2-8a84-48b5-8d67-4c256df2ed27                    0
#  ...                                     ...                  ...
#  17794  fee80ce5-a7bb-4e9c-ab17-8ed671255cd3                   74
#  17795  fee80ce5-a7bb-4e9c-ab17-8ed671255cd3                   74
#  17796  fee80ce5-a7bb-4e9c-ab17-8ed671255cd3                   74
#  17797  fee80ce5-a7bb-4e9c-ab17-8ed671255cd3                   74
#  17798  fee80ce5-a7bb-4e9c-ab17-8ed671255cd3                   74
#
#        planactiontype                           supply_uuid  is_selected  \
#  0              OFFER  411810d6-6a75-496c-a108-46b1d5e7ed5a            0
#  1              OFFER  faf04233-a075-4c99-8079-799f1d7aa564            0
#  2              OFFER  51a36341-c0e2-4347-aee2-4b9a5a58fd6b            0
#  3              OFFER  3ccccdee-265c-4b75-903b-82454f697ec2            0
#  4              OFFER  fac11bff-4993-442e-baf8-db68953af482            0
#  ...              ...                                   ...          ...
#  17794          OFFER  bcba44a4-b91d-4d33-9ce3-148c8e333469            0
#  17795          OFFER  d68d49ff-5c4c-4dd4-b153-da51d8448fe9            0
#  17796          OFFER  3b6424f1-224d-49f1-9a36-39f52a98aba1            0
#  17797          OFFER  ea22f057-b870-4aa9-91c8-bd88bcb8ba1c            0
#  17798          OFFER  aae88139-4096-4ee6-ae05-6f582bbdd230            0
#
#            eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0       357.0          357           357.0   0.1276   0.1220   0.0048
#  1       717.0          717           717.0   0.3621   0.3790   0.0048
#  2       338.0          338           338.0   0.1816   0.0935   0.0048
#  3       695.0          695           695.0   0.6245   0.4187   0.0048
#  4      1229.0         1229          1229.0   0.4144   0.7256   0.0048
#  ...       ...          ...             ...      ...      ...      ...
#  17794   723.0          723           723.0   0.3060   0.6471   0.0180
#  17795   458.0          458           458.0   0.6522   0.4187   0.0180
#  17796   645.0          645           645.0   0.8247   0.6222   0.0180
#  17797   387.0          387           387.0   0.8900   0.3307   0.0180
#  17798   197.0          197           197.0   0.9920   0.1845   0.0180
#
#         continuation_cr  preferred_destination_adjustment     of_value  \
#  0             0.698703                               0.0   529.051362
#  1             0.590495                               0.0  1060.034393
#  2             0.718975                               0.0   487.154861
#  3             0.575175                               0.0  1101.438239
#  4             0.517247                               0.0  1456.549727
#  ...                ...                               ...          ...
#  17794         0.326297                               0.0  1277.370823
#  17795         0.477321                               0.0  1035.075207
#  17796         0.354286                               0.0  1295.324033
#  17797         0.432316                               0.0   962.680979
#  17798         0.567019                               0.0   714.414452
#
#         trip_length   fare
#  0            480.0  20.33
#  1            480.0  20.33
#  2            480.0  20.33
#  3            480.0  20.33
#  4            480.0  20.33
#  ...            ...    ...
#  17794        540.0  11.06
#  17795        540.0  11.06
#  17796        540.0  11.06
#  17797        540.0  11.06
#  17798        540.0  11.06
#
#  [17799 rows x 20 columns],
#  'replay_city143_(9697)_2022-09-16_segment0':         datestr  city_id                             scan_uuid  \
#  0    2022-09-16      143  0bb1c750-1b25-4724-afe8-c6d7f8c95abf
#  1    2022-09-16      143  0bb1c750-1b25-4724-afe8-c6d7f8c95abf
#  2    2022-09-16      143  0bb1c750-1b25-4724-afe8-c6d7f8c95abf
#  3    2022-09-16      143  0bb1c750-1b25-4724-afe8-c6d7f8c95abf
#  4    2022-09-16      143  0bb1c750-1b25-4724-afe8-c6d7f8c95abf
#  ..          ...      ...                                   ...
#  847  2022-09-16      143  0fb62bee-d4dc-4747-bd8c-718811621538
#  848  2022-09-16      143  0fb62bee-d4dc-4747-bd8c-718811621538
#  849  2022-09-16      143  0fb62bee-d4dc-4747-bd8c-718811621538
#  850  2022-09-16      143  0ce1ec58-cae9-4a23-ae77-5a6d2ab37312
#  851  2022-09-16      143  0ce1ec58-cae9-4a23-ae77-5a6d2ab37312
#
#                               plangen_uuid  \
#  0    ae2d478f-064f-4371-ad60-6af57ac61941
#  1    ae2d478f-064f-4371-ad60-6af57ac61941
#  2    ae2d478f-064f-4371-ad60-6af57ac61941
#  3    ae2d478f-064f-4371-ad60-6af57ac61941
#  4    ae2d478f-064f-4371-ad60-6af57ac61941
#  ..                                    ...
#  847  2167a1f9-db9b-48d2-bfce-6646de17a76f
#  848  2167a1f9-db9b-48d2-bfce-6646de17a76f
#  849  2167a1f9-db9b-48d2-bfce-6646de17a76f
#  850  8bde0d5a-40c9-433a-a7ff-c996eaa3e454
#  851  8bde0d5a-40c9-433a-a7ff-c996eaa3e454
#
#                                   job_uuid  time_since_creation planactiontype  \
#  0    0a080959-c35c-4e8d-aadb-42f6699e301b                    0          OFFER
#  1    0a080959-c35c-4e8d-aadb-42f6699e301b                    0          OFFER
#  2    0a080959-c35c-4e8d-aadb-42f6699e301b                    0          OFFER
#  3    0a080959-c35c-4e8d-aadb-42f6699e301b                    0          OFFER
#  4    0a080959-c35c-4e8d-aadb-42f6699e301b                    0          OFFER
#  ..                                    ...                  ...            ...
#  847  f3dfc141-5d68-4fd4-89f8-a1c693d90695                    0          OFFER
#  848  f3dfc141-5d68-4fd4-89f8-a1c693d90695                    0          OFFER
#  849  f3dfc141-5d68-4fd4-89f8-a1c693d90695                    0          OFFER
#  850  f8ed3beb-c6bf-4ef9-a5d1-a5445de4fc26                   37     KEEP_ALIVE
#  851  f8ed3beb-c6bf-4ef9-a5d1-a5445de4fc26                   37     KEEP_ALIVE
#
#                                supply_uuid  is_selected    eta  adjustedeta  \
#  0    ebcda2dc-308f-4741-882b-0e9394f89004            0  530.0          530
#  1    3bfac14c-6a71-4ed9-bf3f-fc97d273ec8a            0  251.0          221
#  2    b99f933d-b3f4-4ba9-96fa-0c71d5b8a6be            0  487.0          487
#  3    b490206d-697d-419e-8b0a-9acee3b019a7            0  622.0          622
#  4    2fd25f34-3847-4caf-a4d0-cedca7b2affe            0  758.0          758
#  ..                                    ...          ...    ...          ...
#  847  6e3539f1-e9e5-455a-be48-e9490f1ca799            0  128.0          128
#  848  ee266a92-5f47-40a8-a3d8-0949f780d37f            0  524.0          524
#  849  e6c74828-1306-4a9a-a592-8e8336b46dbb            0  368.0          368
#  850  30121bf9-3f12-4ee2-b715-a99240c808fa            0  740.0          740
#  851  00d190df-342b-4899-84e3-1ad872fb7ece            0  708.0          708
#
#       ranking_metric  d_proba  r_proba  s_proba  continuation_cr  \
#  0             530.0   0.2662   0.2140   0.0016         0.434920
#  1             221.0   0.1467   0.0508   0.0016         0.641328
#  2             487.0   0.8898   0.1720   0.0016         0.476539
#  3             622.0   0.8647   0.2555   0.0016         0.414301
#  4             758.0   0.2506   0.3385   0.0016         0.395591
#  ..              ...      ...      ...      ...              ...
#  847           128.0   0.0812   0.0221   0.0016         0.841624
#  848           524.0   0.3773   0.2544   0.0016         0.614853
#  849           368.0   0.1264   0.1002   0.0016         0.713955
#  850           740.0   0.6786   0.3112   0.0116         0.502426
#  851           708.0   0.0590   0.2957   0.0116         0.543189
#
#       preferred_destination_adjustment     of_value  trip_length    fare
#  0                                 0.0   769.935530        840.0  201.25
#  1                                30.0   309.861181        840.0  201.25
#  2                                 0.0   752.055450        840.0  201.25
#  3                                 0.0   937.554702        840.0  201.25
#  4                                 0.0  1042.373390        840.0  201.25
#  ..                                ...          ...          ...     ...
#  847                               0.0   176.838104        720.0  130.78
#  848                               0.0   812.909394        720.0  130.78
#  849                               0.0   502.865498        720.0  130.78
#  850                               0.0  1056.489353       1260.0  306.24
#  851                               0.0   967.437060       1260.0  306.24
#
#  [852 rows x 20 columns],
#  'replay_city16_(7423)_2022-09-16_segment0':          datestr  city_id                             scan_uuid  \
#  0     2022-09-16       16  006681d7-cf04-4293-81c7-499008f2c9b4
# ...
#  46929        660.0  3952.0
#  46930        660.0  3952.0
#
#  [46931 rows x 20 columns],
#  'replay_city531_(1964)_2022-09-16_segment0':           datestr  city_id                             scan_uuid  \
#  0      2022-09-16      531  0abb68f3-cc4e-414e-bf3e-f544157960a4
#  1      2022-09-16      531  0abb68f3-cc4e-414e-bf3e-f544157960a4
#  2      2022-09-16      531  0abb68f3-cc4e-414e-bf3e-f544157960a4
#  3      2022-09-16      531  0abb68f3-cc4e-414e-bf3e-f544157960a4
#  4      2022-09-16      531  0abb68f3-cc4e-414e-bf3e-f544157960a4
#  ...           ...      ...                                   ...
#  10701  2022-09-16      531  0da4a496-0440-4636-aebc-d51fa94f5149
#  10702  2022-09-16      531  0da4a496-0440-4636-aebc-d51fa94f5149
#  10703  2022-09-16      531  0da4a496-0440-4636-aebc-d51fa94f5149
#  10704  2022-09-16      531  0da4a496-0440-4636-aebc-d51fa94f5149
#  10705  2022-09-16      531  0da4a496-0440-4636-aebc-d51fa94f5149
#
#                                 plangen_uuid  \
#  0      0b757d1e-0d2e-4815-9f86-0a009aa00d39
#  1      0b757d1e-0d2e-4815-9f86-0a009aa00d39
#  2      0b757d1e-0d2e-4815-9f86-0a009aa00d39
#  3      0b757d1e-0d2e-4815-9f86-0a009aa00d39
#  4      0b757d1e-0d2e-4815-9f86-0a009aa00d39
#  ...                                     ...
#  10701  3b6cd46d-3a19-4600-96fa-7ea516cb263c
#  10702  3b6cd46d-3a19-4600-96fa-7ea516cb263c
#  10703  3b6cd46d-3a19-4600-96fa-7ea516cb263c
#  10704  3b6cd46d-3a19-4600-96fa-7ea516cb263c
#  10705  3b6cd46d-3a19-4600-96fa-7ea516cb263c
#
#                                     job_uuid  time_since_creation  \
#  0      0076da02-2ffe-49ab-b428-cf4c45b25cd6                    4
#  1      0076da02-2ffe-49ab-b428-cf4c45b25cd6                    4
#  2      0076da02-2ffe-49ab-b428-cf4c45b25cd6                    4
#  3      0076da02-2ffe-49ab-b428-cf4c45b25cd6                    4
#  4      0076da02-2ffe-49ab-b428-cf4c45b25cd6                    4
#  ...                                     ...                  ...
#  10701  fe5a405c-d80f-45a0-be56-6890f1642625                  169
#  10702  fe5a405c-d80f-45a0-be56-6890f1642625                  169
#  10703  fe5a405c-d80f-45a0-be56-6890f1642625                  169
#  10704  fe5a405c-d80f-45a0-be56-6890f1642625                  169
#  10705  fe5a405c-d80f-45a0-be56-6890f1642625                  169
#
#        planactiontype                           supply_uuid  is_selected  \
#  0              OFFER  1cdd1173-605e-4a5b-96a5-2ec9c66297a2            0
#  1              OFFER  1c157955-eb80-46c8-9d76-593fb748a7ec            0
#  2              OFFER  3c36bb9e-1863-4e0b-9d6e-775b1fbea591            0
#  3              OFFER  ec01d862-0619-4b77-a587-48bf22db05be            0
#  4              OFFER  75bb8db0-ee65-45b2-b06a-548944155082            0
#  ...              ...                                   ...          ...
#  10701          OFFER  b7fbd985-6a62-43cf-9c8d-27292b1437c7            0
#  10702          OFFER  fa62f5c7-ba6d-4665-9da6-5f12a4caee80            0
#  10703          OFFER  5cc9f7d1-eae7-43a3-a40c-46b24854550b            0
#  10704          OFFER  50c7698a-0cec-4b6e-be17-3593f1321c70            0
#  10705          OFFER  1301c02e-22a4-4d5c-a762-4910d7faade6            0
#
#           eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0      266.0          266           266.0   0.2062   0.3307   0.0040
#  1      316.0          316           316.0   0.4121   0.4047   0.0040
#  2      215.0          215           215.0   0.2553   0.3705   0.0040
#  3      747.0          747           747.0   0.3512   0.7914   0.0040
#  4      738.0          738           738.0   0.4081   0.8120   0.0040
#  ...      ...          ...             ...      ...      ...      ...
#  10701  946.0          946           946.0   0.3230   0.5835   0.0074
#  10702  567.0          567           567.0   0.5460   0.3112   0.0074
#  10703  608.0          518           518.0   0.4704   0.3624   0.0074
#  10704  847.0          847           847.0   0.3441   0.5803   0.0074
#  10705  294.0          294           294.0   0.5309   0.2657   0.0074
#
#         continuation_cr  preferred_destination_adjustment     of_value  \
#  0             0.533747                               0.0   706.550155
#  1             0.492777                               0.0   844.735332
#  2             0.539097                               0.0   726.860140
#  3             0.322824                               0.0  1379.430637
#  4             0.324685                               0.0  1396.971935
#  ...                ...                               ...          ...
#  10701         0.365201                               0.0  1320.219354
#  10702         0.295065                               0.0   937.778716
#  10703         0.349733                              90.0   947.535403
#  10704         0.291701                               0.0  1278.825640
#  10705         0.355868                               0.0   688.474116
#
#         trip_length    fare
#  0           1500.0   62.15
#  1           1500.0   62.15
#  2           1500.0   62.15
#  3           1500.0   62.15
#  4           1500.0   62.15
#  ...            ...     ...
#  10701       3180.0  184.37
#  10702       3180.0  184.37
#  10703       3180.0  184.37
#  10704       3180.0  184.37
#  10705       3180.0  184.37
#
#  [10706 rows x 20 columns],
#  'replay_city214_(1720)_2022-09-16_segment0':          datestr  city_id                             scan_uuid  \
#  0     2022-09-16      214  0301b4f7-4527-4c3c-b804-42582d9a0b65
#  1     2022-09-16      214  0301b4f7-4527-4c3c-b804-42582d9a0b65
#  2     2022-09-16      214  0301b4f7-4527-4c3c-b804-42582d9a0b65
#  3     2022-09-16      214  0301b4f7-4527-4c3c-b804-42582d9a0b65
#  4     2022-09-16      214  0301b4f7-4527-4c3c-b804-42582d9a0b65
#  ...          ...      ...                                   ...
#  1768  2022-09-16      214  0e7f1e3e-9605-4fea-bddb-12a29ed4440b
#  1769  2022-09-16      214  0e7f1e3e-9605-4fea-bddb-12a29ed4440b
#  1770  2022-09-16      214  0e7f1e3e-9605-4fea-bddb-12a29ed4440b
#  1771  2022-09-16      214  0e7f1e3e-9605-4fea-bddb-12a29ed4440b
#  1772  2022-09-16      214  0e7f1e3e-9605-4fea-bddb-12a29ed4440b
#
#                                plangen_uuid  \
#  0     a48772d5-1c30-4f3a-a494-ad97f701adf4
#  1     a48772d5-1c30-4f3a-a494-ad97f701adf4
#  2     a48772d5-1c30-4f3a-a494-ad97f701adf4
#  3     a48772d5-1c30-4f3a-a494-ad97f701adf4
#  4     a48772d5-1c30-4f3a-a494-ad97f701adf4
#  ...                                    ...
#  1768  dfcf76da-0c6d-46e1-a9ae-99654e065ee3
#  1769  dfcf76da-0c6d-46e1-a9ae-99654e065ee3
#  1770  dfcf76da-0c6d-46e1-a9ae-99654e065ee3
#  1771  dfcf76da-0c6d-46e1-a9ae-99654e065ee3
#  1772  dfcf76da-0c6d-46e1-a9ae-99654e065ee3
#
#                                    job_uuid  time_since_creation  \
#  0     0289c84b-a45a-49ba-8cff-b2d6a5218fc6                  157
#  1     0289c84b-a45a-49ba-8cff-b2d6a5218fc6                  157
#  2     0289c84b-a45a-49ba-8cff-b2d6a5218fc6                  157
#  3     0289c84b-a45a-49ba-8cff-b2d6a5218fc6                  157
#  4     0289c84b-a45a-49ba-8cff-b2d6a5218fc6                  157
#  ...                                    ...                  ...
#  1768  fb10b627-fae4-42a5-8678-36a1372d6d04                   90
#  1769  fb10b627-fae4-42a5-8678-36a1372d6d04                   90
#  1770  fb10b627-fae4-42a5-8678-36a1372d6d04                   90
#  1771  fb10b627-fae4-42a5-8678-36a1372d6d04                   90
#  1772  fb10b627-fae4-42a5-8678-36a1372d6d04                   90
#
#       planactiontype                           supply_uuid  is_selected  \
#  0             OFFER  2603cfaf-7110-4a70-8c8c-4769572459d3            0
#  1             OFFER  5ec3b2f9-105e-4ed2-a0c7-68bfc1e784b6            0
#  2             OFFER  68021b27-c19c-42ac-a553-20390e296893            0
#  3             OFFER  bf2800bb-b38e-41f2-bd84-cd1c320490a6            0
#  4             OFFER  8cb9df2a-6d2b-4c9f-8ea3-ea8b1c98c56a            0
#  ...             ...                                   ...          ...
#  1768     KEEP_ALIVE  5d5706b0-0645-46a8-b7a2-6eaf602954ea            0
#  1769     KEEP_ALIVE  10f0fb52-85a2-487b-a962-de6155a5b097            0
#  1770     KEEP_ALIVE  bb4cd22b-62d4-48b0-b647-b8a1cd181b3d            0
#  1771     KEEP_ALIVE  2591e488-4bef-420d-b61c-4641de5f2cc8            0
#  1772     KEEP_ALIVE  6c7353c7-bbfb-44e8-831c-927c6a712e03            0
#
#           eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0      862.0          862           862.0   0.8790   0.3035   0.0090
#  1      909.0          909           909.0   0.8014   0.3399   0.0090
#  2     1253.0         1253          1253.0   0.9165   0.4940   0.0090
#  3     1293.0         1293          1293.0   0.9006   0.4940   0.0090
#  4      822.0          822           822.0   0.8422   0.2846   0.0090
#  ...      ...          ...             ...      ...      ...      ...
#  1768  1025.0         1025          1025.0   0.6863   0.4518   0.0111
#  1769  1178.0         1178          1178.0   0.8668   0.5130   0.0111
#  1770  1229.0         1229          1229.0   0.4397   0.5691   0.0111
#  1771   787.0          679           679.0   0.8985   0.3385   0.0111
#  1772   857.0          857           857.0   0.9564   0.4420   0.0111
#
#        continuation_cr  preferred_destination_adjustment     of_value  \
#  0            0.517623                               0.0  1215.017081
#  1            0.566922                               0.0  1248.242369
#  2            0.440676                               0.0  1471.216451
#  3            0.506658                               0.0  1485.503538
#  4            0.583993                               0.0  1172.497975
#  ...               ...                               ...          ...
#  1768         0.365201                               0.0  1339.185124
#  1769         0.348639                               0.0  1441.470161
#  1770         0.339735                               0.0  1431.489599
#  1771         0.438094                               0.0  1137.204512
#  1772         0.438094                               0.0  1289.598590
#
#        trip_length   fare
#  0          1860.0  65.20
#  1          1860.0  65.20
#  2          1860.0  65.20
#  3          1860.0  65.20
#  4          1860.0  65.20
#  ...           ...    ...
#  1768        360.0  11.69
#  1769        360.0  11.69
#  1770        360.0  11.69
#  1771        360.0  11.69
#  1772        360.0  11.69
#
#  [1773 rows x 20 columns],
#  'replay_city1542_(10004302)_2022-09-16_segment0':          datestr  city_id                             scan_uuid  \
#  0     2022-09-16     1542  074f7d3e-dd77-405f-9213-f2b7443cd9fe
#  1     2022-09-16     1542  074f7d3e-dd77-405f-9213-f2b7443cd9fe
#  2     2022-09-16     1542  074f7d3e-dd77-405f-9213-f2b7443cd9fe
#  3     2022-09-16     1542  074f7d3e-dd77-405f-9213-f2b7443cd9fe
#  4     2022-09-16     1542  074f7d3e-dd77-405f-9213-f2b7443cd9fe
#  ...          ...      ...                                   ...
#  2639  2022-09-16     1542  09154e2d-15a0-4645-9af3-29f5e8730f7f
#  2640  2022-09-16     1542  09154e2d-15a0-4645-9af3-29f5e8730f7f
#  2641  2022-09-16     1542  09154e2d-15a0-4645-9af3-29f5e8730f7f
#  2642  2022-09-16     1542  09154e2d-15a0-4645-9af3-29f5e8730f7f
#  2643  2022-09-16     1542  09154e2d-15a0-4645-9af3-29f5e8730f7f
#
#                                plangen_uuid  \
#  0     48a26598-e5ac-4aab-987d-b657eca86807
#  1     48a26598-e5ac-4aab-987d-b657eca86807
#  2     48a26598-e5ac-4aab-987d-b657eca86807
#  3     48a26598-e5ac-4aab-987d-b657eca86807
#  4     48a26598-e5ac-4aab-987d-b657eca86807
#  ...                                    ...
#  2639  f00667fc-044d-4d08-b605-09e68938b042
#  2640  f00667fc-044d-4d08-b605-09e68938b042
#  2641  f00667fc-044d-4d08-b605-09e68938b042
#  2642  f00667fc-044d-4d08-b605-09e68938b042
#  2643  f00667fc-044d-4d08-b605-09e68938b042
#
#                                    job_uuid  time_since_creation  \
#  0     00aaea54-1149-4638-80dd-6598338d75ea                   20
#  1     00aaea54-1149-4638-80dd-6598338d75ea                   20
#  2     00aaea54-1149-4638-80dd-6598338d75ea                   20
#  3     00aaea54-1149-4638-80dd-6598338d75ea                   20
#  4     00aaea54-1149-4638-80dd-6598338d75ea                   20
#  ...                                    ...                  ...
#  2639  feae66ad-775c-4446-893a-f804043dfee7                    0
#  2640  feae66ad-775c-4446-893a-f804043dfee7                    0
#  2641  feae66ad-775c-4446-893a-f804043dfee7                    0
#  2642  feae66ad-775c-4446-893a-f804043dfee7                    0
#  2643  feae66ad-775c-4446-893a-f804043dfee7                    0
#
#       planactiontype                           supply_uuid  is_selected  \
#  0             OFFER  812ef9c7-54eb-4a37-bb38-a37f63469199            0
#  1             OFFER  334668d7-acfe-4b68-a2ea-e226ad1730c3            0
#  2             OFFER  2c41fe1c-75fb-4458-a306-b96d27121c88            0
#  3             OFFER  4ff507ef-e9fc-412a-bdc3-7eb397bf028c            0
#  4             OFFER  dd51575e-a6fe-46f0-ba5d-af89522dc022            0
#  ...             ...                                   ...          ...
#  2639          OFFER  d0bae359-7a67-49ad-8733-6ef194b0ced5            1
#  2640          OFFER  e8d04d2a-bf3b-4b86-a30a-66a1d1fd7216            0
#  2641          OFFER  beb66637-1781-4fd7-8755-25c71360ca76            0
#  2642          OFFER  789e1846-a93e-4aae-90bb-e1d17eae45ba            0
#  2643          OFFER  b218fa5a-9f23-4472-b8ae-cf763be36b3d            0
#
#           eta  adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
#  0     1077.0         1077          1077.0   0.7082   0.2283   0.0033
#  1      649.0          649           649.0   0.9977   0.1058   0.0033
#  2      570.0          570           570.0   0.9647   0.0861   0.0033
#  3      789.0          789           789.0   0.9939   0.1334   0.0033
#  4      929.0          929           929.0   0.4434   0.1645   0.0033
#  ...      ...          ...             ...      ...      ...      ...
#  2639   180.0          180           180.0   0.5485   0.0352   0.0018
#  2640  1337.0         1337          1337.0   0.7344   0.3338   0.0018
#  2641  1269.0         1269          1269.0   0.7657   0.3112   0.0018
#  2642   285.0          285           285.0   0.8361   0.0401   0.0018
#  2643  1238.0         1238          1238.0   0.1075   0.3452   0.0018
#
#        continuation_cr  preferred_destination_adjustment     of_value  \
#  0            0.597001                               0.0  1258.389165
#  1            0.700171                               0.0   839.689877
#  2            0.710120                               0.0   747.693051
#  3            0.710120                               0.0   994.026964
#  4            0.650260                               0.0  1079.561468
#  ...               ...                               ...          ...
#  2639         0.744707                               0.0   283.693645
#  2640         0.526442                               0.0  1482.161163
#  2641         0.467817                               0.0  1448.827069
#  2642         0.753000                               0.0   417.152857
#  2643         0.533747                               0.0  1348.107837
#
#        trip_length   fare
#  0           600.0  16.96
#  1           600.0  16.96
#  2           600.0  16.96
#  3           600.0  16.96
#  4           600.0  16.96
#  ...           ...    ...
#  2639       1020.0  28.50
#  2640       1020.0  28.50
#  2641       1020.0  28.50
#  2642       1020.0  28.50
#  2643       1020.0  28.50
#
#  [2644 rows x 20 columns]}

# %%
# %%time
# clean data
scans = pd.concat(cdf.dfs.values(), axis=0, ignore_index=True)
scans.shape
df = scans
df = clean_df(df)
df = compute_new_of(df, gamma = 0)
# Out:
# CPU times: user 1.12 s, sys: 168 ms, total: 1.29 s
# Wall time: 1.29 s

# %%
len(set(df['job_uuid']))
# Out:
# 18631

# %%
df.groupby(['city_id', 'datestr']).count()
# Out:
#                     scan_uuid  plangen_uuid  job_uuid  time_since_creation  \
# city_id datestr
# 5       2022-09-16      23842         23842     23842                23842
# 7       2022-09-16       3657          3657      3657                 3657
# 12      2022-09-16      10285         10285     10285                10285
# 14      2022-09-16      10859         10859     10859                10859
# 16      2022-09-16       1510          1510      1510                 1510
# 39      2022-09-16      17749         17749     17749                17749
# 90      2022-09-16      79012         79012     79012                79012
# 143     2022-09-16        837           837       837                  837
# 148     2022-09-16      46876         46876     46876                46876
# 214     2022-09-16       1770          1770      1770                 1770
# 458     2022-09-16     295345        295345    295345               295345
# 531     2022-09-16      10635         10635     10635                10635
# 1542    2022-09-16       2643          2643      2643                 2643
#
#                     planactiontype  supply_uuid  is_selected     eta  \
# city_id datestr
# 5       2022-09-16           23842        23842        23842   23842
# 7       2022-09-16            3657         3657         3657    3657
# 12      2022-09-16           10285        10285        10285   10285
# 14      2022-09-16           10859        10859        10859   10859
# 16      2022-09-16            1510         1510         1510    1510
# 39      2022-09-16           17749        17749        17749   17749
# 90      2022-09-16           79012        79012        79012   79012
# 143     2022-09-16             837          837          837     837
# 148     2022-09-16           46876        46876        46876   46876
# 214     2022-09-16            1770         1770         1770    1770
# 458     2022-09-16          295345       295345       295345  295345
# 531     2022-09-16           10635        10635        10635   10635
# 1542    2022-09-16            2643         2643         2643    2643
#
#                     adjustedeta  ranking_metric  d_proba  r_proba  s_proba  \
# city_id datestr
# 5       2022-09-16        23842           23842    23842    23842    23842
# 7       2022-09-16         3657            3657     3657     3657     3657
# 12      2022-09-16        10285           10285    10285    10285    10285
# 14      2022-09-16        10859           10859    10859    10859    10859
# 16      2022-09-16         1510            1510     1510     1510     1510
# 39      2022-09-16        17749           17749    17749    17749    17749
# 90      2022-09-16        79012           79012    79012    79012    79012
# 143     2022-09-16          837             837      837      837      837
# 148     2022-09-16        46876           46876    46876    46876    46876
# 214     2022-09-16         1770            1770     1770     1770     1770
# 458     2022-09-16       295345          295345   295345   295345   295345
# 531     2022-09-16        10635           10635    10635    10635    10635
# 1542    2022-09-16         2643            2643     2643     2643     2643
#
#                     continuation_cr  preferred_destination_adjustment  \
# city_id datestr
# 5       2022-09-16            23842                             23842
# 7       2022-09-16             3657                              3657
# 12      2022-09-16            10285                             10285
# 14      2022-09-16            10859                             10859
# 16      2022-09-16             1510                              1510
# 39      2022-09-16            17749                             17749
# 90      2022-09-16            79012                             79012
# 143     2022-09-16              837                               837
# 148     2022-09-16            46876                             46876
# 214     2022-09-16             1770                              1770
# 458     2022-09-16           295345                            295345
# 531     2022-09-16            10635                             10635
# 1542    2022-09-16             2643                              2643
#
#                     of_value  trip_length    fare      cr  new_of
# city_id datestr
# 5       2022-09-16     23842        23842   23842   23842   23842
# 7       2022-09-16      3657         3657    3657    3657    3657
# 12      2022-09-16     10285        10285   10285   10285   10285
# 14      2022-09-16     10859        10859   10859   10859   10859
# 16      2022-09-16      1510         1510    1510    1510    1510
# 39      2022-09-16     17749        17749   17749   17749   17749
# 90      2022-09-16     79012        79012   79012   79012   79012
# 143     2022-09-16       837          837     837     837     837
# 148     2022-09-16     46876        46876   46876   46876   46876
# 214     2022-09-16      1770         1770    1770    1770    1770
# 458     2022-09-16    295345       295345  295345  295345  295345
# 531     2022-09-16     10635        10635   10635   10635   10635
# 1542    2022-09-16      2643         2643    2643    2643    2643

# %%
#df.head()

# %%
df.drop_duplicates(subset=['job_uuid', 'supply_uuid'], inplace=True)

# %%
# %%time
matching = solve_all_dict(df,lambda scan: supply_cost_solve_dict(scan, markov = False))
matching
# Out:
# CPU times: user 14 s, sys: 446 ms, total: 14.4 s
# Wall time: 14.4 s
# {'total_jobs': 18751.0,
#  'match_rate': 0.954562423337422,
#  'overwrite': 0.6069542957708922,
#  'Average Matched ETA': 535.9910050840829,
#  'Average CR': 0.7201124463117327,
#  'Driver AR': 0.446542533102408,
#  'Rider cancel': 0.1464397619978768,
#  'Average trip length': 1281.5565115369573,
#  'Average GB': 323.28644589706573,
#  'Total GB': 5786504.09511158}

# %%
# %%time
matching = solve_all_dict(df,lambda scan: supply_cost_solve_dict(scan, markov = True))
matching
# Out:
# CPU times: user 12.6 s, sys: 202 ms, total: 12.8 s
# Wall time: 12.8 s
# {'total_jobs': 18751.0,
#  'match_rate': 0.947629459762146,
#  'overwrite': 0.0,
#  'Average Matched ETA': 419.83898925094263,
#  'Average CR': 0.6835272348732228,
#  'Driver AR': 0.3132606899656707,
#  'Rider cancel': 0.1226702346783724,
#  'Average trip length': 1278.085429680905,
#  'Average GB': 295.7178216906831,
#  'Total GB': 5254609.973621747}

# %%
# %%time
# clean data
scans = pd.concat(cdf.dfs.values(), axis=0, ignore_index=True)
scans.shape
df = scans
df = clean_df(df)
results_df = pd.DataFrame()

gamma_list = [0.1 * i for i in range(101)]

#sca
for gamma in gamma_list:
    df = compute_new_of(df, gamma = gamma)
    df.drop_duplicates(subset=['job_uuid', 'supply_uuid'], inplace=True)
    matching = solve_all_dict(df,lambda scan: supply_cost_solve_dict(scan, markov = False))
    tmp_df = convert_dict(matching)
    tmp_df['gamma'] = [gamma]
    results_df = results_df.append(tmp_df, ignore_index = True)
        
#markov
matching = solve_all_dict(df,lambda scan: supply_cost_solve_dict(scan, markov = True))
tmp_df = convert_dict(matching)

# %%
results_df.to_csv('efof_lsr_global_9_16_2022.csv')

# %%
results_df

# %%
#markov
matching = solve_all_dict(df,lambda scan: supply_cost_solve_dict(scan, markov = True))
tmp_df = convert_dict(matching)
