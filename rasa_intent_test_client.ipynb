# %%
import requests

# %%
def get_intent(message):
    headers = {'Content-type': 'application/json'}
    payload = '{"text": "'+message+'","message_id": "a"}'
    raw_response = requests.post(
        "http://localhost:5005/model/parse",
        verify=False,data=payload,headers=headers).json()
    # raw_intent = raw_response
    # print('intent=',intent)
    # await asyncio.sleep(0.001)
#     print(raw_response)
    return raw_response['intent']['name'],raw_response['intent']['confidence']

# %%
# message = df['processed'][12]
# print("email : {}".format(message))
# print(get_intent(message))

# %%
import pandas as pd
import os

# %%
# df = pd.read_csv('Email Output sheet - NLP Model_2107.csv')

# %%
df = pd.read_csv('NLP_data_copied - Sheet1 (2).csv')

# %%
len(df)
# Out:
# 36

# %%
df
# Out:
#     S.No.                                      Ticket Number  \
# 0     101  https://uberfreight.zendesk.com/agent/tickets/...
# 1     102  https://uberfreight.zendesk.com/agent/tickets/...
# 2     103  https://uberfreight.zendesk.com/agent/tickets/...
# 3     104  https://uberfreight.zendesk.com/agent/tickets/...
# 4     105  https://uberfreight.zendesk.com/agent/tickets/...
# 5     106  https://uberfreight.zendesk.com/agent/tickets/...
# 6     107  https://uberfreight.zendesk.com/agent/tickets/...
# 7     108  https://uberfreight.zendesk.com/agent/tickets/...
# 8     109  https://uberfreight.zendesk.com/agent/tickets/...
# 9     110  https://uberfreight.zendesk.com/agent/tickets/...
# 10    111  https://uberfreight.zendesk.com/agent/tickets/...
# 11    112  https://uberfreight.zendesk.com/agent/tickets/...
# 12    113  https://uberfreight.zendesk.com/agent/tickets/...
# 13    115  https://uberfreight.zendesk.com/agent/tickets/...
# ...

# %%
df.fillna(" ", inplace=True)

# %%
df
# Out:
#     S.No.                                      Ticket Number  \
# 0     101  https://uberfreight.zendesk.com/agent/tickets/...
# 1     102  https://uberfreight.zendesk.com/agent/tickets/...
# 2     103  https://uberfreight.zendesk.com/agent/tickets/...
# 3     104  https://uberfreight.zendesk.com/agent/tickets/...
# 4     105  https://uberfreight.zendesk.com/agent/tickets/...
# 5     106  https://uberfreight.zendesk.com/agent/tickets/...
# 6     107  https://uberfreight.zendesk.com/agent/tickets/...
# 7     108  https://uberfreight.zendesk.com/agent/tickets/...
# 8     109  https://uberfreight.zendesk.com/agent/tickets/...
# 9     110  https://uberfreight.zendesk.com/agent/tickets/...
# 10    111  https://uberfreight.zendesk.com/agent/tickets/...
# 11    112  https://uberfreight.zendesk.com/agent/tickets/...
# 12    113  https://uberfreight.zendesk.com/agent/tickets/...
# 13    115  https://uberfreight.zendesk.com/agent/tickets/...
# ...

# %%
df.drop(columns = ['Ticket Number', 'RPA Bot Processed?'],inplace=True)

# %%
df['Intent'].value_counts()
# Out:
# Account Information Intent    23
# others                        12
# Others                         1
# Name: Intent, dtype: int64

# %%
duplicate = df[df.duplicated(['Subject line', 'Email body'])]

# %%
df.drop_duplicates(subset =['Subject line', 'Email body'],
                     keep = False, inplace = True)

# %%
df['Intent'].value_counts()
# Out:
# Account Information Intent    23
# others                        12
# Others                         1
# Name: Intent, dtype: int64

# %%
df.loc[df['Intent'] != 'Account Information Intent', 'Intent'] = 'Others'

# %%
df['email'] = df['Subject line'] + " " + df['Email body']

# %%
df
# Out:
#     S.No.                      Intent  \
# 0     101  Account Information Intent
# 1     102  Account Information Intent
# 2     103  Account Information Intent
# 3     104  Account Information Intent
# 4     105  Account Information Intent
# 5     106  Account Information Intent
# 6     107  Account Information Intent
# 7     108  Account Information Intent
# 8     109  Account Information Intent
# 9     110  Account Information Intent
# 10    111  Account Information Intent
# 11    112  Account Information Intent
# 12    113  Account Information Intent
# 13    115  Account Information Intent
# 14    116  Account Information Intent
# 15    117  Account Information Intent
# 16    118  Account Information Intent
# 17    119  Account Information Intent
# 18    120  Account Information Intent
# 19    121  Account Information Intent
# 20    122  Account Information Intent
# 21    123  Account Information Intent
# 22    124  Account Information Intent
# ...

# %%
from nltk.corpus import stopwords
sw = set(stopwords.words('english'))

# %%
import re

# %%
#lowering and removing punctuation
df['processed'] = df['email'].apply(lambda x: re.sub(r'[^\w\s]','', x.lower()))
#removing the numerical values and working only with text values
df['processed'] = df['processed'].apply(lambda x : re.sub('[^a-zA-Z]', " ", x ))
#removing the stopwords
df['processed'] = df['processed'].apply(lambda x: ' '.join([word for word in x.split() if word not in sw ]))

# %%
df.columns
# Out:
# Index(['S.No.', 'Intent', 'Subject line', 'Email body', 'email', 'processed'], dtype='object')

# %%
results = []
for index,row in df.iterrows():
#     print(row)
#     break
#     print(len(row))
    result = get_intent(row[5])
    results.append(result)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/opt/anaconda3/envs/py365/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~/opt/anaconda3/envs/py365/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~/opt/anaconda3/envs/py365/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# ...

# %%
df['predicted_intent'] = [result[0] for result in results]
df['predicted_confidence'] = [result[1] for result in results]

# %%
df
# Out:
#     S.No.                      Intent  \
# 0     101  Account Information Intent
# 1     102  Account Information Intent
# 2     103  Account Information Intent
# 3     104  Account Information Intent
# 4     105  Account Information Intent
# 5     106  Account Information Intent
# 6     107  Account Information Intent
# 7     108  Account Information Intent
# 8     109  Account Information Intent
# 9     110  Account Information Intent
# 10    111  Account Information Intent
# 11    112  Account Information Intent
# 12    113  Account Information Intent
# 13    115  Account Information Intent
# 14    116  Account Information Intent
# 15    117  Account Information Intent
# 16    118  Account Information Intent
# 17    119  Account Information Intent
# 18    120  Account Information Intent
# 19    121  Account Information Intent
# 20    122  Account Information Intent
# 21    123  Account Information Intent
# 22    124  Account Information Intent
# ...

# %%
'Account_Information_Intent'.split('_') == 'Account Information Intent'.split()
# Out:
# True

# %%
wrong_predictions = 0
for index, row in df.iterrows():
    if df.loc[index,'Intent'].split() != df.loc[index,'predicted_intent'].split('_'):
        wrong_predictions+=1
#         print(os.path.basename(df.iloc[index,0]))
        print(df.loc[index,'Intent'], df.loc[index,'predicted_intent'], df.loc[index,'predicted_confidence'])
# Out:
# Others Account_Information_Intent 0.626998245716095
# Others Account_Information_Intent 0.9994483590126038
# Others Account_Information_Intent 0.9930046200752258
# Others nlu_fallback 0.481300950050354

# %%
wrong_predictions = 0
for index, row in df.iterrows():
    if df.loc[index,'Intent'].split() != df.loc[index,'predicted_intent'].split('_'):
        wrong_predictions+=1
#         print(os.path.basename(df.iloc[index,0]))
        print(df.loc[index,'Intent'], df.loc[index,'predicted_intent'], df.loc[index,'predicted_confidence'])
# Out:
# Others Account_Information_Intent 0.6309170722961426
# Others Account_Information_Intent 0.9989737272262573
# Others Account_Information_Intent 0.991972804069519
# Others Account_Information_Intent 0.5492392182350159

# %%
print("Accuracy = {}".format(1 - wrong_predictions/len(df)))
# Out:
# Accuracy = 0.8888888888888888

# %%
df.loc[
# Out:
#   File "<ipython-input-139-724bf87be88e>", line 1
#     df.loc[
#            ^
# SyntaxError: unexpected EOF while parsing

# %%
def preprocess_text(message):
    #lowering and removing punctuation
    message = re.sub(r'[^\w\s]','', message.lower())
    #removing the numerical values and working only with text values
    message = re.sub('[^a-zA-Z]', " ", message )
    #removing the stopwords
    message = ' '.join([word for word in message.split() if word not in sw ])
    return message

# %%
preprocess_text(df.loc[0,'email'])
# Out:
# 'arfreight coastal export account hello ar account balance coastal export intl ne nd ave miami fl moe'

# %%
df.loc[0,'processed']
# Out:
# 'arfreight coastal export account hello ar account balance coastal export intl ne nd ave miami fl moe'

# %%
df.loc[0,'email']
# Out:
# '[ar-freight] coastal export account Hello AR\nwhat is my account balance?\n\ncoastal export intl\n7455 NE 2nd ave\nmiami fl. 33138\n\nMoe 3052180323'

# %%
def intent_classification(subject,email_body):
    
    url_address = "https://uipathmltest.corp.uber.com"
   # url_address = "http://127.0.0.1:5000"
    # url_address = http://DCA1-UP-ML-P01
    # url_address = "http://dca1-ic-d-aby01:5000/iacoe_ocr/doc-ai/data_extractor"
    ENDPOINT = '/iacoe_ocr/intentclassifier/email_intent'
    url = url_address + ENDPOINT


    payload = {'subject': subject,
               'email_body':email_body,
               # 'sa_key_base64': sa_key_base64
    }
    try:
        response = requests.post(url, data=payload, verify=False)
    #     print(response.text.encode('utf8'))

       
        return response
    
    except:
        return None

# %%
subject = '[ar-freight] ALDI Payment Remittance Detail'
email_body = 'Dear Supplier, Attached is the remittance regarding a recent payment sent by Aldi Inc. If you have any questions regarding this payment please contact via email Corp-Checkwriting@aldi.us *Please do not hit reply to this email as this email address does not receive incoming emails. Thank you, Corp - Checkwriting ALDI Inc. Corporate Administration US 1200 North Kirk Road Batavia, 60510-1477 Tel: +1 (630) 879-8100 Fax: +1 (630) 879-9901 SAVE PAPER - THINK BEFORE YOU PRINT This email and any files transmitted with it are confidential and intended solely for the use of the individual or entity to which they are addressed. If you have received this email in error please notify the sender. Please note that any views or opinions presented in this email are solely those of the author and do not necessarily represent those of the company. Finally, the recipient should check this email and any attachments for the presence of viruses. Aldi accepts no liability for any damage caused by any virus transmitted by this email. -- To unsubscribe from this group and stop receiving emails from it, send an email to ar-freight+unsubscribe@uber.com.'
print(subject + " " + email_body)
response = intent_classification(subject,email_body)
print(response.text)
# Out:
# [ar-freight] ALDI Payment Remittance Detail Dear Supplier, Attached is the remittance regarding a recent payment sent by Aldi Inc. If you have any questions regarding this payment please contact via email Corp-Checkwriting@aldi.us *Please do not hit reply to this email as this email address does not receive incoming emails. Thank you, Corp - Checkwriting ALDI Inc. Corporate Administration US 1200 North Kirk Road Batavia, 60510-1477 Tel: +1 (630) 879-8100 Fax: +1 (630) 879-9901 SAVE PAPER - THINK BEFORE YOU PRINT This email and any files transmitted with it are confidential and intended solely for the use of the individual or entity to which they are addressed. If you have received this email in error please notify the sender. Please note that any views or opinions presented in this email are solely those of the author and do not necessarily represent those of the company. Finally, the recipient should check this email and any attachments for the presence of viruses. Aldi accepts no l
# ...

# %%
subject = df.loc[0,'Subject line']
email_body = df.loc[0, 'Email body']
print(subject + " " + email_body)
response = intent_classification(subject,email_body)
print(response.text)
# Out:
# [ar-freight] coastal export account Hello AR
# what is my account balance?
#
# coastal export intl
# 7455 NE 2nd ave
# miami fl. 33138
#
# Moe 3052180323
# {
#   "success": "Account_Information_Intent:0.9999582767486572"
# }

# %%
# import traceback
import os
import base64
import requests
import json

# INP_PATH = "/Users/hsingh151/My_Work/Parsers and Classifiers/IP CLASSIFIERS/01_Data/IMAGE_DATA/NORAM_INVOICE/GOOGLE_IMAGES/VARIATION_1_images"
# INP_PATH = "/Users/hsingh151/My_Work/Parsers and Classifiers/IP CLASSIFIERS/02_canada_classifier/samples/images/CDW Canada Corp_images"
# INP_PATH = "/Users/hsingh151/My_Work/Parsers and Classifiers/IP CLASSIFIERS/02_canada_classifier/samples/images/TORPEDO MARKETING INC_images"
INP_PATH = r"/Users/jghosh2/Downloads/image.png"

APIKEY = 'AIzaSyCGSGCUuN4PH576zqRqk_hHWiBd1mN7SwA'
ENDPOINT_URL = "https://vision.googleapis.com/v1/images:annotate"

files = os.listdir(INP_PATH)
print(files)
print(len(files))


def request_ocr(api_key, data):
    response = requests.post(ENDPOINT_URL, data=data, params={'key': api_key},
                             headers={'Content-Type': 'application/json'})

    return response


def make_request_data(image_base64):
    img_requests = [{
        'image': {'content': image_base64.decode()},
        'features': [{
            'type': 'TEXT_DETECTION',
            'maxResults': 1
        }]
    }]
    return json.dumps({"requests": img_requests}).encode()


def vision_from_api_key(img_base64, apikey, file_path):
    """
    :param img_base64:
    :param apikey:
    :param file_path:
    :return:
    """
    request_data = make_request_data(img_base64)
    response = request_ocr(api_key=apikey, data=request_data)
    if response.status_code != 200 or response.json().get('error'):
        print(response.text)
    try:
        raw_text = response.json()['responses'][0]["textAnnotations"][0]["description"]
        json_data = response.json()
    except:
        raw_text = "NULL"
    with open(str(file_path) + ".json", 'w') as outfile:
        json.dump(response.json(), outfile)
    fp = str(file_path) + "_raw_text.txt"
    print(fp)
    with open(fp, 'w', encoding='utf-8') as f:
        f.write(raw_text)


for file in files:
    if file.endswith('JPG') or file.endswith('JPEG') or file.endswith('jpg') or file.endswith('jpeg') or file.endswith(
            'png'):
        #     if file == "binary_stopped_working.png":
        file_path = os.path.join(INP_PATH, file)
        with open(file_path, 'rb') as img_file:
            img_bytes = img_file.read()
        img_base64 = base64.b64encode(img_bytes)
        vision_from_api_key(img_base64, APIKEY, file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/dk/dcz1bsq51ydb6f7j_7n8pxpr0000gn/T/ipykernel_25849/4284822881.py in <module>
#      13 ENDPOINT_URL = "https://vision.googleapis.com/v1/images:annotate"
#      14
# ---> 15 files = os.listdir(INP_PATH)
#      16 print(files)
#      17 print(len(files))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\hsingh151\\My_Work\\BOL_GENERAL_PARSER\\BOL_Target Customer\\BOL_CLASSIFIER\\Data_Samples\\Other_documents\\image_samples'

# %%
url_address = "http://127.0.0.1:5000"
#url_address = "https://127.0.0.1"
#url_address = "http://dca1-up-ml-t01"
#url_address = "https://uipathmltest.corp.uber.com"
# url_address = "http://dca1-ic-d-aby01:5000"
#url_address = "https://uipathmldev.corp.uber.com"
#url_address="https://uipathmlprod.corp.uber.com"
#ENDPOINT = '/iacoe_ocr/l1_triage_classifier'
ENDPOINT = '/iacoe_ocr/l1_triage_classifier_component_michelangelo'
#ENDPOINT = '/iacoe_ocr/l1_triage_classifier_tier_type_1_multi'
#ENDPOINT = '/iacoe_ocr/l1_triage_classifier_tier_type_2_multi'
url = url_address + ENDPOINT


################L1 traige inputs#############
summary1='uSupplir Query (Ticket # 2400900)'
description1='"Hi Team,The supplier does not have ""invoice creation permission to process the invoice in usupplier portal with PO # 467746, please help us with the below request.!image.png|thumbnail!"'
#HFM


summary2='PROD ::: Registering Supplier User - Error Details'
description2='Hello,Below are the new error details from the Supplier user auto-registration process.Concurrent Request ID :142730498 h3. Error Summary||Record ID||	Supplier Name||	Supplier Number||	Contact Person Name||	User Name||	Email Address||	Error Message||	Processing Date|||49300|	CARLA CAFE LLC|	1065382|	aviahdoot@gmail.com|	-|	aviahdoot@gmail.com|	Trying to create a new user, but an user is already existing with the same email address.|	22-Mar-2022 08:33:31|Thank You,Uber Finance'
#Oracle_ap

summary3="Request Access to Kryba and Ucash"
description3='Hi Team,I am a new user , part of the Revenue Accounting Payments Team , Bangalore. Please could you provide Access to the below programs as they are required to perform some BAU activities related to RA|Revenue Platforms (uCash)|'
#Kyriba_access_request


payload_1={'l1triage_input_data':[{"summary":summary1,"description":description1},
            {"summary":summary2,"description":description2},
            {"summary":summary3,"description":description3}]}
print(type(payload_1))
data={"summary":"JSON 210 ERRORS - TRICOR BRAUN","description":"== Created by JEMH via e-mail from: <POKLI@KLEINSCHMIDT.COM> == CUSTOMER_NAME: TricorBraun - USINVOICE_NUMBER: 8041382599INVOICE_NUMBER: 1007776816INVOICE_NUMBER: 4718348161ERROR: NULLS FOUND IN JSON ADDRESS"}
    

#data={'item_summary':summary1,'description':description1,'establishment_type':establishment_type1}
try:
    response = requests.post(url, json=payload_1, verify=False)
    #response = requests.post(url, data=data, verify=False)
    print(response.text)

except requests.ConnectionError as e:
    print("OOPS!! Connection Error. Make sure you are connected to Internet. Technical Details given below.\n")
    print(str(e))            
    #renewIPadress()
    #continue
except requests.Timeout as e:
    print("OOPS!! Timeout Error")
    print(str(e))
    #renewIPadress()
    #continue
except requests.RequestException as e:
    print("OOPS!! General Error")
    print(str(e))
    #renewIPadress()
    #continue
except KeyboardInterrupt:
    print("Someone closed the program")
