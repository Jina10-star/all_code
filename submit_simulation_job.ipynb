# %%
from flipr_client.clients.remote_client import RemoteClient
from queryrunner_client import Client as QueryRunnerClient
import yaml
from typing import *
import copy
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

from mdstk import (
    SimulationJob,
    MultiverseClient,
    DataFetcher,
)

from batch_utils import helpers
from batch_utils.study_run import StudyRun
from batch_utils.batch_querier import BatchQuerier
from batch_utils.batch_querier_sim_x import create_x_batch_querier, study_run_to_cache_name
from batch_utils.batch_runner import BatchRunner

# %%
USER_EMAIL = 'mehrdadb@uber.com'
USER_UUID = '115cfaf7-2e91-4ff7-ad2e-9009cbd18727'
QR_CONSUMER = 'intelligentdispatch'

# %%
sum_cols = [
    "Number of Unfulfilled Trips",
    "Number of Rider Canceled Trips",
    "Number of Driver Canceled Trips",
    "Number of Completed Trips",
    "Number of Prematch Trips",
    "Number of Trip Swaps",
    "Number of Trips Without Fares",
    "Number Of Jobs With Greedy Fallback",
    "Number of Spinner Canceled Trips",
    "Number of ReRequest Trips",
    
    "Total Hours",
    "Full Bookings. (Local Fare Calc.)",
    "n"
]

avg_cols = [
    "Overall Avg. Pickup Time",
    "Driver Offer Rejection Rate",
    "Overall Avg. Cost (Local Fare Calc.)",
    "Cancel Probability Avg. Rider",
    "Cancel Probability Avg. Driver",
    "Overall Avg. Trip Duration",
]

# %%
def agg_sum(df, c, total_col='n'):
    return df[c].sum()

def agg_avg(df, c, total_col='n'):
    return (df[c]*df[total_col]).sum() / df[total_col].sum()

def aggregate_func(df):
    return pd.DataFrame({
        **{c: [agg_sum(df, c)] for c in sum_cols},
        **{c: [agg_avg(df, c)] for c in avg_cols},
    })

# %%
#qr_client = QueryRunnerClient(user_email=USER_EMAIL)
qr_client = QueryRunnerClient(consumer_name=QR_CONSUMER)

CACHE_DIR = 'cache'
STUDY_PREFIX = 'partitioning_preXP'
# MULTILEG_VERSION = '04e41cd6baa8'
MULTILEG_VERSION = 'cd511031ba1485dfb784dfb2db3c2fcb5375f0b7'

X_VVIDS = {
    90: 651,
    146: 1934,
    803: 10369,
    218: 837,
    1379: 10002430,
    799: 11047,

}
city_ids = [90, 146, 218, 803, 799, 1379]
city_id = 90

# %%
flipr = RemoteClient(
    host='localhost',
    port=14570,
    application_identifier='autolaszlo'
)
sim_client = MultiverseClient(
    user_email=USER_EMAIL, 
    user_uuid=USER_UUID,
)

# %%
pipelines = [
    f'rt-sim{n:02d}'
    for n in range(5, 32)
]
# pipelines

# %%
partitioning_settings = yaml.load('''
gb_centric_of.lambda: 1
polysolve.graph_partitioning_enabled: true
polysolve.plangen_parallel_of_enabled: true
polysolve.plangen_parallel_of_names:
    - gb_centric_of
polysolve.plangen_parallel_of_override_is_enabled: true
polysolve.plangen_parallel_of_solving_enabled: true
objective_function.use_compound_completion_rate_of: false
''')
# Out:
# /dsw/snapshots/snapshot_dsw_default_jupyter/python3/lib/python3.6/site-packages/ipykernel_launcher.py:10: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   # Remove the CWD from sys.path while we load stuff.

# %%
def get_partitioning_multileg(enabled: bool, percentage_based_override=False):
     return {
        'gb_centric_of.lambda': 1,
        'polysolve.graph_partitioning_enabled': enabled,
        'polysolve.plangen_parallel_of_enabled': True,
        'polysolve.plangen_parallel_of_names': ['gb_centric_of'],
        'polysolve.plangen_parallel_of_override_is_enabled': enabled,
        'polysolve.plangen_parallel_of_solving_enabled': enabled,
        'objective_function.use_compound_completion_rate_of': False,
        'polysolve.should_use_percentage_based_override': percentage_based_override,
        'polysolve.percentage_based_override_value': 0.1,
    }

# %%
def create_sim(r: StudyRun, 
               bq: BatchQuerier,
               study_prefix: str,
               sim_client, 
               mitm_perf_version='v5.0.1',
               multileg_sim_version='cd511031ba1485dfb784dfb2db3c2fcb5375f0b7',
               rt_control_tower_sim_version='main',
              ) -> SimulationJob:
    supply_df = bq.dfs[study_run_to_cache_name('supply', r)]
    demand_df = bq.dfs[study_run_to_cache_name('demand', r)]

    radars = helpers.get_radars(r.city_id, flipr)
    spinner_rates, spinner_params = helpers.get_spinners(city_id=r.city_id, vvid=r.x_vvid, flipr_client=flipr)

    sim_job = SimulationJob(
        sim_uuid=None,
        flow_type='solo',
        description=f'{study_prefix}_{r.name}',
        batch_ids=[study_prefix, str(r.city_id)],
        sim_client=sim_client,
        sim_object=None
    )
    
    sim_job.get_dependencies()['mitm-perf'] = mitm_perf_version
    sim_job.get_dependencies()['multileg-sim'] = multileg_sim_version
    sim_job.get_dependencies()['rt-control-tower-sim'] = rt_control_tower_sim_version

    sim_job.set_demand_input(demand_df)
    sim_job.set_supply_input(supply_df)
    sim_job.set_city_id(r.city_id)
    helpers.fix_michelangelo_keys(sim_job, r.city_id)
    helpers.clear_fliprs(sim_job)
    sim_job.update_fliprs({
         'rt-control-tower': {
             'ct_radars_v1': helpers.get_polysolve_radars(radars, r.x_vvid),
             'ct_radars_v2': radars
         },
        'multileg': get_partitioning_multileg(
            enabled=r.params['partitioning_enabled'],
            percentage_based_override=r.params['percentage_based_override'],
        ),
        'disco': {
            'objective_value.calculator_type': 'markov_eta_v2',
        },
    })
    sim_job.update_settings({
        'spinner_cancel_params': spinner_params,
        'use_production_fliprs': True,
    })

    return sim_job

# %%
time_periods = [
     ("2021-08-23 09:00:00", "2021-08-23 10:00:00"),
    ("2021-08-25 11:00:00", "2021-08-25 11:30:00"),
]


sim_study = []
for _city_id in city_ids:
    for start, end in time_periods:
        sim_study.append(
            StudyRun(
                city_id=_city_id,
                x_vvid=X_VVIDS[_city_id],
                start_timestamp_local=start,
                end_timestamp_local=end,
                params={
                    "partitioning_enabled": True,
                    "percentage_based_override": True,
                }
            )
        )

# %%
bq = create_x_batch_querier(
    sim_study=sim_study,
    qr=qr_client,
)

# %%
bq.submit_jobs()
# Out:
# zz_data_cache_demand_90_651_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_90_651_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_90_651_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_90_651_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_146_1934_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_146_1934_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_146_1934_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_146_1934_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_218_837_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_218_837_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_218_837_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_218_837_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_803_10369_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_803_10369_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_803_10369_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_803_10369_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_799_11047_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_799_11047_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_799_11047_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_799_11047_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_1379_10002430_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_1379_10002430_2021-08-23 09:00:00_2021-08-23 10:00:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_demand_1379_10002430_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!
# zz_data_cache_supply_1379_10002430_2021-08-25 11:00:00_2021-08-25 11:30:00.csv is already loaded from cache and bust_cache = False!

# %%
bq.block_until_complete()
# Out:
# Done!

# %%
if len(bq.get_failed_jobs()) > 0:
    raise ValueError(bq.get_failed_jobs())

# %%
pipelines = [
    f'rt-sim{n:02d}'
    for n in range(6, 32)
]

br = BatchRunner(
    sim_client=sim_client,
    sim_study=sim_study,
    create_sim=create_sim,
    study_prefix=STUDY_PREFIX,
    pipelines=pipelines,
)
br.start(bq=bq, 
         study_prefix=STUDY_PREFIX, 
         sim_client=sim_client, 
         # bust_cache=True,
         multileg_sim_version=MULTILEG_VERSION)
# Out:
# Failed to load from cache/partitioning_preXP_90_651_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_90_651_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_90_651_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_90_651_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_146_1934_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_146_1934_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_146_1934_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_146_1934_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_218_837_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_218_837_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_218_837_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_218_837_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_803_10369_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_803_10369_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_803_10369_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_803_10369_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_799_11047_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_799_11047_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_799_11047_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_799_11047_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_1379_10002430_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_1379_10002430_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Failed to load from cache/partitioning_preXP_1379_10002430_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info: [Errno 2] No such file or directory: 'cache/partitioning_preXP_1379_10002430_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True.sim_info'
# Able to load 0 runs from cache!
# Overwriting radar... {'marketplace': 'personal_transport', 'radarData': {'upgradableProductTypeUUIDs': ['a18156c2-7523-48c6-9b08-fc768124fcea', '3ecdcafd-c771-42ec-b36d-c84481bdb817'], 'isPremiumRadar': False}, 'center': {'latitude': 19.5704756574, 'longitude': -99.2024972481}, 'cityName': 'mexico_city', 'uuid': 'radar_mexico_city_vvid651_index0', 'cityId': 90, 'tenancy': '', 'radarFlow': 'uberx', 'productTypeUUID': 'e1dbcf02-1429-4f90-b5cc-fd6af08e38f1', 'maxRadius': 41126, 'vvid': 651}
# Submitting 90_651_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 90_651_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'radarData': {'upgradableProductTypeUUIDs': ['a18156c2-7523-48c6-9b08-fc768124fcea', '3ecdcafd-c771-42ec-b36d-c84481bdb817'], 'isPremiumRadar': False}, 'center': {'latitude': 19.5704756574, 'longitude': -99.2024972481}, 'cityName': 'mexico_city', 'uuid': 'radar_mexico_city_vvid651_index0', 'cityId': 90, 'tenancy': '', 'radarFlow': 'uberx', 'productTypeUUID': 'e1dbcf02-1429-4f90-b5cc-fd6af08e38f1', 'maxRadius': 41126, 'vvid': 651}
# Submitting 90_651_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 90_651_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'uuid': 'radar_bogota_vvid1934_index0', 'center': {'latitude': 4.7091245231, 'longitude': -74.0719614391}, 'cityName': 'bogota', 'cityId': 146, 'tenancy': '', 'radarFlow': 'uberx', 'productTypeUUID': '3e061fc9-61dd-4d54-ae54-1b70384f27c2', 'maxRadius': 48420, 'vvid': 1934}
# Submitting 146_1934_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 146_1934_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'uuid': 'radar_bogota_vvid1934_index0', 'center': {'latitude': 4.7091245231, 'longitude': -74.0719614391}, 'cityName': 'bogota', 'cityId': 146, 'tenancy': '', 'radarFlow': 'uberx', 'productTypeUUID': '3e061fc9-61dd-4d54-ae54-1b70384f27c2', 'maxRadius': 48420, 'vvid': 1934}
# Submitting 146_1934_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 146_1934_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'uuid': 'radar_tijuana_vvid837_index0', 'center': {'latitude': 31.8570127247, 'longitude': -116.6056661039}, 'cityName': 'tijuana', 'vvid': 837, 'cityId': 218, 'radarFlow': 'uberx', 'productTypeUUID': '0ef18b8d-218c-4776-ba1c-31f6301a42e4', 'maxRadius': 22995, 'radarData': {'upgradableProductTypeUUIDs': ['79e14605-be3c-40cf-91ea-8bf110f00b87'], 'isPremiumRadar': False}}
# Submitting 218_837_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 218_837_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'uuid': 'radar_tijuana_vvid837_index0', 'center': {'latitude': 31.8570127247, 'longitude': -116.6056661039}, 'cityName': 'tijuana', 'vvid': 837, 'cityId': 218, 'radarFlow': 'uberx', 'productTypeUUID': '0ef18b8d-218c-4776-ba1c-31f6301a42e4', 'maxRadius': 22995, 'radarData': {'upgradableProductTypeUUIDs': ['79e14605-be3c-40cf-91ea-8bf110f00b87'], 'isPremiumRadar': False}}
# Submitting 218_837_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 218_837_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'radarData': {'upgradableProductTypeUUIDs': ['5c847d08-5d54-421e-aa3c-fedffae4328e'], 'isPremiumRadar': False}, 'center': {'latitude': -16.6927952669, 'longitude': -49.2726146148}, 'cityName': 'goiania', 'vvid': 10369, 'cityId': 803, 'tenancy': '', 'radarFlow': 'uberx', 'productTypeUUID': '46fd97b0-7650-4e6e-85ed-4590d378c8c5', 'maxRadius': 32389, 'uuid': 'radar_goiania_vvid10369_index0'}
# Submitting 803_10369_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 803_10369_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'radarData': {'upgradableProductTypeUUIDs': ['5c847d08-5d54-421e-aa3c-fedffae4328e'], 'isPremiumRadar': False}, 'center': {'latitude': -16.6927952669, 'longitude': -49.2726146148}, 'cityName': 'goiania', 'vvid': 10369, 'cityId': 803, 'tenancy': '', 'radarFlow': 'uberx', 'productTypeUUID': '46fd97b0-7650-4e6e-85ed-4590d378c8c5', 'maxRadius': 32389, 'uuid': 'radar_goiania_vvid10369_index0'}
# Submitting 803_10369_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 803_10369_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'uuid': 'radar_recife_vvid11047_index0', 'center': {'latitude': -7.958603197, 'longitude': -34.8650315361}, 'cityName': 'recife', 'radarData': {'upgradableProductTypeUUIDs': ['241735fe-4ec6-400e-93e7-3051acf42260'], 'isPremiumRadar': False}, 'cityId': 799, 'tenancy': '', 'radarFlow': 'uberx', 'productTypeUUID': '22e9fd39-d5f0-4b8e-84e3-2502c1510334', 'maxRadius': 38265, 'vvid': 11047}
# Submitting 799_11047_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 799_11047_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'uuid': 'radar_recife_vvid11047_index0', 'center': {'latitude': -7.958603197, 'longitude': -34.8650315361}, 'cityName': 'recife', 'radarData': {'upgradableProductTypeUUIDs': ['241735fe-4ec6-400e-93e7-3051acf42260'], 'isPremiumRadar': False}, 'cityId': 799, 'tenancy': '', 'radarFlow': 'uberx', 'productTypeUUID': '22e9fd39-d5f0-4b8e-84e3-2502c1510334', 'maxRadius': 38265, 'vvid': 11047}
# Submitting 799_11047_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 799_11047_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'uuid': 'radar_cabo_frio_vvid10002430_index0', 'center': {'latitude': -22.83040042, 'longitude': -42.07664753}, 'cityName': 'cabo_frio', 'vvid': 10002430, 'cityId': 1379, 'tenancy': '', 'radarFlow': 'uberx', 'productTypeUUID': 'ed2a3949-baf2-4882-9440-b889ba135243', 'maxRadius': 65000, 'radarData': {'upgradableProductTypeUUIDs': ['5b4df5d7-3a63-45de-9811-ceb8a188c272'], 'isPremiumRadar': False}}
# Submitting 1379_10002430_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 1379_10002430_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_True_percentage_based_override_True to disk...
# Overwriting radar... {'marketplace': 'personal_transport', 'uuid': 'radar_cabo_frio_vvid10002430_index0', 'center': {'latitude': -22.83040042, 'longitude': -42.07664753}, 'cityName': 'cabo_frio', 'vvid': 10002430, 'cityId': 1379, 'tenancy': '', 'radarFlow': 'uberx', 'productTypeUUID': 'ed2a3949-baf2-4882-9440-b889ba135243', 'maxRadius': 65000, 'radarData': {'upgradableProductTypeUUIDs': ['5b4df5d7-3a63-45de-9811-ceb8a188c272'], 'isPremiumRadar': False}}
# Submitting 1379_10002430_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True...
# Writing sim_uuid of 1379_10002430_2021-08-25 11:00:00_2021-08-25 11:30:00_partitioning_enabled_True_percentage_based_override_True to disk...

# %%
j = list(br.cache.values())[0].sim_job
print(yaml.dump(list(br.cache.values())[0].sim_job.get_params()))
# Out:
# batchIds:
# - PARTITIONING_V1
# - '90'
# cityId: 90
# createdAt: '2021-11-19T07:17:00.585Z'
# dependencyGitSha:
#   mitm-perf: 773ba4d3d9ed2b60bb59cf41c170a7a9873b9032
#   multileg-sim: 2a93d29691ffbd89017ae3fad15c64e34268e20e
#   rt-control-tower-sim: 8e836e61dd98b7a23ccae85b613c2b154f542dab
# dependencySpecs:
#   mitm-perf: v5.0.1
#   multileg-sim: 2a93d29691ffbd89017ae3fad15c64e34268e20e
#   rt-control-tower-sim: main
# description: partitioning_v1_90_651_2021-08-23 09:00:00_2021-08-23 10:00:00_partitioning_enabled_False
# errorMessage: 'java.lang.Exception: simulation 34f9f1d3-c366-402b-873b-6d18b52089b5
#   terminated'
# errorType: SIM_ERROR_UNKNOWN
# fliprOverrides:
#   disco:
#     objective_value.calculator_type: markov_eta_v2
#   dispatch:
#     jit.radarScanIntervalMs: 10000.0
#   motown: {}
#   multileg:
#     gb_centric_of.lambda: 1.0
#     objective_function.use_compound_completion_rate_of: false
#     polysolve.graph_partitioning_enabled: false
#     polysolve.plangen_parallel_of_enabled: true
#     polysolve.plangen_parallel_of_names:
#     - gb_centric_of
#     polysolve.plangen_parallel_of_override_is_enabled: false
#     polysolve.plangen_parallel_of_solving_enabled: false
#   rt-control-tower:
#     ct_radars_v1:
#       radars:
#       - center:
#           latitude: 19.4164143276
#           longitude: -99.1848260082
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 26148.0
#         productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#         radarData:
#           isPremiumRadar: true
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid188_index0
#         vvid: 188.0
#       - center:
#           latitude: 19.5704756574
#           longitude: -99.2024972481
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 9999999.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarData:
#           isPremiumRadar: false
#           upgradableProductTypeUUIDs:
#           - a18156c2-7523-48c6-9b08-fc768124fcea
#           - 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_index0
#         vvid: 651.0
#       - center:
#           latitude: 19.4301831787
#           longitude: -99.0570597726
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 44631.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarData:
#           isPremiumRadar: false
#           upgradableProductTypeUUIDs:
#           - a18156c2-7523-48c6-9b08-fc768124fcea
#           - 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_index1
#         vvid: 651.0
#       - center:
#           latitude: 19.3549726168
#           longitude: -99.192703678
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 21842.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarData:
#           isPremiumRadar: false
#           upgradableProductTypeUUIDs:
#           - a18156c2-7523-48c6-9b08-fc768124fcea
#           - 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_index2
#         vvid: 651.0
#       - center:
#           latitude: 19.4284398224
#           longitude: -99.1587411405
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 12941.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarData:
#           isPremiumRadar: false
#           upgradableProductTypeUUIDs:
#           - a18156c2-7523-48c6-9b08-fc768124fcea
#           - 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_index3
#         vvid: 651.0
#       - center:
#           latitude: 19.4449554635
#           longitude: -99.2105174673
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 11799.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarData:
#           isPremiumRadar: false
#           upgradableProductTypeUUIDs:
#           - a18156c2-7523-48c6-9b08-fc768124fcea
#           - 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_index4
#         vvid: 651.0
#       - center:
#           latitude: 19.5704756574
#           longitude: -99.2024972481
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 41126.0
#         productTypeUUID: 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         productTypeUUIDs:
#         - 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         - 7a63a403-c6e7-4297-980f-4011981aa929
#         - 35ac8da3-310a-4fac-8c79-07b8bedefb00
#         radarFlow: pool
#         tenancy: ''
#         uuid: radar_mexico_city_vvid7093_index0
#         vvid: 7093.0
#       - center:
#           latitude: 19.4301831787
#           longitude: -99.0570597726
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 44631.0
#         productTypeUUID: 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         productTypeUUIDs:
#         - 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         - 7a63a403-c6e7-4297-980f-4011981aa929
#         - 35ac8da3-310a-4fac-8c79-07b8bedefb00
#         radarFlow: pool
#         tenancy: ''
#         uuid: radar_mexico_city_vvid7093_index1
#         vvid: 7093.0
#       - center:
#           latitude: 19.3549726168
#           longitude: -99.192703678
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 21842.0
#         productTypeUUID: 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         productTypeUUIDs:
#         - 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         - 7a63a403-c6e7-4297-980f-4011981aa929
#         - 35ac8da3-310a-4fac-8c79-07b8bedefb00
#         radarFlow: pool
#         tenancy: ''
#         uuid: radar_mexico_city_vvid7093_index2
#         vvid: 7093.0
#       - center:
#           latitude: 19.4284398224
#           longitude: -99.1587411405
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 12941.0
#         productTypeUUID: 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         productTypeUUIDs:
#         - 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         - 7a63a403-c6e7-4297-980f-4011981aa929
#         - 35ac8da3-310a-4fac-8c79-07b8bedefb00
#         radarFlow: pool
#         tenancy: ''
#         uuid: radar_mexico_city_vvid7093_index3
#         vvid: 7093.0
#       - center:
#           latitude: 19.4449554635
#           longitude: -99.2105174673
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 11799.0
#         productTypeUUID: 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         productTypeUUIDs:
#         - 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         - 7a63a403-c6e7-4297-980f-4011981aa929
#         - 35ac8da3-310a-4fac-8c79-07b8bedefb00
#         radarFlow: pool
#         tenancy: ''
#         uuid: radar_mexico_city_vvid7093_index4
#         vvid: 7093.0
#       - center:
#           latitude: 19.4414353
#           longitude: -99.0676697
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4414353:-99.0676697
#         marketplace: personal_transport
#         maxRadius: 5000.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         productTypeUUIDs: []
#         radarFlow: solo_fifo
#         uuid: radar_mex_solo_fifo_mexico_city_vvid651_index0
#         vvid: 651.0
#       - center:
#           latitude: 19.4474901
#           longitude: -99.0871316
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4474901:-99.0871316
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         productTypeUUIDs: []
#         radarFlow: solo_fifo
#         uuid: radar_mex_solo_fifo_mexico_city_vvid651_index1
#         vvid: 651.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#         radarFlow: suv
#         tenancy: ''
#         uuid: radar_mexico_city_vvid434_index0
#         vvid: 434.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20010885_index0
#         vvid: 20010885.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 69d6bfe5-f488-48b6-a6c7-24257ca33b39
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid11073_index0
#         vvid: 11073.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20005029_index0
#         vvid: 20005029.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 6c23100c-3b83-4eec-a28a-564c061f2273
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20003643_index0
#         vvid: 20003643.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 8d1d9dd4-22cc-4fcb-b756-f18bcb5908fe
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20008097_index0
#         vvid: 20008097.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid10002592_index0
#         vvid: 10002592.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20011017_index0
#         vvid: 20011017.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: e44c94c3-7725-4f39-b768-43c445d45b04
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid4267_index0
#         vvid: 4267.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 4b285a9c-e69f-4da8-be3a-5086a737699b
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20013369_index0
#         vvid: 20013369.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#         radarFlow: uberxl
#         tenancy: ''
#         uuid: radar_mexico_city_vvid2569_index0
#         vvid: 2569.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: d99a3d62-f3ef-46c7-bac0-53633b2adb85
#         radarFlow: stunt
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20022093_index0
#         vvid: 20022093.0
#       - center:
#           latitude: 19.4036762
#           longitude: -99.0993496
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4036762:-99.0993496
#         marketplace: personal_transport
#         maxRadius: 5000.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         productTypeUUIDs: []
#         radarFlow: solo_fifo
#         uuid: radar_f1_event_mexico_city_vvid651_index0
#         vvid: 651.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: c4e28b0a-b7af-4f9a-9533-53102d820708
#         radarFlow: stunt
#         tenancy: ''
#         uuid: radar_mexico_city_vvid10002892_index0
#         vvid: 10002892.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 84aff688-aed2-4f13-b28c-7d384fc15101
#         radarFlow: stunt
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20015823_index0
#         vvid: 20015823.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: ea39975b-dc60-42a8-92a9-b613958bde10
#         radarFlow: stunt
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20006407_index0
#         vvid: 20006407.0
#       - center:
#           latitude: 19.4414353
#           longitude: -99.0676697
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4414353:-99.0676697
#         marketplace: personal_transport
#         maxRadius: 20000.0
#         productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#         productTypeUUIDs: []
#         radarFlow: solo_fifo
#         uuid: radar_mex_solo_fifo_uberx_vip_vvid20005029_index0
#         vvid: 20005029.0
#       - center:
#           latitude: 19.4474901
#           longitude: -99.0871316
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4474901:-99.0871316
#         marketplace: personal_transport
#         maxRadius: 20000.0
#         productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#         productTypeUUIDs: []
#         radarFlow: solo_fifo
#         uuid: radar_mex_solo_fifo_uberx_vip_vvid20005029_index1
#         vvid: 20005029.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 4ffdaa3b-0c05-49dc-882c-3149a40ae384
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20025493_index0
#         vvid: 20025493.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20025681_index0
#         vvid: 20025681.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 0f64000d-e7a6-4a76-bd7c-90507fd1ed11
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20025809_index0
#         vvid: 20025809.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: ff0d6d81-180b-4d14-9bef-005953d33fc0
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20026803_index0
#         vvid: 20026803.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: b5cdb1f7-b570-4452-80c8-22e110f5eaf5
#         radarFlow: rideritemdelivery
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20026899_index0
#         vvid: 20026899.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20030823_index0
#         vvid: 20030823.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 12a518b2-cbc9-401a-a4b4-3a55f730744d
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20033129_index0
#         vvid: 20033129.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20033343_index0
#         vvid: 20033343.0
#       - center:
#           latitude: 19.4474901
#           longitude: -99.0871316
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4474901:-99.0871316
#         isTemplate: true
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#         radarData:
#           fifoProducts:
#           - productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#             vehicleViewId: 188.0
#           - productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#             vehicleViewId: 434.0
#           - productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#             vehicleViewId: 2569.0
#           - productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#             vehicleViewId: 10002592.0
#           - productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#             vehicleViewId: 20010885.0
#           - productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#             vehicleViewId: 20011017.0
#           - productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#             vehicleViewId: 20025681.0
#           - productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#             vehicleViewId: 20030823.0
#           - productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#             vehicleViewId: 20033343.0
#         radarFlow: solo_fifo
#         tenancy: ''
#         uuid: radar_solo_fifo_19.4474901_-99.0871316_mexico_city_vvid<vvid>_index0
#         vvid: 20033343.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 200000.0
#         productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#         radarFlow: scheduledrideupfrontmatch
#         tenancy: ''
#         uuid: radar_mexico_city_vvid188_scheduled_solo_index0
#         vvid: 188.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 200000.0
#         productTypeUUID: 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: scheduledrideupfrontmatch
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20025509_scheduled_solo_index0
#         vvid: 20025509.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 200000.0
#         productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#         radarFlow: scheduledrideupfrontmatch
#         tenancy: ''
#         uuid: radar_mexico_city_vvid434_scheduled_solo_index0
#         vvid: 434.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 200000.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarFlow: scheduledrideupfrontmatch
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_scheduled_solo_index0
#         vvid: 651.0
#       - center:
#           latitude: 19.5704756574
#           longitude: -99.1848260082
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 50000.0
#         productTypeUUID: 39477121-7e0f-4428-bb59-788e3b294c61
#         productTypeUUIDs:
#         - 39477121-7e0f-4428-bb59-788e3b294c61
#         productUUID: 0347f054-fa6a-5a0e-b027-315e9a637ea1
#         radarFlow: hcv_rider_matching
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20036835_index1
#         vvid: 20036835.0
#       - center:
#           latitude: 19.5704756574
#           longitude: -99.1848260082
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 50000.0
#         productTypeUUID: 39477121-7e0f-4428-bb59-788e3b294c61
#         productTypeUUIDs:
#         - 39477121-7e0f-4428-bb59-788e3b294c61
#         productUUID: 0347f054-fa6a-5a0e-b027-315e9a637ea1
#         radarFlow: hcv_fleet_movement
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20036835_index2
#         vvid: 20036835.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#         radarFlow: rideritemdelivery
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20036429_index0
#         vvid: 20036429.0
#       - center:
#           latitude: 19.4414353
#           longitude: -99.0676697
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4414353:-99.0676697
#         isTemplate: true
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#         radarData:
#           fifoProducts:
#           - productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#             vehicleViewId: 188.0
#           - productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#             vehicleViewId: 434.0
#           - productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#             vehicleViewId: 651.0
#           - productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#             vehicleViewId: 2569.0
#           - productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#             vehicleViewId: 10002592.0
#           - productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#             vehicleViewId: 20010885.0
#           - productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#             vehicleViewId: 20011017.0
#           - productTypeUUID: 3ecdcafd-c771-42ec-b36d-c84481bdb817
#             vehicleViewId: 20025509.0
#           - productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#             vehicleViewId: 20025681.0
#           - productTypeUUID: ff0d6d81-180b-4d14-9bef-005953d33fc0
#             vehicleViewId: 20026803.0
#           - productTypeUUID: b5cdb1f7-b570-4452-80c8-22e110f5eaf5
#             vehicleViewId: 20026899.0
#           - productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#             vehicleViewId: 20030823.0
#           - productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#             vehicleViewId: 20033343.0
#           - productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#             vehicleViewId: 20036429.0
#         radarFlow: solo_fifo
#         tenancy: ''
#         uuid: radar_solo_fifo_19.4414353_-99.0676697_mexico_city_vvid<vvid>_index0
#         vvid: 20036429.0
#       - center:
#           latitude: 19.404700907
#           longitude: -99.09957445
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.404700907:-99.09957445
#         isTemplate: true
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#         radarData:
#           fifoProducts:
#           - productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#             vehicleViewId: 188.0
#           - productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#             vehicleViewId: 434.0
#           - productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#             vehicleViewId: 651.0
#           - productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#             vehicleViewId: 2569.0
#           - productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#             vehicleViewId: 10002592.0
#           - productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#             vehicleViewId: 20005029.0
#           - productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#             vehicleViewId: 20010885.0
#           - productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#             vehicleViewId: 20011017.0
#           - productTypeUUID: 3ecdcafd-c771-42ec-b36d-c84481bdb817
#             vehicleViewId: 20025509.0
#           - productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#             vehicleViewId: 20025681.0
#           - productTypeUUID: ff0d6d81-180b-4d14-9bef-005953d33fc0
#             vehicleViewId: 20026803.0
#           - productTypeUUID: b5cdb1f7-b570-4452-80c8-22e110f5eaf5
#             vehicleViewId: 20026899.0
#           - productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#             vehicleViewId: 20030823.0
#           - productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#             vehicleViewId: 20033343.0
#           - productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#             vehicleViewId: 20036429.0
#         radarFlow: solo_fifo
#         tenancy: ''
#         uuid: radar_solo_fifo_19.404700907_-99.09957445_mexico_city_vvid<vvid>_index0
#         vvid: 188.0
#       - center:
#           latitude: 19.411804611
#           longitude: -99.088729016
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.411804611:-99.088729016
#         isTemplate: true
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#         radarData:
#           fifoProducts:
#           - productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#             vehicleViewId: 188.0
#           - productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#             vehicleViewId: 434.0
#           - productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#             vehicleViewId: 651.0
#           - productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#             vehicleViewId: 2569.0
#           - productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#             vehicleViewId: 10002592.0
#           - productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#             vehicleViewId: 20005029.0
#           - productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#             vehicleViewId: 20010885.0
#           - productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#             vehicleViewId: 20011017.0
#           - productTypeUUID: 3ecdcafd-c771-42ec-b36d-c84481bdb817
#             vehicleViewId: 20025509.0
#           - productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#             vehicleViewId: 20025681.0
#           - productTypeUUID: ff0d6d81-180b-4d14-9bef-005953d33fc0
#             vehicleViewId: 20026803.0
#           - productTypeUUID: b5cdb1f7-b570-4452-80c8-22e110f5eaf5
#             vehicleViewId: 20026899.0
#           - productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#             vehicleViewId: 20030823.0
#           - productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#             vehicleViewId: 20033343.0
#           - productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#             vehicleViewId: 20036429.0
#         radarFlow: solo_fifo
#         tenancy: ''
#         uuid: radar_solo_fifo_19.411804611_-99.088729016_mexico_city_vvid<vvid>_index0
#         vvid: 188.0
#       - center:
#           latitude: 19.399409674
#           longitude: -99.086720428
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.399409674:-99.086720428
#         isTemplate: true
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#         radarData:
#           fifoProducts:
#           - productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#             vehicleViewId: 188.0
#           - productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#             vehicleViewId: 434.0
#           - productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#             vehicleViewId: 651.0
#           - productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#             vehicleViewId: 2569.0
#           - productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#             vehicleViewId: 10002592.0
#           - productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#             vehicleViewId: 20005029.0
#           - productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#             vehicleViewId: 20010885.0
#           - productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#             vehicleViewId: 20011017.0
#           - productTypeUUID: 3ecdcafd-c771-42ec-b36d-c84481bdb817
#             vehicleViewId: 20025509.0
#           - productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#             vehicleViewId: 20025681.0
#           - productTypeUUID: ff0d6d81-180b-4d14-9bef-005953d33fc0
#             vehicleViewId: 20026803.0
#           - productTypeUUID: b5cdb1f7-b570-4452-80c8-22e110f5eaf5
#             vehicleViewId: 20026899.0
#           - productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#             vehicleViewId: 20030823.0
#           - productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#             vehicleViewId: 20033343.0
#           - productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#             vehicleViewId: 20036429.0
#         radarFlow: solo_fifo
#         tenancy: ''
#         uuid: radar_solo_fifo_19.399409674_-99.086720428_mexico_city_vvid<vvid>_index0
#         vvid: 188.0
#     ct_radars_v2:
#       radars:
#       - center:
#           latitude: 19.4164143276
#           longitude: -99.1848260082
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 26148.0
#         productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#         radarData:
#           isPremiumRadar: true
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid188_index0
#         vvid: 188.0
#       - center:
#           latitude: 19.5704756574
#           longitude: -99.2024972481
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 41126.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarData:
#           isPremiumRadar: false
#           upgradableProductTypeUUIDs:
#           - a18156c2-7523-48c6-9b08-fc768124fcea
#           - 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_index0
#         vvid: 651.0
#       - center:
#           latitude: 19.4301831787
#           longitude: -99.0570597726
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 44631.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarData:
#           isPremiumRadar: false
#           upgradableProductTypeUUIDs:
#           - a18156c2-7523-48c6-9b08-fc768124fcea
#           - 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_index1
#         vvid: 651.0
#       - center:
#           latitude: 19.3549726168
#           longitude: -99.192703678
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 21842.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarData:
#           isPremiumRadar: false
#           upgradableProductTypeUUIDs:
#           - a18156c2-7523-48c6-9b08-fc768124fcea
#           - 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_index2
#         vvid: 651.0
#       - center:
#           latitude: 19.4284398224
#           longitude: -99.1587411405
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 12941.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarData:
#           isPremiumRadar: false
#           upgradableProductTypeUUIDs:
#           - a18156c2-7523-48c6-9b08-fc768124fcea
#           - 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_index3
#         vvid: 651.0
#       - center:
#           latitude: 19.4449554635
#           longitude: -99.2105174673
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 11799.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarData:
#           isPremiumRadar: false
#           upgradableProductTypeUUIDs:
#           - a18156c2-7523-48c6-9b08-fc768124fcea
#           - 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_index4
#         vvid: 651.0
#       - center:
#           latitude: 19.5704756574
#           longitude: -99.2024972481
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 41126.0
#         productTypeUUID: 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         productTypeUUIDs:
#         - 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         - 7a63a403-c6e7-4297-980f-4011981aa929
#         - 35ac8da3-310a-4fac-8c79-07b8bedefb00
#         radarFlow: pool
#         tenancy: ''
#         uuid: radar_mexico_city_vvid7093_index0
#         vvid: 7093.0
#       - center:
#           latitude: 19.4301831787
#           longitude: -99.0570597726
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 44631.0
#         productTypeUUID: 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         productTypeUUIDs:
#         - 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         - 7a63a403-c6e7-4297-980f-4011981aa929
#         - 35ac8da3-310a-4fac-8c79-07b8bedefb00
#         radarFlow: pool
#         tenancy: ''
#         uuid: radar_mexico_city_vvid7093_index1
#         vvid: 7093.0
#       - center:
#           latitude: 19.3549726168
#           longitude: -99.192703678
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 21842.0
#         productTypeUUID: 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         productTypeUUIDs:
#         - 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         - 7a63a403-c6e7-4297-980f-4011981aa929
#         - 35ac8da3-310a-4fac-8c79-07b8bedefb00
#         radarFlow: pool
#         tenancy: ''
#         uuid: radar_mexico_city_vvid7093_index2
#         vvid: 7093.0
#       - center:
#           latitude: 19.4284398224
#           longitude: -99.1587411405
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 12941.0
#         productTypeUUID: 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         productTypeUUIDs:
#         - 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         - 7a63a403-c6e7-4297-980f-4011981aa929
#         - 35ac8da3-310a-4fac-8c79-07b8bedefb00
#         radarFlow: pool
#         tenancy: ''
#         uuid: radar_mexico_city_vvid7093_index3
#         vvid: 7093.0
#       - center:
#           latitude: 19.4449554635
#           longitude: -99.2105174673
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 11799.0
#         productTypeUUID: 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         productTypeUUIDs:
#         - 0de90586-568f-45e7-a93a-f1ee7bb0901c
#         - 7a63a403-c6e7-4297-980f-4011981aa929
#         - 35ac8da3-310a-4fac-8c79-07b8bedefb00
#         radarFlow: pool
#         tenancy: ''
#         uuid: radar_mexico_city_vvid7093_index4
#         vvid: 7093.0
#       - center:
#           latitude: 19.4414353
#           longitude: -99.0676697
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4414353:-99.0676697
#         marketplace: personal_transport
#         maxRadius: 5000.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         productTypeUUIDs: []
#         radarFlow: solo_fifo
#         uuid: radar_mex_solo_fifo_mexico_city_vvid651_index0
#         vvid: 651.0
#       - center:
#           latitude: 19.4474901
#           longitude: -99.0871316
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4474901:-99.0871316
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         productTypeUUIDs: []
#         radarFlow: solo_fifo
#         uuid: radar_mex_solo_fifo_mexico_city_vvid651_index1
#         vvid: 651.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#         radarFlow: suv
#         tenancy: ''
#         uuid: radar_mexico_city_vvid434_index0
#         vvid: 434.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20010885_index0
#         vvid: 20010885.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 69d6bfe5-f488-48b6-a6c7-24257ca33b39
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid11073_index0
#         vvid: 11073.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20005029_index0
#         vvid: 20005029.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 6c23100c-3b83-4eec-a28a-564c061f2273
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20003643_index0
#         vvid: 20003643.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 8d1d9dd4-22cc-4fcb-b756-f18bcb5908fe
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20008097_index0
#         vvid: 20008097.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid10002592_index0
#         vvid: 10002592.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20011017_index0
#         vvid: 20011017.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: e44c94c3-7725-4f39-b768-43c445d45b04
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid4267_index0
#         vvid: 4267.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 4b285a9c-e69f-4da8-be3a-5086a737699b
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20013369_index0
#         vvid: 20013369.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#         radarFlow: uberxl
#         tenancy: ''
#         uuid: radar_mexico_city_vvid2569_index0
#         vvid: 2569.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: d99a3d62-f3ef-46c7-bac0-53633b2adb85
#         radarFlow: stunt
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20022093_index0
#         vvid: 20022093.0
#       - center:
#           latitude: 19.4036762
#           longitude: -99.0993496
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4036762:-99.0993496
#         marketplace: personal_transport
#         maxRadius: 5000.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         productTypeUUIDs: []
#         radarFlow: solo_fifo
#         uuid: radar_f1_event_mexico_city_vvid651_index0
#         vvid: 651.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: c4e28b0a-b7af-4f9a-9533-53102d820708
#         radarFlow: stunt
#         tenancy: ''
#         uuid: radar_mexico_city_vvid10002892_index0
#         vvid: 10002892.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 84aff688-aed2-4f13-b28c-7d384fc15101
#         radarFlow: stunt
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20015823_index0
#         vvid: 20015823.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: ea39975b-dc60-42a8-92a9-b613958bde10
#         radarFlow: stunt
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20006407_index0
#         vvid: 20006407.0
#       - center:
#           latitude: 19.4414353
#           longitude: -99.0676697
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4414353:-99.0676697
#         marketplace: personal_transport
#         maxRadius: 20000.0
#         productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#         productTypeUUIDs: []
#         radarFlow: solo_fifo
#         uuid: radar_mex_solo_fifo_uberx_vip_vvid20005029_index0
#         vvid: 20005029.0
#       - center:
#           latitude: 19.4474901
#           longitude: -99.0871316
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4474901:-99.0871316
#         marketplace: personal_transport
#         maxRadius: 20000.0
#         productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#         productTypeUUIDs: []
#         radarFlow: solo_fifo
#         uuid: radar_mex_solo_fifo_uberx_vip_vvid20005029_index1
#         vvid: 20005029.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 4ffdaa3b-0c05-49dc-882c-3149a40ae384
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20025493_index0
#         vvid: 20025493.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20025681_index0
#         vvid: 20025681.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 0f64000d-e7a6-4a76-bd7c-90507fd1ed11
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20025809_index0
#         vvid: 20025809.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: ff0d6d81-180b-4d14-9bef-005953d33fc0
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20026803_index0
#         vvid: 20026803.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: b5cdb1f7-b570-4452-80c8-22e110f5eaf5
#         radarFlow: rideritemdelivery
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20026899_index0
#         vvid: 20026899.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20030823_index0
#         vvid: 20030823.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 12a518b2-cbc9-401a-a4b4-3a55f730744d
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20033129_index0
#         vvid: 20033129.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#         radarFlow: uberx
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20033343_index0
#         vvid: 20033343.0
#       - center:
#           latitude: 19.4474901
#           longitude: -99.0871316
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4474901:-99.0871316
# ...
#         maxRadius: 10000.0
#         productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#         radarData:
#           fifoProducts:
#           - productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#             vehicleViewId: 188.0
#           - productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#             vehicleViewId: 434.0
#           - productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#             vehicleViewId: 2569.0
#           - productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#             vehicleViewId: 10002592.0
#           - productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#             vehicleViewId: 20010885.0
#           - productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#             vehicleViewId: 20011017.0
#           - productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#             vehicleViewId: 20025681.0
#           - productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#             vehicleViewId: 20030823.0
#           - productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#             vehicleViewId: 20033343.0
#         radarFlow: solo_fifo
#         tenancy: ''
#         uuid: radar_solo_fifo_19.4474901_-99.0871316_mexico_city_vvid<vvid>_index0
#         vvid: 20033343.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 200000.0
#         productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#         radarFlow: scheduledrideupfrontmatch
#         tenancy: ''
#         uuid: radar_mexico_city_vvid188_scheduled_solo_index0
#         vvid: 188.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 200000.0
#         productTypeUUID: 3ecdcafd-c771-42ec-b36d-c84481bdb817
#         radarFlow: scheduledrideupfrontmatch
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20025509_scheduled_solo_index0
#         vvid: 20025509.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 200000.0
#         productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#         radarFlow: scheduledrideupfrontmatch
#         tenancy: ''
#         uuid: radar_mexico_city_vvid434_scheduled_solo_index0
#         vvid: 434.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 200000.0
#         productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#         radarFlow: scheduledrideupfrontmatch
#         tenancy: ''
#         uuid: radar_mexico_city_vvid651_scheduled_solo_index0
#         vvid: 651.0
#       - center:
#           latitude: 19.5704756574
#           longitude: -99.1848260082
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 50000.0
#         productTypeUUID: 39477121-7e0f-4428-bb59-788e3b294c61
#         productTypeUUIDs:
#         - 39477121-7e0f-4428-bb59-788e3b294c61
#         productUUID: 0347f054-fa6a-5a0e-b027-315e9a637ea1
#         radarFlow: hcv_rider_matching
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20036835_index1
#         vvid: 20036835.0
#       - center:
#           latitude: 19.5704756574
#           longitude: -99.1848260082
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 50000.0
#         productTypeUUID: 39477121-7e0f-4428-bb59-788e3b294c61
#         productTypeUUIDs:
#         - 39477121-7e0f-4428-bb59-788e3b294c61
#         productUUID: 0347f054-fa6a-5a0e-b027-315e9a637ea1
#         radarFlow: hcv_fleet_movement
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20036835_index2
#         vvid: 20036835.0
#       - center:
#           latitude: 19.432924
#           longitude: -99.138479
#         cityId: 90.0
#         cityName: mexico_city
#         marketplace: personal_transport
#         maxRadius: 65000.0
#         productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#         radarFlow: rideritemdelivery
#         tenancy: ''
#         uuid: radar_mexico_city_vvid20036429_index0
#         vvid: 20036429.0
#       - center:
#           latitude: 19.4414353
#           longitude: -99.0676697
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.4414353:-99.0676697
#         isTemplate: true
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#         radarData:
#           fifoProducts:
#           - productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#             vehicleViewId: 188.0
#           - productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#             vehicleViewId: 434.0
#           - productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#             vehicleViewId: 651.0
#           - productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#             vehicleViewId: 2569.0
#           - productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#             vehicleViewId: 10002592.0
#           - productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#             vehicleViewId: 20010885.0
#           - productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#             vehicleViewId: 20011017.0
#           - productTypeUUID: 3ecdcafd-c771-42ec-b36d-c84481bdb817
#             vehicleViewId: 20025509.0
#           - productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#             vehicleViewId: 20025681.0
#           - productTypeUUID: ff0d6d81-180b-4d14-9bef-005953d33fc0
#             vehicleViewId: 20026803.0
#           - productTypeUUID: b5cdb1f7-b570-4452-80c8-22e110f5eaf5
#             vehicleViewId: 20026899.0
#           - productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#             vehicleViewId: 20030823.0
#           - productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#             vehicleViewId: 20033343.0
#           - productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#             vehicleViewId: 20036429.0
#         radarFlow: solo_fifo
#         tenancy: ''
#         uuid: radar_solo_fifo_19.4414353_-99.0676697_mexico_city_vvid<vvid>_index0
#         vvid: 20036429.0
#       - center:
#           latitude: 19.404700907
#           longitude: -99.09957445
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.404700907:-99.09957445
#         isTemplate: true
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#         radarData:
#           fifoProducts:
#           - productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#             vehicleViewId: 188.0
#           - productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#             vehicleViewId: 434.0
#           - productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#             vehicleViewId: 651.0
#           - productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#             vehicleViewId: 2569.0
#           - productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#             vehicleViewId: 10002592.0
#           - productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#             vehicleViewId: 20005029.0
#           - productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#             vehicleViewId: 20010885.0
#           - productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#             vehicleViewId: 20011017.0
#           - productTypeUUID: 3ecdcafd-c771-42ec-b36d-c84481bdb817
#             vehicleViewId: 20025509.0
#           - productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#             vehicleViewId: 20025681.0
#           - productTypeUUID: ff0d6d81-180b-4d14-9bef-005953d33fc0
#             vehicleViewId: 20026803.0
#           - productTypeUUID: b5cdb1f7-b570-4452-80c8-22e110f5eaf5
#             vehicleViewId: 20026899.0
#           - productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#             vehicleViewId: 20030823.0
#           - productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#             vehicleViewId: 20033343.0
#           - productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#             vehicleViewId: 20036429.0
#         radarFlow: solo_fifo
#         tenancy: ''
#         uuid: radar_solo_fifo_19.404700907_-99.09957445_mexico_city_vvid<vvid>_index0
#         vvid: 188.0
#       - center:
#           latitude: 19.411804611
#           longitude: -99.088729016
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.411804611:-99.088729016
#         isTemplate: true
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#         radarData:
#           fifoProducts:
#           - productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#             vehicleViewId: 188.0
#           - productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#             vehicleViewId: 434.0
#           - productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#             vehicleViewId: 651.0
#           - productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#             vehicleViewId: 2569.0
#           - productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#             vehicleViewId: 10002592.0
#           - productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#             vehicleViewId: 20005029.0
#           - productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#             vehicleViewId: 20010885.0
#           - productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#             vehicleViewId: 20011017.0
#           - productTypeUUID: 3ecdcafd-c771-42ec-b36d-c84481bdb817
#             vehicleViewId: 20025509.0
#           - productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#             vehicleViewId: 20025681.0
#           - productTypeUUID: ff0d6d81-180b-4d14-9bef-005953d33fc0
#             vehicleViewId: 20026803.0
#           - productTypeUUID: b5cdb1f7-b570-4452-80c8-22e110f5eaf5
#             vehicleViewId: 20026899.0
#           - productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#             vehicleViewId: 20030823.0
#           - productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#             vehicleViewId: 20033343.0
#           - productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#             vehicleViewId: 20036429.0
#         radarFlow: solo_fifo
#         tenancy: ''
#         uuid: radar_solo_fifo_19.411804611_-99.088729016_mexico_city_vvid<vvid>_index0
#         vvid: 188.0
#       - center:
#           latitude: 19.399409674
#           longitude: -99.086720428
#         cityId: 90.0
#         cityName: mexico_city
#         fifoQueueId: 19.399409674:-99.086720428
#         isTemplate: true
#         marketplace: personal_transport
#         maxRadius: 10000.0
#         productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#         radarData:
#           fifoProducts:
#           - productTypeUUID: a18156c2-7523-48c6-9b08-fc768124fcea
#             vehicleViewId: 188.0
#           - productTypeUUID: aaab999c-07e5-4314-a50c-9d7fbef0c490
#             vehicleViewId: 434.0
#           - productTypeUUID: e1dbcf02-1429-4f90-b5cc-fd6af08e38f1
#             vehicleViewId: 651.0
#           - productTypeUUID: 2c154bda-1dea-40eb-8b75-d4c3211fc5b3
#             vehicleViewId: 2569.0
#           - productTypeUUID: 7e73f291-293a-465e-9487-0c6d678fadd1
#             vehicleViewId: 10002592.0
#           - productTypeUUID: d43c82c3-e978-479d-8c2d-3c7e2e7bfaed
#             vehicleViewId: 20005029.0
#           - productTypeUUID: a35301ce-7301-487c-bf89-ddf4b0f4f795
#             vehicleViewId: 20010885.0
#           - productTypeUUID: 5cf5482d-a49b-4d1e-b333-4fea7e949ed6
#             vehicleViewId: 20011017.0
#           - productTypeUUID: 3ecdcafd-c771-42ec-b36d-c84481bdb817
#             vehicleViewId: 20025509.0
#           - productTypeUUID: cacb2d9f-e570-4dff-8a49-b3f7602ceec4
#             vehicleViewId: 20025681.0
#           - productTypeUUID: ff0d6d81-180b-4d14-9bef-005953d33fc0
#             vehicleViewId: 20026803.0
#           - productTypeUUID: b5cdb1f7-b570-4452-80c8-22e110f5eaf5
#             vehicleViewId: 20026899.0
#           - productTypeUUID: 4b17048e-9041-48ce-9b78-3a514179a5bb
#             vehicleViewId: 20030823.0
#           - productTypeUUID: 31d737b0-78a9-442e-8af4-3d48cf460cb0
#             vehicleViewId: 20033343.0
#           - productTypeUUID: cf4cd83c-65d8-4770-a3b4-8d997dca66dc
#             vehicleViewId: 20036429.0
#         radarFlow: solo_fifo
#         tenancy: ''
#         uuid: radar_solo_fifo_19.399409674_-99.086720428_mexico_city_vvid<vvid>_index0
#         vvid: 188.0
#     enable.product.type.scan: false
#     entityAggregator.sticky_routing.enabled: false
#     jit.is_simulation: true
#     jit.streaming_jit_flow.mode: ignore
#   rt-surge: {}
# postprocessingResult: {}
# postprocessingScripts:
# - pt_local_fare_calculation_postprocessing.py
# - report_generation_postprocessing.py
# - result_accuracy_assessment_postprocessing.py
# preprocessingResult: {}
# priority: 3
# result: {}
# settings:
#   cancel_model_name: pt_agent_cancels_deterministic_production
#   demand_input_type: trip
#   dropoff_walking_radius: 350.0
#   enable_cancel_sim: true
#   enable_matching_cache_warmup: true
#   fd_window_sec: 120.0
#   geobase_client: SimDepsGeobase
#   matcher_type: ProdJitMatcher
#   max_capacity: 4.0
#   pickup_duration: 35.0
#   pickup_walking_radius: 350.0
#   rt_demand_client: SimDepsRtDemand
#   rt_supply_client: SimDepsRtSupply
#   scan_for_radar_interval_sec: 10.0
#   solo_cancel_params:
#     driverMichelangeloGroup: michelangelo-gateway
#     driverMichelangeloShardKey: michelangelo-prediction-group48:city_id_90
#     driverModelLabel: driver_city_90_v4
#     driverProjectID: dispatch_driver_cancels_v5
#     loggingPercentage: 1.0
#     michelangeloMode: riderAndDriver
#     morpheusExperimentName: solo_cancel_model_jit_batched
#     rankingMode: 'off'
#     riderMichelangeloGroup: michelangelo-gateway
#     riderMichelangeloShardKey: michelangelo-prediction-group38:city_id_90
#     riderModelLabel: rider_city_90_v4
#     riderProjectID: dispatch_rider_cancels_v5
#     useRealtimeFeatures: false
#   spinner_cancel_params:
#     '651':
#       intervalModel1MS: 10000.0
#       intervalModel2MS: 10000.0
#       spinnerCancelRatesModel1:
#       - 0.0036493172
#       - 0.0044082685000000005
#       - 0.0041133166
#       - 0.0046957823000000004
#       - 0.0060697063
#       - 0.0068545362000000006
#       - 0.008065652100000001
#       - 0.0092259969
#       - 0.0099865986
#       - 0.0110487403
#       - 0.0116929057
#       - 0.0119842251
#       - 0.009587870600000001
#       spinnerCancelRatesModel2:
#       - 0.0053627377
#       - 0.0079254459
#       - 0.0093033156
#       - 0.0094845451
#       - 0.0095956244
#       - 0.0096910088
#       - 0.0106089545
#       - 0.0105673723
#       - 0.0120048479
#       - 0.012572446900000001
#       - 0.015303821
#       - 0.014364079200000001
#       - 0.015145823000000001
#   use_ct_keep_alive: true
#   use_production_fliprs: true
# simulationType: SIM_TYPE_MARKETPLACE_SIM
# state: SIM_STATE_MARKETPLACE_SIM_CANCELED
# states:
# - name: SIM_STATE_MARKETPLACE_SIM_QUEUED
#   simulationUuid: 34f9f1d3-c366-402b-873b-6d18b52089b5
#   timestamp: '2021-11-19T07:17:00.585Z'
# - name: SIM_STATE_MARKETPLACE_SIM_PREPROC_STARTED
#   simulationUuid: 34f9f1d3-c366-402b-873b-6d18b52089b5
#   timestamp: '2021-11-19T07:17:04.714Z'
# - addedBy: mehrdadb@uber.com
#   name: SIM_STATE_MARKETPLACE_SIM_CANCELED
#   simulationUuid: 34f9f1d3-c366-402b-873b-6d18b52089b5
#   timestamp: '2021-11-19T07:19:21.268Z'
# submitterEmail: mehrdadb@uber.com
# submitterUuid: 115cfaf7-2e91-4ff7-ad2e-9009cbd18727
# supplyData: f76d6573-aa01-409a-9b47-b9433feccd9e
# supplyDataParameters: {}
# targetPipelineUuids:
# - rt-sim06
# - rt-sim07
# - rt-sim08
# - rt-sim09
# - rt-sim10
# - rt-sim11
# - rt-sim12
# - rt-sim13
# - rt-sim14
# - rt-sim15
# - rt-sim16
# - rt-sim17
# - rt-sim18
# - rt-sim19
# - rt-sim20
# - rt-sim21
# - rt-sim22
# - rt-sim23
# - rt-sim24
# - rt-sim25
# - rt-sim26
# - rt-sim27
# - rt-sim28
# - rt-sim29
# - rt-sim30
# - rt-sim31
# tripData: 4fc4de23-1630-4c1d-8e86-3d1943794140
# tripDataParameters: {}
# updatedAt: '2021-11-19T07:19:21.268Z'
# uuid: 34f9f1d3-c366-402b-873b-6d18b52089b5

# %%
# for j in br.cache.values():
#     if j.sim_job.get_state() not in ('postproc_completed', 'sim_failed', 'canceled'):
#         j.sim_job.cancel()
