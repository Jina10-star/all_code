# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
import seaborn as sns
# Out:
# /dsw/snapshots/snapshot_dsw_default_jupyter/python37/lib/python3.7/site-packages/sklearn/utils/validation.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LARGE_SPARSE_SUPPORTED = LooseVersion(scipy_version) >= '0.14.0'

# %%
gb_fare_1269 = pd.read_csv(f'mlof_gb_plot_fare_city_1269.csv')
gb_fare_38 = pd.read_csv(f'mlof_gb_plot_fare_city_38.csv')
gb_fare_34 = pd.read_csv(f'mlof_gb_plot_fare_city_34.csv')
gb_fare_36 = pd.read_csv(f'mlof_gb_plot_fare_city_36.csv')

# %%
plt.plot(gb_fare_1269['upfront_fare_usd'], gb_fare_1269['gb_usd'], 'b+')
plt.xlabel('upfront_fare_usd')
plt.ylabel('gb_usd')
plt.savefig('gb_fare_1269.png')

# %%
gb_fare_1269_truncated = gb_fare_1269.loc[gb_fare_1269['upfront_fare_usd'] < 20]

# %%
plt.plot(gb_fare_1269_truncated['upfront_fare_usd'], gb_fare_1269_truncated['gb_usd'], 'b+')
plt.xlabel('upfront_fare_usd')
plt.ylabel('gb_usd')
plt.savefig('gb_fare_1269_truncated.png')

# %%
plt.plot(gb_fare_38['upfront_fare_usd'], gb_fare_38['gb_usd'], 'b+')
plt.xlabel('upfront_fare_usd')
plt.ylabel('gb_usd')
plt.savefig('gb_fare_38.png')

# %%
gb_fare_38_truncated = gb_fare_38.loc[gb_fare_38['upfront_fare_usd'] < 40]

# %%
plt.plot(gb_fare_38_truncated['upfront_fare_usd'], gb_fare_38_truncated['gb_usd'], 'b+')
plt.xlabel('upfront_fare_usd')
plt.ylabel('gb_usd')
plt.savefig('gb_fare_38_truncated.png')

# %%
gb_fare_34 = gb_fare_34.apply(pd.to_numeric)

# %%
plt.plot(gb_fare_34['upfront_fare_usd'], gb_fare_34['gb_usd'], 'b+')
plt.xlabel('upfront_fare_usd')
plt.ylabel('gb_usd')
plt.savefig('gb_fare_34.png')

# %%
gb_fare_34_truncated = gb_fare_34.loc[gb_fare_34['upfront_fare_usd'] < 100]

# %%
plt.plot(gb_fare_34_truncated['upfront_fare_usd'], gb_fare_34_truncated['gb_usd'], 'b+')
plt.xlabel('upfront_fare_usd')
plt.ylabel('gb_usd')
plt.savefig('gb_fare_34_truncated.png')

# %%
plt.plot(gb_fare_36['upfront_fare_usd'], gb_fare_36['gb_usd'], 'b+')
plt.xlabel('upfront_fare_usd')
plt.ylabel('gb_usd')
plt.savefig('gb_fare_36.png')

# %%
gb_fare_36_truncated = gb_fare_36.loc[gb_fare_36['upfront_fare_usd'] < 40]

# %%
plt.plot(gb_fare_36_truncated['upfront_fare_usd'], gb_fare_36_truncated['gb_usd'], 'b+')
plt.xlabel('upfront_fare_usd')
plt.ylabel('gb_usd')
plt.savefig('gb_fare_36_truncated.png')
