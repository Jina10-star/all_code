# %%
import pandas as pd
import numpy as np

# %%
# !mkdir -p pyml_model

# %%
# %%writefile pyml_model/__init__.py
# Out:
# Overwriting pyml_model/__init__.py

# %%
# %%writefile pyml_model/model_configuration.py
# Parameters to tune the model
'''
The value at folder_level defines what features we are using to train.
For example, the feature of the following files is shown as follows.

1. apps/presidio/helix/app/src/test/java/com/ubercab/presidio/app/optional/root/
main/menu/MenuStreamWithFallbackWorkerTest.java -- root

2. "apps/carbon/DriverLibraries/Core/RealtimeDriver/RealtimeDriver/TestMocks/
RealtimeDriverProtocolMocks.swift" -- RealtimeDriver

In other words, if folder_level = 4, the 4th level of directory structure is
considered as a feature for that particular file.
The feature for the files,

"apps/presidio/carbon/features/social-profiles-driver/src/main/java/com/ubercab/
social_profiles_driver/hub/SocialProfilesHubBuilder.java"
"apps/presidio/carbon/features/social-profiles-driver/src/main/java/com/ubercab/
social_profiles_driver/profile/SocialProfilesBuilder.java"
"apps/presidio/carbon/features/social-profiles-driver/src/main/java/com/ubercab/
social_profiles_driver/profile/SocialProfilesInteractor.java"
"apps/presidio/carbon/features/social-profiles-driver/src/test/java/com/ubercab/
social_profiles_driver/profile/SocialProfilesInteractorTest.java"

when folder_level=4 is ubercab.
'''
folder_level = 4
repo = ['mobile/android', 'mobile/ios', 'lm/fievel', 'go-code']  # Repo name
#repo = 'mobile/android'
p95_cutoff = {
    "mobile/android" : 65,
    "mobile/ios" : 20,
    "lm/fievel" : 20,
    "go-code" : 20,
}
train_test_split_ratio = 0.67
# Out:
# Overwriting pyml_model/model_configuration.py

# %%
# Constructing a query to get submitqueue and phab data for the last 90 days
import time
unix_timestamp_3_months_ago = (int(round(time.time() * 1000)) - 7776000000)
query = "select kafka_hp_phab_events_streamer_uci_diff_change_log_nodedup.msg.differential_id, \
kafka_hp_phab_events_streamer_uci_diff_change_log_nodedup.msg.files_changed, \
mysql_submitqueue_cigreeter_submitqueue_requests_rows.diff_id, \
mysql_submitqueue_cigreeter_submitqueue_requests_rows.revision_id, \
mysql_submitqueue_cigreeter_submitqueue_requests_rows.raw_request, \
mysql_submitqueue_cigreeter_submitqueue_requests_rows.received_timestamp, \
mysql_submitqueue_cigreeter_contexts_rows.latency_in_ms \
from rawdata_user.mysql_submitqueue_cigreeter_contexts_requests_mapping_rows \
inner join \
rawdata_user.mysql_submitqueue_cigreeter_contexts_rows \
on mysql_submitqueue_cigreeter_contexts_rows.id=mysql_submitqueue_cigreeter_contexts_requests_mapping_rows.context_id \
inner join rawdata_user.mysql_submitqueue_cigreeter_submitqueue_requests_rows \
on mysql_submitqueue_cigreeter_contexts_requests_mapping_rows.submit_queue_id=mysql_submitqueue_cigreeter_submitqueue_requests_rows.id  \
inner join rawdata_user.mysql_submitqueue_cigreeter_state_transitions_agg_rows \
on mysql_submitqueue_cigreeter_submitqueue_requests_rows.id=mysql_submitqueue_cigreeter_state_transitions_agg_rows.submit_queue_id \
inner join rawdata_user.kafka_hp_phab_events_streamer_uci_diff_change_log_nodedup \
on kafka_hp_phab_events_streamer_uci_diff_change_log_nodedup.msg.differential_id=mysql_submitqueue_cigreeter_submitqueue_requests_rows.revision_id \
where (mysql_submitqueue_cigreeter_contexts_rows.processor_id='BUILD_CHECKER' AND mysql_submitqueue_cigreeter_contexts_rows.activation_state='COMPLETE' AND mysql_submitqueue_cigreeter_state_transitions_agg_rows.state_name='SUCCEEDED' AND mysql_submitqueue_cigreeter_submitqueue_requests_rows.received_timestamp > %s) order by mysql_submitqueue_cigreeter_submitqueue_requests_rows.received_timestamp asc" %(unix_timestamp_3_months_ago)

# %%
# Executing a hive presto query which returns submitqueue_data
from queryrunner_client import Client
qr_obj = Client(user_email='ramsri@uber.com')
hive_data = qr_obj.execute('presto', query)
submitqueue_raw_data = []
for item in hive_data:
    submitqueue_raw_data.append(item)
# Out:
# 08/21/2019 06:34:32 PM  [Polling] e3ca7ac8-667d-4ee1-9504-2e53ab3ffe14
# 08/21/2019 06:34:32 PM  [Status] pending validation
# 08/21/2019 06:34:33 PM  [Status] pending execution
# 08/21/2019 06:34:34 PM  [Status] in execution
# 08/21/2019 06:34:34 PM  [External ID] 20190821_183434_72125_7eftn
# 08/21/2019 06:35:00 PM  [Status] finished success
# 08/21/2019 06:35:00 PM  [Query Success] finished success

# %%
# %%writefile pyml_model/model_utils.py
from collections import OrderedDict

# Parses submitqueue data and provides us with list features.
def feature_list(repo, submitqueue_raw_data, folder_level):
    list_of_features = OrderedDict()
    list_of_revision_ids = []
    for item in submitqueue_raw_data:
        # Every element in submitqueue_raw_data (item) list contains a set of information specific to each request.
        # item['raw_request'] contains information of the specific repo that a particular request queries.
        # We parse item['raw_request'] to query that.
        # An example of what is present in each item['raw_request'] is given below.
        # item['raw_request'] = {"remote":"gitolite@code.uber.internal:pricing/wayfare","diffId":"8438835", \
        #                       "revisionId":"2665737","targetOnto":"master"}
        # Filtering queries belonging to a particular repo!
        if item['raw_request'].split('internal:')[1].split("\"")[0] == repo: # filtering reques based on repo
            list_of_revision_ids.append(item['differential_id'])
            # Similarly, every element in item['files_changed'] contains the list of files changes for each diff.
            # An example of list of files for a sample item['files_changed' is illustrated in the two lines below.
            # item['files_changed'] = [u'apps/eats/app_root/app/src/main/java/com/ubercab/eats/app/module/EatsExperimentModule.java', \
            # u'apps/eats/library/core/build.gradle', u'apps/eats/library/core/src/main/java/com/ubercab/eats/core/module/package-info.java',\
            # u'apps/eats/app_root/app/src/main/java/com/ubercab/eats/package-info.java', u'apps/eats/library/core/BUCK']
            for fl in item['files_changed'].split(', '):
                feature = fl.split('\'')[1]
                if len(feature.split('/')) >= folder_level:
                    list_of_features[feature.split('/')[len(feature.split('/'))-folder_level]] = 0
                else:
                    list_of_features[feature] = 0
    return list_of_features, list_of_revision_ids

# Convert raw_data into a 2D list. i.e. For each query (1st Dimension),
# list of all features that are applicable (2nd Dimension)
def create_dataframe(repo, list_of_features, submitqueue_raw_data, folder_level):
    submitqueue_data = [] # retuns  1. list of list
    latency_list = []     # returns 2. list of all latencies
    temp_vector = list_of_features.copy() # make a copy of a OrderedDict, that contains a dictionary of features

    for item in submitqueue_raw_data:
        # Every element in submitqueue_raw_data (item) list contains a set of information specific to each request.
        # item['raw_request'] contains information of the specific repo that a particular request queries.
        # We parse item['raw_request'] to query that.
        # An example of what is present in each item['raw_request'] is given below.
        # item['raw_request'] = {"remote":"gitolite@code.uber.internal:pricing/wayfare","diffId":"8438835", \
        #                       "revisionId":"2665737","targetOnto":"master"}
        # Filtering queries belonging to a particular repo!
        if item['raw_request'].split('internal:')[1].split("\"")[0] == repo:
            temp_list = []
            # Similarly, every element in item['files_changed'] contains the list of files changes for each diff.
            # An example of list of files for a sample item['files_changed' is illustrated in the two lines below.
            # item['files_changed'] = [u'apps/eats/app_root/app/src/main/java/com/ubercab/eats/app/module/EatsExperimentModule.java', \
            # u'apps/eats/library/core/build.gradle', u'apps/eats/library/core/src/main/java/com/ubercab/eats/core/module/package-info.java',\
            # u'apps/eats/app_root/app/src/main/java/com/ubercab/eats/package-info.java', u'apps/eats/library/core/BUCK']
            for fl in item['files_changed'].split(', '):
                feature = fl.split('\'')[1]
                # for every file that's changed its corresponding feature is the folder name at the folder_level.
                # if the level of folders are lesser, the use the entire filename as feature.
                if len(feature.split('/')) >= folder_level:
                    if feature.split('/')[len(feature.split('/')) - folder_level] in temp_vector.keys():
                        temp_vector[feature.split('/')[len(feature.split('/')) - folder_level]] = 1 # Enable feature in dictionary
                else:
                    if feature in temp_vector.keys():
                        temp_vector[feature] = 1

            # Dump a vector of features into a list, a list of 0s and 1s which corresponds to the features enabled and disabled.
            temp_list.extend(temp_vector.values())

            # Reinitialize the features that are enabled to 0. It is then used for ne next SQ request in the next iteration
            for fl in item['files_changed'].split(', '):
                feature = fl.split('\'')[1]
                if len(feature.split('/')) >= folder_level:
                    if feature.split('/')[len(feature.split('/')) - folder_level] in temp_vector.keys():
                        temp_vector[feature.split('/')[len(feature.split('/')) - folder_level]] = 0
                else:
                    if feature in temp_vector.keys():
                        temp_vector[feature] = 0

            # Appending latency as a feature
            temp_list.append(float(item['latency_in_ms'])/1000)
            latency_list.append(float(item['latency_in_ms'])/1000)

            # Generating SubmitQueue feature 2D vector
            submitqueue_data.append(temp_list)

            del temp_list
    return submitqueue_data, latency_list
# Out:
# Overwriting pyml_model/model_utils.py

# %%
# !rm pyml_model/weights.pkl
# !rm pyml_model/listfile.txt
# !rm pyml_model/requirements.txt

# %%
# %%writefile pyml_model/requirements.txt
# pandas==0.18.1
# scipy==0.17.1
# numpy==1.16.4
# scikit-learn==0.20.3
# phabricator==0.7.0
# Out:
# Writing pyml_model/requirements.txt

# %%
# %%writefile pyml_model/model.py
import pandas as pd
import numpy as np
import os
import time
from collections import OrderedDict
import logging
import model_configuration


from pyml.model.dataframe_model import DataFrameModel
from sklearn.externals import joblib

class SQLogisticRegressionModel(DataFrameModel):
    """In order for your model to be evaluated on data in Hive, it must
    inherit from DataFrameModel. A DataFrameModel takes input as a pandas dataframe
    and produces predictions as a Pandas Dataframe. 
    """
    def __init__(self):
        super(SQLogisticRegressionModel, self).__init__()  # Don't forget this line
        
        # All paths should be relative to the root of your model folder. 
        self.clf = joblib.load('weights.pkl')
        
        # Initialize the list of features from the file
        f = open("listfile.txt", "r")
        self.list_of_features = OrderedDict()
        for idx,x in enumerate(f):
            self.list_of_features[x.split('\n')[0]] = 0
            #self.feature_columns.append(x.split('\n')[0])
        f.close()
        
        #self.feature_columns =  map(unicode,self.feature_columns)
        self.folder_level = model_configuration.folder_level
        
        # Your code should always access dataframe fields by name and never assume
        # that the columns will arrive in a particular order. Since sklearn
        # expects columns to be in a particular order, it's useful to have a list
        # of column names in that order. 

    def predict(self, df):
        """Predict receives data from a query as a pandas dataframe and returns
        results as a pandas dataframe.
        """
        
        # Obtain a feature vector based on string
        df_list = df.values.tolist()
        commit_features = [item for sublist in df_list for item in sublist]
        
        # Convert the features into 0s and 1s, then to a dataframe
        temp_list = []
        for item in commit_features:
            if item in self.list_of_features:
                self.list_of_features[item] = 1

        temp_list.extend(self.list_of_features.values())

        for item in commit_features:
            if item in self.list_of_features:
                self.list_of_features[item] = 0 

        predict_input = []
        predict_input.append(temp_list)
        feature = pd.DataFrame(predict_input)

        op_df = pd.DataFrame(self.clf.predict(feature), columns=['job_class'])
        return op_df
# Out:
# Overwriting pyml_model/model.py

# %%
import pyml_model.model_configuration as conf
import pyml_model.model_utils as util

# Train and get best model
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# Print training metrics
from sklearn.metrics import confusion_matrix

# Dump model into a pkl file
from sklearn.externals import joblib

# Dump model into a pkl file
from sklearn.externals import joblib

# PyML libraries
from pyml import PyMLModel, PythonML
from phabricator import Phabricator

# Splitting submitqueue data into two parts for train test and for validation
submitqueue_raw_data_train_test = submitqueue_raw_data[0:(2*len(submitqueue_raw_data))/3]
submitqueue_raw_data_validation = submitqueue_raw_data[(2*len(submitqueue_raw_data))/3:len(submitqueue_raw_data)]

model_ids = []

for repo_name in conf.repo:
    print repo_name
    # Obtaining a list of features (i.e. folder levels)
    list_of_features, list_of_revision_ids = util.feature_list(repo_name, submitqueue_raw_data_train_test, conf.folder_level)
    #print len(list_of_features), len(list_of_revision_ids)
    
    #Get train test raw data
    submitqueue_data_train_test, latency_list = util.create_dataframe(repo_name, list_of_features, submitqueue_raw_data_train_test, conf.folder_level)
    #print len(submitqueue_data_train_test), len(latency_list)
    
    # Feature names with latency
    column_names = []
    features = []
    for item in list_of_features:
        column_names.append(item)
        features.append(item)
    column_names.append("latency")
    

    
    # get pandas dataframe for train test data. This is used by scikit learn to perform training 
    data = pd.DataFrame(submitqueue_data_train_test, columns=column_names)

    # Create a bucket for classifying SQ requests below and above p95 latencies. 
    # e.g. bins - [-1.0, 3900, 7712.439], p95 = 39000s 
    bins = [np.min(latency_list)-1, conf.p95_cutoff[repo_name]*60, \
            max(np.max(latency_list)+1, conf.p95_cutoff[repo_name]*60 + 1)]
    #print bins

    # Label for SQ requests below p95 latency - 0 
    # Label for SQ requests above p95 latency - 1
    labels = [0,1]

    # Create a bucket colunm in my dataframe that assignns corresponding labels to my SQ data.
    data["bucket"] = pd.cut(data["latency"], bins, labels=labels, right=False)

    # Feature vector 
    feature_data = data[features] #X
    # Latency vector 
    latency_bins = data["bucket"]#y
    
    # Training using Logistic Regression
    logreg = LogisticRegression( max_iter=5000) # change to 5000

    # Hyperparameters
    penalty = ['l1', 'l2']
    C = np.logspace(0, 4, 10)
    hyperparameters = dict(C=C, penalty=penalty)
    clf = GridSearchCV(logreg, hyperparameters, cv=10, n_jobs=-1, verbose=1, scoring='f1_micro')
    best_model = clf.fit(feature_data, latency_bins)
    
    joblib.dump(best_model, 'pyml_model/weights.pkl') 
    
    with open('pyml_model/listfile.txt', 'w') as filehandle:  
        for listitem in features:
            filehandle.write('%s\n' % listitem)
        
    project_id = 'ram_python_ml_model_test'
    model_name = 'sq_ml'
    pyml_model = PyMLModel(model_path="pyml_model/",
                          project_id=project_id,
                          model_name=model_name)
    
    # Create project -- afterwards it will be available at https://michelangelo.uberinternal.com/ram_python_ml_model_test
    client = PythonML(user_email="ramsri@uber.com", ublame_team="mobile-ci-compute")
    model_id = client.upload_model(pyml_model, use_ma_processor=True, enable_validation=False) 

    model_ids.append(model_id)
    
    #client.deploy_model(project_id, 
    #                    model_id,
    #                    deployment_label=repo_name,
    #                    wait_timeout=3600)
    #
    #!rm pyml_model/listfile.txt
    # !rm pyml_model/weights.pkl
# Out:
# mobile/android
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:   58.7s finished
# 08/21/2019 06:37:31 PM  1. Archiving, Uploading, & Registering model with Michelangelo
# 2019-08-21 18:37:31,408 pyml INFO  1. Archiving, Uploading, & Registering model with Michelangelo
# 08/21/2019 06:37:31 PM  1/3 - Archiving model...
# 2019-08-21 18:37:31,411 pyml INFO  1/3 - Archiving model...
# 08/21/2019 06:37:31 PM  Success!
# 2019-08-21 18:37:31,427 pyml INFO  Success!
# 08/21/2019 06:37:31 PM  2/3 - Registering model...
# 2019-08-21 18:37:31,431 pyml INFO  2/3 - Registering model...
# 08/21/2019 06:37:31 PM  Success!
# 2019-08-21 18:37:31,454 pyml INFO  Success!
# 08/21/2019 06:37:31 PM  Uploading model archive to Michelangelo backend...
# 2019-08-21 18:37:31,475 pyml INFO  Uploading model archive to Michelangelo backend...
# 08/21/2019 06:37:31 PM  3/3 - Uploading model archive to Michelangelo backend...
# 2019-08-21 18:37:31,479 pyml INFO  3/3 - Uploading model archive to Michelangelo backend...
# 08/21/2019 06:37:31 PM  Success!
# 2019-08-21 18:37:31,632 pyml INFO  Success!
# 08/21/2019 06:37:31 PM  Model was registered. model_id: tm20190821-183731-YEVIEFAD-QVYTAS
# 2019-08-21 18:37:31,636 pyml INFO  Model was registered. model_id: tm20190821-183731-YEVIEFAD-QVYTAS
# 08/21/2019 06:37:31 PM  2. Building a new Docker Image for model
# 2019-08-21 18:37:31,639 pyml INFO  2. Building a new Docker Image for model
# 08/21/2019 06:37:31 PM  1/2 - Submitting docker image build request ...
# 2019-08-21 18:37:31,641 pyml INFO  1/2 - Submitting docker image build request ...
# 08/21/2019 06:37:32 PM  Success!
# 2019-08-21 18:37:32,587 pyml INFO  Success!
# 08/21/2019 06:37:32 PM  Docker status id: 8f5bd92c-6ee9-4548-b5e2-c1985e630c44
# 2019-08-21 18:37:32,590 pyml INFO  Docker status id: 8f5bd92c-6ee9-4548-b5e2-c1985e630c44
# 08/21/2019 06:37:32 PM  2/2 - Building image...
# 2019-08-21 18:37:32,592 pyml INFO  2/2 - Building image...
# 08/21/2019 06:37:32 PM  On average, this will take less than 10 min
# 2019-08-21 18:37:32,595 pyml INFO  On average, this will take less than 10 min
# 08/21/2019 06:37:47 PM  DockerBuildStatus({'status': None, 'dockerImageId': None, 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412652077, 'startTime': None, 'ubuildId': None, 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:37:47,624 pyml INFO  DockerBuildStatus({'status': None, 'dockerImageId': None, 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412652077, 'startTime': None, 'ubuildId': None, 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:38:02 PM  DockerBuildStatus({'status': None, 'dockerImageId': None, 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412652077, 'startTime': None, 'ubuildId': None, 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:38:02,647 pyml INFO  DockerBuildStatus({'status': None, 'dockerImageId': None, 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412652077, 'startTime': None, 'ubuildId': None, 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:38:17 PM  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412695498, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:38:17,670 pyml INFO  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412695498, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:38:32 PM  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412695498, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:38:32,690 pyml INFO  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412695498, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:38:47 PM  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412695498, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:38:47,714 pyml INFO  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412695498, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:39:02 PM  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412695498, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:39:02,739 pyml INFO  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412695498, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:39:17 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412756101, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:39:17,762 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412756101, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:39:32 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412756101, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:39:32,783 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412756101, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:39:47 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412756101, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:39:47,807 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412756101, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:40:02 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412756101, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:40:02,817 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412756101, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:40:17 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412816857, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:40:17,839 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412816857, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:40:32 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412816857, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:40:32,863 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412816857, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:40:47 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412816857, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:40:47,886 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412816857, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:41:02 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412816857, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:41:02,907 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412816857, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:41:17 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412877483, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:41:17,930 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412877483, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:41:32 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412877483, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:41:32,952 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412877483, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:41:47 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412877483, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:41:47,974 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412877483, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:42:02 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412877483, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:42:02,995 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412877483, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:42:18 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412877483, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:42:18,007 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412877483, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:42:33 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412938075, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:42:33,026 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412938075, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:42:48 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412938075, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:42:48,038 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412938075, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:43:03 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412938075, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:43:03,057 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412938075, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:43:18 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412938075, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:43:18,082 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412938075, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:43:33 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412998450, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:43:33,105 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412998450, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:43:48 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412998450, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:43:48,123 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412998450, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:44:03 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412998450, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:44:03,136 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412998450, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:44:18 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412998450, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:44:18,161 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566412998450, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:44:33 PM  DockerBuildStatus({'status': u'SUCCESS', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566413058798, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 2019-08-21 18:44:33,186 pyml INFO  DockerBuildStatus({'status': u'SUCCESS', 'dockerImageId': u'phx2-produ-0000000331', 'dockerBuildStatusId': u'8f5bd92c-6ee9-4548-b5e2-c1985e630c44', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-183731-YEVIEFAD', 'modifiedAt': 1566413058798, 'startTime': None, 'ubuildId': u'c20055db-8f86-4fea-82f9-7694038b458f', 'logUrl': None, 'modelId': u'tm20190821-183731-YEVIEFAD-QVYTAS'})
# 08/21/2019 06:44:33 PM  Updating model...
# 2019-08-21 18:44:33,189 pyml INFO  Updating model...
# 08/21/2019 06:44:33 PM  Model successfully updated.
# 2019-08-21 18:44:33,206 pyml INFO  Model successfully updated.
# mobile/ios
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  3.9min finished
# 08/21/2019 06:48:50 PM  1. Archiving, Uploading, & Registering model with Michelangelo
# 2019-08-21 18:48:50,233 pyml INFO  1. Archiving, Uploading, & Registering model with Michelangelo
# 08/21/2019 06:48:50 PM  1/3 - Archiving model...
# 2019-08-21 18:48:50,237 pyml INFO  1/3 - Archiving model...
# 08/21/2019 06:48:50 PM  Success!
# 2019-08-21 18:48:50,258 pyml INFO  Success!
# 08/21/2019 06:48:50 PM  2/3 - Registering model...
# 2019-08-21 18:48:50,261 pyml INFO  2/3 - Registering model...
# 08/21/2019 06:48:50 PM  Success!
# 2019-08-21 18:48:50,282 pyml INFO  Success!
# 08/21/2019 06:48:50 PM  Uploading model archive to Michelangelo backend...
# 2019-08-21 18:48:50,306 pyml INFO  Uploading model archive to Michelangelo backend...
# 08/21/2019 06:48:50 PM  3/3 - Uploading model archive to Michelangelo backend...
# 2019-08-21 18:48:50,309 pyml INFO  3/3 - Uploading model archive to Michelangelo backend...
# 08/21/2019 06:48:50 PM  Success!
# 2019-08-21 18:48:50,442 pyml INFO  Success!
# 08/21/2019 06:48:50 PM  Model was registered. model_id: tm20190821-184850-GHDRNJLL-BWVXEZ
# 2019-08-21 18:48:50,445 pyml INFO  Model was registered. model_id: tm20190821-184850-GHDRNJLL-BWVXEZ
# 08/21/2019 06:48:50 PM  2. Building a new Docker Image for model
# 2019-08-21 18:48:50,448 pyml INFO  2. Building a new Docker Image for model
# 08/21/2019 06:48:50 PM  1/2 - Submitting docker image build request ...
# 2019-08-21 18:48:50,450 pyml INFO  1/2 - Submitting docker image build request ...
# 08/21/2019 06:48:50 PM  Success!
# 2019-08-21 18:48:50,680 pyml INFO  Success!
# 08/21/2019 06:48:50 PM  Docker status id: df62e700-8730-4cce-af49-13f13c850ed4
# 2019-08-21 18:48:50,683 pyml INFO  Docker status id: df62e700-8730-4cce-af49-13f13c850ed4
# 08/21/2019 06:48:50 PM  2/2 - Building image...
# 2019-08-21 18:48:50,686 pyml INFO  2/2 - Building image...
# 08/21/2019 06:48:50 PM  On average, this will take less than 10 min
# 2019-08-21 18:48:50,689 pyml INFO  On average, this will take less than 10 min
# 08/21/2019 06:49:05 PM  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413335949, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:49:05,708 pyml INFO  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413335949, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:49:20 PM  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413335949, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:49:20,718 pyml INFO  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413335949, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:49:35 PM  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413335949, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:49:35,738 pyml INFO  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413335949, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:49:50 PM  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413335949, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:49:50,764 pyml INFO  DockerBuildStatus({'status': u'PREPARE', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413335949, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:50:05 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413396434, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:50:05,787 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413396434, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:50:20 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413396434, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:50:20,811 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413396434, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:50:35 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413396434, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:50:35,829 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413396434, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:50:50 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413396434, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:50:50,854 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413396434, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:51:05 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413457127, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:51:05,875 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413457127, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:51:20 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413457127, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:51:20,899 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413457127, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:51:35 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413457127, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:51:35,924 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413457127, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:51:50 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413457127, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:51:50,942 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413457127, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:52:05 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413517548, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:52:05,958 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413517548, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:52:20 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413517548, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:52:20,969 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413517548, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:52:35 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413517548, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:52:35,979 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413517548, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:52:51 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413517548, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:52:51,000 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413517548, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:53:06 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413577891, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:53:06,020 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413577891, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:53:21 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413577891, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 2019-08-21 18:53:21,040 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413577891, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# 08/21/2019 06:53:36 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000332', 'dockerBuildStatusId': u'df62e700-8730-4cce-af49-13f13c850ed4', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-184850-GHDRNJLL', 'modifiedAt': 1566413577891, 'startTime': None, 'ubuildId': u'8a833e05-4ffc-4098-9911-90d0380af521', 'logUrl': None, 'modelId': u'tm20190821-184850-GHDRNJLL-BWVXEZ'})
# ...
# 2019-08-21 19:14:39,424 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414870186, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:14:54 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414870186, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:14:54,433 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414870186, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:15:09 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414870186, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:15:09,453 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414870186, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:15:24 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414870186, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:15:24,468 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414870186, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:15:39 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414930376, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:15:39,486 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414930376, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:15:54 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414930376, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:15:54,507 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414930376, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:16:09 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414930376, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:16:09,531 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414930376, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:16:24 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414930376, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:16:24,555 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414930376, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:16:39 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414990550, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:16:39,575 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414990550, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:16:54 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414990550, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:16:54,600 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414990550, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:17:09 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414990550, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:17:09,624 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414990550, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:17:24 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414990550, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:17:24,679 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566414990550, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:17:39 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566415050685, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:17:39,705 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566415050685, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:17:54 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566415050685, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:17:54,730 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566415050685, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:18:09 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566415050685, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:18:09,746 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566415050685, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:18:24 PM  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566415050685, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:18:24,767 pyml INFO  DockerBuildStatus({'status': u'STARTED', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566415050685, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:18:39 PM  DockerBuildStatus({'status': u'SUCCESS', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566415110989, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 2019-08-21 19:18:39,780 pyml INFO  DockerBuildStatus({'status': u'SUCCESS', 'dockerImageId': u'phx2-produ-0000000334', 'dockerBuildStatusId': u'6c44cc1e-7d23-442e-a8f8-01d69befca43', 'endTime': None, 'projectId': u'ram_python_ml_model_test', 'errorMessage': None, 'tmId': u'tm20190821-191223-OMEBAFNY', 'modifiedAt': 1566415110989, 'startTime': None, 'ubuildId': u'd3198edd-be37-47bc-8bfc-ab7dc2e12aa2', 'logUrl': None, 'modelId': u'tm20190821-191223-OMEBAFNY-OGAKBE'})
# 08/21/2019 07:18:39 PM  Updating model...
# 2019-08-21 19:18:39,783 pyml INFO  Updating model...
# 08/21/2019 07:18:39 PM  Model successfully updated.
# 2019-08-21 19:18:39,801 pyml INFO  Model successfully updated.

# %%
f = open("model_ids.txt", "r")
project_id = 'ram_python_ml_model_test'

if len(model_ids) == 4:
    for repo_idx, repo_name in enumerate(conf.repo):
        client.deploy_model(project_id, 
            model_ids[repo_idx],
            deployment_label=repo_name,
            wait_timeout=3600)

if len(model_ids) == 4:
    for idx, model_id in enumerate(f):
        model_id_retire = model_id.split('\n')[0]
        client.retire_model(project_id, 
                            model_id_retire)
# Out:
# 08/21/2019 07:58:00 PM  Sending deployment request for model tm20190821-183731-YEVIEFAD-QVYTAS...
# 2019-08-21 19:58:00,645 pyml INFO  Sending deployment request for model tm20190821-183731-YEVIEFAD-QVYTAS...
# 08/21/2019 07:58:01 PM  Sent!
# 2019-08-21 19:58:01,854 pyml INFO  Sent!
# 08/21/2019 07:58:01 PM  On average, this will take less than 10 min
# 2019-08-21 19:58:01,857 pyml INFO  On average, this will take less than 10 min
# 08/21/2019 07:58:01 PM  For updates on the deployment status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 2019-08-21 19:58:01,860 pyml INFO  For updates on the deployment status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 08/21/2019 07:58:01 PM  Deploying...
# 2019-08-21 19:58:01,862 pyml INFO  Deploying...
# 08/21/2019 07:58:01 PM  You can find your custom logs here: https://search.uberinternal.com/#/dashboard/elasticsearch/pyml-image?_g=(model:tm20190821-183731-YEVIEFAD-QVYTAS)
# 2019-08-21 19:58:01,865 pyml INFO  You can find your custom logs here: https://search.uberinternal.com/#/dashboard/elasticsearch/pyml-image?_g=(model:tm20190821-183731-YEVIEFAD-QVYTAS)
# 08/21/2019 08:00:32 PM  Your model has been successfully deployed.
# 2019-08-21 20:00:32,275 pyml INFO  Your model has been successfully deployed.
# 08/21/2019 08:00:32 PM  Sending deployment request for model tm20190821-184850-GHDRNJLL-BWVXEZ...
# 2019-08-21 20:00:32,299 pyml INFO  Sending deployment request for model tm20190821-184850-GHDRNJLL-BWVXEZ...
# 08/21/2019 08:00:36 PM  Sent!
# 2019-08-21 20:00:36,710 pyml INFO  Sent!
# 08/21/2019 08:00:36 PM  On average, this will take less than 10 min
# 2019-08-21 20:00:36,713 pyml INFO  On average, this will take less than 10 min
# 08/21/2019 08:00:36 PM  For updates on the deployment status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 2019-08-21 20:00:36,716 pyml INFO  For updates on the deployment status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 08/21/2019 08:00:36 PM  Deploying...
# 2019-08-21 20:00:36,719 pyml INFO  Deploying...
# 08/21/2019 08:00:36 PM  You can find your custom logs here: https://search.uberinternal.com/#/dashboard/elasticsearch/pyml-image?_g=(model:tm20190821-184850-GHDRNJLL-BWVXEZ)
# 2019-08-21 20:00:36,722 pyml INFO  You can find your custom logs here: https://search.uberinternal.com/#/dashboard/elasticsearch/pyml-image?_g=(model:tm20190821-184850-GHDRNJLL-BWVXEZ)
# 08/21/2019 08:02:31 PM  Your model has been successfully deployed.
# 2019-08-21 20:02:31,981 pyml INFO  Your model has been successfully deployed.
# 08/21/2019 08:02:32 PM  Sending deployment request for model tm20190821-190228-VZPIXTVG-VFBAXW...
# 2019-08-21 20:02:32,002 pyml INFO  Sending deployment request for model tm20190821-190228-VZPIXTVG-VFBAXW...
# 08/21/2019 08:02:33 PM  Sent!
# 2019-08-21 20:02:33,355 pyml INFO  Sent!
# 08/21/2019 08:02:33 PM  On average, this will take less than 10 min
# 2019-08-21 20:02:33,358 pyml INFO  On average, this will take less than 10 min
# 08/21/2019 08:02:33 PM  For updates on the deployment status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 2019-08-21 20:02:33,361 pyml INFO  For updates on the deployment status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 08/21/2019 08:02:33 PM  Deploying...
# 2019-08-21 20:02:33,403 pyml INFO  Deploying...
# 08/21/2019 08:02:33 PM  You can find your custom logs here: https://search.uberinternal.com/#/dashboard/elasticsearch/pyml-image?_g=(model:tm20190821-190228-VZPIXTVG-VFBAXW)
# 2019-08-21 20:02:33,405 pyml INFO  You can find your custom logs here: https://search.uberinternal.com/#/dashboard/elasticsearch/pyml-image?_g=(model:tm20190821-190228-VZPIXTVG-VFBAXW)
# 08/21/2019 08:04:33 PM  Your model has been successfully deployed.
# 2019-08-21 20:04:33,696 pyml INFO  Your model has been successfully deployed.
# 08/21/2019 08:04:33 PM  Sending deployment request for model tm20190821-191223-OMEBAFNY-OGAKBE...
# 2019-08-21 20:04:33,720 pyml INFO  Sending deployment request for model tm20190821-191223-OMEBAFNY-OGAKBE...
# 08/21/2019 08:04:34 PM  Sent!
# 2019-08-21 20:04:34,928 pyml INFO  Sent!
# 08/21/2019 08:04:34 PM  On average, this will take less than 10 min
# 2019-08-21 20:04:34,931 pyml INFO  On average, this will take less than 10 min
# 08/21/2019 08:04:34 PM  For updates on the deployment status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 2019-08-21 20:04:34,934 pyml INFO  For updates on the deployment status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 08/21/2019 08:04:34 PM  Deploying...
# 2019-08-21 20:04:34,936 pyml INFO  Deploying...
# 08/21/2019 08:04:35 PM  You can find your custom logs here: https://search.uberinternal.com/#/dashboard/elasticsearch/pyml-image?_g=(model:tm20190821-191223-OMEBAFNY-OGAKBE)
# 2019-08-21 20:04:35,004 pyml INFO  You can find your custom logs here: https://search.uberinternal.com/#/dashboard/elasticsearch/pyml-image?_g=(model:tm20190821-191223-OMEBAFNY-OGAKBE)
# 08/21/2019 08:09:35 PM  Your model has been successfully deployed.
# 2019-08-21 20:09:35,766 pyml INFO  Your model has been successfully deployed.
# 08/21/2019 08:09:35 PM  Sending retirement request for model tm20190820-000509-OECZMDTI-PQGPAZ...
# 2019-08-21 20:09:35,791 pyml INFO  Sending retirement request for model tm20190820-000509-OECZMDTI-PQGPAZ...
# 08/21/2019 08:09:36 PM  Sent!
# 2019-08-21 20:09:36,234 pyml INFO  Sent!
# 08/21/2019 08:09:36 PM  On average, this will take less than 20 min
# 2019-08-21 20:09:36,237 pyml INFO  On average, this will take less than 20 min
# 08/21/2019 08:09:36 PM  For updates on the retirement status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 2019-08-21 20:09:36,241 pyml INFO  For updates on the retirement status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 08/21/2019 08:09:36 PM  Started waiting for a retirement request to finish
# 2019-08-21 20:09:36,244 pyml INFO  Started waiting for a retirement request to finish
# 08/21/2019 08:11:36 PM  Your model has been successfully retired.
# 2019-08-21 20:11:36,561 pyml INFO  Your model has been successfully retired.
# 08/21/2019 08:11:36 PM  Sending retirement request for model tm20190820-001359-TZVJCVWF-VKEDZE...
# 2019-08-21 20:11:36,584 pyml INFO  Sending retirement request for model tm20190820-001359-TZVJCVWF-VKEDZE...
# 08/21/2019 08:11:37 PM  Sent!
# 2019-08-21 20:11:37,021 pyml INFO  Sent!
# 08/21/2019 08:11:37 PM  On average, this will take less than 20 min
# 2019-08-21 20:11:37,025 pyml INFO  On average, this will take less than 20 min
# 08/21/2019 08:11:37 PM  For updates on the retirement status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 2019-08-21 20:11:37,101 pyml INFO  For updates on the retirement status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 08/21/2019 08:11:37 PM  Started waiting for a retirement request to finish
# 2019-08-21 20:11:37,104 pyml INFO  Started waiting for a retirement request to finish
# 08/21/2019 08:12:37 PM  Your model has been successfully retired.
# 2019-08-21 20:12:37,269 pyml INFO  Your model has been successfully retired.
# 08/21/2019 08:12:37 PM  Sending retirement request for model tm20190820-002917-PLAMURGK-IHXKCH...
# 2019-08-21 20:12:37,293 pyml INFO  Sending retirement request for model tm20190820-002917-PLAMURGK-IHXKCH...
# 08/21/2019 08:12:37 PM  Sent!
# 2019-08-21 20:12:37,754 pyml INFO  Sent!
# 08/21/2019 08:12:37 PM  On average, this will take less than 20 min
# 2019-08-21 20:12:37,757 pyml INFO  On average, this will take less than 20 min
# 08/21/2019 08:12:37 PM  For updates on the retirement status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 2019-08-21 20:12:37,760 pyml INFO  For updates on the retirement status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 08/21/2019 08:12:37 PM  Started waiting for a retirement request to finish
# 2019-08-21 20:12:37,762 pyml INFO  Started waiting for a retirement request to finish
# 08/21/2019 08:14:38 PM  Your model has been successfully retired.
# 2019-08-21 20:14:38,052 pyml INFO  Your model has been successfully retired.
# 08/21/2019 08:14:38 PM  Sending retirement request for model tm20190820-003851-PCFFXTBN-PCEGIP...
# 2019-08-21 20:14:38,074 pyml INFO  Sending retirement request for model tm20190820-003851-PCFFXTBN-PCEGIP...
# 08/21/2019 08:14:38 PM  Sent!
# 2019-08-21 20:14:38,435 pyml INFO  Sent!
# 08/21/2019 08:14:38 PM  On average, this will take less than 20 min
# 2019-08-21 20:14:38,438 pyml INFO  On average, this will take less than 20 min
# 08/21/2019 08:14:38 PM  For updates on the retirement status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 2019-08-21 20:14:38,440 pyml INFO  For updates on the retirement status, see UI here: https://michelangelo.uberinternal.com/ram_python_ml_model_test/models
# 08/21/2019 08:14:38 PM  Started waiting for a retirement request to finish
# 2019-08-21 20:14:38,443 pyml INFO  Started waiting for a retirement request to finish
# 08/21/2019 08:17:38 PM  Your model has been successfully retired.
# 2019-08-21 20:17:38,906 pyml INFO  Your model has been successfully retired.

# %%
if len(model_ids) == 4:
    # !rm pyml_model/listfile.txt
    with open('model_ids.txt', 'w') as filehandle:  
        for model_id in model_ids:
            filehandle.write('%s\n' % model_id)
