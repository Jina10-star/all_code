# %%
## Retrieval augmented generation

import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
#pip install llama-index

# %%
os.environ['OPENAI_API_KEY']='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'

# %%
from llama_index import VectorStoreIndex,SimpleDirectoryReader
documents=SimpleDirectoryReader("data").load_data()

# %%
documents
# Out:
# [Document(id_='2fdecd9a-dd6b-42d9-8131-6012937030e2', embedding=None, metadata={'page_label': '1', 'file_name': 'ARA_FIRE.pdf', 'file_path': 'data/ARA_FIRE.pdf', 'file_type': 'application/pdf', 'file_size': 281449, 'creation_date': '2024-01-31', 'last_modified_date': '2024-01-31', 'last_accessed_date': '2024-01-31'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='TAX INV OICE\nUBER AUSTRALIA PTY LTD\nAttn: Uber Australia Pty Ltd\nPKE LAWLER C/O PKE LAWLER SYDNEY 8\nSYDNEY\nNSW\nAU\nSite\nUBER 580 George\nLevel 30 580 George St Sydney NSW 2000\nJob Name\nrepair the solenoid on the pre-action systemInvoice Number\nAR000470\nClient Order No.\n507275\nInvoice Date\n3rd May 2023\nJob Number\nSY0872632\nDebtor Code (Email)\nAFC001153 (ap-au@uber.com)\nSite Workorder Number\n127270\nService Request / Works Performed:\n20-3-23\nElectrical tech rewired solenoid\nReplaced solenoid on pre action\nTested solenoid working ok\nDescription Qty Unit Price Price\nCallout - after hours (up to 1hr travel and 2hr labour included) 2.00 $600.00 $1,200.00\nLabour - after hours 4.00 $155.00 $620.00\nINVOICE VALUE EXCLUDING GST $1,820.00\nGST TOTAL $182.00\nINVOICE VALUE INCLUDING GST $2,002.00\nTerms of Payment:\nStrictly 14 days after invoice date.\nEFT Banking Details (please reference invoice no. AR000470):\nName: ARA Fire Protection Services Pty. Ltd.\nBSB: 032 267\nAccount No: 362381\nPayments may be made by credit card, phone (02) 8886 1300. Credit card payments incur a surcharge.\nE & O.E.\nProperty and ownership of these goods shall not pass to you until full payment is made.\nThis claim is made pursuant to the Building and Construction Industry Security of Payment Act 1999 (NSW) or Building and Construction\nIndustry Security of Payment Act 2009 (ACT).ARA Fire Protection Services Pty Ltd\nABN: 19 002 051 041\n20 Binney Road,\nKings Park NSW 2148\n1300 272 347infosyd@arafire.com.au\narafire.com.au\nPage 1 of 1', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='0cee584f-eea0-4d2a-9990-6c6ddd92f9cb', embedding=None, metadata={'page_label': '2', 'file_name': 'ARA_FIRE.pdf', 'file_path': 'data/ARA_FIRE.pdf', 'file_type': 'application/pdf', 'file_size': 281449, 'creation_date': '2024-01-31', 'last_modified_date': '2024-01-31', 'last_accessed_date': '2024-01-31'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text=" \n     SalesForce Details  \n \n \nSubject: UBER 580 George - Task #872632 repair the solenoid on the pre -action system  \nType: FeedItem  \nUpdatedBy: Vinay Guptha Dogiparthy  \nUpdated Time: 05/04/2023 09:57:35  \ninvoice processed in UI path. Awaiting to release hold  \n  \n \n \n \n \nType: FeedItem  \nUpdatedBy: RPA Integration User  \nUpdated Time: 05/03/2023 09:43:32  \nHi AP team,Something went wrong, please investigate further. 1) Access was denied (to Oracle or \nSalesforce) 2) Macro didn't work (Salesforce)Regards,Uber RPA Team  \n \n \n \nType: Em ail \nUpdatedBy: Admin User  \nUpdated Time: 05/02/2023 23:09:51  \nDear manager,  \nPlease find attached yourinvoicefor services carried out at UBER 580 George.  \n  Your invoice:  \n      Invoice Number: AR000470  ", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='998da091-c567-41fb-9a12-7569bd3dc94a', embedding=None, metadata={'page_label': '3', 'file_name': 'ARA_FIRE.pdf', 'file_path': 'data/ARA_FIRE.pdf', 'file_type': 'application/pdf', 'file_size': 281449, 'creation_date': '2024-01-31', 'last_modified_date': '2024-01-31', 'last_accessed_date': '2024-01-31'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='    Your Reference: 507275   \n    Customer Code: AFC001153   \n    Job Number: SY0872632   \n   \nFor any questions please contact the office.  \nRegards,  \nARA Fire NSW  \n20 Binney Road,  \nKings Park NSW 2148  \nT: 02 8886 1300  \nE: infosyd@arafire.com.au | W: www.arafire.com.au  \nPlease consider the environment before printing this email.  \nThis email contains privileged and confidential information intended only for the  \nuse of the addressee named above. If you are not the intended recipient of this message  \nyou are hereby notified th at you must not disseminate, copy or take action in reliance  \non it. If you have received this message in error please notify the sender immediately.  \n \n \n \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='2d9d77ca-7eeb-4ea0-a71c-5c573b0a1171', embedding=None, metadata={'page_label': '1', 'file_name': 'CARRIPOOK.pdf', 'file_path': 'data/CARRIPOOK.pdf', 'file_type': 'application/pdf', 'file_size': 234719, 'creation_date': '2024-01-31', 'last_modified_date': '2024-01-31', 'last_accessed_date': '2024-01-31'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="TAX INVOICE\nUBER AUSTRALIA PTY LTD\nAttention: AU ACCOUNTS PAYABLE\nC/-PKF Lawler Sydney\nUnit 8, 1 O'Connell Street\nSYDNEY NSW 2000Invoice Date\n1 Apr 2023\nInvoice Number\nINV-2107902\nReference\nApril 2023\nABN\n59 109 943 280Carripook Interior Plant\nCare\nP.O. BOX 396\nLilydale Vic 3140\nPH: 1300 587 875\nDescription Quantity Unit Price Amount AUD\nPurchase Order: PO# 507310\n200mm Plants with Liners for Tambour Planters @ $1.34 ea per\nweek80.00 5.8067 464.54\n200mm Plants with Liners for In-Built Planters @ $1.34 ea per week 22.00 5.8065 127.74\nKITCHEN\nBowl Desk Planters (top of Cupboards) @ $3.20 ea per week 6.00 13.86 83.16\nFloor Planters (Window) @ $4.70 ea per week 3.00 20.36 61.08\nTall Floor Troughs @ $6.20 ea per week. 2.00 26.86 53.72\nMedium Floor Planters ( to create step effect) @ $4.30 ea per week 6.00 18.63 111.78\nSmall Floor Planters ( to create step effect) @ $3.90 6.00 16.90 101.40\nBELLS BEACH\nTall Floor Troughs @ $6.20 ea per week 2.00 26.86 53.72\nTHE G\nTall Floor Troughs @ $6.20 ea per week 2.00 26.86 53.72\nPATTEN\nTall Floor Troughs @ $6.20 ea per week 2.00 26.86 53.72\nTODAYS MEETING\nTall Floor Troughs @ $6.20 ea per week 3.00 26.86 80.58\n5% CPI increase. 1.00 61.84 61.84\nSubtotal 1,307.00", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='e6ecc5c7-40d3-46c7-97f3-d5a57e98cd32', embedding=None, metadata={'page_label': '2', 'file_name': 'CARRIPOOK.pdf', 'file_path': 'data/CARRIPOOK.pdf', 'file_type': 'application/pdf', 'file_size': 234719, 'creation_date': '2024-01-31', 'last_modified_date': '2024-01-31', 'last_accessed_date': '2024-01-31'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='TOTAL\xa0 GST\xa0 10% 130.69\nTOTAL AUD 1,437.69\nDue Date: 15 Apr 2023\nDIRECT DEPOSIT\nAcct: Carripook Interior Plant Care\nBSB: 124 001\nAcct No: 20733654\nBank: Bank of Queensland.\nPlease send remittance advice to : accounts@carripook.com.au\nView and pay online now', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3b1bdf5f-d0cf-4b65-a5f0-f00e38adf97c', embedding=None, metadata={'page_label': '3', 'file_name': 'CARRIPOOK.pdf', 'file_path': 'data/CARRIPOOK.pdf', 'file_type': 'application/pdf', 'file_size': 234719, 'creation_date': '2024-01-31', 'last_modified_date': '2024-01-31', 'last_accessed_date': '2024-01-31'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text=' \n     SalesForce Details  \n \n \nSubject: Please process - Line 2 PO#507310 - Carripook  \nType: Email  \nUpdatedBy: Admin User  \nUpdated Time: 04/04/2023 19:10:14  \nHi Ap,  \nCan you please process the attached invoice against PO#  507310 - Line 2Vendor:  Carripook  \nRegards,  \nSaad Obeid  \nAssistant Facilities Manager   | JLL @ Uber  \n+61 434 436 821  \n \n @ \n \n \nNeed facilities help?   \nOpen a ticket on SIRequest!  \n \n \n \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %%
import os
os.environ['CURL_CA_BUNDLE'] = ''

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
index=VectorStoreIndex.from_documents(documents,show_progress=True)
# Out:
# Parsing nodes:   0%|          | 0/6 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     162                     self._sock.settimeout(timeout)
# --> 163                     sock = ssl_context.wrap_socket(
#     164                         self._sock, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      65     try:
# ---> 66         yield
#      67     except Exception as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     267                     self.response_closed(status)
# --> 268                 raise exc
#     269             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     250             try:
# --> 251                 response = connection.handle_request(request)
#     252             except ConnectionNotAvailable:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      98                     self._connect_failed = True
# ---> 99                     raise exc
#     100             elif not self._connection.is_available():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      75                 try:
# ---> 76                     stream = self._connect(request)
#      77
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in _connect(self, request)
#     155                     with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156                         stream = stream.start_tls(**kwargs)
#     157                         trace.return_value = stream
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857         try:
# --> 858             response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859             log.debug(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     900
# --> 901         response = self._send_handling_auth(
#     902             request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     928             while True:
# --> 929                 response = self._send_handling_redirects(
#     930                     request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     965
# --> 966             response = self._send_single_request(request)
#     967             try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1001         with request_context(request=request):
# -> 1002             response = transport.handle_request(request)
#    1003
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      82         message = str(exc)
# ---> 83         raise mapped_exc(message) from exc
#      84
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# During handling of the above exception, another exception occurred:
#
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     162                     self._sock.settimeout(timeout)
# --> 163                     sock = ssl_context.wrap_socket(
#     164                         self._sock, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      65     try:
# ---> 66         yield
#      67     except Exception as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     267                     self.response_closed(status)
# --> 268                 raise exc
#     269             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     250             try:
# --> 251                 response = connection.handle_request(request)
#     252             except ConnectionNotAvailable:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      98                     self._connect_failed = True
# ---> 99                     raise exc
#     100             elif not self._connection.is_available():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      75                 try:
# ---> 76                     stream = self._connect(request)
#      77
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in _connect(self, request)
#     155                     with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156                         stream = stream.start_tls(**kwargs)
#     157                         trace.return_value = stream
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857         try:
# --> 858             response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859             log.debug(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     900
# --> 901         response = self._send_handling_auth(
#     902             request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     928             while True:
# --> 929                 response = self._send_handling_redirects(
#     930                     request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     965
# --> 966             response = self._send_single_request(request)
#     967             try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1001         with request_context(request=request):
# -> 1002             response = transport.handle_request(request)
#    1003
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      82         message = str(exc)
# ---> 83         raise mapped_exc(message) from exc
#      84
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# During handling of the above exception, another exception occurred:
#
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     162                     self._sock.settimeout(timeout)
# --> 163                     sock = ssl_context.wrap_socket(
#     164                         self._sock, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      65     try:
# ---> 66         yield
#      67     except Exception as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     267                     self.response_closed(status)
# --> 268                 raise exc
#     269             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     250             try:
# --> 251                 response = connection.handle_request(request)
#     252             except ConnectionNotAvailable:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      98                     self._connect_failed = True
# ---> 99                     raise exc
#     100             elif not self._connection.is_available():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      75                 try:
# ---> 76                     stream = self._connect(request)
#      77
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in _connect(self, request)
#     155                     with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156                         stream = stream.start_tls(**kwargs)
#     157                         trace.return_value = stream
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857         try:
# --> 858             response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859             log.debug(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     900
# --> 901         response = self._send_handling_auth(
#     902             request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     928             while True:
# --> 929                 response = self._send_handling_redirects(
#     930                     request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     965
# --> 966             response = self._send_single_request(request)
#     967             try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1001         with request_context(request=request):
# -> 1002             response = transport.handle_request(request)
#    1003
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      82         message = str(exc)
# ---> 83         raise mapped_exc(message) from exc
#      84
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# During handling of the above exception, another exception occurred:
#
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     162                     self._sock.settimeout(timeout)
# --> 163                     sock = ssl_context.wrap_socket(
#     164                         self._sock, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      65     try:
# ---> 66         yield
#      67     except Exception as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     267                     self.response_closed(status)
# --> 268                 raise exc
#     269             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     250             try:
# --> 251                 response = connection.handle_request(request)
#     252             except ConnectionNotAvailable:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      98                     self._connect_failed = True
# ---> 99                     raise exc
#     100             elif not self._connection.is_available():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      75                 try:
# ---> 76                     stream = self._connect(request)
#      77
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in _connect(self, request)
#     155                     with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156                         stream = stream.start_tls(**kwargs)
#     157                         trace.return_value = stream
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857         try:
# --> 858             response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859             log.debug(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     900
# --> 901         response = self._send_handling_auth(
#     902             request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     928             while True:
# --> 929                 response = self._send_handling_redirects(
#     930                     request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     965
# --> 966             response = self._send_single_request(request)
#     967             try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1001         with request_context(request=request):
# -> 1002             response = transport.handle_request(request)
#    1003
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      82         message = str(exc)
# ---> 83         raise mapped_exc(message) from exc
#      84
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# During handling of the above exception, another exception occurred:
#
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     162                     self._sock.settimeout(timeout)
# --> 163                     sock = ssl_context.wrap_socket(
#     164                         self._sock, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      65     try:
# ---> 66         yield
#      67     except Exception as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     267                     self.response_closed(status)
# --> 268                 raise exc
#     269             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     250             try:
# --> 251                 response = connection.handle_request(request)
#     252             except ConnectionNotAvailable:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      98                     self._connect_failed = True
# ---> 99                     raise exc
#     100             elif not self._connection.is_available():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      75                 try:
# ---> 76                     stream = self._connect(request)
#      77
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in _connect(self, request)
#     155                     with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156                         stream = stream.start_tls(**kwargs)
#     157                         trace.return_value = stream
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857         try:
# --> 858             response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859             log.debug(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     900
# --> 901         response = self._send_handling_auth(
#     902             request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     928             while True:
# --> 929                 response = self._send_handling_redirects(
#     930                     request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     965
# --> 966             response = self._send_single_request(request)
#     967             try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1001         with request_context(request=request):
# -> 1002             response = transport.handle_request(request)
#    1003
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      82         message = str(exc)
# ---> 83         raise mapped_exc(message) from exc
#      84
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# During handling of the above exception, another exception occurred:
#
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     162                     self._sock.settimeout(timeout)
# --> 163                     sock = ssl_context.wrap_socket(
#     164                         self._sock, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      65     try:
# ---> 66         yield
#      67     except Exception as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     267                     self.response_closed(status)
# --> 268                 raise exc
#     269             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     250             try:
# --> 251                 response = connection.handle_request(request)
#     252             except ConnectionNotAvailable:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      98                     self._connect_failed = True
# ---> 99                     raise exc
#     100             elif not self._connection.is_available():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      75                 try:
# ---> 76                     stream = self._connect(request)
#      77
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in _connect(self, request)
#     155                     with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156                         stream = stream.start_tls(**kwargs)
#     157                         trace.return_value = stream
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857         try:
# --> 858             response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859             log.debug(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     900
# --> 901         response = self._send_handling_auth(
#     902             request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     928             while True:
# --> 929                 response = self._send_handling_redirects(
#     930                     request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     965
# --> 966             response = self._send_single_request(request)
#     967             try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1001         with request_context(request=request):
# -> 1002             response = transport.handle_request(request)
#    1003
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      82         message = str(exc)
# ---> 83         raise mapped_exc(message) from exc
#      84
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# During handling of the above exception, another exception occurred:
#
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     162                     self._sock.settimeout(timeout)
# --> 163                     sock = ssl_context.wrap_socket(
#     164                         self._sock, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      65     try:
# ---> 66         yield
#      67     except Exception as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     267                     self.response_closed(status)
# --> 268                 raise exc
#     269             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     250             try:
# --> 251                 response = connection.handle_request(request)
#     252             except ConnectionNotAvailable:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      98                     self._connect_failed = True
# ---> 99                     raise exc
#     100             elif not self._connection.is_available():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      75                 try:
# ---> 76                     stream = self._connect(request)
#      77
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_sync/connection.py in _connect(self, request)
#     155                     with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156                         stream = stream.start_tls(**kwargs)
#     157                         trace.return_value = stream
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857         try:
# --> 858             response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859             log.debug(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     900
# --> 901         response = self._send_handling_auth(
#     902             request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     928             while True:
# --> 929                 response = self._send_handling_redirects(
#     930                     request,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     965
# --> 966             response = self._send_single_request(request)
#     967             try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1001         with request_context(request=request):
# -> 1002             response = transport.handle_request(request)
#    1003
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      82         message = str(exc)
# ---> 83         raise mapped_exc(message) from exc
#      84
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# During handling of the above exception, another exception occurred:
#
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     162                     self._sock.settimeout(timeout)
# --> 163                     sock = ssl_context.wrap_socket(
#     164                         self._sock, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ...
#     965
# --> 966             response = self._send_single_request(request)
#     967             try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1001         with request_context(request=request):
# -> 1002             response = transport.handle_request(request)
#    1003
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     227         with map_httpcore_exceptions():
# --> 228             resp = self._pool.handle_request(req)
#     229
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      82         message = str(exc)
# ---> 83         raise mapped_exc(message) from exc
#      84
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# <ipython-input-8-b2aa4fd00b70> in <module>
# ----> 1 index=VectorStoreIndex.from_documents(documents,show_progress=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/indices/base.py in from_documents(cls, documents, storage_context, service_context, show_progress, **kwargs)
#     110             )
#     111
# --> 112             return cls(
#     113                 nodes=nodes,
#     114                 storage_context=storage_context,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/indices/vector_store/base.py in __init__(self, nodes, objects, index_struct, service_context, storage_context, use_async, store_nodes_override, insert_batch_size, show_progress, **kwargs)
#      51         self._store_nodes_override = store_nodes_override
#      52         self._insert_batch_size = insert_batch_size
# ---> 53         super().__init__(
#      54             nodes=nodes,
#      55             index_struct=index_struct,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/indices/base.py in __init__(self, nodes, objects, index_struct, storage_context, service_context, show_progress, **kwargs)
#      73             if index_struct is None:
#      74                 nodes = nodes or []
# ---> 75                 index_struct = self.build_index_from_nodes(
#      76                     nodes + objects  # type: ignore
#      77                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/indices/vector_store/base.py in build_index_from_nodes(self, nodes, **insert_kwargs)
#     272             )
#     273
# --> 274         return self._build_index_from_nodes(nodes, **insert_kwargs)
#     275
#     276     def _insert(self, nodes: Sequence[BaseNode], **insert_kwargs: Any) -> None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/indices/vector_store/base.py in _build_index_from_nodes(self, nodes, **insert_kwargs)
#     244             run_async_tasks(tasks)
#     245         else:
# --> 246             self._add_nodes_to_index(
#     247                 index_struct,
#     248                 nodes,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/indices/vector_store/base.py in _add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     197
#     198         for nodes_batch in iter_batch(nodes, self._insert_batch_size):
# --> 199             nodes_batch = self._get_node_with_embedding(nodes_batch, show_progress)
#     200             new_ids = self._vector_store.add(nodes_batch, **insert_kwargs)
#     201
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/indices/vector_store/base.py in _get_node_with_embedding(self, nodes, show_progress)
#     105
#     106         """
# --> 107         id_to_embed_map = embed_nodes(
#     108             nodes, self._service_context.embed_model, show_progress=show_progress
#     109         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/indices/utils.py in embed_nodes(nodes, embed_model, show_progress)
#     135             id_to_embed_map[node.node_id] = node.embedding
#     136
# --> 137     new_embeddings = embed_model.get_text_embedding_batch(
#     138         texts_to_embed, show_progress=show_progress
#     139     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/core/embeddings/base.py in get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     254                     payload={EventPayload.SERIALIZED: self.to_dict()},
#     255                 ) as event:
# --> 256                     embeddings = self._get_text_embeddings(cur_batch)
#     257                     result_embeddings.extend(embeddings)
#     258                     event.on_end(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/embeddings/openai.py in _get_text_embeddings(self, texts)
#     411         """
#     412         client = self._get_client()
# --> 413         return get_embeddings(
#     414             client,
#     415             texts,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     287         @functools.wraps(f)
#     288         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289             return self(f, *args, **kw)
#     290
#     291         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     377         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378         while True:
# --> 379             do = self.iter(retry_state=retry_state)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tenacity/__init__.py in iter(self, retry_state)
#     323             retry_exc = self.retry_error_cls(fut)
#     324             if self.reraise:
# --> 325                 raise retry_exc.reraise()
#     326             raise retry_exc from fut.exception()
#     327
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tenacity/__init__.py in reraise(self)
#     156     def reraise(self) -> t.NoReturn:
#     157         if self.last_attempt.failed:
# --> 158             raise self.last_attempt.result()
#     159         raise self
#     160
#
# ~/opt/anaconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# ~/opt/anaconda3/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
# --> 382                     result = fn(*args, **kwargs)
#     383                 except BaseException:  # noqa: B902
#     384                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/llama_index/embeddings/openai.py in get_embeddings(client, list_of_text, engine, **kwargs)
#     176     list_of_text = [text.replace("\n", " ") for text in list_of_text]
#     177
# --> 178     data = client.embeddings.create(input=list_of_text, model=engine, **kwargs).data
#     179     return [d.embedding for d in data]
#     180
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/resources/embeddings.py in create(self, input, model, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     103             return obj
#     104
# --> 105         return self._post(
#     106             "/embeddings",
#     107             body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1053             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1054         )
# -> 1055         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1056
#    1057     def patch(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     832         stream_cls: type[_StreamT] | None = None,
#     833     ) -> ResponseT | _StreamT:
# --> 834         return self._request(
#     835             cast_to=cast_to,
#     836             options=options,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888         except Exception as err:
#     889             if retries > 0:
# --> 890                 return self._retry_request(
#     891                     options,
#     892                     cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     923         time.sleep(timeout)
#     924
# --> 925         return self._request(
#     926             options=options,
#     927             cast_to=cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888         except Exception as err:
#     889             if retries > 0:
# --> 890                 return self._retry_request(
#     891                     options,
#     892                     cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     923         time.sleep(timeout)
#     924
# --> 925         return self._request(
#     926             options=options,
#     927             cast_to=cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888         except Exception as err:
#     889             if retries > 0:
# --> 890                 return self._retry_request(
#     891                     options,
#     892                     cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     923         time.sleep(timeout)
#     924
# --> 925         return self._request(
#     926             options=options,
#     927             cast_to=cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888         except Exception as err:
#     889             if retries > 0:
# --> 890                 return self._retry_request(
#     891                     options,
#     892                     cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     923         time.sleep(timeout)
#     924
# --> 925         return self._request(
#     926             options=options,
#     927             cast_to=cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888         except Exception as err:
#     889             if retries > 0:
# --> 890                 return self._retry_request(
#     891                     options,
#     892                     cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     923         time.sleep(timeout)
#     924
# --> 925         return self._request(
#     926             options=options,
#     927             cast_to=cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888         except Exception as err:
#     889             if retries > 0:
# --> 890                 return self._retry_request(
#     891                     options,
#     892                     cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     923         time.sleep(timeout)
#     924
# --> 925         return self._request(
#     926             options=options,
#     927             cast_to=cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888         except Exception as err:
#     889             if retries > 0:
# --> 890                 return self._retry_request(
#     891                     options,
#     892                     cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     923         time.sleep(timeout)
#     924
# --> 925         return self._request(
#     926             options=options,
#     927             cast_to=cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888         except Exception as err:
#     889             if retries > 0:
# --> 890                 return self._retry_request(
#     891                     options,
#     892                     cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     923         time.sleep(timeout)
#     924
# --> 925         return self._request(
#     926             options=options,
#     927             cast_to=cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888         except Exception as err:
#     889             if retries > 0:
# --> 890                 return self._retry_request(
#     891                     options,
#     892                     cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     923         time.sleep(timeout)
#     924
# --> 925         return self._request(
#     926             options=options,
#     927             cast_to=cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888         except Exception as err:
#     889             if retries > 0:
# --> 890                 return self._retry_request(
#     891                     options,
#     892                     cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     923         time.sleep(timeout)
#     924
# --> 925         return self._request(
#     926             options=options,
#     927             cast_to=cast_to,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     895                     stream_cls=stream_cls,
#     896                 )
# --> 897             raise APIConnectionError(request=request) from err
#     898
#     899         return self._process_response(
#
# APIConnectionError: Connection error.

# %%
index

# %%
query_engine=index.as_query_engine()

# %%
from llama_index.retrievers import VectorIndexRetriever
from llama_index.query_engine import RetrieverQueryEngine
from llama_index.indices.postprocessor import SimilarityPostprocessor

retriever=VectorIndexRetriever(index=index,similarity_top_k=4)
postprocessor=SimilarityPostprocessor(similarity_cutoff=0.80)

query_engine=RetrieverQueryEngine(retriever=retriever,
                                  node_postprocessors=[postprocessor])

# %%
response=query_engine.query("What is attention is all yopu need?")

# %%
from llama_index.response.pprint_utils import pprint_response
pprint_response(response,show_source=True)
print(response)
# Out:
# Final Response: The paper "Attention Is All You Need" proposes a new
# network architecture called the Transformer. This architecture is
# based solely on attention mechanisms and does not use recurrent or
# convolutional neural networks. The paper demonstrates that the
# Transformer models outperform existing models in terms of quality,
# parallelizability, and training time. The Transformer achieves state-
# of-the-art results in machine translation tasks and generalizes well
# to other tasks such as English constituency parsing.
# ______________________________________________________________________
# Source Node 1/1
# Node ID: be144ab8-cb0a-44fa-af69-3dbfe555e41a
# Similarity: 0.8107415810551661
# Text: Provided proper attribution is provided, Google hereby grants
# permission to reproduce the tables and figures in this paper solely
# for use in journalistic or scholarly works. Attention Is All You Need
# Ashish Vaswani∗ Google Brain avaswani@google.comNoam Shazeer∗ Google
# Brain noam@google.comNiki Parmar∗ Google Research
# nikip@google.comJakob Uszkor...
# The paper "Attention Is All You Need" proposes a new network architecture called the Transformer. This architecture is based solely on attention mechanisms and does not use recurrent or convolutional neural networks. The paper demonstrates that the Transformer models outperform existing models in terms of quality, parallelizability, and training time. The Transformer achieves state-of-the-art results in machine translation tasks and generalizes well to other tasks such as English constituency parsing.

# %%
import os.path
from llama_index import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
)

# check if storage already exists
PERSIST_DIR = "./storage"
if not os.path.exists(PERSIST_DIR):
    # load the documents and create the index
    documents = SimpleDirectoryReader("data").load_data()
    index = VectorStoreIndex.from_documents(documents)
    # store it for later
    index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    # load the existing index
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
    index = load_index_from_storage(storage_context)

# either way we can now query the index
query_engine = index.as_query_engine()
response = query_engine.query("What are transformers?")
print(response)
# Out:
# Transformers are a model architecture that rely entirely on an attention mechanism to draw global dependencies between input and output. They eschew recurrence and do not use sequence-aligned RNNs or convolution. Transformers allow for significantly more parallelization and have been shown to achieve state-of-the-art results in tasks such as translation. They can be trained faster than architectures based on recurrent or convolutional layers.
