# %%
import os
import openai
# paste this at the start of code
import ssl 

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
from openai import OpenAI
#os.environ['CURL_CA_BUNDLE'] = ''

openai.api_base = 'https://api.openai.com/v1/completions'
openai.api_key = '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'

client = OpenAI(base_url=openai.api_base, api_key=openai.api_key)
response = client.chat.completions.create(
    model="gpt-4",  # or the specific model name
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a joke."}
    ]
)

print(response['choices'][0]['message']['content'])
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/httpcore/_backends/sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     162                     self._sock.settimeout(timeout)
# --> 163                     sock = ssl_context.wrap_socket(
#     164                         self._sock, server_hostname=server_hostname
#
# ...

# %%
import pandas as pd
df=pd.read_excel('/Users/jghosh2/Desktop/2023-12-12 - INCA Query Updates.xlsx')
df.replace('\\N', pd.NA, inplace=True)
print(df.shape)

filtered_df_sec1 = df[df['catalog_uuid'].notna() & df['entity_uuid'].notna()]
filtered_df_sec1=filtered_df_sec1.rename(columns={'catalog_uuid': 'storeUUID','entity_uuid':'objectUUID'})


filtered_df_sec2 = df[df['em_canonical_cataloguuid'].notna() & df['em_canonical_entityuuid'].notna()]
filtered_df_sec2=filtered_df_sec2.rename(columns={'em_canonical_cataloguuid': 'storeUUID','em_canonical_entityuuid':'objectUUID'})

filtered_df_sec3 = df[df['em_linkedproduct_cataloguuid'].notna() & df['em_linkedproduct_entityuuid'].notna()]
filtered_df_sec3=filtered_df_sec3.rename(columns={'em_linkedproduct_cataloguuid': 'storeUUID','em_linkedproduct_entityuuid':'objectUUID'})

filtered_df_sec4 = df[df['em_productref_cataloguuid'].notna() & df['em_productref_entityuuid'].notna()]
filtered_df_sec4=filtered_df_sec4.rename(columns={'em_productref_cataloguuid': 'storeUUID','em_productref_entityuuid':'objectUUID'})

filtered_df = pd.concat([filtered_df_sec1, filtered_df_sec2, filtered_df_sec3, filtered_df_sec4], ignore_index=True)
#filtered_df=filtered_df.drop(['catalog_uuid','entity_uuid','em_canonical_cataloguuid','em_canonical_entityuuid',\
                      # 'em_linkedproduct_cataloguuid','em_linkedproduct_entityuuid','em_productref_cataloguuid',
                      # 'em_productref_entityuuid'],axis=1)

#filtered_df['objectType']='ITEM'
#filtered_df['path']='TaxLabelInfo::DefaultValue::Labels'
print(filtered_df.shape)
filtered_df.to_csv('filtered_df.csv')
# Out:
# (13, 25)
# (21, 27)

# %%
import pandas as pd
df=pd.read_excel('/Users/jghosh2/Desktop/2023-12-12 - INCA Query Updates.xlsx')
df.replace('\\N', pd.NA, inplace=True)
print(df.shape)

filtered_df_sec1 = df[df['catalog_uuid'].notna() & df['entity_uuid'].notna()]
filtered_df_sec1['storeUUID']=filtered_df_sec1['catalog_uuid']
#filtered_df_sec1.rename(columns={'catalog_uuid': 'storeUUID','entity_uuid':'objectUUID'})
filtered_df_sec1['objectUUID']=filtered_df_sec1['entity_uuid']

filtered_df_sec2 = df[df['em_canonical_cataloguuid'].notna() & df['em_canonical_entityuuid'].notna()]
#filtered_df_sec2=filtered_df_sec2.rename(columns={'em_canonical_cataloguuid': 'storeUUID','em_canonical_entityuuid':'objectUUID'})
filtered_df_sec2['storeUUID']=filtered_df_sec2['em_canonical_cataloguuid']
filtered_df_sec2['objectUUID']=filtered_df_sec2['em_canonical_entityuuid']

filtered_df_sec3 = df[df['em_linkedproduct_cataloguuid'].notna() & df['em_linkedproduct_entityuuid'].notna()]
#filtered_df_sec3=filtered_df_sec3.rename(columns={'em_linkedproduct_cataloguuid': 'storeUUID','em_linkedproduct_entityuuid':'objectUUID'})
filtered_df_sec3['storeUUID']=filtered_df_sec3['em_linkedproduct_cataloguuid']
filtered_df_sec3['objectUUID']=filtered_df_sec3['em_linkedproduct_entityuuid']

filtered_df_sec4 = df[df['em_productref_cataloguuid'].notna() & df['em_productref_entityuuid'].notna()]
#filtered_df_sec4=filtered_df_sec4.rename(columns={'em_productref_cataloguuid': 'storeUUID','em_productref_entityuuid':'objectUUID'})
filtered_df_sec4['storeUUID']=filtered_df_sec4['em_productref_cataloguuid']
filtered_df_sec4['objectUUID']=filtered_df_sec4['em_productref_entityuuid']

filtered_df = pd.concat([filtered_df_sec1, filtered_df_sec2, filtered_df_sec3, filtered_df_sec4], ignore_index=True)
#filtered_df=filtered_df.drop(['catalog_uuid','entity_uuid','em_canonical_cataloguuid','em_canonical_entityuuid',\
                      # 'em_linkedproduct_cataloguuid','em_linkedproduct_entityuuid','em_productref_cataloguuid',
                      # 'em_productref_entityuuid'],axis=1)

#filtered_df['objectType']='ITEM'
#filtered_df['path']='TaxLabelInfo::DefaultValue::Labels'
print(filtered_df.shape)
filtered_df.to_csv('filtered_df.csv')
# Out:
# (13, 25)
# (21, 27)
# <ipython-input-6-7006ce0cea76>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_sec2['storeUUID']=filtered_df_sec2['em_canonical_cataloguuid']
# <ipython-input-6-7006ce0cea76>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_sec2['objectUUID']=filtered_df_sec2['em_canonical_entityuuid']
# <ipython-input-6-7006ce0cea76>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
filtered_df
# Out:
#                         store_name establishment_type  \
# 0          Vons (8891 Atlanta Ave)            GROCERY
# 1       Safeway (13606 E 32nd Ave)            GROCERY
# 2         Grocery Outlet (Compton)            GROCERY
# 3     Walgreens (308 E Perkins St)           PHARMACY
# 4   Walgreens (19927 Century Blvd)           PHARMACY
# 5          Vons (8891 Atlanta Ave)            GROCERY
# 6   Walgreens (215 State Route 34)           PHARMACY
# 7             CVS (325 PINEOLA ST)        CONVENIENCE
# 8         Walgreens (824 N 3Rd St)           PHARMACY
# 9     Target (1405 W Pacheco Blvd)            GROCERY
# 10    Target (1405 W Pacheco Blvd)            GROCERY
# 11    Target (1405 W Pacheco Blvd)            GROCERY
# 12    Target (1405 W Pacheco Blvd)            GROCERY
# 13    Walgreens (308 E Perkins St)           PHARMACY
# 14  Walgreens (19927 Century Blvd)           PHARMACY
# 15         Vons (8891 Atlanta Ave)            GROCERY
# ...
