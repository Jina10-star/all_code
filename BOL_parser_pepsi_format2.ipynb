# %%
import os
import json
import re
import pandas as pd
import numpy as np

from google.cloud import storage
from google.cloud import documentai_v1beta2 as documentai

# os.environ["GOOGLE_APPLICATION_CREDENTIALS"]=r"C:\Users\ksaluj1\Documents\work\dev\gv\iacoe_sa.json"
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="C:/Users/hsingh151/My_Work/Uber_IACOE_OCR_ML_Pipeline_v1.1.0/iacoe_sa.json"
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000

def parse_ner_json_to_string(parsed_ner):
    ner_string = ""
    flag = True
    for key, value in parsed_ner.items():
        if flag:
            ner_string = ner_string + value + "|" + key
            flag = False
        else:
            ner_string = ner_string + ";" + value + "|" + key
    return ner_string

def upload_blob(bucket_name, source_file_name, destination_blob_name):
    """Uploads a file to the bucket."""
    file_name = source_file_name.split('/')[-1]
    destination_blob_name = destination_blob_name + "/" + file_name
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)

    blob.upload_from_filename(source_file_name)
    gs_bucket_url = "gs://iacoe-cloud-bucket"
    gcs_uri = gs_bucket_url + '/' + destination_blob_name
    return gcs_uri

def extract_data_doc_ai(input_uri, project_id='concrete-tuner-241417'):
         # input_uri='gs://iacoe-cloud-bucket/k'):
    """Process a single document with the Document AI API, including
    text extraction and entity extraction."""

    client = documentai.DocumentUnderstandingServiceClient()
    gcs_source = documentai.types.GcsSource(uri=input_uri)

    input_config = documentai.types.InputConfig(
        gcs_source=gcs_source, mime_type='application/pdf')

    form_extraction_params = documentai.types.FormExtractionParams(
        enabled=True)
    table_extraction_params = documentai.types.TableExtractionParams(
        enabled=True)
    entity_extraction_params = documentai.types.EntityExtractionParams(
        enabled=True)

    parent = 'projects/{}/locations/us'.format(project_id)
    request = documentai.types.ProcessDocumentRequest(
        parent=parent,
        input_config=input_config,
        form_extraction_params=form_extraction_params,
        table_extraction_params=table_extraction_params,
        entity_extraction_params=entity_extraction_params)

    document = client.process_document(request=request)
    data = {}
    data["raw_text"] = (document.text).encode('utf-8')

    def _get_text(el):
        """Convert text offset indexes into text snippets.
        """
        response = ''
        for segment in el.text_anchor.text_segments:
            start_index = segment.start_index
            end_index = segment.end_index
            response += document.text[start_index:end_index]
        return response
    ent_dict = {}
    for entity in document.entities:
        ent_dict[_get_text(entity)] = (entity.mention_text)

    data["entities"] = ent_dict
    form_ent = {}
    for page in document.pages:
        for form_field in page.form_fields:
            key = (_get_text(form_field.field_name), form_field.field_name.confidence)
            value = (_get_text(form_field.field_value), form_field.field_value.confidence)
            form_ent[key] = value
    data["form_data"] = form_ent
    
    out_tables = []
    for page in document.pages:
        for table_num, table in enumerate(page.tables):
            out_table = []
            for row_num, row in enumerate(table.header_rows):
                out_header_row = [_get_text(cell.layout) for cell in row.cells]
                out_table.append(out_header_row)
            for row_num, row in enumerate(table.body_rows):
                out_body_row = [_get_text(cell.layout) for cell in row.cells]
                out_table.append(out_body_row)
            out_tables.append(out_table)

    data["tables"] = out_tables
    
    labels = {}
    for label in document.labels:
        labels[label.name] = label.confidence
    data["labels"] = labels

    return data

# %%
pwd
# Out:
# 'C:\\Users\\hsingh151\\My_Work\\BOL\\02_NER_Bol_processing\\01_Format_1\\04_jupyter_notebook'

# %%
import time
import os

# %%
data_files = {}

# %%
GCS_BUCKET = "iacoe-cloud-bucket"
DESTINATION_BLOB_NAME = "iacoe_ocr_ml"
file_loc = 'C:/Users/hsingh151/My_Work/BOL/02_NER_Bol_processing/02_Format_2/02_samples/pdf_samples/'

arr_txt =  [x for x in os.listdir(file_loc) if x.endswith(".pdf") or x.endswith(".PDF")]
t1 = time.time()

for i in arr_txt:
    file_path = file_loc + i
    t3 = time.time()
    gcs_uri = upload_blob(GCS_BUCKET, file_path, DESTINATION_BLOB_NAME)
    data_files[i] = extract_data_doc_ai(gcs_uri)
    print("File {} : time {}".format(i, time.time() - t3))
    
t2 = time.time()
# Out:
# File 00_Format2 & Packing List.pdf : time 12.081998586654663
# File 01_.32.pdf : time 9.763676643371582
# File 02.pdf : time 8.814495325088501
# File 03_.ll.pdf : time 8.624138593673706
# File 04_PEPSI_5_PROOF_OF_DELIVERY.PDF : time 10.061527729034424
# File 05_PEPSI_29_PROOF_OF_DELIVERY.PDF : time 8.812445640563965
# File 06.pdf : time 8.677384853363037
# File 07_done.pdf : time 9.220245599746704
# File 08_pepsi.pdf : time 8.206258058547974
# File 09.pdf : time 8.978200912475586
# File 10_2_PEPSI-PROOF_OF_DELIVERY.PDF.pdf : time 9.140926122665405
# File 11_PEPSI_33_-PROOF_OF_DELIVERY.PDF : time 12.116760969161987
# File 12.pdf : time 8.60085391998291
# File 13_5956134233.pdf : time 8.719850301742554
# File 14.pdf : time 9.975892782211304
# File 15_PEPSI_44_PROOF_OF_DELIVERY.PDF : time 8.403712511062622
# File 16.PDF : time 9.29437255859375
# File 17_6408420256-proof_of_delivery.pdf : time 8.93416142463684
# File 18_8750899445b.pdf : time 7.970776557922363
# File 19_9663840468-PROOF_OF_DELIVERY.pdf : time 9.891825675964355
# File 20_a.pdf : time 8.694247484207153
# File 21_.pdf : time 10.551090478897095
# File 22_.pdf : time 12.680931329727173
# File 23_file2.pdf : time 9.314427852630615
# File 24_hg.pdf : time 8.676054954528809
# File 25.pdf : time 8.046379089355469
# File 26.pdf : time 11.215694189071655
# File 27.pdf : time 8.896810054779053
# File 28.pdf : time 9.71568489074707
# File 29.pdf : time 8.890320062637329
# File 30.pdf : time 9.043267965316772
# File 31.pdf : time 8.383317232131958
# File 32.pdf : time 9.549445867538452
# File 33.pdf : time 9.486743927001953
# File 34.pdf : time 9.218281984329224
# File 35.pdf : time 10.577023267745972
# File 36.pdf : time 8.613093137741089
# File 37.pdf : time 10.316213369369507
# File 38.pdf : time 7.681607246398926
# File 39.pdf : time 8.733129262924194
# File 40.pdf : time 8.516892433166504
# File 41.pdf : time 9.260737419128418
# File 42.pdf : time 8.92334771156311
# File 43_issue_3602786212-proof_of_delivery.pdf : time 8.752278804779053

# %%
data_files[[*data_files][40]]['raw_text']
# Out:
# b'72\nPage 1\nDate: 8/11/2021 0:05:33\nBILL OF LADING\nSHIP FROM\nDocument Number:\n34844450248\nName: 3484-QTG TACOMA SC\nAddress: 2309 MILWAUKEE WAY\nAppt: 8/10/21 8:00 PM\nCity/State/Zip: TACOMA, WA 98421-2709\nCheckin: 8/10/21 7:13 PM\nLoaded: 8/10/21 11:49 PM\nSID/BOL#: 57088785\n(402) 34844450248\nFOB:\nDispatch: 8/11/21 12:05 AM\nSHIP TO\nCarrier Name: PEPSI LOGISTICS CO INC\nMOS: T\nName: FRED MEYER\nTrailer Number: LIVE775PLCB\nAddress: 349 VALLEY AVE NW\nSeal number(s): 646632\nCity/State/Zip: PUYALLUP, WA 98371-3314\nSCAC: PLCB\nCAR MOVE: 57088785\nID: C10001238\nFOB:\nPro Number:\nLOAD SEQ:\nTHIRD PARTY FREIGHT CHARGES BILL TO:\nFreight Charge (freight charges are prepaid unless marked\nName: PEPSICO C/O CASS INFO. SERVICES\notherwise)\nAddress: PO BOX 17608\nPrepaid\nCollect\n3rd Party\nCity/State/Zip: ST LOUIS, MO 63178-7608\nMaster Bill of Lading: with attached underlying Bills of\n(check box)\nLading\nSPECIAL INSTRUCTIONS: OTHERS-Carriers are to use One Network for appts For missed I oad or late delivery call 5035572514Receiving hours are\nSun Friday 8pm 3am For Reverse Logistics call 8774022435For drop loads phone the Clackamas scheduling desk to make sure it i sset up as a drop\n2537 706842 Ask for Jessi\n11241\nCUSTOMER ORDER NUMBER\n#PKGS\nCUSTOMER ORDER INFORMATION\nPallet/Slip\nWEIGHT (LB)\nADDITIONAL SHIPPER INFO\n(Circle One)\n59\n39153 Y\nN RAD-08/10/21 O-8251776045 S-1210935233\n45263\nRECEIVED\nY\nN\nY\nN\nTime in- 12.30 AM SUBJECT TO COUNT\nOut-4.48 AM Date: 8-11-21\nPO\n#: 452103\n9-11-21 Total cases received\nLate for delivery because delay\nGRAND TOTAL\nY\nN\nFor Loading\nY\nNat shipper.\n59\n39153\nLTL ONLY\nHANDLING UNIT\nPACKAGE\nCARRIER INFORMATION\nCOMMODITY DESCRIPTION\nH.M.\nCommodities requiring special or additional attention in handling or stowing must be so marked\n(X)\nand packaged as to ensure safe transportation with ordinary care.\nSee Section 2(e) of NMFC Item 360\nWEIGHT (LB)\nNMFC #\nCLASS\nQTY\nTYPE\nQTY\nTYPE\nSEE ATTACHED SUPPLEMENT PAGE\nGROSS WGT\nGRAND\nWhere the rate is dependent on value, shippers are required to state specifically in writing the agreed or\nCOD Amount: $\ndeclared value of the property as follows:\nThe agreed or declared value of the property is specifically stated by the shipper to be not exceeding\nFee Terms:\nCollect: \xe2\x98\x90 Prepaid:\nper\nCustomer check acceptable:\nNOTE Liability Limitation for loss or damage in this shipment may be applicable. See 49 U.S.C. - 14706(c)(1)(A) and (B).\nThe carrier shall not make delivery of this shipment without\nRECEIVED, subject to individually determined rates or contracts that have been agreed upon in writing between the carrier and\npayment of freight and all other lawful charges.\nshipper, if applicable, otherwise to the rates, classifications and rules that have been \nestablished by the carrier and are available \nto\nShipper\nthe shipper, on request, and to all applicable state and federal regulations.\nSignature\nSHIPPER SIGNATURE/DATE\nCARRIER SIGNATURE/PICKUP DATE\nTrailer Loaded:\nFreight Counted:\nThis is to certify that the above named materials are property\nCarrier acknowledges receipt of packages and required placards. Carrier certifies\nclassified, described, packaged, marked and labeled, and are in By Shipper\nBy Shipper\nemergency response information was made available and/or carrier has the DOT\nproper condition for transportation according to the \napplicable\nemergency response guidebook or equivalent documentation in the vehicle.\nregulations of the Department of Transportation\nBy Driver/pallets said to\nBy Driver/Pieces\nBy Driver\nP. Gemple\n'

# %%
data_files[[*data_files][1]]['entities']
# Out:
# {'Date: 8/9/2021 19:12:26': '8/9/2021 19:12:26',
#  'Document Number:\n32165665361': '32165665361',
#  'Name: 3216-QTG-ATLANTA SC\nAddress: 747 DOUGLAS HILL BLVD': '3216-QTG-ATLANTA SC\nAddress: 747 DOUGLAS HILL BLVD',
#  'Appt: 8/9/21 8:00 PM': '8/9/21 8:00 PM',
#  'Checkin: 8/9/21 5:00 PM': '8/9/21 5:00 PM',
#  'City/State/Zip: LITHIA SPRINGS, GA 30122-3606': 'LITHIA SPRINGS, GA 30122-3606',
#  'Loaded: 8/9/21 6:34 PM': '8/9/21 6:34 PM',
#  'SID/BOL#: 57129480': '57129480',
#  'Dispatch: 8/9/21 7:12 PM': '8/9/21 7:12 PM',
#  'Carrier Name: PEPSI LOGISTICS CO INC': 'PEPSI LOGISTICS CO INC',
#  'Name: PBG-FT SMITH': 'PBG-FT SMITH',
#  'Address: 3700 S ZERO': '3700 S ZERO',
#  'City/State/Zip: FORT SMITH, AR 72908-6915': '72908-6915',
#  'SCAC: PLCB': 'PLCB',
#  'CAR MOVE: 57129480': '57129480',
#  'ID: C10004506': 'C10004506',
#  'Name: PEPSICO C/O CASS INFO. SERVICES': 'PEPSICO C/O CASS INFO. SERVICES',
#  'Address: PO BOX 17608': 'PO BOX 17608',
#  'City/State/Zip: ST LOUIS, MO 63178-7608': 'ST LOUIS, MO 63178-7608',
#  'Jovanni SPECIAL INSTRUCTIONS: OTHERS-For Reverse Logistics call 877-402-2435\nCerda': 'SPECIAL INSTRUCTIONS: OTHERS-For Reverse Logistics call 877-402-2435\nCerda',
#  'Signature\npayment of freight and all other lawful charges.': 'payment of freight and all other lawful charges.'}

# %%
def parse_ner_json_to_string(parsed_ner):
    ner_string = ""
    flag = True
    print(parsed_ner)
    for key, value in parsed_ner.items():
        if flag:
            ner_string = ner_string + value + "|" + key
            flag = False
        else:
            ner_string = ner_string + ";" + value + "|" + key
    return ner_string

# %%
def pepsi_format2_doc_ai_ner_parser(raw_text, entities_json):
    parsed_data = {}
    
    # Look Up keys
    BOL_KEY = "SID/BOL#"
    
    # Entities to return
    PO_NUMBER = "PO Number"
    DROPOFF_ADDRESS = "Dropoff Address"
    PICKUP_ADDRESS = "Pickup Address"
    BOL_NUMBER = "BOL#"
    
    PO_FLAG = True
    PICKUP_FLAG = True
    DROPOFF_FLAG = True
    BOL_KEY_FLAG = True
    
    for key, value in entities_json.items():
        if key.startswith(BOL_KEY):
            try:
                if BOL_KEY_FLAG:
                    parsed_data[BOL_NUMBER] = value.strip()
                    if len(parsed_data[BOL_NUMBER]) >= 25:
                        parsed_data[BOL_NUMBER] = "NA"
                        BOL_KEY_FLAG = False
            except:
                pass
    
    def get_bol_number_from_raw_text(text):
        start_search_key = 'CUSTOMER'
        end_search_key = 'ADDITIONAL SHIPPER INFO'
        start_idx = text.find(start_search_key)
        end_idx = text.find(end_search_key)
        search_str = text[start_idx + len(start_search_key):end_idx].strip()
        bol_list = re.findall(r'\b\d{6,}\b', search_str)
        if len(bol_list) >= 1:
            bol_num = bol_list[-1].strip()
            return bol_num
        elif len(bol_list) == 0:
            start_search_key = 'CUSTOMER'
            end_search_key = 'GRAND TOTAL'
            start_idx = text.find(start_search_key)
            end_idx = text.find(end_search_key)
            search_str = text[start_idx + len(start_search_key):end_idx].strip()
            po_num_list =[]
            data = search_str.split('\n')
            for po in data:
                if len(po)>= 5 and po[:1].isdigit():
                    if (' ' in po.strip()):
                        continue
                    po_num_list.append(po.strip())
            if len(po_num_list) == 1:
                return(po_num_list[0])
            else:
                return('@'.join(po_num_list))
            
            
    if PO_FLAG:
        bol_number = get_bol_number_from_raw_text(raw_text)
        parsed_data[PO_NUMBER] = bol_number
        
    # Checking Po Number in some extra cases
    if parsed_data[PO_NUMBER] == '':
        start_search_key = 'CUSTOMER'
        end_search_key = 'GRAND TOTAL'
        start_idx = raw_text.find(start_search_key)
        end_idx = raw_text.find(end_search_key)
        search_str = raw_text[start_idx + len(start_search_key):end_idx].strip()
            
        po_key = 'S-'
        po_idx = search_str.find(po_key)
        po_str = search_str[po_idx + len(po_key): po_idx + len(po_key) + 21].strip()
        po_list = po_str.split('\n')
        for po_num in po_list:
            if (len(po_num)>= 5 and not po_num[:1].isdigit()):
                if (' ' in po_num.strip()):
                    continue
                po_number = po_num.strip() 
                parsed_data[PO_NUMBER] = po_number
                
    if parsed_data[PO_NUMBER] == '':
        po_key = 'CUSTOMER ORDER NUMBER'
        po_idx = raw_text.find(po_key)
        po_str = raw_text[po_idx + len(po_key): po_idx + len(po_key) + 10].strip()
        po_list = po_str.split('\n')
        for po_num in po_list:
            if (len(po_num)>= 5 and not po_num[:1].isdigit()):
                if (' ' in po_num.strip() or '#' in po_num.strip()):
                    continue
                po_number = po_num.strip() 
                parsed_data[PO_NUMBER] = po_number
                
                     
    def get_pickup_address_from_raw_text(text):
        start_search_key = 'SHIP FROM'
        end_search_key = 'SHIP TO'        
        start_idx = text.find(start_search_key)
        end_idx = text.find(end_search_key)
        search_str = text[start_idx + len(start_search_key):end_idx].strip()
        
        name_key = 'Name:'
        name_idx = search_str.find(name_key)
        name_str = search_str[name_idx + len(name_key): name_idx + len(name_key) + 50]
        name_list = name_str.split('\n')
        name = name_list[0].strip()
        
        address_key = 'Address:'
        address_idx = search_str.find(address_key)
        address_str = search_str[address_idx + len(address_key): address_idx + len(address_key) + 50]
        address_list = address_str.split('\n')
        address = address_list[0].strip()
        
        city_state_zip_key = 'City/State/Zip:'
        city_state_zip_idx = search_str.find(city_state_zip_key)
        city_state_zip_str = search_str[city_state_zip_idx + len(city_state_zip_key): city_state_zip_idx + len(city_state_zip_key) + 50]
        city_state_zip_list = city_state_zip_str.split('\n')
        city_state_zip = city_state_zip_list[0].strip()
        
        pick_up_address = name + address + city_state_zip
        if pick_up_address:
            return pick_up_address
        else:
            return ''
        
    if PICKUP_FLAG:
        pickup_add = get_pickup_address_from_raw_text(raw_text)
        parsed_data[PICKUP_ADDRESS] = pickup_add
        PICKUP_FLAG = False
 
    def get_dropoff_address_from_raw_text(text):
        start_search_key = 'SHIP TO'
        end_search_key = 'THIRD PARTY FREIGHT'        
        start_idx = text.find(start_search_key)
        end_idx = text.find(end_search_key)
        search_str = text[start_idx + len(start_search_key):end_idx].strip()
        
        
        def get_name(search_str):
            start_search_key = 'Carrier Name:'
            end_search_key = 'THIRD PARTY FREIGHT'
            start_idx = search_str.find(start_search_key)
            end_idx = search_str.find(end_search_key)
            name_string = search_str[start_idx + len(start_search_key):end_idx].strip()
            name_key = 'Name:'
            name_idx = name_string.find(name_key)
            name_str = name_string[name_idx + len(name_key): name_idx + len(name_key) + 50]
            name_list = name_str.split('\n')
            name_ = name_list[0].strip()
            return name_
        
        name = get_name(search_str)
    
        address_key = 'Address:'
        address_idx = search_str.find(address_key)
        address_str = search_str[address_idx + len(address_key): address_idx + len(address_key) + 50]
        address_list = address_str.split('\n')
        address = address_list[0].strip()
        
        city_state_zip_key = 'City/State/Zip:'
        city_state_zip_idx = search_str.find(city_state_zip_key)
        city_state_zip_str = search_str[city_state_zip_idx + len(city_state_zip_key): city_state_zip_idx + len(city_state_zip_key) + 50]
        city_state_zip_list = city_state_zip_str.split('\n')
        city_state_zip = city_state_zip_list[0].strip()
        
        drop_off_address = name + address + city_state_zip
        if drop_off_address:
            return drop_off_address
        else:
            return ''
        
    if DROPOFF_FLAG:
        dropadd = get_dropoff_address_from_raw_text(raw_text)
        parsed_data[DROPOFF_ADDRESS] = dropadd
        DROPOFF_FLAG = False
    
            
    ner_string = parse_ner_json_to_string(parsed_data)
    return [200, ner_string]

# %%
data = data_files[[*data_files][24]]

# %%
a = pepsi_format2_doc_ai_ner_parser(data['raw_text'].decode(), data['entities'])
# Out:
# {'BOL#': '57194857', 'PO Number': 'SNN7ADVO', 'Pickup Address': '3399-QUAKER-CARLISLE SC1200 DISTRIBUTION DRCARLISLE, PA 17013-7456', 'Dropoff Address': 'AMAZON.COM SORT GREENWOOD IND91151 S GRAHAM RDGREENWOOD, IN 46143-7830'}

# %%
a
# Out:
# [200,
#  '57194857|BOL#;SNN7ADVO|PO Number;3399-QUAKER-CARLISLE SC1200 DISTRIBUTION DRCARLISLE, PA 17013-7456|Pickup Address;AMAZON.COM SORT GREENWOOD IND91151 S GRAHAM RDGREENWOOD, IN 46143-7830|Dropoff Address']

# %%
extract_data = []

# %%
for file,data in data_files.items():
    a = pepsi_format2_doc_ai_ner_parser(data['raw_text'].decode(), data['entities'])
    extract_data.append(a)
# Out:
# {'BOL#': '53709863', 'PO Number': 'BXGSTION', 'Pickup Address': '3264-QTG-TRACY SC1565 N MACARTHUR DRIVETRACY, CA 95376-2839', 'Dropoff Address': 'I LOGISTICS CO INC24300 NANDINA AVEMORENO VALLEY, CA 92551-9534'}
# {'BOL#': '57129480', 'PO Number': '43571@00050415', 'Pickup Address': '3216-QTG-ATLANTA SC747 DOUGLAS HILL BLVDLITHIA SPRINGS, GA 30122-3606', 'Dropoff Address': 'PBG-FT SMITH3700 S ZERO STFORT SMITH, AR 72908-6915'}
# {'BOL#': '57268332', 'PO Number': '00211738', 'Pickup Address': '3928-PCNA OXNARD DC2100 EASTMAN AVEOXNARD, CA 93030-7591', 'Dropoff Address': 'PBG-SEATTLE2300 26TH AVESSEATTLE, WA 98144-5339'}
# {'BOL#': '57118259', 'PO Number': '002670723432', 'Pickup Address': '3389-QTG-INDIANAPOLIS SC9101 ORLY RDINDIANAPOLIS, IN 46241-9605', 'Dropoff Address': 'COSTCO MW MORRIS DPT #2673800 N DIVISION STMORRIS, IL 60450-9476'}
# {'BOL#': '53877137', 'PO Number': '1568928700', 'Pickup Address': '3442-PCNA CARLISLE1301 DISTRIBUTION DRCARLISLE, PA 17013-7457', 'Dropoff Address': "SAM'S CLUB DC #6499140 FLEET DRVILLA RICA, GA 30180-1090"}
# {'PO Number': '323912607946', 'Pickup Address': '3442-PCNA CARLISLE1301 DISTRIBUTION DRCARLISLE, PA 17013-7457', 'Dropoff Address': 'PBG-ERIE5820 EVANS ROADERIE, PA 16509'}
# {'BOL#': '57130844', 'PO Number': '2UZ4D7HS@75KY2CVN', 'Pickup Address': '3264-QTG-TRACY SCAddress: 1565 N1565 NTRACY', 'Dropoff Address': 'AMAZON.COM NON-SORT PHOENIX GYR38181 WPEPSI LOGISTICS COMPANY INC'}
# {'BOL#': '57194825', 'PO Number': '758Z36QF@39515', 'Pickup Address': 'ment Number:t Number:r:', 'Dropoff Address': 'I LOGISTICS COMPANY INC.3450 E HOLMES RDMEMPHIS, TN 38118-8102'}
# {'BOL#': '57218191', 'PO Number': '122397', 'Pickup Address': 'ment Number:1635 WESTGATE PKWY SWATLANTA, GA 30336-2855eko', 'Dropoff Address': 'WALMART DC #605745346 PARKWAY BLVDROBERT, LA, 70455-2221 e 06:32 Seal number(s):'}
# {'BOL#': '57130844', 'PO Number': '2UZ4D7HS', 'Pickup Address': '3264-QTG-TRACY SCAddress:TRACY', 'Dropoff Address': 'I LOGISTICS COMPANY INC MOS: T8181 WOM NON-SORT PHOENIX GYR3Address: 8181 W'}
# {'BOL#': '53737099', 'PO Number': '1CTL571B', 'Pickup Address': '4024-QTG-CHALK HILL DC1350 CHALK HILLDALLAS, TX 75211', 'Dropoff Address': 'I LOGISTICS CO INC33333 LYNDON B JOHNSON FWYDALLAS, TX 75241-7201'}
# {'BOL#': 'NA', 'PO Number': '23345424', 'Pickup Address': '3936-QTG-SAN BERNARDINO SC1650 E CENTRAL AVESAN BERNARDINO, CA 92408-2413', 'Dropoff Address': 'KEHE DISTRIBUTORS16081 FERN AVECHINO, CA 91708-9000'}
# {'BOL#': '53737099', 'PO Number': '1CTL571B', 'Pickup Address': '4024-QTG-CHALK HILL DC1350 CHALK HILLDALLAS, TX 75211', 'Dropoff Address': 'I LOGISTICS CO INC33333 LYNDON B JOHNSON FWYDALLAS, TX 75241-7201'}
# {'BOL#': '57240066\nFOB:', 'PO Number': '8246173483', 'Pickup Address': '1017-GATORADE-TOLLESON PLANT410 S 104TH AVETOLLESON, AZ 85353-9236', 'Dropoff Address': 'I LOGISTICS CO INC1565 N MACARTHUR DRTRACY, CA 95376-2839'}
# {'BOL#': '57292223', 'PO Number': '00103002', 'Pickup Address': '3216-QTG-ATLANTA SC747 DOUGLAS HILL BLVDLITHIA SPRINGS, GA 30122-3606', 'Dropoff Address': 'PBG-METTER GA535 W LYTELL STMETTER, GA 30439'}
# {'BOL#': '53709863', 'PO Number': 'BXGSTIL', 'Pickup Address': '3264-QTG-TRACY SC1565 N MACARTHUR DRIVETRACY, CA 95376-2839', 'Dropoff Address': 'I LOGISTICS CO INC24300 NANDINA AVEMORENO VALLEY, CA 92551-9534'}
# {'BOL#': '57128859', 'PO Number': '55973', 'Pickup Address': "1017-GATORADE-TOLLESON PLANTAddress: 410'S 104TH410'S 104TH AVETOLLESON, AZ 85353-9236", 'Dropoff Address': 'I LOGISTICS CO INC14900 GARFIELD AVECity/ROCERY'}
# {'BOL#': '57273008', 'PO Number': '16QCPDPR', 'Pickup Address': '3399-QUAKER-CARLISLE SC1200 DISTRIBUTION DRCARLISLE, PA 17013-7456', 'Dropoff Address': 'I LOGISTICS COMPANY INC601SOMERSET, NJ 08873'}
# {'PO Number': '8718121', 'Pickup Address': 'Niagara Keller Logistics - JupiterAddress:a Keller Logistics - JupiterAddress:', 'Dropoff Address': 'PEPSI7701 SOUTHLAND BLVDCity:Address: 7701 SOUTHLAND BLVDCity:'}
# {'BOL#': 'NA', 'PO Number': 'BOLCHE2N', 'Pickup Address': '3944-QTG-LANCASTER SCCity/Statet Number:r:', 'Dropoff Address': 'I LOGISTICS COMPANY INC31555 HIGHWAY 90 EBROOKSHIRE, TX 77423-2769'}
# {'BOL#': '57130844', 'PO Number': '2UZ4D7HS', 'Pickup Address': '3264-QTG-TRACY SC1565 N MACARTHUR DRIVETRACY, CA 95376-2839', 'Dropoff Address': 'AMAZON.COM NON-SORT PHOENIX GYR38181 W ROOSEVELT STPHOENIX, AZ 85043-2356'}
# {'PO Number': '8251991554/YMT', 'Pickup Address': 'GATORADE CP CENTURY FOODS 31357 HOESCHLER DRIVE PLANTSPARTA WI 54656-2468', 'Dropoff Address': '9101 ORLY RDINDIANAPOLIS IN 46241-9605'}
# {'BOL#': '57458704', 'PO Number': '11054292', 'Pickup Address': '1017-GATORADE-TOLLESON PLANT410 S 104THTOLLESON, AZ 85353-9236', 'Dropoff Address': 'STATER BROS311 S TIPPECANOESAN BERNARDINO, CA 92408'}
# {'BOL#': '57391545', 'PO Number': '146912', 'Pickup Address': '3390-BEVERAGE MOUNTAIN TOP SVC CTRAddress: 545 OA545 OAKMOUNTAIN TOP, PA 18707-2141', 'Dropoff Address': 'ALDI-SAXONBURG6000 N NOAH DRSAXONBURG, PA 16056-9730'}
# {'BOL#': '57194857', 'PO Number': 'SNN7ADVO', 'Pickup Address': '3399-QUAKER-CARLISLE SC1200 DISTRIBUTION DRCARLISLE, PA 17013-7456', 'Dropoff Address': 'AMAZON.COM SORT GREENWOOD IND91151 S GRAHAM RDGREENWOOD, IN 46143-7830'}
# {'PO Number': '8251890272', 'Pickup Address': '1008-GATORADE-BLUERIDGE316 GATOR LANEWYTHEVILLE, VA 24382', 'Dropoff Address': 'HFSC-PCNA-WHARTON DC20 HARRY SHUPE BLVDWHARTON, NJ 07885-1646'}
# {'BOL#': 'TRACY, 57148778', 'PO Number': '35997@11WR8UYO@8-17-21@35996', 'Pickup Address': 'AMAZON.COM NON-SORT HENDERSON LAS11565 N MACARTHUR DRIVECity/State/Zip: TRACY, CATRACY, CA', 'Dropoff Address': 'I LOGISTICS COMPANY INC MOS: T12300 BERMUDA ROADCity/State/Zip: HENDERSONHENDERSON'}
# {'BOL#': '57270929', 'PO Number': 'BCUROLJE', 'Pickup Address': '3399-QUAKER-CARLISLE SCKER-CARLISLE SC', 'Dropoff Address': 'I LOGISTICS COMPANY INC30260 SRESH WILMINGTON HMW1'}
# {'BOL#': '57297106', 'PO Number': '85536050000', 'Pickup Address': '3390-BEVERAGE MOUNTAIN TOP SVC CTRAddress: 545 OA545 OAK HILL ROADMOUNTAIN TOP, PA 18707-2141', 'Dropoff Address': 'ler Number:NT DEPOT #855Address:'}
# {'BOL#': '53911555', 'PO Number': '0114-01385@4/6/20', 'Pickup Address': '3264-QTG-TRACY SC1565 N MACARTHUR DRIVEr:', 'Dropoff Address': 'BOXED.COM LAS VEGASName: PEPSI LOGISTICS CO INCLAS VEGAS, NV 89115-3489'}
# {'BOL#': '53856680', 'PO Number': '19F8TEBO', 'Pickup Address': '3944-QTG-LANCASTER SC2101 DANIELDALE RDLANCASTER, TX 75134-1550', 'Dropoff Address': 'I LOGISTICS CO INC33333 LYNDON B JOHNSON FWYDALLAS, TX 75241-7201'}
# {'BOL#': '53825159', 'PO Number': '3UQWVY3Z', 'Pickup Address': '3944-QTG-LANCASTER SC2101 DANIELDALE RDLANCASTER, TX 75134-1550', 'Dropoff Address': 'I LOGISTICS CO INC31555 HIGHWAY 90 EBROOKSHIRE, TX 77423-2769'}
# {'BOL#': '53825681', 'PO Number': '102CGVLE', 'Pickup Address': '3944-QTG-LANCASTER SC2101 DANIELDALE RDLANCASTER, TX 75134-1550', 'Dropoff Address': 'AMAZON.COM NON-SORT STOCKTON SMF33923 S B STSTOCKTON, CA 95206-8202'}
# {'BOL#': '53926304', 'PO Number': '8223198581', 'Pickup Address': '1008-GATORADE-BLUERIDGE316 GATOR LANEWYTHEVILLE, VA 24382', 'Dropoff Address': 'I LOGISTICS CO INC9101 ORLY RDINDIANAPOLIS, IN 46241-9605'}
# {'BOL#': '53855706', 'PO Number': '5269062916', 'Pickup Address': '3944-QTG-LANCASTER SC2101-LANCASTER SC', 'Dropoff Address': "I LOGISTICS CO INCAM'S CLUB DC #6698DAYTON, TX 77535-6378"}
# {'BOL#': '53855706', 'PO Number': '5269062916', 'Pickup Address': '3944-QTG-LANCASTER SC2101-LANCASTER SC', 'Dropoff Address': "I LOGISTICS CO INCAM'S CLUB DC #6698DAYTON, TX 77535-6378"}
# {'BOL#': '53888146', 'PO Number': '3960048@3960051@3960052', 'Pickup Address': '3936-QTG-SAN BERNARDINO SC1650 E CENTRAL AVESAN BERNARDINO, CA 92408-2413', 'Dropoff Address': 'KEHE DISTRIBUTORS16081 FERN AVECHINO, CA 91708-9000'}
# {'BOL#': '57183600', 'PO Number': '8252841507@8/11/2021', 'Pickup Address': '1012-GATORADE-ATLANTA PLANT1635 WESTGATE PKWY SWATLANTA, GA 30336-2865', 'Dropoff Address': 'I LOGISTICS CO INC8060 STATE ROAD 33 NLAKELAND, FL 33809-1704'}
# {'BOL#': '57274418', 'PO Number': '', 'Pickup Address': '1017-GATORADE-TOLLESON PLANT410 S 104TH AVETOLLESON, AZ 85353-9236', 'Dropoff Address': 'BEVERAGE MOUNTAIN TOP SVC CTR545 OAKHILL RDMOUNTAIN TOP, PA 18707-2141'}
# {'PO Number': '1211096153', 'Pickup Address': '3936-QTG-SAN BERNARDINO SC1650 E CENTRAL AVESAN BERNARDINO, CA 92408-2413', 'Dropoff Address': 'ALBERTSONS IRVINE DIST CTR #879100 JERONIMOIRVINE, CA 92618'}
# {'BOL#': '57088785', 'PO Number': '45263', 'Pickup Address': '3484-QTG TACOMA SC2309 MILWAUKEE WAYTACOMA, WA 98421-2709', 'Dropoff Address': 'FRED MEYER349 VALLEY AVE NWPUYALLUP, WA 98371-3314'}
# {'BOL#': '57309302', 'PO Number': '7329015327', 'Pickup Address': 'ment Number:1635 WESTGATE PKWY SWATLANTA, GA 30336-2865', 'Dropoff Address': 'WALMART GROCERY WHSE #6072973 STATE HIGHWAY 30 WPEPSI LOGISTICS CO INC'}
# {'BOL#': '57089684', 'PO Number': '00054371', 'Pickup Address': '2042-GAT INDY CONNECT5510 EXPLORATION DRINDIANAPOLIS, IN 46241-9007', 'Dropoff Address': 'PBG-ELYRIA-OH925 LORAIN BLVDELYRIA, OH 44035-2819'}
# {'BOL#': '57851253', 'PO Number': '09420602', 'Pickup Address': '3390-BEVERAGE MOUNTAIN TOP SVC CTRAddress: 545 OA545 OAK HILL ROADCity/State/r:', 'Dropoff Address': 'ler Number:OOD LION INC #7AddressN INC #7Address'}

# %%
df = pd.DataFrame(extract_data)

# %%
df
# Out:
#       0                                                  1
# 0   200  BXGSTION|PO Number;3264-QTG-TRACY SC1565 N MAC...
# 1   200  43571@00050415|PO Number;3216-QTG-ATLANTA SC74...
# 2   200  00211738|PO Number;3928-PCNA OXNARD DC2100 EAS...
# 3   200  002670723432|PO Number;3389-QTG-INDIANAPOLIS S...
# 4   200  1568928700|PO Number;3442-PCNA CARLISLE1301 DI...
# 5   200  323912607946|PO Number;3442-PCNA CARLISLE1301 ...
# 6   200  2UZ4D7HS@75KY2CVN|PO Number;3264-QTG-TRACY SCA...
# 7   200  758Z36QF@39515|PO Number;ment Number:t Number:...
# 8   200  122397|PO Number;ment Number:1635 WESTGATE PKW...
# 9   200  2UZ4D7HS|PO Number;3264-QTG-TRACY SCAddress:TR...
# 10  200  1CTL571B|PO Number;4024-QTG-CHALK HILL DC1350 ...
# 11  200  23345424|PO Number;3936-QTG-SAN BERNARDINO SC1...
# 12  200  1CTL571B|PO Number;4024-QTG-CHALK HILL DC1350 ...
# 13  200  8246173483|PO Number;1017-GATORADE-TOLLESON PL...
# 14  200  00103002|PO Number;3216-QTG-ATLANTA SC747 DOUG...
# 15  200  BXGSTIL|PO Number;3264-QTG-TRACY SC1565 N MACA...
# 16  200  55973|PO Number;1017-GATORADE-TOLLESON PLANTAd...
# 17  200  16QCPDPR|PO Number;3399-QUAKER-CARLISLE SC1200...
# 18  200  8718121|PO Number;Niagara Keller Logistics - J...
# 19  200  BOLCHE2N|PO Number;3944-QTG-LANCASTER SCCity/S...
# 20  200  2UZ4D7HS|PO Number;3264-QTG-TRACY SC1565 N MAC...
# 21  200  8251991554/YMT|PO Number;GATORADE CP CENTURY F...
# 22  200  11054292|PO Number;1017-GATORADE-TOLLESON PLAN...
# 23  200  146912|PO Number;3390-BEVERAGE MOUNTAIN TOP SV...
# 24  200  SNN7ADVO|PO Number;3399-QUAKER-CARLISLE SC1200...
# 25  200  8251890272|PO Number;1008-GATORADE-BLUERIDGE31...
# 26  200  35997@11WR8UYO@8-17-21@35996|PO Number;AMAZON....
# 27  200  BCUROLJE|PO Number;3399-QUAKER-CARLISLE SCKER-...
# 28  200  85536050000|PO Number;3390-BEVERAGE MOUNTAIN T...
# 29  200  0114-01385@4/6/20|PO Number;3264-QTG-TRACY SC1...
# 30  200  19F8TEBO|PO Number;3944-QTG-LANCASTER SC2101 D...
# 31  200  3UQWVY3Z|PO Number;3944-QTG-LANCASTER SC2101 D...
# 32  200  102CGVLE|PO Number;3944-QTG-LANCASTER SC2101 D...
# 33  200  8223198581|PO Number;1008-GATORADE-BLUERIDGE31...
# 34  200  5269062916|PO Number;3944-QTG-LANCASTER SC2101...
# 35  200  5269062916|PO Number;3944-QTG-LANCASTER SC2101...
# 36  200  3960048@3960051@3960052|PO Number;3936-QTG-SAN...
# 37  200  8252841507@8/11/2021|PO Number;1012-GATORADE-A...
# 38  200  |PO Number;1017-GATORADE-TOLLESON PLANT410 S 1...
# 39  200  1211096153|PO Number;3936-QTG-SAN BERNARDINO S...
# 40  200  45263|PO Number;3484-QTG TACOMA SC2309 MILWAUK...
# 41  200  7329015327|PO Number;ment Number:1635 WESTGATE...
# 42  200  00054371|PO Number;2042-GAT INDY CONNECT5510 E...
# 43  200  09420602|PO Number;3390-BEVERAGE MOUNTAIN TOP ...

# %%
def pepsi_format2_doc_ai_ner_parser2(raw_text, entities_json):
    parsed_data = {}
    
    # Look Up keys
    BOL_KEY = "SID/BOL#"
    
    # Entities to return
    PO_NUMBER = "PO Number"
    DROPOFF_ADDRESS = "Dropoff Address"
    PICKUP_ADDRESS = "Pickup Address"
    BOL_NUMBER = "BOL#"
    
    PO_FLAG = True
    PICKUP_FLAG = True
    DROPOFF_FLAG = True
    BOL_KEY_FLAG = True
    
    for key, value in entities_json.items():
        if key.startswith(BOL_KEY):
            try:
                if BOL_KEY_FLAG:
                    parsed_data[BOL_NUMBER] = value.strip()
                    if len(parsed_data[BOL_NUMBER]) >= 25:
                        parsed_data[BOL_NUMBER] = "NA"
                        BOL_KEY_FLAG = False
            except:
                pass
    
    
    
    def get_bol_number_from_raw_text(text):
        start_search_key = 'CUSTOMER'
        end_search_key = 'ADDITIONAL SHIPPER INFO'
        start_idx = text.find(start_search_key)
        end_idx = text.find(end_search_key)
        search_str = text[start_idx + len(start_search_key):end_idx].strip()
        bol_list = re.findall(r'\b\d{6,}\b', search_str)
        if len(bol_list) >= 1:
            bol_num = bol_list[-1].strip()
            return bol_num
        elif len(bol_list) == 0:
            start_search_key = 'CUSTOMER'
            end_search_key = 'GRAND TOTAL'
            start_idx = text.find(start_search_key)
            end_idx = text.find(end_search_key)
            search_str = text[start_idx + len(start_search_key):end_idx].strip()
            po_num_list =[]
            data = search_str.split('\n')
            for po in data:
                if len(po)>= 5 and po[:1].isdigit():
                    if (' ' in po.strip()):
                        continue
                    po_num_list.append(po.strip())
            if len(po_num_list) == 1:
                return(po_num_list[0])
            else:
                return('@'.join(po_num_list))
            
            
    if PO_FLAG:
        bol_number = get_bol_number_from_raw_text(raw_text)
        parsed_data[PO_NUMBER] = bol_number
        
    if parsed_data[PO_NUMBER] == '':
        start_search_key = 'CUSTOMER'
        end_search_key = 'GRAND TOTAL'
        start_idx = raw_text.find(start_search_key)
        end_idx = raw_text.find(end_search_key)
        search_str = raw_text[start_idx + len(start_search_key):end_idx].strip()
            
        po_key = 'S-'
        po_idx = search_str.find(po_key)
        po_str = search_str[po_idx + len(po_key): po_idx + len(po_key) + 21].strip()
        po_list = po_str.split('\n')
        for po_num in po_list:
            if (len(po_num)>= 5 and not po_num[:1].isdigit()):
                if (' ' in po_num.strip()):
                    continue
                po_number = po_num.strip() 
                parsed_data[PO_NUMBER] = po_number
                
    if parsed_data[PO_NUMBER] == '':
        po_key = 'CUSTOMER ORDER NUMBER'
        po_idx = raw_text.find(po_key)
        po_str = raw_text[po_idx + len(po_key): po_idx + len(po_key) + 10].strip()
        po_list = po_str.split('\n')
        for po_num in po_list:
            if (len(po_num)>= 5 and not po_num[:1].isdigit()):
                if (' ' in po_num.strip() or '#' in po_num.strip()):
                    continue
                po_number = po_num.strip() 
                parsed_data[PO_NUMBER] = po_number
                
                     
    def get_pickup_address_from_raw_text(text):
        start_search_key = 'SHIP FROM'
        end_search_key = 'SHIP TO'        
        start_idx = text.find(start_search_key)
        end_idx = text.find(end_search_key)
        search_str = text[start_idx + len(start_search_key):end_idx].strip()
        
        name_key = 'Name:'
        name_idx = search_str.find(name_key)
        name_str = search_str[name_idx + len(name_key): name_idx + len(name_key) + 50]
        name_list = name_str.split('\n')
        name = name_list[0].strip()
        
        address_key = 'Address:'
        address_idx = search_str.find(address_key)
        address_str = search_str[address_idx + len(address_key): address_idx + len(address_key) + 50]
        address_list = address_str.split('\n')
        address = address_list[0].strip()
        
        city_state_zip_key = 'City/State/Zip:'
        city_state_zip_idx = search_str.find(city_state_zip_key)
        city_state_zip_str = search_str[city_state_zip_idx + len(city_state_zip_key): city_state_zip_idx + len(city_state_zip_key) + 50]
        city_state_zip_list = city_state_zip_str.split('\n')
        city_state_zip = city_state_zip_list[0].strip()
        
        pick_up_address = name + address + city_state_zip
        if pick_up_address:
            return pick_up_address
        else:
            return ''
        
    if PICKUP_FLAG:
        pickup_add = get_pickup_address_from_raw_text(raw_text)
        parsed_data[PICKUP_ADDRESS] = pickup_add
        PICKUP_FLAG = False
 
    def get_dropoff_address_from_raw_text(text):
        start_search_key = 'SHIP TO'
        end_search_key = 'THIRD PARTY FREIGHT'        
        start_idx = text.find(start_search_key)
        end_idx = text.find(end_search_key)
        search_str = text[start_idx + len(start_search_key):end_idx].strip()
        
        
        def get_name(search_str):
            start_search_key = 'Carrier Name:'
            end_search_key = 'THIRD PARTY FREIGHT'
            start_idx = search_str.find(start_search_key)
            end_idx = search_str.find(end_search_key)
            name_string = search_str[start_idx + len(start_search_key):end_idx].strip()
            name_key = 'Name:'
            name_idx = name_string.find(name_key)
            name_str = name_string[name_idx + len(name_key): name_idx + len(name_key) + 50]
            name_list = name_str.split('\n')
            name_ = name_list[0].strip()
            return name_
        
        name = get_name(search_str)
    
        address_key = 'Address:'
        address_idx = search_str.find(address_key)
        address_str = search_str[address_idx + len(address_key): address_idx + len(address_key) + 50]
        address_list = address_str.split('\n')
        address = address_list[0].strip()
        
        city_state_zip_key = 'City/State/Zip:'
        city_state_zip_idx = search_str.find(city_state_zip_key)
        city_state_zip_str = search_str[city_state_zip_idx + len(city_state_zip_key): city_state_zip_idx + len(city_state_zip_key) + 50]
        city_state_zip_list = city_state_zip_str.split('\n')
        city_state_zip = city_state_zip_list[0].strip()
        
        drop_off_address = name + address + city_state_zip
        if drop_off_address:
            return drop_off_address
        else:
            return ''
        
    if DROPOFF_FLAG:
        dropadd = get_dropoff_address_from_raw_text(raw_text)
        parsed_data[DROPOFF_ADDRESS] = dropadd
        DROPOFF_FLAG = False
    
            
    ner_string = parse_ner_json_to_string(parsed_data)
    return [200, ner_string]
    #print(parsed_data)
    #return parsed_data

# %%
extract_data = []

# %%
for file,data in data_files.items():
    a = pepsi_format2_doc_ai_ner_parser2(data['raw_text'].decode(), data['entities'])
    extract_data.append(a)
# Out:
# {'BOL#': '53709863', 'PO Number': 'BXGSTION', 'Pickup Address': '3264-QTG-TRACY SC1565 N MACARTHUR DRIVETRACY, CA 95376-2839', 'Dropoff Address': 'I LOGISTICS CO INC24300 NANDINA AVEMORENO VALLEY, CA 92551-9534'}
# {'BOL#': '57129480', 'PO Number': '43571@00050415', 'Pickup Address': '3216-QTG-ATLANTA SC747 DOUGLAS HILL BLVDLITHIA SPRINGS, GA 30122-3606', 'Dropoff Address': 'PBG-FT SMITH3700 S ZERO STFORT SMITH, AR 72908-6915'}
# {'BOL#': '57268332', 'PO Number': '00211738', 'Pickup Address': '3928-PCNA OXNARD DC2100 EASTMAN AVEOXNARD, CA 93030-7591', 'Dropoff Address': 'PBG-SEATTLE2300 26TH AVESSEATTLE, WA 98144-5339'}
# {'BOL#': '57118259', 'PO Number': '002670723432', 'Pickup Address': '3389-QTG-INDIANAPOLIS SC9101 ORLY RDINDIANAPOLIS, IN 46241-9605', 'Dropoff Address': 'COSTCO MW MORRIS DPT #2673800 N DIVISION STMORRIS, IL 60450-9476'}
# {'BOL#': '53877137', 'PO Number': '1568928700', 'Pickup Address': '3442-PCNA CARLISLE1301 DISTRIBUTION DRCARLISLE, PA 17013-7457', 'Dropoff Address': "SAM'S CLUB DC #6499140 FLEET DRVILLA RICA, GA 30180-1090"}
# {'PO Number': '323912607946', 'Pickup Address': '3442-PCNA CARLISLE1301 DISTRIBUTION DRCARLISLE, PA 17013-7457', 'Dropoff Address': 'PBG-ERIE5820 EVANS ROADERIE, PA 16509'}
# {'BOL#': '57130844', 'PO Number': '2UZ4D7HS@75KY2CVN', 'Pickup Address': '3264-QTG-TRACY SCAddress: 1565 N1565 NTRACY', 'Dropoff Address': 'AMAZON.COM NON-SORT PHOENIX GYR38181 WPEPSI LOGISTICS COMPANY INC'}
# {'BOL#': '57194825', 'PO Number': '758Z36QF@39515', 'Pickup Address': 'ment Number:t Number:r:', 'Dropoff Address': 'I LOGISTICS COMPANY INC.3450 E HOLMES RDMEMPHIS, TN 38118-8102'}
# {'BOL#': '57218191', 'PO Number': '122397', 'Pickup Address': 'ment Number:1635 WESTGATE PKWY SWATLANTA, GA 30336-2855eko', 'Dropoff Address': 'WALMART DC #605745346 PARKWAY BLVDROBERT, LA, 70455-2221 e 06:32 Seal number(s):'}
# {'BOL#': '57130844', 'PO Number': '2UZ4D7HS', 'Pickup Address': '3264-QTG-TRACY SCAddress:TRACY', 'Dropoff Address': 'I LOGISTICS COMPANY INC MOS: T8181 WOM NON-SORT PHOENIX GYR3Address: 8181 W'}
# {'BOL#': '53737099', 'PO Number': '1CTL571B', 'Pickup Address': '4024-QTG-CHALK HILL DC1350 CHALK HILLDALLAS, TX 75211', 'Dropoff Address': 'I LOGISTICS CO INC33333 LYNDON B JOHNSON FWYDALLAS, TX 75241-7201'}
# {'BOL#': 'NA', 'PO Number': '23345424', 'Pickup Address': '3936-QTG-SAN BERNARDINO SC1650 E CENTRAL AVESAN BERNARDINO, CA 92408-2413', 'Dropoff Address': 'KEHE DISTRIBUTORS16081 FERN AVECHINO, CA 91708-9000'}
# {'BOL#': '53737099', 'PO Number': '1CTL571B', 'Pickup Address': '4024-QTG-CHALK HILL DC1350 CHALK HILLDALLAS, TX 75211', 'Dropoff Address': 'I LOGISTICS CO INC33333 LYNDON B JOHNSON FWYDALLAS, TX 75241-7201'}
# {'BOL#': '57240066\nFOB:', 'PO Number': '8246173483', 'Pickup Address': '1017-GATORADE-TOLLESON PLANT410 S 104TH AVETOLLESON, AZ 85353-9236', 'Dropoff Address': 'I LOGISTICS CO INC1565 N MACARTHUR DRTRACY, CA 95376-2839'}
# {'BOL#': '57292223', 'PO Number': '00103002', 'Pickup Address': '3216-QTG-ATLANTA SC747 DOUGLAS HILL BLVDLITHIA SPRINGS, GA 30122-3606', 'Dropoff Address': 'PBG-METTER GA535 W LYTELL STMETTER, GA 30439'}
# {'BOL#': '53709863', 'PO Number': 'BXGSTIL', 'Pickup Address': '3264-QTG-TRACY SC1565 N MACARTHUR DRIVETRACY, CA 95376-2839', 'Dropoff Address': 'I LOGISTICS CO INC24300 NANDINA AVEMORENO VALLEY, CA 92551-9534'}
# {'BOL#': '57128859', 'PO Number': '55973', 'Pickup Address': "1017-GATORADE-TOLLESON PLANTAddress: 410'S 104TH410'S 104TH AVETOLLESON, AZ 85353-9236", 'Dropoff Address': 'I LOGISTICS CO INC14900 GARFIELD AVECity/ROCERY'}
# {'BOL#': '57273008', 'PO Number': '16QCPDPR', 'Pickup Address': '3399-QUAKER-CARLISLE SC1200 DISTRIBUTION DRCARLISLE, PA 17013-7456', 'Dropoff Address': 'I LOGISTICS COMPANY INC601SOMERSET, NJ 08873'}
# {'PO Number': '8718121', 'Pickup Address': 'Niagara Keller Logistics - JupiterAddress:a Keller Logistics - JupiterAddress:', 'Dropoff Address': 'PEPSI7701 SOUTHLAND BLVDCity:Address: 7701 SOUTHLAND BLVDCity:'}
# {'BOL#': 'NA', 'PO Number': 'BOLCHE2N', 'Pickup Address': '3944-QTG-LANCASTER SCCity/Statet Number:r:', 'Dropoff Address': 'I LOGISTICS COMPANY INC31555 HIGHWAY 90 EBROOKSHIRE, TX 77423-2769'}
# {'BOL#': '57130844', 'PO Number': '2UZ4D7HS', 'Pickup Address': '3264-QTG-TRACY SC1565 N MACARTHUR DRIVETRACY, CA 95376-2839', 'Dropoff Address': 'AMAZON.COM NON-SORT PHOENIX GYR38181 W ROOSEVELT STPHOENIX, AZ 85043-2356'}
# {'PO Number': '8251991554/YMT', 'Pickup Address': 'GATORADE CP CENTURY FOODS 31357 HOESCHLER DRIVE PLANTSPARTA WI 54656-2468', 'Dropoff Address': '9101 ORLY RDINDIANAPOLIS IN 46241-9605'}
# {'BOL#': '57458704', 'PO Number': '11054292', 'Pickup Address': '1017-GATORADE-TOLLESON PLANT410 S 104THTOLLESON, AZ 85353-9236', 'Dropoff Address': 'STATER BROS311 S TIPPECANOESAN BERNARDINO, CA 92408'}
# {'BOL#': '57391545', 'PO Number': '146912', 'Pickup Address': '3390-BEVERAGE MOUNTAIN TOP SVC CTRAddress: 545 OA545 OAKMOUNTAIN TOP, PA 18707-2141', 'Dropoff Address': 'ALDI-SAXONBURG6000 N NOAH DRSAXONBURG, PA 16056-9730'}
# {'BOL#': '57194857', 'PO Number': 'SNN7ADVO', 'Pickup Address': '3399-QUAKER-CARLISLE SC1200 DISTRIBUTION DRCARLISLE, PA 17013-7456', 'Dropoff Address': 'AMAZON.COM SORT GREENWOOD IND91151 S GRAHAM RDGREENWOOD, IN 46143-7830'}
# {'PO Number': '8251890272', 'Pickup Address': '1008-GATORADE-BLUERIDGE316 GATOR LANEWYTHEVILLE, VA 24382', 'Dropoff Address': 'HFSC-PCNA-WHARTON DC20 HARRY SHUPE BLVDWHARTON, NJ 07885-1646'}
# {'BOL#': 'TRACY, 57148778', 'PO Number': '35997@11WR8UYO@8-17-21@35996', 'Pickup Address': 'AMAZON.COM NON-SORT HENDERSON LAS11565 N MACARTHUR DRIVECity/State/Zip: TRACY, CATRACY, CA', 'Dropoff Address': 'I LOGISTICS COMPANY INC MOS: T12300 BERMUDA ROADCity/State/Zip: HENDERSONHENDERSON'}
# {'BOL#': '57270929', 'PO Number': 'BCUROLJE', 'Pickup Address': '3399-QUAKER-CARLISLE SCKER-CARLISLE SC', 'Dropoff Address': 'I LOGISTICS COMPANY INC30260 SRESH WILMINGTON HMW1'}
# {'BOL#': '57297106', 'PO Number': '85536050000', 'Pickup Address': '3390-BEVERAGE MOUNTAIN TOP SVC CTRAddress: 545 OA545 OAK HILL ROADMOUNTAIN TOP, PA 18707-2141', 'Dropoff Address': 'ler Number:NT DEPOT #855Address:'}
# {'BOL#': '53911555', 'PO Number': '0114-01385@4/6/20', 'Pickup Address': '3264-QTG-TRACY SC1565 N MACARTHUR DRIVEr:', 'Dropoff Address': 'BOXED.COM LAS VEGASName: PEPSI LOGISTICS CO INCLAS VEGAS, NV 89115-3489'}
# {'BOL#': '53856680', 'PO Number': '19F8TEBO', 'Pickup Address': '3944-QTG-LANCASTER SC2101 DANIELDALE RDLANCASTER, TX 75134-1550', 'Dropoff Address': 'I LOGISTICS CO INC33333 LYNDON B JOHNSON FWYDALLAS, TX 75241-7201'}
# {'BOL#': '53825159', 'PO Number': '3UQWVY3Z', 'Pickup Address': '3944-QTG-LANCASTER SC2101 DANIELDALE RDLANCASTER, TX 75134-1550', 'Dropoff Address': 'I LOGISTICS CO INC31555 HIGHWAY 90 EBROOKSHIRE, TX 77423-2769'}
# {'BOL#': '53825681', 'PO Number': '102CGVLE', 'Pickup Address': '3944-QTG-LANCASTER SC2101 DANIELDALE RDLANCASTER, TX 75134-1550', 'Dropoff Address': 'AMAZON.COM NON-SORT STOCKTON SMF33923 S B STSTOCKTON, CA 95206-8202'}
# {'BOL#': '53926304', 'PO Number': '8223198581', 'Pickup Address': '1008-GATORADE-BLUERIDGE316 GATOR LANEWYTHEVILLE, VA 24382', 'Dropoff Address': 'I LOGISTICS CO INC9101 ORLY RDINDIANAPOLIS, IN 46241-9605'}
# {'BOL#': '53855706', 'PO Number': '5269062916', 'Pickup Address': '3944-QTG-LANCASTER SC2101-LANCASTER SC', 'Dropoff Address': "I LOGISTICS CO INCAM'S CLUB DC #6698DAYTON, TX 77535-6378"}
# {'BOL#': '53855706', 'PO Number': '5269062916', 'Pickup Address': '3944-QTG-LANCASTER SC2101-LANCASTER SC', 'Dropoff Address': "I LOGISTICS CO INCAM'S CLUB DC #6698DAYTON, TX 77535-6378"}
# {'BOL#': '53888146', 'PO Number': '3960048@3960051@3960052', 'Pickup Address': '3936-QTG-SAN BERNARDINO SC1650 E CENTRAL AVESAN BERNARDINO, CA 92408-2413', 'Dropoff Address': 'KEHE DISTRIBUTORS16081 FERN AVECHINO, CA 91708-9000'}
# {'BOL#': '57183600', 'PO Number': '8252841507@8/11/2021', 'Pickup Address': '1012-GATORADE-ATLANTA PLANT1635 WESTGATE PKWY SWATLANTA, GA 30336-2865', 'Dropoff Address': 'I LOGISTICS CO INC8060 STATE ROAD 33 NLAKELAND, FL 33809-1704'}
# {'BOL#': '57274418', 'PO Number': '', 'Pickup Address': '1017-GATORADE-TOLLESON PLANT410 S 104TH AVETOLLESON, AZ 85353-9236', 'Dropoff Address': 'BEVERAGE MOUNTAIN TOP SVC CTR545 OAKHILL RDMOUNTAIN TOP, PA 18707-2141'}
# {'PO Number': '1211096153', 'Pickup Address': '3936-QTG-SAN BERNARDINO SC1650 E CENTRAL AVESAN BERNARDINO, CA 92408-2413', 'Dropoff Address': 'ALBERTSONS IRVINE DIST CTR #879100 JERONIMOIRVINE, CA 92618'}
# {'BOL#': '57088785', 'PO Number': '45263', 'Pickup Address': '3484-QTG TACOMA SC2309 MILWAUKEE WAYTACOMA, WA 98421-2709', 'Dropoff Address': 'FRED MEYER349 VALLEY AVE NWPUYALLUP, WA 98371-3314'}
# {'BOL#': '57309302', 'PO Number': '7329015327', 'Pickup Address': 'ment Number:1635 WESTGATE PKWY SWATLANTA, GA 30336-2865', 'Dropoff Address': 'WALMART GROCERY WHSE #6072973 STATE HIGHWAY 30 WPEPSI LOGISTICS CO INC'}
# {'BOL#': '57089684', 'PO Number': '00054371', 'Pickup Address': '2042-GAT INDY CONNECT5510 EXPLORATION DRINDIANAPOLIS, IN 46241-9007', 'Dropoff Address': 'PBG-ELYRIA-OH925 LORAIN BLVDELYRIA, OH 44035-2819'}
# {'BOL#': '57851253', 'PO Number': '09420602', 'Pickup Address': '3390-BEVERAGE MOUNTAIN TOP SVC CTRAddress: 545 OA545 OAK HILL ROADCity/State/r:', 'Dropoff Address': 'ler Number:OOD LION INC #7AddressN INC #7Address'}

# %%
df = pd.DataFrame(extract_data)

# %%
df
# Out:
#       0                                                  1
# 0   200  53709863|BOL#;BXGSTION|PO Number;3264-QTG-TRAC...
# 1   200  57129480|BOL#;43571@00050415|PO Number;3216-QT...
# 2   200  57268332|BOL#;00211738|PO Number;3928-PCNA OXN...
# 3   200  57118259|BOL#;002670723432|PO Number;3389-QTG-...
# 4   200  53877137|BOL#;1568928700|PO Number;3442-PCNA C...
# 5   200  323912607946|PO Number;3442-PCNA CARLISLE1301 ...
# 6   200  57130844|BOL#;2UZ4D7HS@75KY2CVN|PO Number;3264...
# 7   200  57194825|BOL#;758Z36QF@39515|PO Number;ment Nu...
# 8   200  57218191|BOL#;122397|PO Number;ment Number:163...
# 9   200  57130844|BOL#;2UZ4D7HS|PO Number;3264-QTG-TRAC...
# 10  200  53737099|BOL#;1CTL571B|PO Number;4024-QTG-CHAL...
# 11  200  NA|BOL#;23345424|PO Number;3936-QTG-SAN BERNAR...
# 12  200  53737099|BOL#;1CTL571B|PO Number;4024-QTG-CHAL...
# 13  200  57240066\nFOB:|BOL#;8246173483|PO Number;1017-...
# 14  200  57292223|BOL#;00103002|PO Number;3216-QTG-ATLA...
# 15  200  53709863|BOL#;BXGSTIL|PO Number;3264-QTG-TRACY...
# 16  200  57128859|BOL#;55973|PO Number;1017-GATORADE-TO...
# 17  200  57273008|BOL#;16QCPDPR|PO Number;3399-QUAKER-C...
# 18  200  8718121|PO Number;Niagara Keller Logistics - J...
# 19  200  NA|BOL#;BOLCHE2N|PO Number;3944-QTG-LANCASTER ...
# 20  200  57130844|BOL#;2UZ4D7HS|PO Number;3264-QTG-TRAC...
# 21  200  8251991554/YMT|PO Number;GATORADE CP CENTURY F...
# 22  200  57458704|BOL#;11054292|PO Number;1017-GATORADE...
# 23  200  57391545|BOL#;146912|PO Number;3390-BEVERAGE M...
# 24  200  57194857|BOL#;SNN7ADVO|PO Number;3399-QUAKER-C...
# 25  200  8251890272|PO Number;1008-GATORADE-BLUERIDGE31...
# 26  200  TRACY, 57148778|BOL#;35997@11WR8UYO@8-17-21@35...
# 27  200  57270929|BOL#;BCUROLJE|PO Number;3399-QUAKER-C...
# 28  200  57297106|BOL#;85536050000|PO Number;3390-BEVER...
# 29  200  53911555|BOL#;0114-01385@4/6/20|PO Number;3264...
# 30  200  53856680|BOL#;19F8TEBO|PO Number;3944-QTG-LANC...
# 31  200  53825159|BOL#;3UQWVY3Z|PO Number;3944-QTG-LANC...
# 32  200  53825681|BOL#;102CGVLE|PO Number;3944-QTG-LANC...
# 33  200  53926304|BOL#;8223198581|PO Number;1008-GATORA...
# 34  200  53855706|BOL#;5269062916|PO Number;3944-QTG-LA...
# 35  200  53855706|BOL#;5269062916|PO Number;3944-QTG-LA...
# 36  200  53888146|BOL#;3960048@3960051@3960052|PO Numbe...
# 37  200  57183600|BOL#;8252841507@8/11/2021|PO Number;1...
# 38  200  57274418|BOL#;|PO Number;1017-GATORADE-TOLLESO...
# 39  200  1211096153|PO Number;3936-QTG-SAN BERNARDINO S...
# 40  200  57088785|BOL#;45263|PO Number;3484-QTG TACOMA ...
# 41  200  57309302|BOL#;7329015327|PO Number;ment Number...
# 42  200  57089684|BOL#;00054371|PO Number;2042-GAT INDY...
# 43  200  57851253|BOL#;09420602|PO Number;3390-BEVERAGE...

# %%
df["Pickup Address"][43]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-62a667cd478b> in <module>
# ----> 1 df["Pickup Address"][43]
#
# c:\users\hsingh151\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# c:\users\hsingh151\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#     360
#
# KeyError: 'Pickup Address'

# %%
df["Dropoff Address"][43]

# %%
data_files[[*data_files][43]]['raw_text']

# %%
data_files[[*data_files][41]]['entities']
