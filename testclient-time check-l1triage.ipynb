# %%
import requests
import http.client
import base64
import time
import json
import traceback
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet
import string
#nltk.download('popular')
import os
import pandas as pd
import csv
from sklearn.utils import shuffle
#from flask import jsonify # <- `jsonify` instead of `json`

# %%
data_df=pd.read_csv('/Users/jghosh2/Documents/my-notebook/L1 triage POC/data/sample_data.csv')

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46298 entries, 0 to 46297
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   summary      46298 non-null  object
#  1   description  45555 non-null  object
# dtypes: object(2)
# memory usage: 723.5+ KB

# %%
data_df = data_df.fillna('')
data_df_new=data_df[:100]
df=data_df_new.to_dict(orient='records')

# %%
len(df)
# Out:
# 100

# %% [markdown]
# # or

# %%
data_df=pd.read_csv('/Users/jghosh2/Documents/my-notebook/L1 triage POC/data/sample_data.csv')

# %%
data_df = shuffle(data_df)

# %%
data_df['id']=0
data_df['label']='component_batch'
data_df['projectid']='L1triage'
data_df = data_df.fillna('')
data_df_new=data_df[0:100]
df=data_df_new.to_dict(orient='records')

# %%
len(df)
# Out:
# 100

# %%
df
# Out:
# [{'summary': 'CLONE - CLONE - Oracle , Kyriba, Ucash and HFM access required',
#   'description': 'Hi Team,\r\nI recently joined the team and need below access.\r\nBusiness reason - New joiner - part of revenue accounting team (GBS team). Access required to perform BAU activities related to Revenue accounting.\r\nAccess / Programs\r\nHFM - loading access\r\nOracle - loading access\r\nOracle RPT\r\nSmartview for Excel Setup - To do after HFM/Oracle access is granted\r\nBanker (ACE)\r\nKyriba and Ucash',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'ACTION REQUIRED: IIQ Coupa Modify - Gisela Osinaga Failed',
#   'description': 'h1. Permissions IIQHi FinTech Support Team,\n\n\n\nIIQ has encountered failures while modifying coupa account for user: Gisela Osinaga. Below is the user details:\n\n\n\n*Employee Name *: Gisela Osinaga\n\n*Employee Number *: 140163\n\n*Employee Email *: gisela@uber.com\n\n*Employee Type *: Employee\n\n\n\nPlease connect with IIQ team for request details and update the user manually in Coupa.\n\nThank you,\n\n- Permissions IIQ Team\n\n\n\n\n----------------------------------------------------------------------------------------Need help for this request? email [iiq-support@uber.com|mailto:iiq-support@uber.com] \n\nITEng > Enterprise IAM > Permissions IIQ',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Error in Receiving Document | UBER |',
#   'description': "Hi Brian,\n\n\n\n\n\nPlease resend the Proof of Delivery Documents for the below shipments.\n\n\n\n\n\n\n|Shipment No|\tDocument Type|\n|46368|\tProof Of Delivery|\n|46385|\tProof Of Delivery|\n\n\n\n\nFor the Shipment ID 46385, Parameter Name should be ' *CN*', and Parameter value should be ' *SSFO0087934*'. We have received  Parameter Name as ' *SSFO0087934*'  and  Parameter value as ' *CN*'. Please modify and resend the \ndocument.\n\n\n\n\n\n !image.png|thumbnail! \n\n\n\n\n\n\n\nRegards\nPrathima",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'UBER B2B Customer Process Status Report',
#   'description': '== Created by JEMH via e-mail from:  <oracle-workflow-prod@uber.com> == \n\nHi Team,\n\nFollowing B2B Customer Process Report are not imported to Oracle.\n\n  Creation Date | Source | Customer Count | Ignore | Error | Processed\n-----------------------------------------------------------------------------\n\n  30-APR-20 | UF      |     197 |     65 |      1 |             94                                                                                                                 \n\nRegards\nFinTech Team',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Warning For Unsolicited Mail',
#   'description': "Messages sent to this account are processed automatically by the Oracle Workflow Notification Mailer.  The message you sent did not appear to be in response to a notification.  If you are responding to a notification, please use the response template that was included with your notification.  Take care to include the 'NID' line of the template in your reply.  If you are not responding to a notification, please do not send mail to this account.\n\nImportant: Some mail clients, notably early releases of Microsoft Outlook Express, may not copy the 'NID' line properly in your response. Please verify that the 'NID' line is included in full and contains the prefix 'NID' and all the details between the square brackets when responding. \n\n________________________________________________________________________\n\nFrom: Jyotsna Tarigoppula <finapps-support@uber.com>\nSubject: FINAPPS-127657 Alert for Missing Concur File\n\nJyotsna Tarigoppula changed the status to In Progress.\n\n\n\nView request: https://jira.uberinternal.com/servicedesk/customer/portal/434/FINAPPS-127657?sda_source=notification-email\n\nTurn off this request's notifications: https://jira.uberinternal.com/servicedesk/customer/portal/434/FINAPPS-127657/unsubscribe?jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..t1L389BlluikcnG4PGyjYeKPcaupTeSxqRJVk0ct2j8\n\nThis is shared with Oracle workflow-prod\n\n------------------------------\nHelp Center, powered by Jira Service Desk, sent you this message.\n\nhttps://www.atlassian.com/software/jira/service-desk/powered-by?utm_medium=email&utm_source=service-desk_email-notification_server&utm_campaign=service-desk_email-notification_server",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'ACTION REQUIRED: IIQ Coupa Modify - Alessandro Bordoli Failed',
#   'description': 'h1. Permissions IIQHi FinTech Support Team,\n\n\n\nIIQ has encountered failures while modifying coupa account for user: Alessandro Bordoli. Below is the user details:\n\n\n\n*Employee Name *: Alessandro Bordoli\n\n*Employee Number *: 149996\n\n*Employee Email *: alessandro.bordoli@uber.com\n\n*Employee Type *: Employee\n\n\n\nPlease connect with IIQ team for request details and update the user manually in Coupa.\n\nThank you,\n\n- Permissions IIQ Team\n\n\n\n\n----------------------------------------------------------------------------------------Need help for this request? email [iiq-support@uber.com|mailto:iiq-support@uber.com] \n\nITEng > Enterprise IAM > Permissions IIQ',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Coupa Account Activation - Urgent',
#   'description': 'Account to be activated for the following users:\r\n1. Zack Scheinholz\r\n2. Latasha Jenkins\r\n3. Natalie Heller\r\n\r\nReference Jira:\r\nhttps://jira.uberinternal.com/servicedesk/customer/portal/434/FINAPPS-117088\r\n\r\n',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Decertification request TRINTECH account 10393',
#   'description': 'Hi Team, \n\n\n\nCan you please help to decertify account 10393 entity 2036 in Trintech? \n\n\n\nI accidentally hit "approve" instead of "reject". \n\n\n\n\n\n\n !image.png|thumbnail! \n\n\n\n\n\nRegards,\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n|\n !https://lh3.googleusercontent.com/Q5eNUFJTQDBsqsfUokKVn24gA4zkzQuAWclUzA0q6QAAOrNoDHQ5U8FZeklg-4Hi6Vn-E5L5e2q6PG3TbhHNk-tef9NfD0KVpGjNj3VrFY6AYq1WhlUk5sRk0PvzbA1T1uhvKtY! \n\n\n|\t\n\n\n|*Ilona Zvinska*\n\n*Finance Operations Specialist II*\n\n[Uber B.V. / Meester Treublaan 7/ 1097 DP Amsterdam|https://www.google.com/maps?q=Meester+Treublaan+7,%C2%A01097+DP+Amsterdam&entry=gmail&source=g] \n\ne: [ilonaz@uber.com|mailto:ilonaz@uber.com]   w: [uber.com|http://uber.com/] \n\n\n !Screen Shot 2016-08-01 at 6.55.16 PM.png|thumbnail! \n\n\n|\n\n|\n\n\n\n\n|\n\n\n\n|\t\n\n|\t|',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Careem Mappings for Jun-20 from DRM',
#   'description': 'Hi Brian/Teresa,\n\n\nPlease find the Careem mappings from DRM and let us know we can import it into FDMEE?\n\n\n\nThanks & Regards,\nKishore Valluri',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Schedule report to capture the MTD AAR report for 12022',
#   'description': 'Hi Fintech,\n\n\nI am trying to schedule a daily/weekly report to capture the MTD AAR report for 12022.\nHowever, I run into difficulty. Please provide some guidance. Thanks!\n\n\n\n\n !image.png|thumbnail!',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'PO sync issues',
#   'description': "Hi Rajesh,\n\n\nPlease assist to investigate why these POs were not in BOPs weekly PO sync sheet?\n\n\n\nThanks,\nIna\n\n\n---------- Forwarded message ---------\n\nFrom: Vinod Palvai <[vpalva@ext.uber.com|mailto:vpalva@ext.uber.com] >\n\n\nDate: Wed, Nov 3, 2021 at 8:27 PM\n\nSubject: Re: PO sync issues\n\nTo: Ina Joseph < [ipj@uber.com|mailto:ipj@uber.com] >\n\nCc: Ramakrishna Dogiparthi < [rdogip@ext.uber.com|mailto:rdogip@ext.uber.com] >\n\n\n\n\n\n\nHi Ina,\n\n\n\n\nWe have checked the PO's listed from the PO sync issue file and below is status for all the PO's.\n\n\n\n\n\n\n|PO Number |\tStatus|\tAdditional comments|\n|457595|\tNot found|\t |\n|459597|\tNot found|\t |\n|459648|\tNot found|\t |\n|459585|\tNot found|\t |\n|450098|\tFound|\tZD#2323690- VM Team working|\n|450693|\tNot found|\t |\n|453469|\tNot found|\t |\n|456278|\tFound|\tZD#2319517-VM Team working|\n|455431|\tFound|\tZD#2313726-VM team working|\n|459236|\tNot found|\t |\n|459327|\tNot found|\t |\n|457302|\t |\tLatam-to be checked with LATAM team|\n|458664|\t |\tLatam-to be checked with LATAM team|\n|457884|\tFound|\tZD#2331645-VM Team working|\n|457670|\t |\tLatam-to be checked with LATAM team|\n|457688|\tNot found|\t |\n|459432|\t |\tLatam-to be checked with LATAM team|\n|459129|\t |\tLatam-to be checked with LATAM team|\n|456977|\t |\tLatam-to be checked with LATAM team|\n\n\n\n\nRegards,\nBuyerOps Team\n\n\n\nOn Wed, Nov 3, 2021 at 5:17 PM Ina Joseph < [ipj@uber.com|mailto:ipj@uber.com] > wrote:\n\n\n\n{quote}\nHi RK and Vinod,\n\n\n\nPlease advise if these POs were in the PO sync issue report?\n\n\n\n\n !Screenshot 2021-11-03 at 19.34.10.png|thumbnail! \n\n\n\n !Screenshot 2021-11-03 at 19.33.46.png|thumbnail! \n\n\n\n\n\nThanks,\nIna\n\n\n{quote}",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Error on POs',
#   'description': '== Created by JEMH via e-mail from: "business admins" <business-admin-emea@uber.com> == \n\nHi Team,\n\n\nPO: [https://uber.coupahost.com/order_headers/414351|https://uber.coupahost.com/order_headers/414351] \nError: Imported into Oracle Error Deriving Line Split CCID:;2149.7065.9001.51003.73205.0000.0000.0000Error Deriving Line Split CCID:;2149.7065.5001.51003.73205.0000.0000.0000\n\n\n\nPlease explain what I need to do \n\n\n\nPO:  [https://uber.coupahost.com/order_headers/415348|https://uber.coupahost.com/order_headers/415348] \nError: Imported into Oracle Error at Line 1: 9279946Cannot update quantity. Cause: You will not be able to update the quantity for any one or more of the following reasons: 1. New quantity is less than received quantity. 2. New quantity is less than billed quantity. 3. New quantity is less than delivered quantity. Error at Line 1: 9279946Cannot update quantity. Cause: You will not be able to update the quantity for any one or more of the following reasons: 1. New quantity is less than received quantity. 2. New quantity is less than billed quantity. 3. New quantity is less than delivered quantity. Selected Expense Account string(2146.1034.9001.51003.73205.0000.0000.0000) is Invalid\n\n\n\nThis PO only has 1 line which, as far a s I can see, has not been revised\n\n\n\nPlease explain what I need to do \n\n\n\nThank you\n\n\nKind regards,\n\n\nJennifer Hasselmeyer\nBusiness Admin EMEA',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Re: [Fin Ops - Treasury Operations] Missing March Month Statements for Account BUADPVUAH000',
#   'description': "[+FinTech Support|mailto:finapps-support@uber.com]  for tracking\n\n\n\n\nOn Fri, Mar 26, 2021 at 8:27 AM Shravan Kumar Vampu < [svampu@ext.uber.com|mailto:svampu@ext.uber.com] > wrote:\n\n\n\n{quote}\nHi Bhuvika,\n\n\nGreetings for the day !\n\n\n\nPlease be informed that we have contacted the bank requesting to provide an MT940 file for the March month.Once we get the update will keep you posted.\n\n\n\nThanks & Regards,\nShravan Kumar\n\n\n !https://mailfoogae.appspot.com/t?sender=ac3ZhbXB1QGV4dC51YmVyLmNvbQ%3D%3D&type=zerocontent&guid=0203dc9d-b3a9-4d4f-a45a-6bba80ef232f! \ná\x90§\n\n\nOn Fri, Mar 26, 2021 at 3:59 PM Bhuvika Singh < [bhuvika@uber.com|mailto:bhuvika@uber.com] > wrote:\n\n\n\n{quote}\n[+Willie Leung|mailto:willie.leung@uber.com]  \n\nHi Willie\n\n\n\nRequest for your support to get these statements for the month of March at the earliest as team needs to start quarter close activities.\n\n\n\nThanks\nBhuvika\n\n\n\nOn Wed, Mar 24, 2021 at 1:58 PM Nancy George < [ngeorg1@ext.uber.com|mailto:ngeorg1@ext.uber.com] > wrote:\n\n\n\n{quote}\nHi Shravan,\n\n\nSince we are near to Quater close, Could you please prioritize this request?\n\n\n\nThanks,\nNancy\n\n\n\nOn Wed, Mar 24, 2021 at 2:11 AM Shravan Kumar Vampu < [svampu@ext.uber.com|mailto:svampu@ext.uber.com] > wrote:\n\n\n\n{quote}\nHi Nancy,\n\n\nGreetings for the day !\n\n\n\nWe are working on the request and will update you soon with the status.\n\n\n\nThanks & Regards,\nShravan Kumar\n\n\n !https://mailfoogae.appspot.com/t?sender=ac3ZhbXB1QGV4dC51YmVyLmNvbQ%3D%3D&type=zerocontent&guid=94825dab-68cb-4f5c-9df5-152f5e2ae73c! \ná\x90§\n\n\nOn Tue, Mar 23, 2021 at 3:22 AM 'Nancy George' via Treasury Operations Team < [treas-ops-group@uber.com|mailto:treas-ops-group@uber.com] > wrote:\n\n\n\n{quote}\nHello Team,\n\n\n\n\nWe haven't received March month Statements for Account BUADPVUAH000.\nAccount Number: UA543052990000029009828960000\n\n\n\nCould you please check?\n\n\n\nThanks,\nNancy\n\n\n{quote}\n\n\n{quote}\n\n\n{quote}\n\n\n\n{quote}\n\n\n{quote}",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': '[Finance Operations] Update: Request For Valid Currency Process',
#   'description': '== Created by JEMH via e-mail from: "Finance Operations" <support+id2170184@uberaf.zendesk.com> == \n\n|\n !https://upload.wikimedia.org/wikipedia/commons/thumb/5/58/Uber_logo_2018.svg/440px-Uber_logo_2018.svg.png! \n|\n\n\n##- Please type your reply above this line -##\nYou are registered as a CC on this request (2170184). Reply to this email to add a comment to the request.\n\n\n|\n\n\n|Bhagat Mamatha (Finance Operations)May 12, 2021, 7:09 PM GMT+2Dear Supplier,\n\n\n\nGreetings from the AP Uber Team !!\n\n\n\nInvoice#-76601-3 is processed and sent it for approval , once approved it will include in next payment run.\n\n\n\nCredit Note#-77930 with amount-(-1857838.65) PKR is issued to cancel the cancel the invoice#-76601 with amount-1857838.65 (PKR).\n\n\n\nCould you please also issue credit note to cancel the invoice#-76601-2 with amount-1587896.28 PKR, as amend invoice#-76601-3 is processed in USD and will get paid soon.\n\n\n\nYou can now track the status of your invoices via uSurv. Click on the link [https://suppliers.uber.com/|https://suppliers.uber.com/] \n\n\n\nThanks in advance,\n\n\n\nRegards,\n\nMamatha\n\n|\n\n|\n\n\n\n\n|\n\n\n|Swarnalatha Jamboju (Finance Operations)May 11, 2021, 12:44 PM GMT+2Hi Team,\n\n\n\nGood Day to you!\n\n\n\nThank you for raising the new req # 566326 in USD.\n\n\n\nWe would await for the approvals.\n\n\n\nRegards,\n\nUber AP Team.\n\n\n\n\n\nAttachment(s)\n\n[Inv_76601_from_NORTHBAY_NETWORKS_INC._27236 (1) (2) (1) (3).pdf|https://uberaf.zendesk.com/attachments/token/QoaLVnFwis1JLvratlcOEHVSd/?name=Inv_76601_from_NORTHBAY_NETWORKS_INC._27236+%281%29+%282%29+%281%29+%283%29.pdf] \n\n|\n\n|\n\n\n\n\n|\n\n\n|Priyaneet SinghMay 10, 2021, 6:37 PM GMT+2Hello There,\n\nI created a new req # 566326 in USD so the invoice # 76601 can get paid. Here is the link-  [https://uber.coupahost.com/requisition_headers/566326|https://uber.coupahost.com/requisition_headers/566326] \n\nPlease cancel the original PO # 425492 at your end.\n\nThanks \n\n\n|\n\n\n|*Priya Singh, CSCP**Global Builds Procurement and Logistics**IT Eng, Global Builds Services *|\n\n|\n||\n|\n\n\n|*[psingh147@ext.uber.com|mailto:psingh147@ext.uber.com]  *|\n\n|\n\n\n\n\n\n\n\n\n\n\n\n\n\n|\n\n|\n\n\n\n\n|\n\n\n|Pradeep Sudhershanam (Finance Operations)May 7, 2021, 1:41 PM GMT+2Request [#2189649|https://uberaf.zendesk.com/hc/requests/2189649]  "Supplier Payment Rejected-NORTHB..." was closed and merged into this request. Last comment in request [#2189649|https://uberaf.zendesk.com/hc/requests/2189649] :Hello,We donâ€™t have a bank account with Local currency (PKR). Please use BOFAUS6S.INTERNATIONAL INCOMING WIRE SWIFT CODE (WIRE IS SENT IN A FOREIGN CURRENCY)BOFAUS6SThank you.Attachment(s)\n\n[image003.jpg|https://uberaf.zendesk.com/attachments/token/YMVRlogxmcS06zgLQTRresBhc/?name=image003.jpg] \n\n[image004.jpg|https://uberaf.zendesk.com/attachments/token/9SFIqrtnsYfA5Aq27lKxNWroD/?name=image004.jpg] \n\n[image001.jpg|https://uberaf.zendesk.com/attachments/token/ddWHCvbEQU71ciTHosE6VnnE4/?name=image001.jpg] \n\n[image002.jpg|https://uberaf.zendesk.com/attachments/token/ar6gsC5rtDEIdlzK79SYb7ukv/?name=image002.jpg] \n\n[NBN - Wire Instruction _BofA_Foreign currency.pdf|https://uberaf.zendesk.com/attachments/token/rVeKpJTiWpEPFlPdfwR9VFeav/?name=NBN+-+Wire+Instruction+_BofA_Foreign+currency.pdf] \n\n[inline-947545425.png|https://uberaf.zendesk.com/attachments/token/m19Wr88HpnzKRzrEB9A8dgHtN/?name=inline-947545425.png] \n\n[image002.png|https://uberaf.zendesk.com/attachments/token/OJZVqRMnEpt5hYP6SgQWwT7la/?name=image002.png] \n\n[image001.jpg|https://uberaf.zendesk.com/attachments/token/Ao7bP9pvkTyU2NCzHNwFLjKbs/?name=image001.jpg] \n\n[image003.jpg|https://uberaf.zendesk.com/attachments/token/MCK91ZQVOKNiUB4s3msnu68oT/?name=image003.jpg] \n\n|\n\n|\n\n\n\n\n|\n\n\n|Swarnalatha Jamboju (Finance Operations)May 6, 2021, 8:49 AM GMT+2Hi,\n\n\n\nHope you are Doing Well!\n\n\n\nInvoice# 76601-2  processed with PO# 425492 in P ...
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Coupa Error',
#   'description': "Hi - Can you please assist with the attached - I'm receiving this coupa error - please let me know!  \n !Screen Shot 2020-04-15 at 1.58.52 PM.png|thumbnail!",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Unable to find supplier in Coupa',
#   'description': 'Dear team,\n\n\n\nI recently put in a handful of orders for business cards for different members on my team. This was through HH Global and their contact reached out to me and requested a PO to complete the order. I am unable to find them as a supplier in Coupa and need some assistance. \n\n\nThank you,',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': '[MONTH END] HFM Access/Dill Down to Entities',
#   'description': 'Hi Vinay and Kishore,\n\n\nWhen performing an HFM drill down, I am not seeing these entities below. Does this have something to do with the access that I have in HFM? Are you able to help verify this? \n\n\n\n1. 3000B.3800 - SHANGHI UBER WOFE\n\n\n2. 3800.3816\n3. 3800.3817\n4. 3800.3818\n5. 3800.3819\n6. 3800.3820\n7. 3800.3821\n8. 3800.3822\n9. 3800.3823\n\n\n\n\n\n\nThank you,\nKelly',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'PROD ::: Registering Supplier User - Error Details',
#   'description': 'Hello,Below are the new error details from the Supplier user auto-registration process.Concurrent Request ID :133933146\n\nh3. Error Summary\n\n\n||Record ID||\tSupplier Name||\tSupplier Number||\tContact Person Name||\tUser Name||\tEmail Address||\tError Message||\tProcessing Date||\n|37842|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 13:37:46|\n\n|37843|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 13:37:46|\n\n|37844|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 13:37:46|\n\n|37846|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 14:02:42|\n\n|37847|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 14:27:22|\n\n|37848|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 14:51:24|\n\n|37849|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 15:15:30|\n\n|37850|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 15:39:34|\n\n|37852|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 16:05:37|\n\n|37854|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 16:29:38|\n\n|37855|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 16:51:39|\n\n|37856|\tLATINFOCUS RESEARCH LLC|\t1061960|\tCarmen Damian|\t-|\tcarmen.damian@focus.com.mx|\tTrying to create a new user, but an user is already existing with the same email address.|\t09-Nov-2021 16:59:39|\n\n\nThank You,\n\nUber Finance',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Revenue Mock Close <> Journal Entries left in GL_Interface table',
#   'description': "Hello, \n\n\nRevenue Accounting is performing their Mock Close in RPT for December today.\n\n\n\nI ran the following query in *RPT*, to see if there are any Uber_BANKER ledgers left after running the Import program: \n\n\n\nSELECT \n    USER_JE_CATEGORY_NAME, \n    DATE_CREATED,\n    CURRENCY_CODE,\n    SUM(ENTERED_CR),\n    SUM(ENTERED_CR),\n    count(*)\nFROM gl_interface \nWHERE \n    USER_JE_SOURCE_NAME = 'Uber_BANKER'\nGROUP BY \n    USER_JE_CATEGORY_NAME, DATE_CREATED, CURRENCY_CODE;\n\n\n\n\n*Question*: \n\n\n* I was expecting no ledgers to be present from the query above, as the Import program is run against all ledgers.  Yet it did return some results (see screenshot below).  Do you know why there are Uber_BANKER ledgers left in GL_Interface?Thanks!\n\n\n\n\n\n !image.png|thumbnail!",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'APEX Access',
#   'description': 'Hello! \r\n\r\nCan I please get credentials to log into APEX? I need to get into APEX in order to request an invoice reclass and the deadline is tomorrow, 8/24 by 4pm PST. \r\n\r\nPlease let me know as soon as possible.\r\n\r\nThank you!\r\n',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Adding Account 74212 to Cost Basis for I/D uAllocate Allocations',
#   'description': 'Hello,\n\n\nWe are in the process of creating a new Account 74212 Facilities Transportation and just wanted to also get it added to the I/D Allocations Cost Pool for COE, Greenlight, and Facilities.\n\n\n\nFacilities should include mapping similar to how the other accounts in I/D Facilities are set up.\n\n\n\nCOE should include mapping to department 60307 and 60313. Similar to how the other accounts in I/D COE allocations are set up.\n\n\n\nGreenlight should include  mapping to department 60308. Similar to how the other accounts in I/D Greenlight allocations are set up.\n\n\n\n\n\n\n\n\n\nThank you,\n\nDiana Lin\n\nSenior Accountant[!https://s3.amazonaws.com/uber-static/emails/2018/global/logos/Uber_Logo_Black_RGB.png! \n|https://uber.com/]',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'New Legal Entity Rollout Subtask - GL',
#   'description': "Hi SaiSahithi,\n\nThe entity  E.4047\n     was committed to DRM .could you please start the oracle setup from your side.\n\n\nThanks,\nVasu.N\n\n\n\n---------- Forwarded message ---------\n\nFrom: DRM ADMIN <[DRM_ADMIN@uber.com|mailto:DRM_ADMIN@uber.com] >\n\n\nDate: Thu, Aug 27, 2020 at 8:33 PM\n\nSubject: E.4047: Committed\n\nTo: < [nvasud@ext.uber.com|mailto:nvasud@ext.uber.com] >\n\n\n\n\n\n\n\n\n\n|\n\n\n|Request Title 1025: [E.4047|http://dca1-orl-drm03.corp.uber.com:80/drm-web-client/m/go.aspx/UBERDRM/request/1025] |\n|&nbsp|\n|Summary|\n|\n\n\n|Model: Add_Company|\tVersion: UBER.2020.08V|\tStage: Commit|\n|Status: Committed|\tSubmitted By: tfink|\tClaimed By:|\n|Tags:|\tSubmit Date: 8/17/2020 7:17:49 AM|\tStage Age: 0|\n\n|\n|&nbsp\n|\n|Items\n|\n|\n\n\n||Name||\tDescription||\tHierarchy||\tTask||\n|E.4047|\tPortier Costa Rica SRL|\tUber_Company_EBS|\tSubmit New Company|\n|E.4047|\tPortier Costa Rica SRL|\tUber_Company_HFM|\tEnrich Company - Insert to HFM Primary Hierarchy|\n|E.4047|\tPortier Costa Rica SRL|\tUber_Company_HFM_Legal|\tEnrich Company - Insert to HFM Alternate Hierarchy|\n|E.4047|\tPortier Costa Rica SRL|\tUber_Company_HFM_Tax|\tEnrich Company - Insert to HFM Alternate Hierarchy|\n\n|\n|&nbsp\n|\n|Recent Activity\n|\n|\n\n\n|(8/27/2020 8:01:24 AM) - Promoted for Stage 'Commit': No assignees available.|\n|(8/27/2020 8:01:24 AM) - Committed for Stage 'Commit'|\n|prithvipai (8/27/2020 8:01:21 AM) - Approved for Stage 'Insert Company to HFM Tax Hierarchy'|\n|prithvipai (8/24/2020 10:43:01 AM) - Updated for Stage 'Insert Company to HFM Tax Hierarchy': Added item 'E.4047'|\n|prithvipai (8/24/2020 10:42:16 AM) - Claimed for Stage 'Insert Company to HFM Tax Hierarchy'|\n|(8/23/2020 11:58:57 PM) - Assigned to Stage 'Insert Company to HFM Tax Hierarchy': DRG - Enrich Tax Consolidation Team|\n|olgal (8/23/2020 11:58:57 PM) - Approved for Stage 'Insert Company to HFM Legal Entity Hierarchy'|\n|olgal (8/23/2020 11:58:52 PM) - Updated for Stage 'Insert Company to HFM Legal Entity Hierarchy': Added item 'E.4047'; Updated item 'E.4047' for property 'DRM Parent'|\n|olgal (8/23/2020 11:58:16 PM) - Claimed for Stage 'Insert Company to HFM Legal Entity Hierarchy'|\n|(8/20/2020 10:45:11 AM) - Assigned to Stage 'Insert Company to HFM Legal Entity Hierarchy': DRG - Enrich Legal Consolidation Team|\n\n|\n|All date/time values are shown for '(UTC-08:00) Pacific Time (US & Canada)' time zone.\n|\n\n|",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Reinitiate invoice #DN21070353',
#   'description': 'Hi team,\n\nGood day!\n\n\n\nCan you assist to reinitiate the invoice approvals for invoice #DN21070353 please?\n\n\n\nThanks!\n\n\n\nThank You and Regards,\n\n\n\n\n|\n\n\n|\n !https://i.imgur.com/Tp5buzX.gif! \n|\n\n\n\n\n\n\n\n\n\n\n\n\n\n|\t\n\n|\tYu Lin\n\nAdministrative Coordinator\nSingapore | [ykoh1@ext.uber.com|mailto:ykoh1@ext.uber.com] \n|\n\n*Quick Links - *\n\n* * Internal: \n[Raise a Purchase Request |https://forms.gle/htDmo6Yma16HKtar9] | \n[Approve your invoices|https://usurv.uberinternal.com/]  | \n[Check on Remaining PO Funds|https://usurv.uberinternal.com/]  | \n[Setup Delegate Approver|https://team.uberinternal.com/display/FFOF/Coupa+Delegate+Request]  | \n[FAQs|https://team.uberinternal.com/display/FFOF/Procure+to+Pay+FAQs]   External: [Uber Supplier Portal|https://www.uber.com/info/suppliers]',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': "Trintech Unassigned accounts- Mar'21",
#   'description': 'Hi Eric/Premdeep\n\n\n\nPlease set up the below Group in Trintech and upload the attached unassigned accounts.\n\n\n\n\n\n\n|Group Account Name|\tLegal Entity (G)|\tAccount (G)|\tIntercompany (G)|\tReconciler|\tReconciler (Backup)|\tReviewer|\tReviewer (Backup)|\tApprover 1|\tApprover 1 (Backup)|\tReporting Director|\tLocation|\tReconciliation Schedule|\tReview Schedule|\tApproval 1 Schedule|\tApproval 2 Schedule|\tTemplate|\tRisk Rating|\tPriority|\tAccount Level|\tBulk Zero Balance|\tBulk No Activity|\n|Merchant Fee Rebates Receivable|\tGRP_14570|\t14570|\t |\tManikandan KV|\tDinesh Krishanamurthy|\tDenise Dovali|\tMadhavi Satishdas Vinnakota|\tGalina Y.|\tNancy Liu|\tJeremy Pearlman|\tPayments|\tReconciliation Monthly Medium|\tReviewer Monthly Medium|\tApprover 1 Monthly Medium|\t |\tBalance_Detail_New|\tMedium Risk|\tMED|\tGroup|\tNo|\tYes|\n\n\n\n\n\n\n\n\nNote : For the cash accounts, please update the reporting director manually once this is loaded.\n\n\n\n\n\n\n\nThank you\nPragna',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Oracle OTM Access Request',
#   'description': 'Daniel Hallgren\r\nDaniel.hallgren@uber.com\r\n1001 Uber Technologies, Inc.',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': "[Horizon JV] Request for increase to CEO's approval authority",
#   'description': "Hi Rajesh,\n\n\nPlease update Tom White's ([tom.white@uber.com|mailto:tom.white@uber.com] ) approval authority in Coupa to $1M.\n\n\n\n\n\nBusiness rationale for the increase and approval are documented in the email thread below.\n\n\n\nThanks,\n\nAusten\n\n\n---------- Forwarded message ---------\n\nFrom: Andrea Casella <[acasella@uber.com|mailto:acasella@uber.com] >\n\n\nDate: Wed, Apr 7, 2021 at 12:55 PM\n\nSubject: Re: [Horizon JV] Request for increase to CEO's approval authority\n\nTo: Mark Arrigotti < [marrigotti@uber.com|mailto:marrigotti@uber.com] >\n\nCc: Sarah Pak < [sarah.pak@uber.com|mailto:sarah.pak@uber.com] >, Harrison Budd < [budd@uber.com|mailto:budd@uber.com] >, Jade Szymanski < [jade.szymanski@uber.com|mailto:jade.szymanski@uber.com] >, Geneva Ng < [geneva.ng@uber.com|mailto:geneva.ng@uber.com] >, Germaine Loy < [germaine@uber.com|mailto:germaine@uber.com] >, Henry Clausner < [hclausner@uber.com|mailto:hclausner@uber.com] >, Austen Blalock < [austen.blalock@uber.com|mailto:austen.blalock@uber.com] >\n\n\n\n\n\n\nThanks for the follow-up and approval Mark.\n\n\n\n\nThis is indeed in alignment with authority amounts for other distinct Uber businesses units.\n\n\n\nThx, Andrea\n\n\n\nOn Wed, Apr 7, 2021 at 10:13 AM Mark Arrigotti < [marrigotti@uber.com|mailto:marrigotti@uber.com] > wrote:\n\n\n\n{quote}\nHi Sarah,\n\n\nThanks for the follow up!  We are good to proceed w/ Tom getting the next level of spend authority at L8 or 1 million. \n\n\n\n@Austen if you could please keep this for our records and make the necessary updates to our policy.\n\n\n\n\n\nThx\nMark\n\n\n\nOn Wed, Apr 7, 2021 at 10:01 AM Sarah Pak < [sarah.pak@uber.com|mailto:sarah.pak@uber.com] > wrote:\n\n\n\n{quote}\nHi Mark, just checking in for an update here! Also adding  [+Austen Blalock|mailto:austen.blalock@uber.com]  as I realize I accidentally left him off the original email chain.\n\n\nOn Sun, Apr 4, 2021 at 9:20 AM Mark Arrigotti < [marrigotti@uber.com|mailto:marrigotti@uber.com] > wrote:\n\n\n\n{quote}\nHi Sarah,\n\n\nI was OOO last week so let me circle internally and get back on this.\n\n\n\nThx\nMark\n\n\n\nOn Mon, Mar 29, 2021 at 5:57 PM Sarah Pak < [sarah.pak@uber.com|mailto:sarah.pak@uber.com] > wrote:\n\n\n\n{quote}\nHi Mark,\n\n\n\nThe Horizon JV is launching later this week and we realized that based on the JV's structure (CEO and CFO are both L7's), any purchase request >$250K USD in Coupa would require approval from the board of directors as the 3rd approver (see spend matrix below). \n\n\n\n\n\nI'd like to request an exception to increase Tom White's approval authority past $250K. The business rationale is that Tom is the CEO and manager of Peter, the CFO (who also has approval authority of up to $250K) and would be the right person based on reporting lines, having the right context and decision making authority to be the next level approver rather than the BOD. We expect ~4 PO's to exceed $250K/annually. \n\n\n\nPlease let me know if you require further details or what next steps are required. Thank you!\n\n\n\n\n\nRegards,\nSarah\n\n\n\n\n !https://lh6.googleusercontent.com/821pQMFPyptTrPkIKagJMWieexBt4uTZuz_0MU69laHfRqrEWqKpsRX7hd3euEdLJoe2icfS9-azvRKuoWJO4Ze4OEnR3-GaPEEDr0XRyLW7gklL4MsXZ9yCKigeebFxOxdOhLgegdA! \n\n\n\n\n\n\n\n\n\n--\n\nSarah Pak M&A Integration[!https://s3.amazonaws.com/uber-static/emails/2018/global/logos/Uber_Logo_Black_RGB.png! \n|https://uber.com/] \n\n\n\n\n\n\n\n\n{quote}\n\n\n{quote}\n\n\n\n\n\n\n--\n\nSarah Pak M&A Integration[!https://s3.amazonaws.com/uber-static/emails/2018/global/logos/Uber_Logo_Black_RGB.png! \n|https://uber.com/] \n\n\n\n\n\n\n{quote}\n\n\n{quote}",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Custom Trigger in XXAPEX - UBER_APEX_COLUMN_COND_DTLS_TRG',
#   'description': '',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Knack Password Reset',
#   'description': 'Hi Team,\n\n\nWe were told that this is the correct email for Knack issues. Seeking your help in resetting the  [Knack|https://uberfreight.knack.com/uf-businessops#the-hub/]  password of the following user. They are having trouble accessing the knack. They tried the "Forgot Password" option in the homepage but they did not receive any forgot password email.\n\n\n\nJessica Ladiao:  [ljessi@ext.uber.com|mailto:ljessi@ext.uber.com] \n\nChristian Nino Garcia:  [christiannino.garcia@ext.uber.com|mailto:christiannino.garcia@ext.uber.com] \n\nRonelyn Aguinaldo:  [raguin@ext.uber.com|mailto:raguin@ext.uber.com] \n\nKathrina Guisado:  [kguisa@ext.uber.com|mailto:kguisa@ext.uber.com] \n\nRiana Mabell Catacio: [rcatac@ext.uber.com|mailto:rcatac@ext.uber.com] \n\n\n\nThan k you!',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Re: New comments added to work item "Role/ Entitlement Owner Approval - Account Changes for User: Gerardo Fuentes"',
#   'description': '[+FinTech Support|mailto:finapps-support@uber.com]  \n\n\n\n\nHi Fintech,\n\n\n\nIt seems it is not possible to request Invoice Entry (Payables) access to local entities/ certain operating units.\nHas this been disabled?\n\n\n\nThank you,\n\n\n\nVicky\n\n\n\nOn Tue, 27 Apr 2021 at 18:20, Gerardo Fuentes < [gfuentes@uber.com|mailto:gfuentes@uber.com] > wrote:\n\n\n\n{quote}\nHi Vicky\n\n\nDo you know how I can specify that I only need access to Uber BV?\n\n\n\nI\'m adding info like this but I can\'t find a way to only ask for Uber BV:\n\n\n\n\n\n !image.png|thumbnail! \n\n\n\n\n\n\n\nThanks\n\n\n\nOn Mon, Apr 26, 2021 at 2:38 AM < [permissions@uber.com|mailto:permissions@uber.com] > wrote:\n\n\n\n{quote}\nComment added to work item "Role/ Entitlement  Owner Approval - Account Changes for User: Gerardo Fuentes" by Vicky Vermeulen on 4/26/21 7:38:08 AM UTC\n\n\n\n--------------------------------------------------------------------------------\n\nHi Gerry, Can you request NL Uber BV AP Invoice Entry? This covers all BV entities.\n{quote}',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Req 411369',
#   'description': 'Hi Team, \n\nCurrently PR 411639 is pending approval from Kaylan Kuchimanchi who is no longer with the company. The approver for this cost center should be Bernie Huddleston. \n\nThanks, \nAaron \n\n\n[https://uber.coupahost.com/requisition_headers/411369|https://uber.coupahost.com/requisition_headers/411369]  \n\n\n !image001.png|thumbnail! \n\n\n\nAaron Bertram\n\n\nManager, P2P Delivery Center\n\n\nNorth America \n\nInternal: \n[Approve your invoices\n|https://slack-redir.net/link?url=https://urldefense.proofpoint.com%2Fv2%2Furl%3Fu%3Dhttps-3A__usurv.uberinternal.com_%26d%3DDwMFaQ%26c%3Dr2dcLCtU9q6n0vrtnDw9vg%26r%3DkeMTJEpwbaUe9jm5Q70OmhRzQe2ZNyf-U5SxubaDGJE%26m%3DXtOI51YMMdtH4qHGZzJK0pygvK7vhEONaBow5Q-rR9s%26s%3D4HDnF2zFeZnntxZFi2RuYihiqMaOKiyh8_2IDwYPK3I%26e%3D] \n | \n[Check on Remaining PO Funds\n|https://slack-redir.net/link?url=https://urldefense.proofpoint.com%2Fv2%2Furl%3Fu%3Dhttps-3A__usurv.uberinternal.com_%26d%3DDwMFaQ%26c%3Dr2dcLCtU9q6n0vrtnDw9vg%26r%3DkeMTJEpwbaUe9jm5Q70OmhRzQe2ZNyf-U5SxubaDGJE%26m%3DXtOI51YMMdtH4qHGZzJK0pygvK7vhEONaBow5Q-rR9s%26s%3D4HDnF2zFeZnntxZFi2RuYihiqMaOKiyh8_2IDwYPK3I%26e%3D] \n | \n[Setup Delegate Approver\n|https://slack-redir.net/link?url=https://urldefense.proofpoint.com%2Fv2%2Furl%3Fu%3Dhttps-3A__team.uberinternal.com_display_FFOF_How-2Bto-2BSetup-2BDelegate-2BApprovals-2Bin-2BCoupa%26d%3DDwMFaQ%26c%3Dr2dcLCtU9q6n0vrtnDw9vg%26r%3DkeMTJEpwbaUe9jm5Q70OmhRzQe2ZNyf-U5SxubaDGJE%26m%3DXtOI51YMMdtH4qHGZzJK0pygvK7vhEONaBow5Q-rR9s%26s%3DZC01TBgNoYbm5921VqHGQilpWXojis5eD7S6fjByyzU%26e%3D] \n | \n[FAQs\n|https://slack-redir.net/link?url=https://urldefense.proofpoint.com%2Fv2%2Furl%3Fu%3Dhttps-3A__team.uberinternal.com_display_FFOF_Procure-2Bto-2BPay-2BFAQs%26d%3DDwMFaQ%26c%3Dr2dcLCtU9q6n0vrtnDw9vg%26r%3DkeMTJEpwbaUe9jm5Q70OmhRzQe2ZNyf-U5SxubaDGJE%26m%3DXtOI51YMMdtH4qHGZzJK0pygvK7vhEONaBow5Q-rR9s%26s%3Dx_llsHXx2pdFJR3HcnyqVTv7VeB9dV0F-Bq7BKo8-M4%26e%3D] \n\n\nExternal: \n\n[Uber Supplier Portal\n|https://slack-redir.net/link?url=https://www.uber.com%2Finfo%2Fsuppliers]',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Non compliant SEPA Transaction Rejection -15-Sep-2020',
#   'description': '== Created by JEMH via e-mail from: "FinOps Payments EMEA" <payments-emea@uber.com> == \n\nHi team,\n\n\n\nCould you please refer to the below rejection and fix the issue at the earliest.\n\n\n\n\n !image.png|thumbnail! \n\n\n\n\n\n\nRegards,\nFinPay EMEA',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'PO# 403452 Sync Issue ZD# 1969971',
#   'description': 'Hi Team,\n\n\nGreetings!\n\n\n\nWe see the PO# 403452 not getting synced to Oracle due to the below error.\n\n\n\nCould you please suggest the PO on how to fix it?\n\n\n\n\n !image.png|thumbnail! \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRegards,\n\n\nSunny',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Oracle scheduler bug',
#   'description': 'Hi Team,\r\n\r\nWe have found an error regarding the scheduler when applying funds to an invoice that has already been paid. The system applies the funds incorrectly causing Oracle to show $0 "On Account" but puts the overpayment directly on the invoices. Can you please review the images provided and pull a report that shows how many payments this has effected?\r\n-----------------------------------\r\n\r\nThis is a follow-up on a previously closed JIRA as the issue has not been fully resolved/re-emerged.\r\n\r\nPrevious JIRA: https://jira.uberinternal.com/servicedesk/customer/portal/434/FINAPPS-106535\r\n\r\nNew Example Below.\r\n\r\nThanks,\r\n\r\nBrandon',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'APEX Password rest',
#   'description': 'Hello,\n\n\nCan you please reset my password to the apex prod environment? I am trying to access the Oracle SCM apex reports at the following link but I can not remember my login information.\n\n\n\n[https://apex-prod.fintech.corp.uber.internal/apex/f?p=113:LOGIN_DESKTOP:110355144063309:::|https://apex-prod.fintech.corp.uber.internal/apex/f?p=113:LOGIN_DESKTOP:110355144063309:::] ::\n\n\n\n\n\nThanks,\nClayton',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Invoices not getting routed for approval in USERV.',
#   'description': 'Hi Team,\n\n\nWe have initiated invoice #028/2020-21 of PROFESSIONAL COMMERCIALS for approval in Oracle but in Userv it is reflected as a result not found.\n\n\n\nWe are receiving many cases with his scenario where invoices are initiated for approval in Oracle but in USERV it is showing as a  *result not found.*\n**\nPlease check this from your end and provide a one-time resolution.',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'File Transfer Failed -  Sender: UBERAP; Receiver: DBDIAP-JP; Msg Format & Type: PAIN001 - XML; Filename: UBER_JP_ORACLEPCHALL.95096634.xml.asc; Transaction Reference Number: 590877957648;',
#   'description': '== Created by JEMH via e-mail from:  <dbdcuat.admin@db.com> == \n\nHi, \n\nAn error caused a transmission failure in the following file:\n\n\nInbound Channel          : HTTPS1867\nFile Transfer Sender     : uberap\nSender                   : UBERAP\nReceiver                 : DBDIAP-JP\nSender File Name         : UBER_JP_ORACLEPCHALL.95096634.xml.asc\nMessage Format           : PAIN001\nMessage Type             : XML\nTransfer Reference No    : 590877957648\nReceive Timestamp        : Aug 25, 2020 3:37:34 PM GMT\nSender Reference Number  : \nFailure Reason           :  Decryption failed\n\n\nThank You \n\n\nDisclaimer:\nThis mail is automatically generated by db-direct Connect. Please do not reply to sender and kindly contact your L1 support for queries or requests. This message and any attachment(s) contained here are information that is confidential, proprietary to Deutsche Bank and its customers, privileged or otherwise protected by law.The information is solely intended for the individual or the entity it is addressed to. If you are not the intended recipient of this message, you are not authorized to read, forward, print, retain, copy or disseminate this',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': '2 Invoices Missing from Apex Expenditure Details Report',
#   'description': 'Hi FinTech,\n\n\nInvoices 000000217842 and 000000214550 are hitting the GL but missing from the Projects Expenditure Details report in Apex. Can we please have these added to Apex so that they tie out?\n\n\n\nBest,\nAlex',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': "Re: AR open transactions for Dec'20",
#   'description': '[+(JIRA)|mailto:finapps-support@uber.com] \n\n[+Lokesh Setty|mailto:lsetty@ext.uber.com]  please look at Ramesh request and advise why AR subledger entries always not reflecting in GL on time? Thanks!\n\n\n\n\n\n|Regards,\n\n\n\n\n !https://s3.amazonaws.com/uber-static/emails/2018/global/logos/Uber_Logo_Black_RGB.png! \n\n\n\n\n|\t\n\n|\tMoody Lam\n\nManager, Customer Payments and Application | FinOps B2B\n\n(415) 949-9835 | [moody.lam@uber.com|mailto:moody.lam@uber.com] |\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOn Mon, Jan 4, 2021 at 10:50 PM Ramesh Chavare < [rchava1@ext.uber.com|mailto:rchava1@ext.uber.com] > wrote:\n\n\n\n{quote}\nHi Naresh,\n\n\n\n\nStill 30th and 31st date transactions are not reflecting in GL. Could you please check and fix the issue asap.\n\n\n\nThanks,\nRamesh\n\n\n\nOn Mon, Jan 4, 2021 at 11:04 PM Moody Lam < [moody.lam@uber.com|mailto:moody.lam@uber.com] > wrote:\n\n\n\n{quote}\nHi Ramesh, thanks for checking!Today is December close BD+1, AR team is still working on the AR receipts, everything will be completed shortly and no later than tomorrow 13:00 PST. Thanks for your patience!\n\n\n\nFor 0.01 penny test, can you please help to book it to  *3006.1130.5001.00000.51045? *\n\n\n\n\n\n\n|Regards,\n\n\n\n\n !https://s3.amazonaws.com/uber-static/emails/2018/global/logos/Uber_Logo_Black_RGB.png! \n\n\n\n\n|\t\n\n|\tMoody Lam\n\nManager, Customer Payments and Application | FinOps B2B\n\n(415) 949-9835 | [moody.lam@uber.com|mailto:moody.lam@uber.com] |\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOn Mon, Jan 4, 2021 at 3:28 AM Naresh Akula < [nakula1@ext.uber.com|mailto:nakula1@ext.uber.com] > wrote:\n\n\n\n{quote}\nHi Ramesh,\n\n\n\n1) The payments for 12/11 and 12/22 are processed and reflecting in oracle.\n\n\n\n2) 0.01 is test payment - we have ignored HRC. 3) 12/30 and 12/31 will be reflecting today in oracle.\n\n\n\n[+Moody Lam|mailto:moody.lam@uber.com]  - Can you please provide the Coding for 0.01 test payment.\n\n\n**\n*Regards,*\n*Naresh Akula*\n*Function:* Order to Cash\n\n\n*Team:*   FinOps B2B Customer Payments\n\n*For Queries Reach Out To *:  *[UberCashApp-group@uber.com|mailto:UberCashApp-group@uber.com] *\n**\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOn Sun, Jan 3, 2021 at 11:55 PM Azhar Mirza < [amirza3@ext.uber.com|mailto:amirza3@ext.uber.com] > wrote:\n\n\n\n{quote}\nSure Moody!\n\n\nOn Sat, Jan 2, 2021, 11:31 PM Moody Lam < [moody.lam@uber.com|mailto:moody.lam@uber.com] > wrote:\n\n\n\n{quote}\n+Azhar to monitor and ensure all u4B Zaakpay are booked properly. Thanks!\n\n\n\n\nMoody\n\n\n\n\n\nOn Sat, Jan 2, 2021 at 9:33 AM Ramesh Chavare < [rchava1@ext.uber.com|mailto:rchava1@ext.uber.com] > wrote:\n\n\n\n{quote}\nHi Naresh,\n\n\nBelow transactions are not reflecting in GL. Could you please check and fix the issue.\n\n\n\n\n\n\n|Account|\tFlow|\tBudget|\tStat.|\tTrans.date|\tValue date|\tLedger Amount|\tAmount|\tFlow amount|\tAmount|\tReference|\tDescription|\tFee|\n|3006HBINR901|\t+195|\t |\tAC|\t12/03/2020|\t12/03/2020|\t+INR|\t0.01|\t+INR|\t0.01|\tNONREF; 7318U4B|\tNEFT FROM DELPHI PROPULSION SYSTEMS20C2G032146G0Y567318U4B BANK OF AMERICA NA2020/12/03 050142|\t |\n|3006HBINR901|\t+195|\t |\tAC|\t12/22/2020|\t12/22/2020|\t+INR|\t182.00|\t+INR|\t182.00|\tNONREF; 7318U4B|\tNEFT FROM PRODAIR AIR INDIA PVT LTD20CM41016Q092X427318U4B BANK OF AMERICA NA2020/12/22 160159|\t |\n|3006HBINR901|\t+108|\t |\tAC|\t12/11/2020|\t12/11/2020|\t+INR|\t6,576.04|\t+INR|\t6,576.04|\tHSBCIFILE17474|\t9004XAZLPE46TFR+7318U4B 0179820000002338|\t |\n|3006HBINR901|\t+195|\t |\tAC|\t12/22/2020|\t12/22/2020|\t+INR|\t10,000.00|\t+INR|\t10,000.00|\tNONREF; 7318U4B|\tNEFT FROM CMS ESCROW NEFT RTGS FUNDN3572013490914057318U4B HDFC BANK LTDESCROW TRF FROM RAJESH ESTATES AND 2020/12/22 183230|\t |\n|3006HBINR901|\t+195|\t |\tAC|\t12/30/2020|\t12/30/2020|\t+INR|\t129,632.00|\t+INR|\t129,632.00|\tNONREF; 7318U4B|\tNEFT FROM M/s. WOODLANDS MULTISPECIALLAH203651601277318U4B ALLAHABAD BANK2020/12/30 140158|\t |\n|3006HBI ...
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'UBER B2B Invoices Process Status Report',
# ...
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': '[OTM] Screening Initiated - 20201203-0016',
#   'description': "Hi team, \n\nCan you please take a look at the subject order?  It's stuck in Screening Initiated. \n\n\n\nThanks\n\n****\n**********\n\n\n\n|**********\n\n\n|\n !https://i.imgur.com/Tp5buzX.gif! \n|\n\n\n\n\n\n\n\n\n\n\n\n\n\n|\t\n\n|\t*Sean Ida*\n\nSr. Logistics Program Specialist \nM: 303-667-8700 | +[isean@uber.com\n|mailto:isean@uber.com] + | [logistics@uber.com|mailto:logistics@uber.com] \n\n\n|",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'HFM - Add to Careem clean team group',
#   'description': "Hi, I'm requesting to be added to the Careem clean team group in HFM.\r\nIf you need an approval, please reach out to tinali@uber.com, cc'd in this ticket.\r\n\r\nThank you,\r\nDaeWook",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Urgent ticket: Coupa not recognizing SSO',
#   'description': 'Team, \n\n\nCan someone please help resolve Jira  ticket [FINOPS-562|https://jira.uberinternal.com/browse/FINOPS-562] ? I opened on Dec 18th and bumped it twice to  [@Mark Arrigotti|mailto:marrigotti@uber.com] , but I haven\'t heard any word back. Need to escalate the issue as I have 4 POs that needed to be submitted in December. Jason Moya (bcc) from Service Desk Support recommended I reach out to you. I appreciate the help!\n\n\n\n_Coupa error message: "Login Error" Unable to locate user record with SSO ID \'[jackwins@uber.com|mailto:jackwins@uber.com] \'"_\n\n\n__\nThanks, \nJack',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Invoice not found in EDI Portal.',
#   'description': 'Hi Team,\n\n\n\nSeeking assistance for invoice resubmission.  Please see the link below. \n\n\n\n[https://docs.google.com/spreadsheets/d/10848PUVIRqfTTiYDPqtMlefwxpE88gf7RqwPOgxiutw/edit?usp=sharing|https://docs.google.com/spreadsheets/d/10848PUVIRqfTTiYDPqtMlefwxpE88gf7RqwPOgxiutw/edit?usp=sharing] \n\n\n\n\n\n*Jayson Phillip Dimayuga\n*\n*Fin Ops Analyst \n\n*+639083632597| [*jdimay2@ext.uber.com\n*|mailto:cgueva5@ext.uber.com] \nUse this ID for Instant Meetings : \n*+jdimay2 \n+**(Slack/Hangouts)\n**[To Report Issue / Incident\n|https://jira.uberinternal.com/servicedesk/customer/portal/299/create/3781]  \n*\n[*To Report Escalations\n*|https://jira.uberinternal.com/servicedesk/customer/portal/299/create/4082] \n\n\n*[To Report process change\n|https://jira.uberinternal.com/servicedesk/customer/portal/299/create/3782] \n*',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Request for new ship-to address',
#   'description': 'PO Creator: snaray11@ext.uber.com \n Manager:  \n Location type: 1 \n If location type is Other:  \n Address: 19-8 Nihonbashi Kabutocho, Chuo-ku,Tokyo, JP, 103-0026 \n Which region are you shipping to?: 1 \n Why are you shipping to this location?: New office \n What item are you shipping?:  Internet link',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'UBER PROD: Long Running Concurrent Programs',
#   'description': 'We need someone to look into these requests running this long.  They are running way too long and causing alerts in the system.\n\n\n\nMatt See\n614-477-5537\n\n\n\n\n\n\n\n\n\n\n\n\n---------- Forwarded message ---------\n\nFrom: <oracle@dca1p-dbadm01.corp.uber.internal>\n\n\nDate: Tue, May 18, 2021 at 5:00 PM\n\nSubject: UBER PROD: Long Running Concurrent Programs\n\nTo: < [sreedhar.marepally@uber.com|mailto:sreedhar.marepally@uber.com] >, < [rdasari@uber.com|mailto:rdasari@uber.com] >, < [msee@uber.com|mailto:msee@uber.com] >, < [narender@uber.com|mailto:narender@uber.com] >, < [deepaks@uber.com|mailto:deepaks@uber.com] >, < [singh@uber.com|mailto:singh@uber.com] >, < [kudikala@uber.com|mailto:kudikala@uber.com] >, < [nduong@uber.com|mailto:nduong@uber.com] >, < [sarath@uber.com|mailto:sarath@uber.com] >\n\n\n\n\n\n\n\n\n\n\n\n\n\n| |\t\n\nh1. UBER PROD: Concurrent Programs Running Longer Than 3 Hours|\t |\n\n\n\n\n||REQ_ID||\tSTART_TIME||\tPROGRAM||\tPHASE||\tSTATUS||\tUSER_NAME||\tHOURS||\n|121123196|\t23:34:13|\tUber Apex MTR Main|\tRunning|\tNormal|\tSCHEDULER|\t14.43|\n|121131260|\t04:20:00|\tUBER AR Transaction Integration Loa|\tRunning|\tPaused|\tSCHEDULER|\t9.66694444|\n|121132427|\t05:05:00|\tUBER AR Transaction Integration Loa|\tRunning|\tPaused|\tSCHEDULER|\t8.91694444|\n|121133881|\t02:43:52|\tUber Apex Reclass In-Digest Program|\tRunning|\tNormal|\tSCHEDULER|\t11.2691667|\n|121138843|\t04:20:00|\tUBER_AR_TRX_INTEGR_LOAD_WB|\tRunning|\tPaused|\tSCHEDULER|\t9.66694444|\n|121138844|\t04:20:03|\tUBER AR Transaction Integration Loa|\tRunning|\tNormal|\tSCHEDULER|\t9.66611111|\n|121140732|\t05:05:00|\tUBER_AR_TRX_INTEGR_LOAD_WB|\tRunning|\tPaused|\tSCHEDULER|\t8.91694444|',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Trintech - Unable to run reports',
#   'description': 'Hi Team/Eric\n\n\n\n\n\nGood Morning!\n\n\n\nI am unable to run any reports in Trintech and no automated reports are run for today. I have even checked with Thor and he also has the same issue.\n\n\n\nPlease address this at the earliest.\n\n\n\nBest Regards\nPragna',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Trintech access ',
#   'description': 'Hi Team,\r\n\r\nCould you please grant Trintech access for following payroll team members.\r\n\r\n1. Employee ID: 147808\r\n    Employee Name: Venkatakrishnan Panneerselvam\r\n    Email ID: venkatakrishnan@uber.com\r\n\r\n2. Employee ID: 145426\r\n    Employee Name: S Meera\r\n    Email ID: meeras@uber.com\r\n\r\nBest regards,\r\nJagan M R\r\n',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Deactivation of account 1201-21360 in Trintech',
#   'description': 'Creating this jira to deactivate 1201-21360 in Trintech as per the DRM request https://jira.uberinternal.com/browse/DRM-288',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Rejection reason - 1373591',
#   'description': 'Hi Praveen and Team,\n\n\nNeed your assistance.\n\n\n\nAs per STP dashboard, the payment doc 1373591 has been rejected, request you to help us with the rejection reason.\n\n\n\nPlease prioritize the request.\n\n\n\nPPR: 2072 Electronic H2H HSBC-18-AUG-2021 00:20:08\n\n\n\n\n !image.png|thumbnail! \n\n\n\n\n\n\nThank you,\nSandhya Chandran',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Re-open the PO #387436 in oracle.',
#   'description': 'Hi Team,\n\n\nPlease re-open the PO #387436 in oracle.\n\n\n\n\n\n !image.png|thumbnail! \n\n\n\n\n\n\n\n !image-1.png|thumbnail! \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRegards,\nAkshay Kumar Ramanboie,\nUber Buyer Operations.',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': '2072-2073 Saudi Arabia VAT Rate Change to 15%',
#   'description': '(+Dan, Mike)\n\n\n\nHi Vinay,\n\n\nTo clear up any confusion, the request is for the VAT rate between entities Uber Saudi Arabia (2072) * *and  *Uber Portier BV (2073)* to be reverted back to 15% since the initial change requested in ticket 109791. \n\n\n\nTicket FINAPPS-112910 has since been closed, creating a new ticket here as suggested.\n\n\n\nTo note, this change only applied to the 2072 Uber Saudi - 2073 Portier BV relationship. The VAT rate between entities 2072 Uber Saudi and 2002 Uber BV will remain at 0% as per the previous request. \n\n\n\n[@Daniel Priestley|mailto:daniel.priestley@uber.com] ,  [@Mike McGlinchey|mailto:mike.mcglinchey@uber.com]  can you please add your confirmation on this thread.\n\n\n\n\n\n\nThanks,\nDanny.',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Submission Blocker for entities 1151 and 2063 in Coupa',
#   'description': 'Hi Rajesh,\n\n\nAt midnight PST hours tonight, can you please create a submission blocker in Coupa for entities 1151 and 2063 due to the sale of ATG to Aurora.\n\n\n\nPlease include the following message:\n\n\n\n"Due to the recent acquisition of ATG by Aurora, no new purchases will be processed for ATG. Please reach out to Austen Blalock or Aaron Bertram with any questions."\n\n\n\nThanks,\nAusten',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Coupa access ZD#2000657',
#   'description': 'Hi Team,\n\nCould you please provide the Coupa access to " Rohan Sawkar" cc\'d we need to transfer the pending POs ownership.',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Flux Admin access',
#   'description': 'HiI need access for the following group in TM1 flux[4:15\n|https://uber.slack.com/archives/D02A0FEPBEH/p1628032555000300] \n\n"StratFin Commentary Admin"',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'Ticket # 1982844, Unable to process Cross border invoice.',
#   'description': 'Hi Team,\n\n\nPlease help us to process the attached cross border invoice as we are facing the following issue provided in below screenshot.\n\n\n\n\n !image.png|thumbnail! \n\n\n\n\n\n !image-1.png|thumbnail!',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'UBER PROD: Long Running Concurrent Programs',
#   'description': 'Need to check on this long running process.\n\n\n\nMatt See\n614-477-5537\n\n\n\n\n\n\n\n\n\n\n\n\n---------- Forwarded message ---------\n\nFrom: <oracle@dca1p-dbadm01.corp.uber.internal>\n\n\nDate: Tue, Feb 16, 2021 at 1:00 PM\n\nSubject: UBER PROD: Long Running Concurrent Programs\n\nTo: < [sreedhar.marepally@uber.com|mailto:sreedhar.marepally@uber.com] >, < [rdasari@uber.com|mailto:rdasari@uber.com] >, < [msee@uber.com|mailto:msee@uber.com] >, < [narender@uber.com|mailto:narender@uber.com] >, < [deepaks@uber.com|mailto:deepaks@uber.com] >, < [singh@uber.com|mailto:singh@uber.com] >, < [kudikala@uber.com|mailto:kudikala@uber.com] >, < [nduong@uber.com|mailto:nduong@uber.com] >, < [sarath@uber.com|mailto:sarath@uber.com] >\n\n\n\n\n\n\n\n\n\n\n\n\n\n| |\t\n\nh1. UBER PROD: Concurrent Programs Running Longer Than 3 Hours|\t |\n\n\n\n\n||REQ_ID||\tSTART_TIME||\tPROGRAM||\tPHASE||\tSTATUS||\tUSER_NAME||\tHOURS||\n|114488127|\t00:42:25|\tUber Coupa PO Integration Status Up|\tRunning|\tNormal|\tSCHEDULER|\t9.29333333|',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'ZD #1956862 PO #378857',
#   'description': "Hi Team,\n\n\n\nAs per the mentioned ticket, this PO was submitted with some changes and sent for approval.\n\n\n\nAll the approvers approve this change request and now it is under last person's (Tony) approval. He is trying to approve this request but it is not allowing him to approve it.\n\n\n\nCould you please check and resolve this issue?\n\n\n !image.png|thumbnail! \n\n\n\n\n\n !image-1.png|thumbnail! \n\n\n\n\n\n\n\nRegards,\nNaveen Kumar\nUber Buyer Ops Team.",
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': '[Finance Operations] Update: Re: Please Pay for Your Overlooked Invoices',
#   'description': "Hi Team,\n\nPlease route approval of invoice 24315650 Adam Kenvarg. Curtis Lambert is no longer with the company and Adam was his previous manager.\n\nThanks,\nAaron\n\n*From:\n* Adam Kenvarg [mailto:[adamk@uber.com|mailto:adamk@uber.com] ]\n\n*Sent:* Monday, April 20, 2020 7:22 PM\n\n*To:* Ronen Sarig <[ronen@uber.com|mailto:ronen@uber.com] >\n\n*Cc:* Support <[atg-ap@uber.com|mailto:atg-ap@uber.com] >; Cle Sales <[cle.sales@mcmaster.com|mailto:cle.sales@mcmaster.com] >; Curtis Lambert <[curtis.lambert@uber.com|mailto:curtis.lambert@uber.com] >\n\n*Subject:* Re: [Finance Operations] Update: Re: Please Pay for Your Overlooked Invoices\n I'm happy to approve this.  Please let me know what I can do to help. \nThanks,\nAdam\n\n On Mon, Apr 20, 2020 at 3:07 PM Ronen Sarig <[ronen@uber.com|mailto:ronen@uber.com] > wrote:\n\n{quote}\nHello Santosh, \nregarding invoice 24315650:\n\n\nPayment to McMaster-Carr is on hold, because our system is waiting on Curtis Lambert's approval. Curtis was an intern who worked for us months ago, but is not at the company any longer (and therefore unable to approve.) I've CC'd his former manager - Adam Kenvarg - on this email. Perhaps Adam can give approval. Or, if it makes any difference, I approve the purchase (I am a FTE engineer that worked on Curtis' team, while he was here.)\n\n\nPlease let us know what we need to do in order to get this resolved. We want to make sure to pay our vendor.\n\n\n-Ronen Sarig\n\n\n\n On Fri, Apr 17, 2020 at 3:53 AM Support <[atg-ap@uber.com|mailto:atg-ap@uber.com] > wrote:\n\n{quote}\n\n\n\n|\n !https://upload.wikimedia.org/wikipedia/commons/thumb/5/58/Uber_logo_2018.svg/440px-Uber_logo_2018.svg.png! \n|\n\n\n##- Please type your reply above this line -##\n\nYou are registered as a CC on this request (1912789). Reply to this email to add a comment to the request.\n\n\n\n|\n\n\n|Santhosh Reddy (Finance Operations) Apr 17, 12:53 CEST Hi Sunny,\n\n\n\nGreetings from the AP team!\n\n\n|Invoice number|\tAP Status|\n|19798262|\tProcessed and approved in our system, it will get paid by the date 22-Apr-2020|\n|24315650|\tProcessed and waiting for approval from ''Curtis Lambert'' in uServ, once approved it will get paid by the following payment run.|\n|26939714|\tProcessed and approved in our system, it will get paid by the date 22-Apr-2020|\n|24962434|\tPaid on 24-MAR-2020 via ACH [#1138449|https://urldefense.proofpoint.com/v2/url?u=https-3A__uberaf.zendesk.com_tickets_1138449&d=DwMFaQ&c=r2dcLCtU9q6n0vrtnDw9vg&r=Pk5n_EMCeRAif7ZUENySVQ&m=OcGdXG1UxnxWC_sQ-n5T7J9gM2u_2_4B3-0H7HkG0Vc&s=VQ1Qnm9onuOSQpAaGGjBgYb0NkqAygCj0YHZLqnrnMM&e=]  for amount $142.57|\n|24024599|\tProcessed and approved in our system, it will get paid by the date 22-Apr-2020|\n|18420150|\tCredit settled on 20-MAR-2020 via ACH [#1137281|https://urldefense.proofpoint.com/v2/url?u=https-3A__uberaf.zendesk.com_tickets_1137281&d=DwMFaQ&c=r2dcLCtU9q6n0vrtnDw9vg&r=Pk5n_EMCeRAif7ZUENySVQ&m=OcGdXG1UxnxWC_sQ-n5T7J9gM2u_2_4B3-0H7HkG0Vc&s=-Ykq6jlpnSiMtUkzD177BoQBQoPBDVW2bNQ8UQaPcKM&e=] |\n\n\n\nPlease let us know if you need help with anything else.\n\n\n\nRegards,\n\nUber AP team\n\n|\n\n|\n\n\n\n\n\n|\n\n\n|Sunny Wan Apr 14, 00:27 CEST Hello AP,Please take a look into the following unpaid invoices and let us know what\n\nis needed to issue payment.*Buyer* *Date* *Invoice/Credit* *Purchase Order / Invoice rec'd date*\n\n*Amount*\n\nAndrew Chellman 10/24/19 Invoice 19798262 358344\n\n2020-MAR-23\n\n$606.11\n\nCurtis Lambert 12/12/19 Invoice 24315650 375916\n\n2019-DEC-17\n\n$774.08\n\nJaye Morrisey 01/07/20 Invoice 26939714 382937\n\n2020-MAR-23\n\n$59.88\n\nMatthew Cerda 12/18/19 Invoice 24962434 374327\n\n2019-DEC-20\n\n$142.57\n\nRonen Sarig 12/10/19 Invoice 24024599 373537\n\n2020-MAR-24\n\n$309.53\n\nSamantha Sunny 10/11/19 Credit 18420150 359351\n\n2020-MAR-19\n\n($74.54)\n\n*Total Amount Due:* *$1,817.63*Warm Regards,Sunny Wan\n\nBuyerOps, Advanced Technologies Group\n\n*[sunnywan@uber.com|mailto: ...
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'},
#  {'summary': 'PO# 293637 Reopen ZD# 1861048',
#   'description': 'Hi Team,\n\n\n\n\nGreetings!\n\n\n\nCould you please help us to reopen the PO# 293637 in Oracle?\n\n\n\n\n !image.png|thumbnail! \n\n\n\n\n\n\n\n\n\n\nThanks,\nSunny\nBuyerOperations',
#   'id': 0,
#   'label': 'component_batch',
#   'projectid': 'L1triage'}]

# %%
import requests
import base64
import time
import json



#url_address = "http://127.0.0.1:5000"
#url_address = "https://uipathmltest.corp.uber.com"
#url_address = "https://uipathmlprod.corp.uber.com"
url_address="https://uipathmldev.corp.uber.com"
#url_address="https://192.168.108.132:443"
#ENDPOINT = '/iacoe_ocr/l1_triage_classifier_component_multi'
#ENDPOINT = '/iacoe_ocr/l1_triage_classifier_tier_type_1_multi'
#ENDPOINT = '/iacoe_ocr/l1_triage_classifier_tier_type_2_multi'
#ENDPOINT = '/iacoe_ocr/l1_triage_classifier_michelangelo_multi'
ENDPOINT = '/iacoe_ocr/l1_triage_classifier_michelangelo_batch_multi'


url = url_address + ENDPOINT
payload_11={'l1triage_input_data':df}

try:
    t_start=time.time()
    response = requests.post(url, json=payload_11, verify=False)
    print(response.text)
    t_end=time.time()
    print(t_end-t_start)
except requests.ConnectionError as e:
    print("OOPS!! Connection Error. Make sure you are connected to Internet. Technical Details given below.\n")
    print(str(e))            
    #renewIPadress()
    #continue
except requests.Timeout as e:
    print("OOPS!! Timeout Error")
    print(str(e))
    #renewIPadress()
    #continue
except requests.RequestException as e:
    print("OOPS!! General Error")
    print(str(e))
    #renewIPadress()
    #continue
except KeyboardInterrupt:
    print("Someone closed the program")
# Out:
# /Users/jghosh2/opt/anaconda3/envs/py365/lib/python3.7/site-packages/urllib3/connectionpool.py:1050: InsecureRequestWarning: Unverified HTTPS request is being made to host 'uipathmldev.corp.uber.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {"success":[{"component_batch":["uCash"],"conf_score":0.44},{"component_batch":["Access Requests"],"conf_score":0.74},{"component_batch":["Oracle Transport Management"],"conf_score":0.66},{"component_batch":["B2B"],"conf_score":0.63},{"component_batch":["Oracle Administration"],"conf_score":0.66},{"component_batch":["Access Requests"],"conf_score":0.75},{"component_batch":["Access Requests"],"conf_score":0.71},{"component_batch":["TrinTech"],"conf_score":0.69},{"component_batch":["DRM/DRG"],"conf_score":0.73},{"component_batch":["Oracle General Ledger"],"conf_score":0.66},{"component_batch":["Coupa"],"conf_score":0.67},{"component_batch":["Coupa"],"conf_score":0.65},{"component_batch":["Oracle Cash Management"],"conf_score":0.56},{"component_batch":["Coupa"],"conf_score":0.53},{"component_batch":["Coupa"],"conf_score":0.66},{"component_batch":["Access Requests"],"conf_score":0.62},{"component_batch":["EPM/Hyperion"],"conf_score":0.85},{"component_batch":["Oracle Payables"],"conf_score":0.69},{"component_batch":["Oracle General Ledger"],"conf_score":0.77},{"component_batch":["Oracle Apex Reports"],"conf_score":0.62},{"component_batch":["Oracle General Ledger"],"conf_score":0.6},{"component_batch":["Oracle General Ledger"],"conf_score":0.69},{"component_batch":["Oracle Payables"],"conf_score":0.69},{"component_batch":["TrinTech"],"conf_score":0.95},{"component_batch":["Oracle Transport Management"],"conf_score":0.93},{"component_batch":["Coupa"],"conf_score":0.69},{"component_batch":["Oracle Administration"],"conf_score":0.57},{"component_batch":["Oracle Administration"],"conf_score":0.57},{"component_batch":["Oracle Administration"],"conf_score":0.62},{"component_batch":["Coupa"],"conf_score":0.44},{"component_batch":["Oracle Payments"],"conf_score":0.73},{"component_batch":["Coupa"],"conf_score":0.79},{"component_batch":["B2B"],"conf_score":0.7},{"component_batch":["Oracle Apex Reports"],"conf_score":0.72},{"component_batch":["Oracle Payables"],"conf_score":0.69},{"component_batch":["Oracle Payments"],"conf_score":0.73},{"component_batch":["Oracle Apex Reports"],"conf_score":0.59},{"component_batch":["B2B"],"conf_score":0.59},{"component_batch":["B2B"],"conf_score":0.73},{"component_batch":["Kofax"],"conf_score":0.47},{"component_batch":["uCash"],"conf_score":0.77},{"component_batch":["Oracle Payments"],"conf_score":0.65},{"component_batch":["Oracle Payables"],"conf_score":0.7},{"component_batch":["B2B"],"conf_score":0.72},{"component_batch":["Oracle Transport Management"],"conf_score":0.67},{"component_batch":["Access Requests"],"conf_score":0.49},{"component_batch":["Coupa"],"conf_score":0.89},{"component_batch":["EPM/Hyperion"],"conf_score":0.66},{"component_batch":["Oracle Administration"],"conf_score":0.75},{"component_batch":["TrinTech"],"conf_score":0.71},{"component_batch":["Access Requests"],"conf_score":0.74},{"component_batch":["Oracle Payables"],"conf_score":0.72},{"component_batch":["Oracle E B Tax"],"conf_score":0.62},{"component_batch":["uAccrue"],"conf_score":0.74},{"component_batch":["Access Requests"],"conf_score":0.54},{"component_batch":["Oracle Transport Management"],"conf_score":0.82},{"component_batch":["Oracle Payments"],"conf_score":0.63},{"component_batch":["DRM/DRG"],"conf_score":0.65},{"component_batch":["Oracle General Ledger"],"conf_score":0.59},{"component_batch":["Coupa"],"conf_score":0.79},{"component_batch":["EPM/Hyperion"],"conf_score":0.73},{"component_batch":["Oracle Cash Management"],"conf_score":0.9},{"component_batch":["Coupa"],"conf_score":0.71},{"component_batch":["EPM/Hyperion"],"conf_score":0.67},{"component_batch":["Oracle Administration"],"conf_score":0.61},{"component_batch":["Concur"],"conf_score":0.71},{"component_batch":["Oracle Payments"],"conf_score":0.47},{"component_batch":["Access Requests"],"conf_score":0.66},{"component_batch":["B2B"],"conf_score":0.88},{"component_batch":["DRM/DRG"],"conf_score":0.7},{"component_batch":["Oracle Payments"],"conf_score":0.71},{"component_ ...
#
# 11.734803199768066

# %%
b=response.text

# %%
c=json.loads(b)

# %%
type(c)
# Out:
# dict

# %%
c
# Out:
# {'success': [{'component_batch': ['Oracle Payables'], 'conf_score': 0.48},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.51},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.51},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.85},
#   {'component_batch': ['uCash'], 'conf_score': 0.83},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.84},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.87},
#   {'component_batch': ['B2B'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.7},
#   {'component_batch': ['B2B'], 'conf_score': 0.64},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.83},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.77},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.62},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.73},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.81},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.57},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.69},
#   {'component_batch': ['Workday'], 'conf_score': 0.55},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.49},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.74},
#   {'component_batch': ['B2B'], 'conf_score': 0.82},
#   {'component_batch': ['Concur'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.65},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.72},
#   {'component_batch': ['uCash'], 'conf_score': 0.91},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.47},
#   {'component_batch': ['Coupa'], 'conf_score': 0.65},
#   {'component_batch': ['Coupa'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.74},
#   {'component_batch': ['Coupa'], 'conf_score': 0.68},
#   {'component_batch': ['FDS'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.6},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.56},
#   {'component_batch': ['Coupa'], 'conf_score': 0.63},
#   {'component_batch': ['Coupa'], 'conf_score': 0.63},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.86},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.73},
#   {'component_batch': ['Coupa'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.8},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.56},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.57},
#   {'component_batch': ['Concur'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.72},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.48},
#   {'component_batch': ['B2B'], 'conf_score': 0.74},
#   {'component_batch': ['Coupa'], 'conf_score': 0.76},
#   {'component_batch': ['Concur'], 'conf_score': 0.7},
#   {'component_batch': ['Coupa'], 'conf_score': 0.81},
#   {'component_batch': ['B2B'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.73},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.6},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Coupa'], 'conf_score': 0.73},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.72},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.77},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['Concur'], 'conf_score': 0.72},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.64},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.82},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.82},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.59},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.59},
#   {'component_batch': ['Coupa'], 'conf_score': 0.74},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.65},
#   {'component_batch': ['Coupa'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle E B Tax'], 'conf_score': 0.56},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.81},
#   {'component_batch': ['B2B'], 'conf_score': 0.75},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.68},
#   {'component_batch': ['Kofax'], 'conf_score': 0.56},
#   {'component_batch': ['B2B'], 'conf_score': 0.83},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.61},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Apex Reports'], 'conf_score': 0.63},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.75},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.64},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.8},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.8},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.8},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.43},
#   {'component_batch': ['uSurv'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.71},
#   {'component_batch': ['Coupa'], 'conf_score': 0.82},
#   {'component_batch': ['uSurv'], 'conf_score': 0.59},
#   {'component_batch': ['uCash'], 'conf_score': 0.78},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.81},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.71},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.83},
#   {'component_batch': ['Oracle Fixed Asset'], 'conf_score': 0.69},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.67},
#   {'component_batch': ['B2B'], 'conf_score': 0.67},
#   {'component_batch': ['T2C'], 'conf_score': 0.59},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.53},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.53},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.85},
#   {'component_batch': ['Coupa'], 'conf_score': 0.65},
#   {'component_batch': ['Coupa'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.6},
#   {'component_batch': ['Coupa'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.64},
#   {'component_batch': ['B2B'], 'conf_score': 0.5},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.83},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.34},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.85},
#   {'component_batch': ['Concur'], 'conf_score': 0.86},
#   {'component_batch': ['T2C'], 'conf_score': 0.58},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.71},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Apex Reports'], 'conf_score': 0.52},
#   {'component_batch': ['Concur'], 'conf_score': 0.69},
#   {'component_batch': ['Coupa'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.77},
#   {'component_batch': ['Coupa'], 'conf_score': 0.75},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.69},
#   {'component_batch': ['B2B'], 'conf_score': 0.64},
#   {'component_batch': ['T2C'], 'conf_score': 0.67},
#   {'component_batch': ['Coupa'], 'conf_score': 0.58},
#   {'component_batch': ['B2B'], 'conf_score': 0.74},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.72},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.73},
#   {'component_batch': ['B2B'], 'conf_score': 0.73},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.46},
#   {'component_batch': ['B2B'], 'conf_score': 0.77},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.57},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.54},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.62},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.49},
#   {'component_batch': ['B2B'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.84},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.65},
#   {'component_batch': ['uCash'], 'conf_score': 0.62},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.7},
#   {'component_batch': ['Coupa'], 'conf_score': 0.78},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.89},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.72},
#   {'component_batch': ['usupplier'], 'conf_score': 0.65},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.65},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.93},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.77},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.56},
#   {'component_batch': ['Coupa'], 'conf_score': 0.58},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.51},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.57},
#   {'component_batch': ['Coupa'], 'conf_score': 0.82},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.69},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.63},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.8},
#   {'component_batch': ['Coupa'], 'conf_score': 0.68},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.79},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.95},
#   {'component_batch': ['Coupa'], 'conf_score': 0.44},
#   {'component_batch': ['Coupa'], 'conf_score': 0.66},
#   {'component_batch': ['Coupa'], 'conf_score': 0.78},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.75},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.63},
#   {'component_batch': ['Coupa'], 'conf_score': 0.59},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.56},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.86},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.82},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.71},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.74},
#   {'component_batch': ['Coupa'], 'conf_score': 0.82},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.54},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.58},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.55},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.72},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.58},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.83},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.74},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.94},
#   {'component_batch': ['Coupa'], 'conf_score': 0.66},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.87},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.56},
#   {'component_batch': ['T2C'], 'conf_score': 0.58},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.45},
#   {'component_batch': ['uSurv'], 'conf_score': 0.5},
#   {'component_batch': ['Coupa'], 'conf_score': 0.6},
#   {'component_batch': ['Coupa'], 'conf_score': 0.69},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.95},
#   {'component_batch': ['usupplier'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.61},
#   {'component_batch': ['Coupa'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.83},
#   {'component_batch': ['B2B'], 'conf_score': 0.79},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.66},
#   {'component_batch': ['Coupa'], 'conf_score': 0.48},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.84},
#   {'component_batch': ['Coupa'], 'conf_score': 0.44},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.5},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.7},
#   {'component_batch': ['Concur'], 'conf_score': 0.71},
#   {'component_batch': ['T2C'], 'conf_score': 0.65},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.71},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.67},
#   {'component_batch': ['Coupa'], 'conf_score': 0.87},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.72},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.56},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.77},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.69},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.48},
#   {'component_batch': ['B2B'], 'conf_score': 0.91},
#   {'component_batch': ['B2B'], 'conf_score': 0.72},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.75},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.61},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.6},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.68},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.75},
#   {'component_batch': ['Coupa'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.5},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.63},
#   {'component_batch': ['B2B'], 'conf_score': 0.69},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.85},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.57},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.58},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.45},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.79},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.56},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.81},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.9},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.86},
#   {'component_batch': ['Coupa'], 'conf_score': 0.57},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.87},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.69},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.62},
#   {'component_batch': ['B2B'], 'conf_score': 0.52},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.57},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.85},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.49},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.74},
#   {'component_batch': ['uCash'], 'conf_score': 0.82},
#   {'component_batch': ['Concur'], 'conf_score': 0.56},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.64},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.69},
#   {'component_batch': ['Concur'], 'conf_score': 0.65},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.76},
#   {'component_batch': ['B2B'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.64},
#   {'component_batch': ['Coupa'], 'conf_score': 0.52},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['uCash'], 'conf_score': 0.54},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.71},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.78},
#   {'component_batch': ['B2B'], 'conf_score': 0.78},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.7},
#   {'component_batch': ['Coupa'], 'conf_score': 0.79},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.59},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.75},
#   {'component_batch': ['Coupa'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.56},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.78},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.74},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.73},
#   {'component_batch': ['Coupa'], 'conf_score': 0.67},
#   {'component_batch': ['Coupa'], 'conf_score': 0.72},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.69},
#   {'component_batch': ['Coupa'], 'conf_score': 0.54},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.6},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.69},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.66},
#   {'component_batch': ['B2B'], 'conf_score': 0.73},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.76},
#   {'component_batch': ['B2B'], 'conf_score': 0.73},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.86},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.73},
#   {'component_batch': ['Coupa'], 'conf_score': 0.73},
#   {'component_batch': ['Coupa'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.55},
#   {'component_batch': ['B2B'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.67},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.55},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.56},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.58},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.65},
#   {'component_batch': ['Coupa'], 'conf_score': 0.69},
#   {'component_batch': ['Kofax'], 'conf_score': 0.77},
#   {'component_batch': ['Concur'], 'conf_score': 0.6},
#   {'component_batch': ['B2B'], 'conf_score': 0.75},
#   {'component_batch': ['B2B'], 'conf_score': 0.73},
#   {'component_batch': ['Coupa'], 'conf_score': 0.68},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.71},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.46},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.69},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.73},
#   {'component_batch': ['Coupa'], 'conf_score': 0.59},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.74},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.48},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.59},
#   {'component_batch': ['uSurv'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.85},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.82},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.46},
#   {'component_batch': ['B2B'], 'conf_score': 0.59},
#   {'component_batch': ['B2B'], 'conf_score': 0.6},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.59},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.87},
#   {'component_batch': ['Coupa'], 'conf_score': 0.66},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.89},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.44},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.78},
#   {'component_batch': ['Workday'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.47},
#   {'component_batch': ['B2B'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.46},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.61},
#   {'component_batch': ['Coupa'], 'conf_score': 0.57},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.88},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.49},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.84},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.61},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.6},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.47},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['uSurv'], 'conf_score': 0.57},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.9},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.71},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.91},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.62},
#   {'component_batch': ['B2B'], 'conf_score': 0.64},
#   {'component_batch': ['Coupa'], 'conf_score': 0.74},
#   {'component_batch': ['Coupa'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Coupa'], 'conf_score': 0.76},
#   {'component_batch': ['Coupa'], 'conf_score': 0.78},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.6},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.78},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['Coupa'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.68},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.71},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.81},
#   {'component_batch': ['B2B'], 'conf_score': 0.72},
#   {'component_batch': ['Coupa'], 'conf_score': 0.62},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.71},
#   {'component_batch': ['Coupa'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.58},
#   {'component_batch': ['B2B'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.62},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.68},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.53},
#   {'component_batch': ['Coupa'], 'conf_score': 0.72},
#   {'component_batch': ['Coupa'], 'conf_score': 0.73},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.67},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.69},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.89},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.63},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.74},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.77},
#   {'component_batch': ['uCash'], 'conf_score': 0.69},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.51},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.69},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.56},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.72},
#   {'component_batch': ['uSurv'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.53},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.69},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.55},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.85},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.57},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.77},
#   {'component_batch': ['Coupa'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.8},
#   {'component_batch': ['Coupa'], 'conf_score': 0.68},
#   {'component_batch': ['T2C'], 'conf_score': 0.51},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.76},
#   {'component_batch': ['Coupa'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.54},
#   {'component_batch': ['B2B'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.79},
#   {'component_batch': ['Coupa'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.6},
#   {'component_batch': ['Concur'], 'conf_score': 0.66},
#   {'component_batch': ['B2B'], 'conf_score': 0.72},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.77},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.78},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.53},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.76},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.76},
#   {'component_batch': ['Coupa'], 'conf_score': 0.63},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.85},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.72},
#   {'component_batch': ['Coupa'], 'conf_score': 0.8},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.6},
#   {'component_batch': ['Coupa'], 'conf_score': 0.78},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.92},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.74},
#   {'component_batch': ['Concur'], 'conf_score': 0.7},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.61},
#   {'component_batch': ['T2C'], 'conf_score': 0.56},
#   {'component_batch': ['Coupa'], 'conf_score': 0.81},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.95},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.72},
#   {'component_batch': ['uSurv'], 'conf_score': 0.55},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.81},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.65},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.63},
#   {'component_batch': ['Coupa'], 'conf_score': 0.81},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.6},
#   {'component_batch': ['B2B'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.68},
#   {'component_batch': ['B2B'], 'conf_score': 0.75},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.63},
#   {'component_batch': ['uCash'], 'conf_score': 0.77},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.88},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.58},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.67},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.63},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.85},
#   {'component_batch': ['B2B'], 'conf_score': 0.73},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.69},
#   {'component_batch': ['Coupa'], 'conf_score': 0.77},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.63},
#   {'component_batch': ['Coupa'], 'conf_score': 0.78},
#   {'component_batch': ['Coupa'], 'conf_score': 0.68},
#   {'component_batch': ['DBA'], 'conf_score': 0.67},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.81},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.75},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.66},
#   {'component_batch': ['B2B'], 'conf_score': 0.67},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.77},
#   {'component_batch': ['DBA'], 'conf_score': 0.5},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.7},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.93},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.58},
#   {'component_batch': ['Coupa'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.65},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.68},
#   {'component_batch': ['Coupa'], 'conf_score': 0.77},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.69},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.74},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.7},
#   {'component_batch': ['Coupa'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.7},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.81},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.72},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.87},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.71},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.7},
#   {'component_batch': ['Coupa'], 'conf_score': 0.75},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.69},
#   {'component_batch': ['uCash'], 'conf_score': 0.67},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.52},
#   {'component_batch': ['B2B'], 'conf_score': 0.69},
#   {'component_batch': ['B2B'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.56},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.59},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.78},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.67},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.67},
#   {'component_batch': ['B2B'], 'conf_score': 0.6},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.71},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.64},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.74},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.69},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.84},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.72},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.74},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.77},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.63},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.87},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.71},
#   {'component_batch': ['Coupa'], 'conf_score': 0.53},
#   {'component_batch': ['B2B'], 'conf_score': 0.68},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.78},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.72},
#   {'component_batch': ['Coupa'], 'conf_score': 0.79},
#   {'component_batch': ['Coupa'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.48},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.65},
#   {'component_batch': ['T2C'], 'conf_score': 0.59},
#   {'component_batch': ['Coupa'], 'conf_score': 0.55},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.59},
#   {'component_batch': ['B2B'], 'conf_score': 0.74},
#   {'component_batch': ['Oracle Receivable'], 'conf_score': 0.56},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.68},
#   {'component_batch': ['Coupa'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.54},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Apex Reports'], 'conf_score': 0.6},
#   {'component_batch': ['uAllocate'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Fixed Asset'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.56},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.83},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.51},
#   {'component_batch': ['T2C'], 'conf_score': 0.63},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.65},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.87},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.77},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.87},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.84},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.82},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.65},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.59},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.64},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.82},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.77},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.96},
#   {'component_batch': ['uCash'], 'conf_score': 0.84},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.51},
#   {'component_batch': ['Coupa'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.68},
#   {'component_batch': ['B2B'], 'conf_score': 0.88},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.53},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.5},
#   {'component_batch': ['B2B'], 'conf_score': 0.84},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.65},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.62},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.54},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.81},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.91},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.71},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.86},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.88},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.53},
#   {'component_batch': ['Coupa'], 'conf_score': 0.73},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.57},
#   {'component_batch': ['B2B'], 'conf_score': 0.69},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.69},
#   {'component_batch': ['B2B'], 'conf_score': 0.66},
#   {'component_batch': ['Coupa'], 'conf_score': 0.72},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.7},
#   {'component_batch': ['Coupa'], 'conf_score': 0.52},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.65},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.93},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.58},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.75},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.69},
#   {'component_batch': ['Coupa'], 'conf_score': 0.57},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.64},
#   {'component_batch': ['Coupa'], 'conf_score': 0.74},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.63},
#   {'component_batch': ['Coupa'], 'conf_score': 0.52},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.64},
#   {'component_batch': ['Coupa'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Apex Reports'], 'conf_score': 0.68},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.71},
#   {'component_batch': ['Coupa'], 'conf_score': 0.73},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.52},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.74},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.45},
#   {'component_batch': ['B2B'], 'conf_score': 0.59},
#   {'component_batch': ['Coupa'], 'conf_score': 0.69},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.71},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.85},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.58},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.68},
#   {'component_batch': ['B2B'], 'conf_score': 0.75},
#   {'component_batch': ['Coupa'], 'conf_score': 0.63},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.65},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.92},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.69},
#   {'component_batch': ['uCash'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.6},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.64},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.73},
#   {'component_batch': ['B2B'], 'conf_score': 0.55},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.73},
#   {'component_batch': ['uCash'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.44},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.47},
#   {'component_batch': ['B2B'], 'conf_score': 0.82},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.76},
#   {'component_batch': ['B2B'], 'conf_score': 0.69},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.71},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.64},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.8},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.55},
#   {'component_batch': ['Coupa'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.64},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.72},
#   {'component_batch': ['Coupa'], 'conf_score': 0.67},
#   {'component_batch': ['Coupa'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.7},
#   {'component_batch': ['B2B'], 'conf_score': 0.67},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.65},
#   {'component_batch': ['B2B'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.63},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.54},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.8},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.69},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.66},
#   {'component_batch': ['B2B'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.78},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.61},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.62},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.79},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.86},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.54},
#   {'component_batch': ['uCash'], 'conf_score': 0.85},
#   {'component_batch': ['Concur'], 'conf_score': 0.73},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.64},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.56},
#   {'component_batch': ['B2B'], 'conf_score': 0.82},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.76},
#   {'component_batch': ['Workday'], 'conf_score': 0.55},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.88},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.75},
#   {'component_batch': ['Coupa'], 'conf_score': 0.72},
#   {'component_batch': ['B2B'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.53},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.73},
#   {'component_batch': ['B2B'], 'conf_score': 0.65},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.74},
#   {'component_batch': ['Coupa'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.53},
#   {'component_batch': ['Coupa'], 'conf_score': 0.63},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['T2C'], 'conf_score': 0.65},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.8},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.54},
#   {'component_batch': ['Oracle Apex Reports'], 'conf_score': 0.75},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.75},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.63},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.72},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.68},
#   {'component_batch': ['B2B'], 'conf_score': 0.7},
#   {'component_batch': ['B2B'], 'conf_score': 0.77},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.59},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.81},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.75},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.68},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.76},
#   {'component_batch': ['B2B'], 'conf_score': 0.77},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.64},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.73},
#   {'component_batch': ['uSurv'], 'conf_score': 0.58},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.74},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.58},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.83},
#   {'component_batch': ['Workday'], 'conf_score': 0.54},
#   {'component_batch': ['Coupa'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.57},
#   {'component_batch': ['Coupa'], 'conf_score': 0.77},
#   {'component_batch': ['B2B'], 'conf_score': 0.8},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.85},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.54},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.67},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.71},
#   {'component_batch': ['B2B'], 'conf_score': 0.63},
#   {'component_batch': ['Coupa'], 'conf_score': 0.64},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['uCash'], 'conf_score': 0.79},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.79},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.73},
#   {'component_batch': ['B2B'], 'conf_score': 0.69},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.48},
#   {'component_batch': ['Coupa'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.64},
#   {'component_batch': ['B2B'], 'conf_score': 0.69},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.77},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.51},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.7},
#   {'component_batch': ['B2B'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.61},
#   {'component_batch': ['usupplier'], 'conf_score': 0.6},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.82},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.7},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.77},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.54},
#   {'component_batch': ['B2B'], 'conf_score': 0.72},
#   {'component_batch': ['B2B'], 'conf_score': 0.69},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.73},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.75},
#   {'component_batch': ['Oracle Receivable'], 'conf_score': 0.6},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.62},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.87},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.57},
#   {'component_batch': ['Coupa'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Receivable'], 'conf_score': 0.61},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.56},
#   {'component_batch': ['Coupa'], 'conf_score': 0.76},
#   {'component_batch': ['Coupa'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.58},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.49},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.84},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.88},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.64},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.54},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.67},
#   {'component_batch': ['Coupa'], 'conf_score': 0.61},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.78},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.77},
#   {'component_batch': ['DBA'], 'conf_score': 0.58},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.72},
#   {'component_batch': ['B2B'], 'conf_score': 0.73},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.91},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.49},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.86},
#   {'component_batch': ['uCash'], 'conf_score': 0.85},
#   {'component_batch': ['Coupa'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.58},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.5},
#   {'component_batch': ['Coupa'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.49},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.82},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.53},
#   {'component_batch': ['Coupa'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.69},
#   {'component_batch': ['Coupa'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.61},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.82},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.89},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.78},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.85},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.86},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.5},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.73},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.73},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.5},
#   {'component_batch': ['uCash'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.63},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.61},
#   {'component_batch': ['Coupa'], 'conf_score': 0.7},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.73},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.75},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.62},
#   {'component_batch': ['B2B'], 'conf_score': 0.72},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.85},
#   {'component_batch': ['Oracle Receivable'], 'conf_score': 0.57},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.55},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.54},
#   {'component_batch': ['Coupa'], 'conf_score': 0.81},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.78},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.77},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.85},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.79},
#   {'component_batch': ['Oracle Apex Reports'], 'conf_score': 0.68},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.71},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.52},
#   {'component_batch': ['Concur'], 'conf_score': 0.66},
#   {'component_batch': ['B2B'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Cash Management'], 'conf_score': 0.75},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.55},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.73},
#   {'component_batch': ['DBA'], 'conf_score': 0.56},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Coupa'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.54},
#   {'component_batch': ['Oracle Apex Reports'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Fixed Asset'], 'conf_score': 0.69},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.45},
#   {'component_batch': ['Coupa'], 'conf_score': 0.63},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.58},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.5},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.72},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.73},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.47},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.65},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.9},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.71},
#   {'component_batch': ['B2B'], 'conf_score': 0.69},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.6},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.71},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.69},
#   {'component_batch': ['Kyriba'], 'conf_score': 0.8},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.71},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.68},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.42},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.54},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.76},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.55},
#   {'component_batch': ['Coupa'], 'conf_score': 0.59},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.86},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.68},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.54},
#   {'component_batch': ['T2C'], 'conf_score': 0.57},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.53},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.61},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.71},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.65},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.73},
#   {'component_batch': ['Coupa'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Apex Reports'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.73},
#   {'component_batch': ['uCash'], 'conf_score': 0.86},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.85},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.65},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.62},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.64},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.77},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.75},
#   {'component_batch': ['Coupa'], 'conf_score': 0.5},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.76},
#   {'component_batch': ['Coupa'], 'conf_score': 0.6},
#   {'component_batch': ['uCash'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['usupplier'], 'conf_score': 0.57},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.7},
#   {'component_batch': ['uCash'], 'conf_score': 0.67},
#   {'component_batch': ['uAccrue'], 'conf_score': 0.71},
#   {'component_batch': ['B2B'], 'conf_score': 0.65},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.63},
#   {'component_batch': ['Coupa'], 'conf_score': 0.66},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.65},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.83},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.72},
#   {'component_batch': ['B2B'], 'conf_score': 0.83},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.8},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.66},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.86},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.64},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.76},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.69},
#   {'component_batch': ['Coupa'], 'conf_score': 0.69},
#   {'component_batch': ['Oracle Project Costing'], 'conf_score': 0.59},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.69},
#   {'component_batch': ['Coupa'], 'conf_score': 0.67},
#   {'component_batch': ['uCash'], 'conf_score': 0.86},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.76},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.82},
#   {'component_batch': ['Coupa'], 'conf_score': 0.54},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.66},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.71},
#   {'component_batch': ['Coupa'], 'conf_score': 0.77},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.62},
#   {'component_batch': ['DRM/DRG'], 'conf_score': 0.77},
#   {'component_batch': ['B2B'], 'conf_score': 0.62},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.74},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.73},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.71},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.78},
#   {'component_batch': ['Oracle Purchasing'], 'conf_score': 0.67},
#   {'component_batch': ['B2B'], 'conf_score': 0.74},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.83},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.9},
#   {'component_batch': ['B2B'], 'conf_score': 0.7},
#   {'component_batch': ['Coupa'], 'conf_score': 0.57},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.79},
#   {'component_batch': ['uCash'], 'conf_score': 0.42},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.63},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.67},
#   {'component_batch': ['Oracle Administration'], 'conf_score': 0.45},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.68},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.6},
#   {'component_batch': ['Oracle General Ledger'], 'conf_score': 0.66},
#   {'component_batch': ['Oracle Transport Management'], 'conf_score': 0.75},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.7},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.72},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.62},
#   {'component_batch': ['Oracle Payments'], 'conf_score': 0.74},
#   {'component_batch': ['Oracle Payables'], 'conf_score': 0.56},
#   {'component_batch': ['TrinTech'], 'conf_score': 0.87},
#   {'component_batch': ['Access Requests'], 'conf_score': 0.74},
#   {'component_batch': ['B2B'], 'conf_score': 0.72},
#   {'component_batch': ['AGIS Intercompany'], 'conf_score': 0.6},
#   {'component_batch': ['EPM/Hyperion'], 'conf_score': 0.8},
#   {'component_batch': ['uCash'], 'conf_score': 0.72},
#   {'component_batch': ['Coupa'], 'conf_score': 0.64},
#   ...]}

# %%
len(c['success'])
# Out:
# 5000
